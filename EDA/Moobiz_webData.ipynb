# %%
import pandas as pd

# %%
df_web = pd.read_excel('./data/webpage_real.xlsx')
df_a = pd.read_excel('./data/dep_jan.xlsx')

# %%
df = pd.merge(df_web, df_a, on='movieNm')
df
# Out:
#            movieNm  movieCd  \
# 0         보헤미안 랩소디   156464
# 1         보헤미안 랩소디   156464
# 2         보헤미안 랩소디   156464
# 3         보헤미안 랩소디   156464
# 4         보헤미안 랩소디   156464
# 5         보헤미안 랩소디   156464
# 6         보헤미안 랩소디   156464
# 7         보헤미안 랩소디   156464
# 8         보헤미안 랩소디   156464
# 9         보헤미안 랩소디   156464
# 10        보헤미안 랩소디   156464
# 11        보헤미안 랩소디   156464
# 12        보헤미안 랩소디   156464
# 13        보헤미안 랩소디   156464
# 14        보헤미안 랩소디   156464
# 15        보헤미안 랩소디   156464
# 16        보헤미안 랩소디   156464
# 17        보헤미안 랩소디   156464
# 18        보헤미안 랩소디   156464
# 19        보헤미안 랩소디   156464
# 20        보헤미안 랩소디   156464
# 21        보헤미안 랩소디   156464
# 22        보헤미안 랩소디   156464
# 23        보헤미안 랩소디   156464
# 24        보헤미안 랩소디   156464
# 25   스파이더맨: 뉴 유니버스   171725
# 26   스파이더맨: 뉴 유니버스   171725
# 27   스파이더맨: 뉴 유니버스   171725
# 28             그린치   150688
# 29             그린치   150688
# ..             ...      ...
# 203      그대 이름은 장미   142256
# ...

# %%
len(df.drop_duplicates('movieNm', keep='first'))
# Out:
# 22
