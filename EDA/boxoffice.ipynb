# %%
import json
import math
import requests
from urllib.request import urlopen
from urllib.parse import urlencode
import os
import pandas as pd
from datetime import datetime
from datetime import timedelta

# %%
class movie(object):

def __init__(self, url, api_key):
    api_key = 'a37309d4545a0c715c2171adbda24a74'
    self.api_key = api_key
    url =    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'
    self.url = url       
def get_movies(self): # 일일 박스오피스 자료 한번 가죠와보까
    target_dt = datetime.now() - timedelta(days = 1000) # 현재날자에서 -1한 날(일)_
    target_dt_str = target_dt.strftime('%Y%m%d') # 날짜를 문자열로 변환해라
    query_url = '{}?key={}&targetDt={}'.format(self.url, self.api_key, target_dt_str) # 영화진흥흥회의 응답 url이지요
    
    res = requests.get(query_url)
    text = res.text
    d = json.loads(text)
    
    for b in d['boxOfficeResult']['dailyBoxOfficeList']:
               print(b['rank'], b['rankIntern'], b['rankOldAndNew'],
                     b['movieNm'], b['movieCd'], b['audiCnt'], b['audiAcc'], 
                     b['scrCnt'], b['showCnt']  )
    return d
    
#     for b in
#     with urlopen(query_url) as fin:
#         return json.loads(fin.read().decode('utf-8'))

# def simplify(self, result): # 내가 가져오고 싶은거 가져올거다
#     return [
#         {
#             '순위' : entry.get('rank'), # 해당일자의 박오 순위다
#             '전일대비 순위의 증감' : entry.get('rankIntern'),
#             '랭킹 신규진입여부' : entry.get('rankOldAndNew'),
#             '영화명' : entry.get('movieNm'),
#             '영화코드' : entry.get('movieCd'),
#             '금일 관객수' : entry.get('audiCnt'),
#             '누적 관객수' : entry.get('audiAcc'),
#             '상영된 스크린 수' : entry.get('scrnCnt'),
#             '상영된 횟수' : entry.get('showCnt')
#         }
#         for entry in result.get('boxOfficeResult').get('dailyBoxOfficeList') # 응답된 경과 에서 일일 박스오피스 차트를 가져와보까
    
#     ]
# box = BoxOffice('a37309d4545a0c715c2171adbda24a74') # 내 Key
# movies = box.get_movies() # 일일 박오 정보 가져와
# print(box.simplify(movies)) # 정보 출력

# %%
import requests
import json

movieCd = 20170561

#url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd=20170561'
url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd='+str(movieCd)
res = requests.get(url)
text = res.text
#print(text)

d = json.loads(text)
#print(d)

print(d['movieInfoResult']['movieInfo']['movieCd'], d['movieInfoResult']['movieInfo']['showTm'], len(d['movieInfoResult']['movieInfo']['actors']), len(d['movieInfoResult']['movieInfo']['showTypes']))
# Out:
# 20170561 134 11 5

# %%
class Movie_detail(object):
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json'
    def __init__(self, api_key, movieCd):
        self.api_key = api_key
        self.movieCd = movieCd
#         self.movieCd = movieCd
        
    def get_movie_detail(self): # 일일 박스오피스 자료 한번 가죠와보까
        movieCd = '20070316'
        query_url = '{}?key={}&movieCd={}'.format(self.url, self.api_key, movieCd) # 영화진흥흥회의 응답 url이지요
        
        with urlopen(query_url) as fin:
            return json.loads(fin.read().decode('utf-8'))
        
    def specify(self, result): # 내가 가져오고 싶은거 가져올거다
        return [
            {
                '영화 코드' : entry.get('movieCd'), # 해당일자의 박오 순위다
                
                '영화명' : entry.get('movieNm'), 
                
                '영화 유형' : entry.get('typeNm'),
                '감독' : entry.get('directors'),
                '감독명' : entry.get('peopleNm'),
                '배우' : entry.get('actors'),
                '배우명' : entry.get('peopleNm'),
                '관람등급' : entry.get('watchGradeNm'),
                '상영된 횟수' : entry.get('showCnt')
            }
            for entry in result.get('movieInfoResult').get('movieInfo)'# 응답된 경과 에서 일일 박스오피스 차트를 가져와보까
            
box_detail = Movie_detail('a37309d4545a0c715c2171adbda24a74') # 내 Key
Movies_detail = box_detail.get_movie_detail() # 일일 박오 정보 가져와
print(box_detail.specify(Movie_detail)) # 정보 출력
# Out:
#   File "<ipython-input-4-13671e78b6ab>", line 32
#     box_detail = Movie_detail('a37309d4545a0c715c2171adbda24a74') # 내 Key
#              ^
# SyntaxError: invalid syntax

# %%
import requests
import json
key = 'a37309d4545a0c715c2171adbda24a74'
openDt = '2017'
url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={}&openDt={}'.format(key, openDt)
res = requests.get(url)
text = res.text
#print(text)

d = json.loads(text) 
#print(d)

for b in d['boxOfficeResult']['dailyBoxOfficeList']:
    print(b['rank'], b['rankOldAndNew'], b['movieCd'], b['movieNm'], b['salesAmt'], b['audiCnt'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-90ec8fc7588d> in <module>()
#      11 #print(d)
#      12
# ---> 13 for b in d['boxOfficeResult']['dailyBoxOfficeList']:
#      14     print(b['rank'], b['rankOldAndNew'], b['movieCd'], b['movieNm'], b['salesAmt'], b['audiCnt'])
#
# KeyError: 'boxOfficeResult'

# %%
import requests
import json
import time
import datetime

my_datetime = datetime.datetime(2017, 12, 10)
for i in range(30):
    new_datetime = my_datetime + datetime.timedelta(days=i)
    targetDt = new_datetime.strftime('%Y%m%d') #20180220
    #print(i)
    #print(targetDt)
    #url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=130ad25d8935a673ca47beb43436aa85&targetDt=20180220'
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={}&targetDt={}'.format(key, targetDt)
    res = requests.get(url)
    text = res.text
    #print(text)

    d = json.loads(text) 
    #print(d)

    for b in d['boxOfficeResult']['dailyBoxOfficeList']:
        print(targetDt, b['rank'], b['rankOldAndNew'], b['movieCd'], b['movieNm'], b['salesAmt'], b['audiCnt'])
    time.sleep(1)

# %%
import requests
import json

movieCd = 20170561

#url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd=20170561'
url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd=20170561'
res = requests.get(url)
text = res.text
#print(text)

d = json.loads(text) 
#print(d)

print(d['movieInfoResult']['movieInfo']['movieCd'], d['movieInfoResult']['movieInfo']['showTm'], len(d['movieInfoResult']['movieInfo']['actors']), len(d['movieInfoResult']['movieInfo']['showTypes']))`

# %%
import requests
import json
import time

movieCds = set()
my_datetime = datetime.datetime(2018, 2, 20)
for i in range(30):
    new_datetime = my_datetime + datetime.timedelta(days=i)
    targetDt = new_datetime.strftime('%Y%m%d') #20180220
    #print(i)
    #print(targetDt)
    #url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=130ad25d8935a673ca47beb43436aa85&targetDt=20180220'
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=a37309d4545a0c715c2171adbda24a74&targetDt=20180220'
    res = requests.get(url)
    text = res.text
    #print(text)

    d = json.loads(text) 
    #print(d)

    for b in d['boxOfficeResult']['movieinfo']:
        print(targetDt, b['rank'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'])
        movieCds.add(b['여기에 코드를 작성하세요'])
    time.sleep(1)

print('#'*10)

for movieCd in movieCds:
    #url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd=20170561'
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=여기에 코드를 작성하세요&movieCd='+여기에 코드를 작성하세요
    res = requests.get(url)
    text = res.text
    #print(text)
    d = json.loads(text)
    #print(d)

    print(d['movieInfoResult']['movieInfo']['movieCd'], d['movieInfoResult']['movieInfo']['여기에 코드를 작성하세요'], len(d['movieInfoResult']['movieInfo']['actors']), len(d['movieInfoResult']['movieInfo']['여기에 코드를 작성하세요s']))

# %%
import requests
import json
import pandas as pd
from pandas import DataFrame, Series
import time

l = []
movieCds = set()
my_datetime = datetime.datetime(2018, 2, 20)
for i in range(30):
    new_datetime = my_datetime + datetime.timedelta(days=i)
    targetDt = new_datetime.strftime('%Y%m%d') #20180220
    #print(i)
    #print(targetDt)
    #url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=130ad25d8935a673ca47beb43436aa85&targetDt=20180220'
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=여기에 코드를 작성하세요&targetDt=20180220'
    res = requests.get(url)
    text = res.text
    #print(text)

    d = json.loads(text)
    #print(d)

    for b in d['boxOfficeResult']['여기에 코드를 작성하세요']:
        #print(targetDt, b['rank'], b['rankOldAndNew'], b['movieCd'], b['movieNm'], b['salesAmt'], b['audiCnt'])
        l.append([targetDt, b['rank'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요']])
        movieCds.add(b['여기에 코드를 작성하세요'])
    time.sleep(1)

columns = ['targetDt','rank','rankOldAndNew','movieCd','movieNm','salesAmt','audiCnt']
df = DataFrame(l, columns=columns)
df.to_csv('./data/kobis_boxoffice.csv',index=False,encoding='cp949')
print('saved')

##########################

l = []
for movieCd in movieCds:
    #url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=130ad25d8935a673ca47beb43436aa85&movieCd=20170561'
    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=여기에 코드를 작성하세요&movieCd=20170561'
    res = requests.get(url)
    text = res.text
    #print(text)

    d = json.loads(text)
    #print(d)

    #print(d['movieInfoResult']['movieInfo']['movieCd'], d['movieInfoResult']['movieInfo']['showTm'], len(d['movieInfoResult']['movieInfo']['actors']), len(d['movieInfoResult']['movieInfo']['showTypes']))
    l.append([d['movieInfoResult']['movieInfo']['movieCd'], d['movieInfoResult']['movieInfo']['여기에 코드를 작성하세요'], len(d['movieInfoResult']['movieInfo']['actors']), len(d['movieInfoResult']['movieInfo']['여기에 코드를 작성하세요'])])

columns=['movieCd','showTm','actors_count','showTypes_count']
df = DataFrame(l, columns=columns)
df.to_csv('./data/kobis_movie.csv',index=False,encoding='cp949')
print('saved')
