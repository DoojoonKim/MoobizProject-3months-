# %%
import json
import math
import requests

from pandas import datetime, Series
from urllib.request import urlopen
from tkinter import *
from urllib.parse import urlencode
import os
import pandas as pd
# from datetime import datetime
# from datetime import timedelta
import datetime
import time

# %%
df_1 = pd.read_excel('./data/영화이름과 개봉일.xlsx')

# %%
movie_list = []
for i, d in enumerate(df_1['openDt']):
    d = d.replace('-', '')
    movie_list.append(d)

movie_list

# %% [markdown]
# # 개봉일에 따른 일별 박스오피스 데이터들 추출

# %%
# def asdf::::
# movie_title_openDt = {
    
    
# #2013년
# '7번방의 선물': '20130123',
# '관상': '20130911',
# '아이언맨 3': '20130425',
# '설국열차': '20130801',
# '베를린': '20130130',
# '은밀하게 위대하게': '20130605',
# '변호인': '20131218',
# '숨바꼭질': '20130814',
# '더 테러 라이브': '20130731',
# '감시자들': '20130703',
# '월드 워 Z': '20130620',
# '신세계': '20130221',
# '박수건달': '20130109',
# '스파이': '20130905',
# '그래비티': '20131017',
# '타워': '20121225',
# '감기': '20130814',
# '토르: 다크 월드': '20131030',
# '레드: 더 레전드': '20130718',
# '친구 2': '20131114',
# '어바웃 타임': '20131205',
# '나우 유 씨 미 : 마술사기단': '20130822',
# '레미제라블': '20121219',
# '소원': '20131002',
# '퍼시픽 림': '20130711',
# '화이: 괴물을 삼킨 아이': '20131009',
# '컨저링': '20130917',
# '맨 오브 스틸': '20130613',
# '용의자': '20131224',
# '호빗: 스마우그의 폐허': '20131212',
# '몽타주': '20130516',
# '연애의 온도': '20130321',
# '지.아이.조 2': '20130328',
# '분노의 질주: 더 맥시멈': '20130522',
# '공범': '20131024',
# '집으로 가는 길': '20131211',
# '전설의 주먹': '20130410',
# '파파로티': '20130314',
# '스타트렉 다크니스': '20130530',
# '오블리비언': '20130411',
# '위대한 개츠비': '20130516',
# '다이하드: 굿 데이 투 다이': '20130206',
# '런닝맨': '20130404',
# '미스터 고': '20130717',
# '결혼전야': '20131121',
# '엘리시움': '20130829',
# '깡철이': '20131002',
# '더 웹툰: 예고살인': '20130627',
# '웜 바디스': '20130314',
# '고령화 가족': '20130509',
# '헝거게임: 캣칭 파이어': '20131121',
# '더 울버린': '20130725',
# '동창생': '20131106',
# '전국노래자랑': '20130501',
# '잭 더 자이언트 킬러': '20130228',
# '열한시': '20131128',
# '남쪽으로 튀어': '20130206',
# '잭 리처': '20130117',
# '반창꼬': '20121219',
# '더 파이브': '20131114',
# '더 임파서블': '20130117',
# '인시디어스: 두번째 집': '20131205',
# '섀도우 헌터스: 뼈의 도시': '20130912',
# '화이트 하우스 다운': '20130627',
# '애프터 어스': '20130530',
# '사이코메트리': '20130307',
# '퍼시 잭슨과 괴물의 바다': '20130912',
# '남자사용설명서': '20130214',
# '다이노소어 어드벤처 3D': '20131219',
# '무서운 이야기 2': '20130605',
# '캐치미': '20131218',
# '노브레싱': '20131030',
# '클라우드 아틀라스': '20130109',
# '창수': '20131128',
# '론 레인저': '20130704',
# '스토커': '20130228',
# '오즈 그레이트 앤드 파워풀': '20130307',
# '미나문방구': '20130516',
# '차이니즈 조디악': '20130227',
# '이스케이프 플랜': '20131205',
# '롤러코스터': '20131017',
# '헨젤과 그레텔: 마녀 사냥꾼 3D': '20130214',
# '장고:분노의 추적자': '20130321',
# '밤의 여왕': '20131017',
# '캡틴 필립스': '20131023',
# '잡스': '20130829',
# '분노의 윤리학': '20130221',
# '송 포 유': '20130418',
# '호빗: 뜻밖의 여정': '20121213',
# '비포 미드나잇': '20130522',
# '응징자': '20131030',
# '프리즈너스': '20131002',
# '마이 리틀 히어로': '20130109',
# '백악관 최후의 날': '20130605',
# '해양경찰 마르코': '20130214',
# '톱스타': '20131024',
# '노리개': '20130418',
# '엔더스 게임': '20131231',
# '히든 카드': '20130926',
    
#  #2014년
#     '명량': '20140730',
# '인터스텔라': '20141106',
# '수상한 그녀': '20140122',
# '해적: 바다로 간 산적': '20140806',
# '변호인': '20131218',
# '국제시장': '20141217',
# '트랜스포머: 사라진 시대': '20140625',
# '군도: 민란의 시대': '20140723',
# '엣지 오브 투모로우': '20140604',
# '엑스맨: 데이즈 오브 퓨처 패스트': '20140522',
# '어메이징 스파이더맨 2': '20140423',
# '혹성탈출: 반격의 서막': '20140710',
# '타짜-신의 손': '20140903',
# '캡틴 아메리카: 윈터 솔져': '20140326',
# '역린': '20140430',
# '신의 한 수': '20140703',
# '끝까지 간다': '20140529',
# '표적': '20140430',
# '메이즈 러너': '20140918',
# '호빗: 다섯 군대 전투': '20141217',
# '나의 사랑 나의 신부': '20141008',
# '논스톱': '20140227',
# '인투 더 스톰': '20140828',
# '노아': '20140320',
# '남자가 사랑할 때': '20140122',
# '루시': '20140903',
# '용의자': '20131224',
# '기술자들': '20141224',
# '나를 찾아줘': '20141023',
# '제보자': '20141002',
# '피끓는 청춘': '20140122',
# '우아한 거짓말': '20140313',
# '두근두근 내 인생': '20140903',
# '300: 제국의 부활': '20140306',
# '엑소더스: 신들과 왕들': '20141203',
# '해무(海霧)': '20140813',
# '인간중독': '20140514',
# '말레피센트': '20140529',
# '폼페이: 최후의 날': '20140220',
# '퓨리': '20141120',
# '드라큘라: 전설의 시작': '20141008',
# '가디언즈 오브 갤럭시': '20140731',
# '찌라시: 위험한 소문': '20140220',
# '빅매치': '20141127',
# '슬로우 비디오': '20141002',
# '방황하는 칼날': '20140410',
# '로보캅': '20140213',
# '우리는 형제입니다': '20141023',
# '애나벨': '20141002',
# '헝거게임: 모킹제이': '20141120',
# '월터의 상상은 현실이 된다': '20131231',
# '카트': '20141113',
# '관능의 법칙': '20140213',
# '안녕, 헤이즐': '20140813',
# '고질라': '20140515',
# '트랜센던스': '20140514',
# '상의원': '20141224',
# '플랜맨': '20140109',
# '우는 남자': '20140604',
# '황제를 위하여': '20140611',
# '패션왕': '20141106',
# '더 울프 오브 월스트리트': '20140109',
# '스텝 업: 올 인': '20140903',
# '어바웃 타임': '20131205',
# '몬스터': '20140313',
# '노예 12년': '20140227',
# '또 하나의 약속': '20140206',
# '엔더스 게임': '20131231',
# '소녀괴담': '20140702',
# '조선미녀삼총사': '20140129',
# '마담 뺑덕': '20141002',
# '다이버전트': '20140416',
# '주온 : 끝의 시작': '20140716',
# '좋은 친구들': '20140710',
# '닌자터틀': '20140828',
# '나의 독재자': '20141030',
# '하이힐': '20140603',
# '선 오브 갓': '20140410',
# '잭 라이언 : 코드네임 쉐도우': '20140116',
# '숲속으로': '20141224',
# '레드카펫': '20141023',
# '미녀와 야수': '20140618',
# '프랑켄슈타인: 불멸의 영웅': '20140206',
# '러브, 로지': '20141210',
# '오큘러스': '20140529',
# '사랑에 대한 모든 것': '20141210',
# '노벰버 맨': '20141016',
# '툼스톤': '20140918',
# '쓰리데이즈 투 킬': '20140403',
# '헤라클레스 : 레전드 비긴즈': '20140410',
# '극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': '20141002',
# '덕수리 5형제': '20141204',
# '덤 앤 더머 투': '20141127',
# '컬러풀 웨딩즈': '20141016',
# '론 서바이버 ': '20140402',
# '아빠를 빌려드립니다': '20141120',
# '라스트베가스': '20140508',
# '호빗: 스마우그의 폐허': '20131212',
# '폴리스 스토리 2014': '20140129',
# '익스펜더블 3': '20140820',
    
# #2015년
#     '베테랑': '20150805',
# '암살': '20150722',
# '어벤져스: 에이지 오브 울트론': '20150423',
# '국제시장': '20141217',
# '내부자들': '20151119',
# '사도': '20150916',
# '미션 임파서블: 로그네이션': '20150730',
# '킹스맨 : 시크릿 에이전트': '20150211',
# '연평해전': '20150624',
# '쥬라기 월드': '20150611',
# '검은 사제들': '20151105',
# '히말라야': '20151216',
# '마션': '20151008',
# '조선명탐정 : 사라진 놉의 딸': '20150211',
# '매드 맥스: 분노의 도로': '20150514',
# '인턴': '20150924',
# '분노의 질주: 더 세븐': '20150401',
# '터미네이터 제니시스': '20150702',
# '스물': '20150325',
# '극비수사': '20150618',
# '앤트맨': '20150903',
# '스타워즈: 깨어난 포스': '20151217',
# '메이즈 러너: 스코치 트라이얼': '20150916',
# '탐정 : 더 비기닝': '20150924',
# '스파이': '20150521',
# '악의 연대기': '20150514',
# '강남 1970': '20150121',
# '뷰티 인사이드': '20150820',
# '오늘의 연애': '20150114',
# '테이큰 3': '20150101',
# '007 스펙터': '20151111',
# '이미테이션 게임': '20150217',
# '샌 안드레아스': '20150603',
# '쎄시봉': '20150205',
# '더 폰': '20151022',
# '대호': '20151216',
# '차이나타운': '20150429',
# '장수상회': '20150409',
# '성난 변호사': '20151008',
# '간신': '20150521',
# '박물관이 살아있다 : 비밀의 무덤': '20150114',
# '그놈이다': '20151028',
# '미쓰 와이프': '20150813',
# '허삼관': '20150114',
# '살인의뢰': '20150312',
# '손님': '20150709',
# '인시디어스 3': '20150709',
# '하트 오브 더 씨': '20151203',
# '헝거게임: 더 파이널': '20151118',
# '기술자들': '20141224',
# '신데렐라': '20150319',
# '픽셀': '20150716',
# '열정같은소리하고있네': '20151125',
# '특종: 량첸살인기': '20151022',
# '서부전선': '20150924',
# '채피': '20150312',
# '헬머니': '20150305',
# '위험한 상견례 2': '20150429',
# '순수의 시대': '20150305',
# '협녀, 칼의 기억': '20150813',
# '오피스': '20150903',
# '무뢰한': '20150527',
# '판타스틱 4': '20150820',
# '내 심장을 쏴라': '20150128',
# '소수의견': '20150624',
# '그레이의 50가지 그림자': '20150226',
# '경성학교: 사라진 소녀들': '20150618',
# '치외법권': '20150827',
# '아메리칸 스나이퍼': '20150114',
# '에베레스트': '20150924',
# '호빗: 다섯 군대 전투': '20141217',
# '극적인 하룻밤': '20151203',
# '도리화가': '20151125',
# '주피터 어센딩': '20150205',
# '패딩턴': '20150107',
# '런 올 나이트': '20150319',
# '인서전트': '20150325',
# '백 투 더 비기닝': '20150226',
# '투모로우랜드': '20150527',
# '스파이 브릿지': '20151105',
# '함정': '20150910',
# '언브로큰': '20150107',
# '하늘을 걷는 남자': '20151028',
# '조선마술사': '20151230',
# '언프렌디드: 친구삭제': '20150507',
# '연애의 맛': '20150507',
# '버드맨': '20150305',
# '기생수 파트1': '20150226',
# '팬': '20151008',
# '더 셰프': '20151105',
# '레전드': '20151210',
# '19곰 테드 2': '20150625',
# '인터스텔라': '20141106',
# '아메리칸 울트라': '20150827',
# '트랜스포터: 리퓰드': '20151015',
# '내부자들: 디 오리지널': '20151231',
# '워킹걸': '20150107',
# '은밀한 유혹': '20150604',
# '워터 디바이너': '20150128',
# '나의 절친 악당들': '20150625',
    
#     #2016년
#     '부산행': '20160720',
# '검사외전': '20160203',
# '캡틴 아메리카: 시빌 워': '20160427',
# '밀정': '20160907',
# '터널': '20160810',
# '인천상륙작전': '20160727',
# '럭키': '20161013',
# '곡성': '20160512',
# '덕혜옹주': '20160803',
# '닥터 스트레인지': '20161026',
# '마스터': '20161221',
# '신비한 동물사전': '20161116',
# '판도라': '20161207',
# '아가씨': '20160601',
# '귀향': '20160224',
# '데드풀': '20160217',
# '나우 유 씨 미 2': '20160713',
# '형': '20161123',
# '엑스맨: 아포칼립스': '20160525',
# '미스 페레그린과 이상한 아이들의 집': '20160928',
# '히말라야': '20151216',
# '제이슨 본': '20160727',
# '아수라': '20160928',
# '정글북': '20160609',
# '라라랜드': '20161207',
# '배트맨 대 슈퍼맨: 저스티스의 시작': '20160324',
# '굿바이 싱글': '20160629',
# '봉이 김선달': '20160706',
# '레버넌트: 죽음에서 돌아온 자': '20160114',
# '컨저링 2': '20160609',
# '내부자들: 디 오리지널': '20151231',
# '수어사이드 스쿼드': '20160803',
# '인디펜던스 데이 : 리써전스': '20160622',
# '탐정 홍길동: 사라진 마을': '20160504',
# '벤허': '20160914',
# '셜록: 유령신부': '20160102',
# '특별수사: 사형수의 편지': '20160616',
# '시간이탈자': '20160413',
# '동주': '20160217',
# '워크래프트: 전쟁의 서막': '20160609',
# '스타트렉 비욘드': '20160817',
# '미씽: 사라진 여자': '20161130',
# '당신, 거기 있어줄래요': '20161214',
# '라이트 아웃': '20160824',
# '오빠생각': '20160121',
# '날, 보러와요': '20160407',
# '맨 인 더 다크': '20161005',
# '고산자, 대동여지도': '20160907',
# '미 비포 유': '20160601',
# '매그니피센트 7': '20160914',
# '갓 오브 이집트': '20160303',
# '레전드 오브 타잔': '20160629',
# '좋아해줘': '20160217',
# '브리짓 존스의 베이비': '20160928',
# '스플릿': '20161109',
# '런던 해즈 폴른': '20160310',
# '국가대표 2': '20160810',
# '인페르노': '20161019',
# '그날의 분위기': '20160114',
# '사냥': '20160629',
# '널 기다리며': '20160310',
# '설리: 허드슨강의 기적': '20160928',
# '잭 리처: 네버 고 백': '20161130',
# '로그 원: 스타워즈 스토리': '20161228',
# '메카닉: 리크루트': '20160831',
# '고스트버스터즈': '20160825',
# '거울나라의 앨리스': '20160907',
# '가려진 시간': '20161116',
# '해어화': '20160413',
# '계춘할망': '20160519',
# '로봇, 소리': '20160127',
# '스타워즈: 깨어난 포스': '20151217',
# '빅쇼트': '20160121',
# '헌츠맨: 윈터스 워': '20160413',
# '나를 잊지 말아요': '20160107',
# '조선마술사': '20151230',
# '언더 워터': '20160713',
# '클로버필드 10번지': '20160407',
# '위자: 저주의 시작': '20161109',
# '위대한 소원': '20160421',
# '스포트라이트': '20160224',
# '구스범스': '20160114',
# '포인트 브레이크': '20160107',
# '혼숨': '20161026',
# '비밀은 없다': '20160623',
# '닌자터틀 : 어둠의 히어로': '20160616',
# '순정': '20160224',
# '독수리 에디': '20160407',
# '남과 여': '20160225',
# '대호': '20151216',
# '부활': '20160317',
# '조이': '20160310',
# '대배우': '20160330',
# '미스컨덕트': '20160330',
# '13시간': '20160303',
# '제 5침공': '20160225',
# '마이 리틀 자이언트': '20160810',
# '피터와 드래곤': '20160928',
# '다이버전트 시리즈: 얼리전트': '20160512',
# '바스티유 데이': '20161013',
# #2017년
#     '택시운전사': '20170802',
# '신과함께-죄와 벌': '20171220',
# '공조': '20170118',
# '스파이더맨: 홈 커밍': '20170705',
# '범죄도시': '20171003',
# '군함도': '20170726',
# '청년경찰': '20170809',
# '더 킹': '20170118',
# '미녀와 야수': '20170316',
# '킹스맨: 골든 서클': '20170927',
# '토르: 라그나로크': '20171025',
# '꾼': '20171122',
# '강철비': '20171214',
# '남한산성': '20171003',
# '미이라': '20170606',
# '분노의 질주: 더 익스트림': '20170412',
# '아이 캔 스피크': '20170921',
# '캐리비안의 해적: 죽은 자는 말이 없다': '20170524',
# '프리즌': '20170323',
# '덩케르크': '20170720',
# '가디언즈 오브 갤럭시 VOL. 2': '20170503',
# '살인자의 기억법': '20170906',
# '트랜스포머: 최후의 기사': '20170621',
# '보안관': '20170503',
# '조작된 도시': '20170209',
# '재심': '20170215',
# '박열': '20170628',
# '마스터': '20161221',
# '원더 우먼': '20170531',
# '겟 아웃': '20170517',
# '로건': '20170301',
# '혹성탈출: 종의 전쟁': '20170815',
# '1987': '20171227',
# '애나벨 : 인형의 주인': '20170810',
# '노무현입니다': '20170525',
# '저스티스 리그': '20171115',
# '킬러의 보디가드': '20170830',
# '콩: 스컬 아일랜드': '20170308',
# '23 아이덴티티': '20170222',
# '임금님의 사건수첩': '20170426',
# '부라더': '20171102',
# '기억의 밤': '20171129',
# '해피 데스데이': '20171108',
# '브이아이피': '20170823',
# '특별시민': '20170426',
# '에이리언: 커버넌트': '20170509',
# '장산범': '20170817',
# '악녀': '20170608',
# '해빙': '20170301',
# '라라랜드': '20161207',
# '하루': '20170615',
# '지오스톰': '20171019',
# '스타워즈: 라스트 제다이': '20171214',
# '불한당: 나쁜 놈들의 세상': '20170517',
# '그것': '20170906',
# '오리엔트 특급 살인': '20171129',
# '대립군': '20170531',
# '베이비 드라이버': '20170914',
# '위대한 쇼맨': '20171220',
# '레지던트 이블: 파멸의 날': '20170125',
# '공각기동대 : 고스트 인 더 쉘': '20170329',
# '패신저스': '20170104',
# '아빠는 딸': '20170412',
# '컨택트': '20170202',
# '47 미터': '20170719',
# '얼라이드': '20170111',
# '발레리안: 천 개 행성의 도시': '20170830',
# '그레이트 월': '20170215',
# '침묵': '20171102',
# '트리플 엑스 리턴즈': '20170208',
# '리얼': '20170628',
# '라이프': '20170405',
# '히든 피겨스': '20170323',
# '반드시 잡는다': '20171129',
# '원라인': '20170329',
# '로그 원: 스타워즈 스토리': '20161228',
# '킹 아서: 제왕의 검': '20170517',
# '아메리칸 메이드': '20170914',
# '보통사람': '20170323',
# '대장 김창수': '20171019',
# '어쌔신 크리드': '20170111',
# '플립': '20170712',
# '석조저택 살인사건': '20170509',
# '싱글라이더': '20170222',
# '7호실': '20171115',
# '사랑하기 때문에': '20170104',
# '희생부활자': '20171012',
# '옥자': '20170629',
# '블레이드 러너 2049': '20171012',
# '존 윅 - 리로드': '20170222',
# '판도라': '20161207',
# '미옥': '20171109',
# '어느날': '20170405',
# '어쌔신: 더 비기닝': '20171207',
# '50가지 그림자: 심연': '20170209',
# '핵소 고지': '20170222',
# '채비': '20171109',
# '더 큐어': '20170215',
# '아토믹 블론드': '20170830',
# '비정규직 특수요원': '20170316'}

# %%
# movie_list = []
# for idx, b in enumerate(movie_title_openDt.values()):
#     movie_list.append(b)

# %%
# movie_list.sort()

# %%
# movie_list

# %%
len(list)
# Out:
# 836

# %%
def get_movie_data(movie_list):
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"
    params = {"key":"ca3f4432da66e0556de8179d18762a19", "targetDt":movie_list}
    r = requests.get(url, params=params)
    return r.json()

# %%
def make_movie_df(movie_list):
    movie_df = pd.DataFrame(columns = ["movieNm",  "openDt", "rank", "scrnCnt", 
                                       "salesAmt", 'salesShare', 'audiCnt','showCnt', 'repGenreNm'])
    for i in movie_list:
        try:
            for data in get_movie_data(i)['boxOfficeResult']['dailyBoxOfficeList']:
                
                movie_df.loc[len(movie_df)] = [
                    data["movieNm"],
                    data["openDt"],
                    data["rank"],
                    data["scrnCnt"],
                    data['salesAmt'],
                    data['salesShare'],
                    data['audiCnt'],
                    data['showCnt'], 
                    data['repGenreNm']
                    
                

                 
                ]
        except:
            i
    return movie_df

# %%
a = make_movie_df(movie_list)

# %%
a.openDt.describe()

# %%
a

# %%
b= a.drop_duplicates(subset='movieNm', keep='last')

# %%
b.index = pd.RangeIndex(len(b.index))
b

# %%
b.to_excel('마지막 개봉일 스크린 수(2013-2017).xlsx', encoding='utf-8')

# %% [markdown]
# # 배우 필모

# %%
actor_list = ['김윤석,하정우', '아만다 사이프리드,메릴 스트립', '차태현,박보영', '설경구,정재영',
       '로버트 다우니 주니어,테렌스 하워드', '해리슨 포드,샤이아 라보프', '브렌든 프레이저,마리아 벨로',
       '크리스찬 베일,마이클 케인', '문소리,김정은', '정재영,한은정', '제임스 맥어보이,안젤리나 졸리',
       '윌 스미스,샤를리즈 테론', '리암 니슨,매기 그레이스', '김민선,김영호', '샤이아 라보프,미셸 모나한',
       '다니엘 크레이그,올가 큐리렌코', '한석규,차승원', '손예진,김주혁', '수애,정진영',
       '레이첼 빌슨,헤이든 크리스텐슨', '김명민,손예진', '양조위,금성무', '변희봉,손현주', '소지섭,강지환',
       '키아누 리브스,제니퍼 코넬리', '크리스틴 스튜어트,로버트 패틴슨', '제리 사인펠드,르네 젤위거', '이연걸,성룡',
       '주지훈,김재욱', '스티븐 스트레이트,카밀라 벨', '김하늘,윤계상', '사라 제시카 파커,킴 캐트럴',
       '선자 손,윌 켐프', '유덕화,매기 큐', '차태현,하지원', '휴 잭맨,니콜 키드먼', '천호진,조현재',
       '차인표,신명철', '짐 캐리,주이 데샤넬', '정지훈,매튜 폭스', '이새별,박해일', '유지태,이연희',
       '하정우,이정민', '조니 뎁,헬레나 본햄 카터', '제라드 버틀러', '카메론 디아즈,애쉬튼 커처',
       '나탈리 포트만,스칼렛 요한슨', '프레디 하이모어,사라 볼거', '김수로,이한위', '줄리안 무어,마크 러팔로',
       '다니엘 크레이그,니콜 키드먼', '곽선영,조승우', '레오나르도 디카프리오,러셀 크로우', '이미숙,김민희',
       '리지 캐플란,오데뜨 유스트만', '제이슨 스타뎀,세프론 버로우스', '홍희자,황정민', '유해진,진구',
       '니콜라스 케이지,존 보이트', '공효진,이종혁', '로리 홀든,토마스 제인', '조인성,주진모', '김선아,박진희',
       '장근석,문메이슨', '에이미 아담스,패트릭 뎀시', '손태영,장근석', '전도연,하정우', '이연걸,유덕화',
       '쿠도 유키,마츠야마 켄이치', '마크 웰버그,주이 데샤넬', '힐러리 스웽크,제라드 버틀러', '주성치,서교',
       '임창정,송지효', '브래들리 쿠퍼,레슬리 빕', '스티븐 파스퀄,레이코 아일리스워스', '이정재,김석훈',
       '잭 니콜슨,모건 프리먼', '키아누 리브스,포레스트 휘테커', '프레디 하이모어,조나단 리스 마이어스',
       '봉태규,김영애', '신현준,허준호', '안성기,이창민', '밀라 쿠니스,마크 웰버그',
       '키이라 나이틀리,랄프 파인즈', '나문희,김선아', '스캇 스피드맨,리브 타일러', '데이비드 듀코브니',
       '캐서린 헤이글,제임스 마스던', '가엘 가르시아 베르날,윌리엄 허트', '찰톤 헤스톤,잭 호킨스',
       '다니엘 크레이그,제이미 벨', '니시지마 히데토시,카타오카 레이코', '무로이 시게루,코바야시 넨지',
       '최원균,이삼순', '제이슨 스타뎀,나탈리아 루다코바', '설경구,하지원', '하정우,성동일',
       '샤이아 라보프,메간 폭스', '샘 워싱턴,조 샐다나', '크리스찬 베일,샘 워싱턴', '김하늘,강지환',
       '김윤석,정경호', '다니엘 래드클리프,엠마 왓슨', '금성무,양조위', '채닝 테이텀,버튼 페레즈',
       '한동학,장동건', '강동원,임수정', '송강호,김옥빈', '하지원,김명민', '벤 스틸러,에이미 아담스',
       '로버트 패틴슨,크리스틴 스튜어트', '톰 행크스,이완 맥그리거', '김성태,최강희', '송요셉,황정민',
       '톰 크루즈,빌 나이히', '엄태웅,정유미', '브래드 피트,케이트 블란쳇', '최경원,조승우', '정준호,최경원',
       '박용하,박희순', '정지훈,나오미 해리스', '임창정,박예진', '휴 잭맨,리브 슈라이버', '이범수,조안',
       '김래원,엄정화', '로버트 다우니 주니어,주드 로', '데브 파텔,프리다 핀토', '크리스 파인,재커리 퀸토',
       '니콜라스 케이지,로즈 번', '한석규,손예진', '제니퍼 코넬리,드류 베리모어', '샬토 코플리,제이슨 코프',
       '김강우,조재현', '제라드 버틀러,제이미 폭스', '브루스 윌리스,라다 미첼', '에릭 바나,레이첼 맥아덤즈',
       '정재영,구교환', '크리스 에반스,다코타 패닝', '권상우,이보영', '빈 디젤,폴 워커', '오연서,장경아',
       '케이 파나베이커,애셔 북', '엄태웅,박용우', '서민균,이범수', '제프리 딘 모건,빌리 크루덥',
       '브렌든 프레이저,시에나 길로리', '정진영,장근석', '안젤리나 졸리,존 말코비치', '고현정,김민희',
       '시릴 라파엘리,데이빗 벨', '베라 파미가,이사벨 퍼만', '조니 뎁,크리스찬 베일', '랄프 파인즈,케이트 윈슬렛',
       '김강우,황정민', '박해일,신민아', '저스틴 채트윈,주윤발', '조니 뎁,히스 레저', '윤계상,조재현',
       '다코타 블루 리차드,이안 그루퍼드', '존 트라볼타,덴젤 워싱턴', '브래드 피트,크리스토프 왈츠',
       '산드라 블록,라이언 레놀즈', '김선영,이범수', '밀라 요보비치,티모시 올리펀트', '아일라 피셔,휴 댄시',
       '제라드 버틀러,앰버 발레타', '카고 아이,미나미 아키나', '정우성,고원원', '바비 캠포,닉 자노',
       '저스틴 롱,알리슨 로먼', '유진,박한별', '남상미,류승룡', '우마 서먼,콜린 퍼스',
       '클라이브 오웬,나오미 왓츠', '윌 스미스,우디 해럴슨', '강혜정,박희순', '오데뜨 유스트만,게리 올드만',
       '조쉬 하트넷,이병헌', '오웬 윌슨,제니퍼 애니스턴', '제러드 파달렉키,다니엘 파나베이커',
       '오드리 토투,브누와 뽀엘부르드', '저스틴 롱,매튜 그레이 구블러', '다니엘 데이 루이스,마리온 꼬띨라르',
       '설경구,류승범', '원빈,김새론', '레오나르도 디카프리오,엘렌 페이지', '송강호,강동원',
       '로버트 다우니 주니어,기네스 팰트로우', '정재영,박해일', '차승원,권상우', '김윤진,김호연', '김주혁,류승범',
       '안젤리나 졸리', '황정민,김승훈', '엄태웅,이민정', '전도연,이정재', '톰 크루즈,카메론 디아즈',
       '조니 뎁,앤 해서웨이', '강동원,김한나', '이선균,최강희', '제이크 질렌할,젬마 아터튼',
       '로건 레먼,피어스 브로스넌', '이영수,설경구', '이병헌,최민식', '러셀 크로우,케이트 블란쳇',
       '주진모,송승헌', '톰 행크스,조앤 쿠삭', '황정민,김성훈', '잭슨 라스본,데브 파텔', '차태현,강예원',
       '나문희,김수미', '수애,유지태', '밀라 요보비치,웬트워스 밀러', '벤 반스,조지 헨리', '엄정화,류승룡',
       '임수정,공유', '김명민,엄기준', '마크 러팔로,레오나르도 디카프리오', '김인권,김정태', '지진희,심호성',
       '안젤리나 졸리,조니 뎁', '에릭 벌포,스카티 톰슨', '김수로,황정음', '리암 니슨,퀸튼 잭슨',
       '지현우,조한선', '달이,성동일', '박중훈,정유미', '샤니 빈슨,릭 말람브리', '정보석,배한성',
       '오재균,한석규', '맷 데이먼,제이슨 아이삭스', '김미소,유오성', '아만다 사이프리드,크리스토퍼 에건',
       '김수로,한재석', '니콜라스 케이지,모니카 벨루치', '심형래,마이클 리스폴리', '제시 아이젠버그,앤드류 가필드',
       '엘리자베스 슈,제시카 스자르', '줄리아 로버츠,제임스 프랑코', '임창정,엄지원', '김해숙,박진희',
       '김정은,진구', '유덕화,양가휘', '덴젤 워싱턴,크리스 파인', '손병호,임원희', '장동건,케이트 보스워스',
       '사라 제시카 파커,크리스틴 데이비스', '실베스터 스탤론,제이슨 스타뎀', '주윤발,주신',
       '존 트라볼타,조나단 리스 마이어스', '산드라 블록', '박희순,고창석', '애쉬튼 커처,캐서린 헤이글',
       '정우성,양자경', '제이든 스미스,성룡', '애드리언 브로디,토퍼 그레이스', '에밀리 블런트,베니치오 델 토로',
       '샤이아 라보프,마이클 더글라스', '메릴 스트립,알렉 볼드윈', '신경선,윤이나', '밀라 요보비치,윌 패튼',
       '덴젤 워싱턴,게리 올드만', '윤정희,이다윗', '러셀 크로우,엘리자베스 뱅크스', '마크 월버그,레이첼 와이즈',
       '엠마 톰슨', '신하균,박소현', '발리에리 르메르시,막심 고다르', '멜 깁슨', '제프 브리지스,가렛 헤드룬드',
       '김윤진,박해일', '이병헌,한채영', '아마미 유키', '조쉬 더하멜,존 말코비치', '박해일,류승룡',
       '유호정,심은경', '김윤석,유아인', '톰 크루즈,제레미 레너', '김명민,김호연', '정유미,공유', '휴 잭맨',
       '이안 맥쉐인,페넬로페 크루즈', '이새별,고창석', '신하균,고수', '손예진,이민기',
       '브라이언 콕스,제임스 프랭코', '송새벽,이시영', '로즈 번,재뉴어리 존스', '박희순,장혁', '김수미,신현준',
       '강신일,김미경', '박용우,류승룡', '잭 블랙', '정진영,이문식', '스텔란 스카스가드,스튜어트 타운젠드',
       '나탈리 포트만,뱅상 카셀', '드웨인 존슨,폴 워커', '장동건,오다기리 조', '미키 루크,헨리 카빌',
       '아론 에크하트,미쉘 로드리게즈', '미셸 모나한,제이크 질렌할', '우혜진,엄태웅', '윤하,류승범',
       '소지섭,한효주', '안젤라 랜스베리,짐 캐리', '박중훈,이선균', '현빈,탕웨이', '조승우,양동근',
       '콜린 퍼스,제프리 러쉬', '황우슬혜,함은정', '송강호,신세경', '윤계상,김규리', '정려원,권상우',
       '김예론,김동욱', '로건 레먼,올랜도 블룸', '티모시 올리펀트,알렉스 페티퍼', '조나 힐,브래드 피트',
       '아만다 사이프리드,킬리언 머피', '칼럼 블루,조 샐다나', '장근석,김하늘', '차태현,김수정', '앤 해서웨이',
       '크리스 에반스,휴고 위빙', '조엘 코트니,엘르 패닝', '정재영,전도연', '이안 그루퍼드,리차드 록스버그',
       '니콜라스 케이지,론 펄먼', '황정민,김민희', '임창정,김규리', '맷 데이먼,에밀리 블런트',
       '아만다 사이프리드,게리 올드만', '공형진,김주혁', '라이언 필립,매튜 매커너히', '김갑수,서영희',
       '윤은혜,박한별', '공리,주윤발', '나탈리 포트만,애쉬튼 커처', '데이비드 코에너',
       '다니엘 크레이그,해리슨 포드', '김주혁,유해진', '벨렌 루에다', '맷 데이먼,기네스 팰트로우',
       '안성기,박원상', '이민정,이정진', '아누크 에메,장-루이 트린티냥', '클라크 게이블,비비안 리',
       '오군여,주혜민', '로버트 레드포드,데미 무어', '다니엘 크레이그,루니 마라', '김윤석,김혜수',
       '이병헌,류승룡', '로버트 다우니 주니어,스칼렛 요한슨', '송중기,박보영', '크리스찬 베일,게리 올드만',
       '앤드류 가필드,엠마 스톤', '최민식,하정우', '임수정,이선균', '김명민,강지원', '엄태웅,한가인',
       '황정민,엄정화', '휴 잭맨,러셀 크로우', '진구,한혜진', '정재영,박시후', '조여정,김동욱',
       '마틴 프리먼,이안 맥켈런', '이선균,김민희', '김윤진,마동석', '다니엘 크레이그,하비에르 바르뎀',
       '리암 니슨,테일러 키치', '설경구,손예진', '하지원,배두나', '고수,한효주', '하정우,공효진',
       '프랑수아 클뤼제,오마 사이', '임창정,최다니엘', '송강호,이여진', '류승범,이요원', '강지환,성유리',
       '박해일,김무열', '김명민,염정아', '박희순,박시연', '콜린 파렐,케이트 베킨세일', '정지훈,유준상',
       '김강우,백윤식', '드웨인 존슨,마이클 케인', '소지섭,이미연', '제레미 레너,레이첼 와이즈', '조성현,정준호',
       '이범수,류승범', '유선,남보라', '누미 라파스,마이클 패스벤더', '라이언 구즈만,캐서린 맥코믹',
       '김수로,오상철', '샘 워싱턴,리암 니슨', '리즈 위더스푼,크리스 파인', '박보영,주원', '주지훈,백윤식',
       '샤를리즈 테론,크리스틴 스튜어트', '고현정,유해진', '제니퍼 로렌스,조쉬 허처슨',
       '샘 워싱턴,엘리자베스 뱅크스', '박용우,고아라', '줄리아 로버츠,릴리 콜린스', '조니 뎁,미쉘 파이퍼',
       '조셉 고든 레빗,브루스 윌리스', '밀라 요보비치,미셸 로드리게즈', '송새벽,성동일', '김명민,안성기',
       '가이 피어스,매기 그레이스', '실베스터 스탤론,브루스 윌리스', '박한별,김지석', '데인 드한,알렉스 러셀',
       '벤자민 워커,도미닉 쿠퍼', '김현수,노강민', '장동건,장쯔이', '리암 니슨,더못 멀로니', '엄태웅,김현정',
       '맷 데이먼,스칼렛 요한슨', '페이지 오하라,로비 벤슨', '박신양,김정태', '톰 행크스,할리 베리',
       '이완 맥그리거,나오미 왓츠', '김래원,지대한', '잭 니콜슨,페이 더너웨이', '강필선', '정연주',
       '류승룡,박신혜', '크리스 에반스,송강호', '송강호,이정재', '하정우,한석규', '김수현,박기웅',
       '송강호,김영애', '하정우,이경영', '설경구,정우성', '브래드 피트,미레유 에노스', '이정재,최민식',
       '설경구,문소리', '장혁,수애', '크리스 헴스워스,톰 히들스턴', '브루스 윌리스,존 말코비치', '유오성,주진모',
       '레이첼 맥아담스,도널 글리슨', '제시 아이젠버그,마크 러팔로', '설경구,엄지원', '찰리 허냄,론 펄먼',
       '여진구,김윤석', '헨리 카빌,에이미 아담스', '공유,박희순', '마틴 프리먼,베네딕트 컴버배치',
       '엄정화,김상경', '이민기,김민희', '이병헌,브루스 윌리스', '빈 디젤,드웨인 존슨', '손예진,김갑수',
       '전도연,고수', '황정민,유준상', '한석규,이제훈', '크리스 파인,칼 어번', '톰 크루즈,모건 프리먼',
       '레오나르도 디카프리오,캐리 뮬리건', '브루스 윌리스,제이 코트니', '신하균,이태리', '서교,성동일',
       '김강우,김효진', '유아인,김해숙', '맷 데이먼,조디 포스터', '이시영,엄기준', '니콜라스 홀트,테레사 팔머',
       '우혜진,박해일', '휴 잭맨,사나다 히로유키', '최승현,한예리', '니콜라스 홀트,이완 맥그리거',
       '정재영,김옥빈', '톰 크루즈,로자문드 파이크', '김선아,마동석', '로즈 번,패트릭 윌슨',
       '릴리 콜린스,제이미 캠벨 바우어', '채닝 테이텀,제이미 폭스', '윌 스미스,제이든 스미스', '김강우,김범',
       '로건 레먼,알렉산드리아 다다리오', '이시영,김영현', '박성웅,우혜진', '김아중,주원', '서인국,이종석',
       '임창정,안내상', '조니 뎁,아미 해머', '미아 와시코브스카,매튜 구드', '제임스 프랭코,미쉘 윌리엄스',
       '최강희,봉태규', '성룡,권상우', '실베스터 스탤론,아놀드 슈왈제네거', '정경호,한성천',
       '레오나르도 디카프리오,제이미 폭스', '천정명,김민정', '톰 행크스,캐서린 키너', '이제훈,조진웅',
       '애쉬튼 커처,조시 게드', '테렌스 스탬프,바네사 레드그레이브', '에단 호크,줄리 델피', '양동근,주상욱',
       '휴 잭맨,제이크 질렌할', '이광수,송지효', '제라드 버틀러,모건 프리먼', '엄태웅,김민준', '마동석,이승연',
       '해리슨 포드,아사 버터필드', '저스틴 팀버레이크,벤 애플렉', '호와킨 피닉스,필립 세이모어 호프만',
       '정재영,한지민', '연정훈,이지훈', '우혜영,박철민', '잉그리드 서린,군넬 린드블롬', '최민식,류승룡',
       '김남길,손예진', '심은경,나문희', '황정민,김윤진', '마크 월버그,제시카 고메즈', '하정우,강동원',
       '톰 크루즈,에밀리 블런트', '휴 잭맨,제임스 맥어보이', '최승현,신세경', '앤디 서키스,게리 올드만',
       '크리스 에반스,스칼렛 요한슨', '현빈,정재영', '정우성,안성기', '이선균,조진웅', '류승룡,유준상',
       '딜런 오브라이언,카야 스코델라리오', '조정석,신민아', '리암 니슨,줄리안 무어',
       '리차드 아미티지,사라 웨인 콜리스', '러셀 크로우,엠마 왓슨', '황정민,한혜진', '스칼렛 요한슨,모건 프리먼',
       '김우빈,김영철', '벤 애플렉,로자먼드 파이크', '박해일,유연석', '박보영,이종석', '송혜교,김승욱',
       '김희애,고아성', '레나 헤디,에바 그린', '크리스찬 베일,조엘 에저튼', '김윤석,박유천', '송승헌,임지연',
       '안젤리나 졸리,엘르 패닝', '킷 해링턴,에밀리 브라우닝', '브래드 피트,로건 레먼', '루크 에반스,도미닉 쿠퍼',
       '김강우,고창석', '이정재,신하균', '차태현,남상미', '이진성,정재영', '조엘 키나만,사무엘 L. 잭슨',
       '김성균,조진웅', '애나벨 월리스,워드 호튼', '염정아,문정희', '엄정화,문소리', '쉐일린 우들리,안셀 엘고트',
       '애런 존슨,브라이언 크랜스톤', '조니 뎁,레베카 홀', '홍수민,한석규', '장동건,김민희',
       '김다율(김아현),주원', '장한새,이민기', '레오나르도 디카프리오,매튜 매커너히',
       '라이언 구즈만,브리아나 에비건', '치웨텔 에지오포,마이클 패스벤더', '강하늘,김소은', '하지원,강예원',
       '정우성,이솜', '쉐일린 우들리,케이트 윈슬렛', '사사키 노조미', '메간 폭스,윌리엄 피츠너', '설경구,박해일',
       '이 동 길,차승원', '크리스 파인,키이라 나이틀리', '메릴 스트립,조니 뎁', '윤계상,고준희',
       '아론 에크하트,빌 나이', '릴리 콜린스,샘 클라플린', '카렌 길런,브렌튼 스웨이츠',
       '피어스 브로스넌,올가 쿠릴렌코', '리암 니슨,보이드 홀브룩', '케빈 코스트너,앰버 허드', '윤상현,송새벽',
       '짐 캐리,토미 스나이더', '프레데릭 벨,엘로디 퐁탕', '마이클 더글라스,제리 페라라', '김상경,문정희',
       '성룡,유엽', '리암 니슨,팜케 얀센', '니콜 키드먼,벤 위쇼', '조여정,클라라', '브래들리 쿠퍼,시에나 밀러',
       '잭 오코넬,도널 글리슨', '장 가뱅,애니 지라르도', '마크 러팔로,에단 호크', '황정민,유아인',
       '전지현,이정재', '로버트 다우니 주니어,크리스 헴스워스', '이병헌,조승우', '콜린 퍼스,태런 에저튼',
       '김무열,진구', '김윤석,강동원', '황정민,정우', '맷 데이먼,제시카 차스테인', '김명민,오달수',
       '앤 해서웨이,로버트 드니로', '아놀드 슈왈제네거,제이슨 클락', '김우빈,이준호', '김윤석,유해진',
       '폴 러드,마이클 더글라스', '해리슨 포드,마크 해밀', '딜런 오브라이언,토마스 생스터', '권상우,성동일',
       '손현주,마동석', '이민호,김래원', '한효주,김대명', '이승기,문채원', '다니엘 크레이그,레아 세이두',
       '베네딕트 컴버배치,키이라 나이틀리', '드웨인 존슨,알렉산드리아 다다리오', '김윤석,정우', '손현주,엄지원',
       '최민식,정만식', '박해빛나,박근형', '오상철,이선균', '주지훈,김강우', '벤 스틸러,로빈 윌리엄스',
       '주원,유해진', '엄정화,송승헌', '하정우,하지원', '김상경,김성균', '스테파니 스콧,더못 멀로니',
       '크리스 헴스워스,킬리언 머피', '정재영,박보영', '조정석,이미숙', '설경구,여진구', '휴 잭맨,샬토 코플리',
       '김수미,정만식', '진세연,홍종현', '신하균,장혁', '고아성,박성웅', '이병헌,전도연', '김남길,전도연',
       '마일즈 텔러,케이트 마라', '이민기,여진구', '윤계상,유해진', '박보영,엄지원', '제이슨 클락,조슈 브롤린',
       '윤계상,한예리', '류승룡,배수지', '밀라 쿠니스,채닝 테이텀', '리암 니슨,조엘 킨나만',
       '쉐일린 우들리,테오 제임스', '조니 웨스턴,소피아 블랙 디엘리아', '조지 클루니,휴 로리',
       '톰 행크스,마크 라이런스', '조셉 고든 레빗,벤 킹슬리', '유승호,고아라', '샐리 헤닝,모세 제이콥 스톰',
       '오지호,최령', '마이클 키튼,에드워드 노튼', '소메타니 쇼타,후카츠 에리', '휴 잭맨,가렛 헤드룬드',
       '톰 하디,태런 에저튼', '마크 월버그,세스 맥팔레인', '제시 아이젠버그,크리스틴 스튜어트',
       '에드 스크레인,론 샤바놀', '러셀 크로우,올가 쿠릴렌코', '류승범,고준희', '데인 드한,로버트 패틴슨',
       '잭 블랙,딜런 미네트', '정우성,김하늘', '루크 브레이시,에드가 라미레즈', '레오나르도 디카프리오,톰 하디',
       '공유,김정희', '황정민,강동원', '크리스 에반스,로버트 다우니 주니어', '송강호,공유', '하정우,배두나',
       '김정철,이정재', '곽도원,황정민', '손예진,박해일', '베네딕트 컴버배치,레이첼 맥아담스',
       '에디 레드메인,콜린 파렐', '라이언 레놀즈,모레나 바카린', '조정석,도경수', '제임스 맥어보이,마이클 패스벤더',
       '에바 그린,사무엘 L. 잭슨', '맷 데이먼,줄리아 스타일즈', '닐 세티,빌 머레이', '헨리 카빌,벤 애플렉',
       '김혜수,마동석', '유승호,조재현', '베라 파미가,패트릭 윌슨', '윌 스미스,자레드 레토',
       '빌 풀만,리암 헴스워스', '이제훈,김성균', '베네딕트 컴버배치,마틴 프리먼', '김명민,김상호',
       '임수정,조정석', '강하늘,박정민', '트래비스 핌멜,벤 포스터', '크리스 파인,사이먼 페그', '서하늬,엄지원',
       '김윤석,변요한', '테레사 팔머,알리시아 벨라 베일리', '김현빈,임시완', '강예원,이상윤',
       '제인 레비,딜런 미네트', '김율호,차승원', '에밀리아 클라크,샘 클라플린', '덴젤 워싱턴,크리스 프랫',
       '제라드 버틀러,니콜라이 코스터 왈도', '알렉산더 스카스가드,마고 로비', '이미연,최지우',
       '르네 젤위거,콜린 퍼스', '유지태,이정현', '제라드 버틀러,아론 에크하트', '수애,오달수',
       '톰 행크스,펠리시티 존스', '김정희,문채원', '심은경,윤제문', '톰 행크스,아론 에크하트',
       '톰 크루즈,코비 스멀더스', '펠리시티 존스,디에고 루나', '제이슨 스타뎀,제시카 알바',
       '멜리사 맥카시,크리스 헴스워스', '강동원,신은수', '한효주,유연석', '윤여정,김고은', '이성민,이희준',
       '크리스찬 베일,스티브 카렐', '크리스 헴스워스,샤를리즈 테론', '메리 엘리자베스 윈스티드,존 굿맨',
       '엘리자베스 리저,애너리즈 바쏘', '류덕환,김동영', '마이클 키튼,마크 러팔로', '류덕환,조복래',
       '도경수,김소현', '메간 폭스,스티븐 아멜', '태런 에저튼,폴 레이놀즈', '조셉 파인즈,톰 펠튼',
       '제니퍼 로렌스,브래들리 쿠퍼', '오달수,윤제문', '알 파치노,안소니 홉킨스', '존 크랜신스키,파블로 쉬레이버',
       '클로이 모레츠,닉 로빈슨', '마크 라이런스,레베카 홀', '브라이스 달라스 하워드,오크스 페글리',
       '이드리스 엘바,리처드 매든', '차태현,김유정', '브래드 피트,마리옹 꼬띠아르', '크리스 프랫,제니퍼 로렌스',
       '마이클 매드슨,스텔라 매브', '이수민,송강호', '하정우,차태현', '현빈,유해진', '제이콥 배덜런,톰 홀랜드',
       '황정민,김규백', '김규백,박서준', '콜린 퍼스,줄리안 무어', '정우성,곽도원', '이병헌,김윤석',
       '톰 크루즈,소피아 부텔라', '나문희,이제훈', '톰 하디,마크 라이런스', '크리스 프랫,조 샐다나',
       '설경구,김남길', '마크 월버그,안소니 홉킨스', '이성민,조진웅', '지창욱,심은경', '정우,강하늘',
       '이제훈,최희서', '휴 잭맨,패트릭 스튜어트', '갤 가돗,로빈 라이트', '다니엘 칼루야,앨리슨 윌리암스',
       '앤디 서키스,우디 해럴슨', '스테파니 시그만,알리시아 벨라 베일리', '벤 애플렉,갤 가돗',
       '라이언 레놀즈,사무엘 L. 잭슨', '톰 히들스턴,브리 라슨', '제임스 맥어보이,안야 테일러 조이',
       '이선균,안재홍', '마동석,이동휘', '강하늘,김무열', '제시카 로테,이스라엘 브로우사드', '강소백,장동건',
       '최민식,곽도원', '마이클 패스벤더,캘리 헤르난데스', '염정아,박혁권', '김옥빈,신하균', '조진웅,신구',
       '캐서린 윈닉,제라드 버틀러', '마크 해밀,캐리 피셔', '설경구,임시완', '오웬 티그,빌 스카스가드',
       '케네스 브래너,페넬로페 크루즈', '이정재,여진구', '안셀 엘고트,케빈 스페이시', '휴 잭맨,잭 에프런',
       '밀라 요보비치,알리 라터', '스칼렛 요한슨,마이클 피트', '윤제문,정소민', '에이미 아담스,제레미 레너',
       '맨디 무어,클레어 홀트', '데인 드한,카라 델러비인', '맷 데이먼,페드로 파스칼', '빈 디젤,사무엘 L. 잭슨',
       '김수현,성동일', '타라지 P. 헨슨,옥타비아 스펜서', '백윤식,성동일', '임시완,진구', '찰리 허냄,주드 로',
       '톰 크루즈,도널 글리슨', '손현주,장혁', '조진웅,송승헌', '마이클 패스벤더,마리옹 꼬띠아르', '황인아,고수',
       '진남수,이병헌', '신하균,도경수', '김래원,김해숙', '틸다 스윈튼,제이크 질렌할',
       '라이언 고슬링,해리슨 포드', '키아누 리브스,이안 맥쉐인', '김혜수,이선균', '김남길,천우희',
       '딜런 오브라이언,테일러 키취', '제이미 도넌,다코타 존슨', '앤드류 가필드,샘 워싱턴', '고두심,김성균',
       '데인 드한,제이슨 아이삭스', '샤를리즈 테론,제임스 맥어보이', '강예원,한채아']

# %%
actor_list
# Out:
# ['김윤석,하정우',
#  '아만다 사이프리드,메릴 스트립',
#  '차태현,박보영',
#  '설경구,정재영',
#  '로버트 다우니 주니어,테렌스 하워드',
#  '해리슨 포드,샤이아 라보프',
#  '브렌든 프레이저,마리아 벨로',
#  '크리스찬 베일,마이클 케인',
#  '문소리,김정은',
#  '정재영,한은정',
#  '제임스 맥어보이,안젤리나 졸리',
#  '윌 스미스,샤를리즈 테론',
#  '리암 니슨,매기 그레이스',
#  '김민선,김영호',
#  '샤이아 라보프,미셸 모나한',
#  '다니엘 크레이그,올가 큐리렌코',
#  '한석규,차승원',
#  '손예진,김주혁',
#  '수애,정진영',
#  '레이첼 빌슨,헤이든 크리스텐슨',
#  '김명민,손예진',
#  '양조위,금성무',
#  '변희봉,손현주',
#  '소지섭,강지환',
#  '키아누 리브스,제니퍼 코넬리',
#  '크리스틴 스튜어트,로버트 패틴슨',
#  '제리 사인펠드,르네 젤위거',
#  '이연걸,성룡',
#  '주지훈,김재욱',
#  '스티븐 스트레이트,카밀라 벨',
#  '김하늘,윤계상',
#  '사라 제시카 파커,킴 캐트럴',
#  '선자 손,윌 켐프',
#  '유덕화,매기 큐',
#  '차태현,하지원',
#  '휴 잭맨,니콜 키드먼',
#  '천호진,조현재',
#  '차인표,신명철',
#  '짐 캐리,주이 데샤넬',
#  '정지훈,매튜 폭스',
#  '이새별,박해일',
#  '유지태,이연희',
#  '하정우,이정민',
#  '조니 뎁,헬레나 본햄 카터',
#  '제라드 버틀러',
#  '카메론 디아즈,애쉬튼 커처',
#  '나탈리 포트만,스칼렛 요한슨',
#  '프레디 하이모어,사라 볼거',
#  '김수로,이한위',
#  '줄리안 무어,마크 러팔로',
#  '다니엘 크레이그,니콜 키드먼',
#  '곽선영,조승우',
#  '레오나르도 디카프리오,러셀 크로우',
#  '이미숙,김민희',
#  '리지 캐플란,오데뜨 유스트만',
#  '제이슨 스타뎀,세프론 버로우스',
#  '홍희자,황정민',
#  '유해진,진구',
#  '니콜라스 케이지,존 보이트',
#  '공효진,이종혁',
#  '로리 홀든,토마스 제인',
#  '조인성,주진모',
#  '김선아,박진희',
#  '장근석,문메이슨',
#  '에이미 아담스,패트릭 뎀시',
#  '손태영,장근석',
#  '전도연,하정우',
#  '이연걸,유덕화',
#  '쿠도 유키,마츠야마 켄이치',
#  '마크 웰버그,주이 데샤넬',
#  '힐러리 스웽크,제라드 버틀러',
#  '주성치,서교',
#  '임창정,송지효',
#  '브래들리 쿠퍼,레슬리 빕',
#  '스티븐 파스퀄,레이코 아일리스워스',
#  '이정재,김석훈',
#  '잭 니콜슨,모건 프리먼',
#  '키아누 리브스,포레스트 휘테커',
#  '프레디 하이모어,조나단 리스 마이어스',
#  '봉태규,김영애',
#  '신현준,허준호',
#  '안성기,이창민',
#  '밀라 쿠니스,마크 웰버그',
#  '키이라 나이틀리,랄프 파인즈',
#  '나문희,김선아',
#  '스캇 스피드맨,리브 타일러',
#  '데이비드 듀코브니',
#  '캐서린 헤이글,제임스 마스던',
#  '가엘 가르시아 베르날,윌리엄 허트',
#  '찰톤 헤스톤,잭 호킨스',
#  '다니엘 크레이그,제이미 벨',
#  '니시지마 히데토시,카타오카 레이코',
#  '무로이 시게루,코바야시 넨지',
#  '최원균,이삼순',
#  '제이슨 스타뎀,나탈리아 루다코바',
#  '설경구,하지원',
#  '하정우,성동일',
#  '샤이아 라보프,메간 폭스',
#  '샘 워싱턴,조 샐다나',
#  '크리스찬 베일,샘 워싱턴',
#  '김하늘,강지환',
#  '김윤석,정경호',
#  '다니엘 래드클리프,엠마 왓슨',
#  '금성무,양조위',
#  '채닝 테이텀,버튼 페레즈',
#  '한동학,장동건',
#  '강동원,임수정',
#  '송강호,김옥빈',
#  '하지원,김명민',
#  '벤 스틸러,에이미 아담스',
#  '로버트 패틴슨,크리스틴 스튜어트',
#  '톰 행크스,이완 맥그리거',
#  '김성태,최강희',
#  '송요셉,황정민',
#  '톰 크루즈,빌 나이히',
#  '엄태웅,정유미',
#  '브래드 피트,케이트 블란쳇',
#  '최경원,조승우',
#  '정준호,최경원',
#  '박용하,박희순',
#  '정지훈,나오미 해리스',
#  '임창정,박예진',
#  '휴 잭맨,리브 슈라이버',
#  '이범수,조안',
#  '김래원,엄정화',
#  '로버트 다우니 주니어,주드 로',
#  '데브 파텔,프리다 핀토',
#  '크리스 파인,재커리 퀸토',
#  '니콜라스 케이지,로즈 번',
#  '한석규,손예진',
#  '제니퍼 코넬리,드류 베리모어',
#  '샬토 코플리,제이슨 코프',
#  '김강우,조재현',
#  '제라드 버틀러,제이미 폭스',
#  '브루스 윌리스,라다 미첼',
#  '에릭 바나,레이첼 맥아덤즈',
#  '정재영,구교환',
#  '크리스 에반스,다코타 패닝',
#  '권상우,이보영',
#  '빈 디젤,폴 워커',
#  '오연서,장경아',
#  '케이 파나베이커,애셔 북',
#  '엄태웅,박용우',
#  '서민균,이범수',
#  '제프리 딘 모건,빌리 크루덥',
#  '브렌든 프레이저,시에나 길로리',
#  '정진영,장근석',
#  '안젤리나 졸리,존 말코비치',
#  '고현정,김민희',
#  '시릴 라파엘리,데이빗 벨',
#  '베라 파미가,이사벨 퍼만',
#  '조니 뎁,크리스찬 베일',
#  '랄프 파인즈,케이트 윈슬렛',
#  '김강우,황정민',
#  '박해일,신민아',
#  '저스틴 채트윈,주윤발',
#  '조니 뎁,히스 레저',
#  '윤계상,조재현',
#  '다코타 블루 리차드,이안 그루퍼드',
#  '존 트라볼타,덴젤 워싱턴',
#  '브래드 피트,크리스토프 왈츠',
#  '산드라 블록,라이언 레놀즈',
#  '김선영,이범수',
#  '밀라 요보비치,티모시 올리펀트',
#  '아일라 피셔,휴 댄시',
#  '제라드 버틀러,앰버 발레타',
#  '카고 아이,미나미 아키나',
#  '정우성,고원원',
#  '바비 캠포,닉 자노',
#  '저스틴 롱,알리슨 로먼',
#  '유진,박한별',
#  '남상미,류승룡',
#  '우마 서먼,콜린 퍼스',
#  '클라이브 오웬,나오미 왓츠',
#  '윌 스미스,우디 해럴슨',
#  '강혜정,박희순',
#  '오데뜨 유스트만,게리 올드만',
#  '조쉬 하트넷,이병헌',
#  '오웬 윌슨,제니퍼 애니스턴',
#  '제러드 파달렉키,다니엘 파나베이커',
#  '오드리 토투,브누와 뽀엘부르드',
#  '저스틴 롱,매튜 그레이 구블러',
#  '다니엘 데이 루이스,마리온 꼬띨라르',
#  '설경구,류승범',
#  '원빈,김새론',
#  '레오나르도 디카프리오,엘렌 페이지',
#  '송강호,강동원',
#  '로버트 다우니 주니어,기네스 팰트로우',
#  '정재영,박해일',
#  '차승원,권상우',
#  '김윤진,김호연',
#  '김주혁,류승범',
#  '안젤리나 졸리',
#  '황정민,김승훈',
#  '엄태웅,이민정',
#  '전도연,이정재',
#  '톰 크루즈,카메론 디아즈',
#  '조니 뎁,앤 해서웨이',
#  '강동원,김한나',
#  '이선균,최강희',
#  '제이크 질렌할,젬마 아터튼',
#  '로건 레먼,피어스 브로스넌',
#  '이영수,설경구',
#  '이병헌,최민식',
#  '러셀 크로우,케이트 블란쳇',
#  '주진모,송승헌',
#  '톰 행크스,조앤 쿠삭',
#  '황정민,김성훈',
#  '잭슨 라스본,데브 파텔',
#  '차태현,강예원',
#  '나문희,김수미',
#  '수애,유지태',
#  '밀라 요보비치,웬트워스 밀러',
#  '벤 반스,조지 헨리',
#  '엄정화,류승룡',
#  '임수정,공유',
#  '김명민,엄기준',
#  '마크 러팔로,레오나르도 디카프리오',
#  '김인권,김정태',
#  '지진희,심호성',
#  '안젤리나 졸리,조니 뎁',
#  '에릭 벌포,스카티 톰슨',
#  '김수로,황정음',
#  '리암 니슨,퀸튼 잭슨',
#  '지현우,조한선',
#  '달이,성동일',
#  '박중훈,정유미',
#  '샤니 빈슨,릭 말람브리',
#  '정보석,배한성',
#  '오재균,한석규',
#  '맷 데이먼,제이슨 아이삭스',
#  '김미소,유오성',
#  '아만다 사이프리드,크리스토퍼 에건',
#  '김수로,한재석',
#  '니콜라스 케이지,모니카 벨루치',
#  '심형래,마이클 리스폴리',
#  '제시 아이젠버그,앤드류 가필드',
#  '엘리자베스 슈,제시카 스자르',
#  '줄리아 로버츠,제임스 프랑코',
#  '임창정,엄지원',
#  '김해숙,박진희',
#  '김정은,진구',
#  '유덕화,양가휘',
#  '덴젤 워싱턴,크리스 파인',
#  '손병호,임원희',
#  '장동건,케이트 보스워스',
#  '사라 제시카 파커,크리스틴 데이비스',
#  '실베스터 스탤론,제이슨 스타뎀',
#  '주윤발,주신',
#  '존 트라볼타,조나단 리스 마이어스',
#  '산드라 블록',
#  '박희순,고창석',
#  '애쉬튼 커처,캐서린 헤이글',
#  '정우성,양자경',
#  '제이든 스미스,성룡',
#  '애드리언 브로디,토퍼 그레이스',
#  '에밀리 블런트,베니치오 델 토로',
#  '샤이아 라보프,마이클 더글라스',
#  '메릴 스트립,알렉 볼드윈',
#  '신경선,윤이나',
#  '밀라 요보비치,윌 패튼',
#  '덴젤 워싱턴,게리 올드만',
#  '윤정희,이다윗',
#  '러셀 크로우,엘리자베스 뱅크스',
#  '마크 월버그,레이첼 와이즈',
#  '엠마 톰슨',
#  '신하균,박소현',
#  '발리에리 르메르시,막심 고다르',
#  '멜 깁슨',
#  '제프 브리지스,가렛 헤드룬드',
#  '김윤진,박해일',
#  '이병헌,한채영',
#  '아마미 유키',
#  '조쉬 더하멜,존 말코비치',
#  '박해일,류승룡',
#  '유호정,심은경',
#  '김윤석,유아인',
#  '톰 크루즈,제레미 레너',
#  '김명민,김호연',
#  '정유미,공유',
#  '휴 잭맨',
#  '이안 맥쉐인,페넬로페 크루즈',
#  '이새별,고창석',
#  '신하균,고수',
#  '손예진,이민기',
#  '브라이언 콕스,제임스 프랭코',
#  '송새벽,이시영',
#  '로즈 번,재뉴어리 존스',
#  '박희순,장혁',
#  '김수미,신현준',
#  '강신일,김미경',
#  '박용우,류승룡',
#  '잭 블랙',
#  '정진영,이문식',
#  '스텔란 스카스가드,스튜어트 타운젠드',
#  '나탈리 포트만,뱅상 카셀',
#  '드웨인 존슨,폴 워커',
#  '장동건,오다기리 조',
#  '미키 루크,헨리 카빌',
#  '아론 에크하트,미쉘 로드리게즈',
#  '미셸 모나한,제이크 질렌할',
#  '우혜진,엄태웅',
#  '윤하,류승범',
#  '소지섭,한효주',
#  '안젤라 랜스베리,짐 캐리',
#  '박중훈,이선균',
#  '현빈,탕웨이',
#  '조승우,양동근',
#  '콜린 퍼스,제프리 러쉬',
#  '황우슬혜,함은정',
#  '송강호,신세경',
#  '윤계상,김규리',
#  '정려원,권상우',
#  '김예론,김동욱',
#  '로건 레먼,올랜도 블룸',
#  '티모시 올리펀트,알렉스 페티퍼',
#  '조나 힐,브래드 피트',
#  '아만다 사이프리드,킬리언 머피',
#  '칼럼 블루,조 샐다나',
#  '장근석,김하늘',
#  '차태현,김수정',
#  '앤 해서웨이',
#  '크리스 에반스,휴고 위빙',
#  '조엘 코트니,엘르 패닝',
#  '정재영,전도연',
#  '이안 그루퍼드,리차드 록스버그',
#  '니콜라스 케이지,론 펄먼',
#  '황정민,김민희',
#  '임창정,김규리',
#  '맷 데이먼,에밀리 블런트',
#  '아만다 사이프리드,게리 올드만',
#  '공형진,김주혁',
#  '라이언 필립,매튜 매커너히',
#  '김갑수,서영희',
#  '윤은혜,박한별',
#  '공리,주윤발',
#  '나탈리 포트만,애쉬튼 커처',
#  '데이비드 코에너',
#  '다니엘 크레이그,해리슨 포드',
#  '김주혁,유해진',
#  '벨렌 루에다',
#  '맷 데이먼,기네스 팰트로우',
#  '안성기,박원상',
#  '이민정,이정진',
#  '아누크 에메,장-루이 트린티냥',
#  '클라크 게이블,비비안 리',
#  '오군여,주혜민',
#  '로버트 레드포드,데미 무어',
#  '다니엘 크레이그,루니 마라',
#  '김윤석,김혜수',
#  '이병헌,류승룡',
#  '로버트 다우니 주니어,스칼렛 요한슨',
#  '송중기,박보영',
#  '크리스찬 베일,게리 올드만',
#  '앤드류 가필드,엠마 스톤',
#  '최민식,하정우',
#  '임수정,이선균',
#  '김명민,강지원',
#  '엄태웅,한가인',
#  '황정민,엄정화',
#  '휴 잭맨,러셀 크로우',
#  '진구,한혜진',
#  '정재영,박시후',
#  '조여정,김동욱',
#  '마틴 프리먼,이안 맥켈런',
#  '이선균,김민희',
#  '김윤진,마동석',
#  '다니엘 크레이그,하비에르 바르뎀',
#  '리암 니슨,테일러 키치',
#  '설경구,손예진',
#  '하지원,배두나',
#  '고수,한효주',
#  '하정우,공효진',
#  '프랑수아 클뤼제,오마 사이',
#  '임창정,최다니엘',
#  '송강호,이여진',
#  '류승범,이요원',
#  '강지환,성유리',
#  '박해일,김무열',
#  '김명민,염정아',
#  '박희순,박시연',
#  '콜린 파렐,케이트 베킨세일',
#  '정지훈,유준상',
#  '김강우,백윤식',
#  '드웨인 존슨,마이클 케인',
#  '소지섭,이미연',
#  '제레미 레너,레이첼 와이즈',
#  '조성현,정준호',
#  '이범수,류승범',
#  '유선,남보라',
#  '누미 라파스,마이클 패스벤더',
#  '라이언 구즈만,캐서린 맥코믹',
#  '김수로,오상철',
#  '샘 워싱턴,리암 니슨',
#  '리즈 위더스푼,크리스 파인',
#  '박보영,주원',
#  '주지훈,백윤식',
#  '샤를리즈 테론,크리스틴 스튜어트',
#  '고현정,유해진',
#  '제니퍼 로렌스,조쉬 허처슨',
#  '샘 워싱턴,엘리자베스 뱅크스',
#  '박용우,고아라',
#  '줄리아 로버츠,릴리 콜린스',
#  '조니 뎁,미쉘 파이퍼',
#  '조셉 고든 레빗,브루스 윌리스',
#  '밀라 요보비치,미셸 로드리게즈',
#  '송새벽,성동일',
#  '김명민,안성기',
#  '가이 피어스,매기 그레이스',
#  '실베스터 스탤론,브루스 윌리스',
#  '박한별,김지석',
#  '데인 드한,알렉스 러셀',
#  '벤자민 워커,도미닉 쿠퍼',
#  '김현수,노강민',
#  '장동건,장쯔이',
#  '리암 니슨,더못 멀로니',
#  '엄태웅,김현정',
#  '맷 데이먼,스칼렛 요한슨',
#  '페이지 오하라,로비 벤슨',
#  '박신양,김정태',
#  '톰 행크스,할리 베리',
#  '이완 맥그리거,나오미 왓츠',
#  '김래원,지대한',
#  '잭 니콜슨,페이 더너웨이',
#  '강필선',
#  '정연주',
#  '류승룡,박신혜',
#  '크리스 에반스,송강호',
#  '송강호,이정재',
#  '하정우,한석규',
#  '김수현,박기웅',
#  '송강호,김영애',
#  '하정우,이경영',
#  '설경구,정우성',
#  '브래드 피트,미레유 에노스',
#  '이정재,최민식',
#  '설경구,문소리',
#  '장혁,수애',
#  '크리스 헴스워스,톰 히들스턴',
#  '브루스 윌리스,존 말코비치',
#  '유오성,주진모',
#  '레이첼 맥아담스,도널 글리슨',
#  '제시 아이젠버그,마크 러팔로',
#  '설경구,엄지원',
#  '찰리 허냄,론 펄먼',
#  '여진구,김윤석',
#  '헨리 카빌,에이미 아담스',
#  '공유,박희순',
#  '마틴 프리먼,베네딕트 컴버배치',
#  '엄정화,김상경',
#  '이민기,김민희',
#  '이병헌,브루스 윌리스',
#  '빈 디젤,드웨인 존슨',
#  '손예진,김갑수',
#  '전도연,고수',
#  '황정민,유준상',
#  '한석규,이제훈',
#  '크리스 파인,칼 어번',
#  '톰 크루즈,모건 프리먼',
#  '레오나르도 디카프리오,캐리 뮬리건',
#  '브루스 윌리스,제이 코트니',
#  '신하균,이태리',
#  '서교,성동일',
#  '김강우,김효진',
#  '유아인,김해숙',
#  '맷 데이먼,조디 포스터',
#  '이시영,엄기준',
#  '니콜라스 홀트,테레사 팔머',
#  '우혜진,박해일',
#  '휴 잭맨,사나다 히로유키',
#  '최승현,한예리',
#  '니콜라스 홀트,이완 맥그리거',
#  '정재영,김옥빈',
#  '톰 크루즈,로자문드 파이크',
#  '김선아,마동석',
#  '로즈 번,패트릭 윌슨',
#  '릴리 콜린스,제이미 캠벨 바우어',
#  '채닝 테이텀,제이미 폭스',
#  '윌 스미스,제이든 스미스',
#  '김강우,김범',
#  '로건 레먼,알렉산드리아 다다리오',
#  '이시영,김영현',
#  '박성웅,우혜진',
#  '김아중,주원',
#  '서인국,이종석',
#  '임창정,안내상',
#  '조니 뎁,아미 해머',
#  '미아 와시코브스카,매튜 구드',
#  '제임스 프랭코,미쉘 윌리엄스',
#  '최강희,봉태규',
#  '성룡,권상우',
#  '실베스터 스탤론,아놀드 슈왈제네거',
#  '정경호,한성천',
#  '레오나르도 디카프리오,제이미 폭스',
#  '천정명,김민정',
#  '톰 행크스,캐서린 키너',
#  '이제훈,조진웅',
#  '애쉬튼 커처,조시 게드',
#  '테렌스 스탬프,바네사 레드그레이브',
#  '에단 호크,줄리 델피',
#  '양동근,주상욱',
#  '휴 잭맨,제이크 질렌할',
#  '이광수,송지효',
#  '제라드 버틀러,모건 프리먼',
#  '엄태웅,김민준',
#  '마동석,이승연',
#  '해리슨 포드,아사 버터필드',
#  '저스틴 팀버레이크,벤 애플렉',
#  '호와킨 피닉스,필립 세이모어 호프만',
#  '정재영,한지민',
#  '연정훈,이지훈',
#  '우혜영,박철민',
#  '잉그리드 서린,군넬 린드블롬',
#  '최민식,류승룡',
#  '김남길,손예진',
#  '심은경,나문희',
#  '황정민,김윤진',
#  '마크 월버그,제시카 고메즈',
#  '하정우,강동원',
#  '톰 크루즈,에밀리 블런트',
#  '휴 잭맨,제임스 맥어보이',
#  '최승현,신세경',
#  '앤디 서키스,게리 올드만',
#  '크리스 에반스,스칼렛 요한슨',
#  '현빈,정재영',
#  '정우성,안성기',
#  '이선균,조진웅',
#  '류승룡,유준상',
#  '딜런 오브라이언,카야 스코델라리오',
#  '조정석,신민아',
#  '리암 니슨,줄리안 무어',
#  '리차드 아미티지,사라 웨인 콜리스',
#  '러셀 크로우,엠마 왓슨',
#  '황정민,한혜진',
#  '스칼렛 요한슨,모건 프리먼',
#  '김우빈,김영철',
#  '벤 애플렉,로자먼드 파이크',
#  '박해일,유연석',
#  '박보영,이종석',
#  '송혜교,김승욱',
#  '김희애,고아성',
#  '레나 헤디,에바 그린',
#  '크리스찬 베일,조엘 에저튼',
#  '김윤석,박유천',
#  '송승헌,임지연',
#  '안젤리나 졸리,엘르 패닝',
#  '킷 해링턴,에밀리 브라우닝',
#  '브래드 피트,로건 레먼',
#  '루크 에반스,도미닉 쿠퍼',
#  '김강우,고창석',
#  '이정재,신하균',
#  '차태현,남상미',
#  '이진성,정재영',
#  '조엘 키나만,사무엘 L. 잭슨',
#  '김성균,조진웅',
#  '애나벨 월리스,워드 호튼',
#  '염정아,문정희',
#  '엄정화,문소리',
#  '쉐일린 우들리,안셀 엘고트',
#  '애런 존슨,브라이언 크랜스톤',
#  '조니 뎁,레베카 홀',
#  '홍수민,한석규',
#  '장동건,김민희',
#  '김다율(김아현),주원',
#  '장한새,이민기',
#  '레오나르도 디카프리오,매튜 매커너히',
#  '라이언 구즈만,브리아나 에비건',
#  '치웨텔 에지오포,마이클 패스벤더',
#  '강하늘,김소은',
#  '하지원,강예원',
#  '정우성,이솜',
#  '쉐일린 우들리,케이트 윈슬렛',
#  '사사키 노조미',
#  '메간 폭스,윌리엄 피츠너',
#  '설경구,박해일',
#  '이 동 길,차승원',
#  '크리스 파인,키이라 나이틀리',
#  '메릴 스트립,조니 뎁',
#  '윤계상,고준희',
#  '아론 에크하트,빌 나이',
#  '릴리 콜린스,샘 클라플린',
#  '카렌 길런,브렌튼 스웨이츠',
#  '피어스 브로스넌,올가 쿠릴렌코',
#  '리암 니슨,보이드 홀브룩',
#  '케빈 코스트너,앰버 허드',
#  '윤상현,송새벽',
#  '짐 캐리,토미 스나이더',
#  '프레데릭 벨,엘로디 퐁탕',
#  '마이클 더글라스,제리 페라라',
#  '김상경,문정희',
#  '성룡,유엽',
#  '리암 니슨,팜케 얀센',
#  '니콜 키드먼,벤 위쇼',
#  '조여정,클라라',
#  '브래들리 쿠퍼,시에나 밀러',
#  '잭 오코넬,도널 글리슨',
#  '장 가뱅,애니 지라르도',
#  '마크 러팔로,에단 호크',
#  '황정민,유아인',
#  '전지현,이정재',
#  '로버트 다우니 주니어,크리스 헴스워스',
#  '이병헌,조승우',
#  '콜린 퍼스,태런 에저튼',
#  '김무열,진구',
#  '김윤석,강동원',
#  '황정민,정우',
#  '맷 데이먼,제시카 차스테인',
#  '김명민,오달수',
#  '앤 해서웨이,로버트 드니로',
#  '아놀드 슈왈제네거,제이슨 클락',
#  '김우빈,이준호',
#  '김윤석,유해진',
#  '폴 러드,마이클 더글라스',
#  '해리슨 포드,마크 해밀',
#  '딜런 오브라이언,토마스 생스터',
#  '권상우,성동일',
#  '손현주,마동석',
#  '이민호,김래원',
#  '한효주,김대명',
#  '이승기,문채원',
#  '다니엘 크레이그,레아 세이두',
#  '베네딕트 컴버배치,키이라 나이틀리',
#  '드웨인 존슨,알렉산드리아 다다리오',
#  '김윤석,정우',
#  '손현주,엄지원',
#  '최민식,정만식',
#  '박해빛나,박근형',
#  '오상철,이선균',
#  '주지훈,김강우',
#  '벤 스틸러,로빈 윌리엄스',
#  '주원,유해진',
#  '엄정화,송승헌',
#  '하정우,하지원',
#  '김상경,김성균',
#  '스테파니 스콧,더못 멀로니',
#  '크리스 헴스워스,킬리언 머피',
#  '정재영,박보영',
#  '조정석,이미숙',
#  '설경구,여진구',
#  '휴 잭맨,샬토 코플리',
#  '김수미,정만식',
#  '진세연,홍종현',
#  '신하균,장혁',
#  '고아성,박성웅',
#  '이병헌,전도연',
#  '김남길,전도연',
#  '마일즈 텔러,케이트 마라',
#  '이민기,여진구',
#  '윤계상,유해진',
#  '박보영,엄지원',
#  '제이슨 클락,조슈 브롤린',
#  '윤계상,한예리',
#  '류승룡,배수지',
#  '밀라 쿠니스,채닝 테이텀',
#  '리암 니슨,조엘 킨나만',
#  '쉐일린 우들리,테오 제임스',
#  '조니 웨스턴,소피아 블랙 디엘리아',
#  '조지 클루니,휴 로리',
#  '톰 행크스,마크 라이런스',
#  '조셉 고든 레빗,벤 킹슬리',
#  '유승호,고아라',
#  '샐리 헤닝,모세 제이콥 스톰',
#  '오지호,최령',
#  '마이클 키튼,에드워드 노튼',
#  '소메타니 쇼타,후카츠 에리',
#  '휴 잭맨,가렛 헤드룬드',
#  '톰 하디,태런 에저튼',
#  '마크 월버그,세스 맥팔레인',
#  '제시 아이젠버그,크리스틴 스튜어트',
#  '에드 스크레인,론 샤바놀',
#  '러셀 크로우,올가 쿠릴렌코',
#  '류승범,고준희',
#  '데인 드한,로버트 패틴슨',
#  '잭 블랙,딜런 미네트',
#  '정우성,김하늘',
#  '루크 브레이시,에드가 라미레즈',
#  '레오나르도 디카프리오,톰 하디',
#  '공유,김정희',
#  '황정민,강동원',
#  '크리스 에반스,로버트 다우니 주니어',
#  '송강호,공유',
#  '하정우,배두나',
#  '김정철,이정재',
#  '곽도원,황정민',
#  '손예진,박해일',
#  '베네딕트 컴버배치,레이첼 맥아담스',
#  '에디 레드메인,콜린 파렐',
#  '라이언 레놀즈,모레나 바카린',
#  '조정석,도경수',
#  '제임스 맥어보이,마이클 패스벤더',
#  '에바 그린,사무엘 L. 잭슨',
#  '맷 데이먼,줄리아 스타일즈',
#  '닐 세티,빌 머레이',
#  '헨리 카빌,벤 애플렉',
#  '김혜수,마동석',
#  '유승호,조재현',
#  '베라 파미가,패트릭 윌슨',
#  '윌 스미스,자레드 레토',
#  '빌 풀만,리암 헴스워스',
#  '이제훈,김성균',
#  '베네딕트 컴버배치,마틴 프리먼',
#  '김명민,김상호',
#  '임수정,조정석',
#  '강하늘,박정민',
#  '트래비스 핌멜,벤 포스터',
#  '크리스 파인,사이먼 페그',
#  '서하늬,엄지원',
#  '김윤석,변요한',
#  '테레사 팔머,알리시아 벨라 베일리',
#  '김현빈,임시완',
#  '강예원,이상윤',
#  '제인 레비,딜런 미네트',
#  '김율호,차승원',
#  '에밀리아 클라크,샘 클라플린',
#  '덴젤 워싱턴,크리스 프랫',
#  '제라드 버틀러,니콜라이 코스터 왈도',
#  '알렉산더 스카스가드,마고 로비',
#  '이미연,최지우',
#  '르네 젤위거,콜린 퍼스',
#  '유지태,이정현',
#  '제라드 버틀러,아론 에크하트',
#  '수애,오달수',
#  '톰 행크스,펠리시티 존스',
#  '김정희,문채원',
#  '심은경,윤제문',
#  '톰 행크스,아론 에크하트',
#  '톰 크루즈,코비 스멀더스',
#  '펠리시티 존스,디에고 루나',
#  '제이슨 스타뎀,제시카 알바',
#  '멜리사 맥카시,크리스 헴스워스',
#  '강동원,신은수',
#  '한효주,유연석',
#  '윤여정,김고은',
#  '이성민,이희준',
#  '크리스찬 베일,스티브 카렐',
#  '크리스 헴스워스,샤를리즈 테론',
#  '메리 엘리자베스 윈스티드,존 굿맨',
#  '엘리자베스 리저,애너리즈 바쏘',
#  '류덕환,김동영',
#  '마이클 키튼,마크 러팔로',
#  '류덕환,조복래',
#  '도경수,김소현',
#  '메간 폭스,스티븐 아멜',
#  '태런 에저튼,폴 레이놀즈',
#  '조셉 파인즈,톰 펠튼',
#  '제니퍼 로렌스,브래들리 쿠퍼',
#  '오달수,윤제문',
#  '알 파치노,안소니 홉킨스',
#  '존 크랜신스키,파블로 쉬레이버',
#  '클로이 모레츠,닉 로빈슨',
#  '마크 라이런스,레베카 홀',
#  '브라이스 달라스 하워드,오크스 페글리',
#  '이드리스 엘바,리처드 매든',
#  '차태현,김유정',
#  '브래드 피트,마리옹 꼬띠아르',
#  '크리스 프랫,제니퍼 로렌스',
#  '마이클 매드슨,스텔라 매브',
#  '이수민,송강호',
#  '하정우,차태현',
#  '현빈,유해진',
#  '제이콥 배덜런,톰 홀랜드',
#  '황정민,김규백',
#  '김규백,박서준',
#  '콜린 퍼스,줄리안 무어',
#  '정우성,곽도원',
#  '이병헌,김윤석',
#  '톰 크루즈,소피아 부텔라',
#  '나문희,이제훈',
#  '톰 하디,마크 라이런스',
#  '크리스 프랫,조 샐다나',
#  '설경구,김남길',
#  '마크 월버그,안소니 홉킨스',
#  '이성민,조진웅',
#  '지창욱,심은경',
#  '정우,강하늘',
#  '이제훈,최희서',
#  '휴 잭맨,패트릭 스튜어트',
#  '갤 가돗,로빈 라이트',
#  '다니엘 칼루야,앨리슨 윌리암스',
#  '앤디 서키스,우디 해럴슨',
#  '스테파니 시그만,알리시아 벨라 베일리',
#  '벤 애플렉,갤 가돗',
#  '라이언 레놀즈,사무엘 L. 잭슨',
#  '톰 히들스턴,브리 라슨',
#  '제임스 맥어보이,안야 테일러 조이',
#  '이선균,안재홍',
#  '마동석,이동휘',
#  '강하늘,김무열',
#  '제시카 로테,이스라엘 브로우사드',
#  '강소백,장동건',
#  '최민식,곽도원',
#  '마이클 패스벤더,캘리 헤르난데스',
#  '염정아,박혁권',
#  '김옥빈,신하균',
#  '조진웅,신구',
#  '캐서린 윈닉,제라드 버틀러',
#  '마크 해밀,캐리 피셔',
#  '설경구,임시완',
#  '오웬 티그,빌 스카스가드',
#  '케네스 브래너,페넬로페 크루즈',
#  '이정재,여진구',
#  '안셀 엘고트,케빈 스페이시',
#  '휴 잭맨,잭 에프런',
#  '밀라 요보비치,알리 라터',
#  '스칼렛 요한슨,마이클 피트',
#  '윤제문,정소민',
#  '에이미 아담스,제레미 레너',
#  '맨디 무어,클레어 홀트',
#  '데인 드한,카라 델러비인',
#  '맷 데이먼,페드로 파스칼',
#  '빈 디젤,사무엘 L. 잭슨',
#  '김수현,성동일',
#  '타라지 P. 헨슨,옥타비아 스펜서',
#  '백윤식,성동일',
#  '임시완,진구',
#  '찰리 허냄,주드 로',
#  '톰 크루즈,도널 글리슨',
#  '손현주,장혁',
#  '조진웅,송승헌',
#  '마이클 패스벤더,마리옹 꼬띠아르',
#  '황인아,고수',
#  '진남수,이병헌',
#  '신하균,도경수',
#  '김래원,김해숙',
#  '틸다 스윈튼,제이크 질렌할',
#  '라이언 고슬링,해리슨 포드',
#  '키아누 리브스,이안 맥쉐인',
#  '김혜수,이선균',
#  '김남길,천우희',
#  '딜런 오브라이언,테일러 키취',
#  '제이미 도넌,다코타 존슨',
#  '앤드류 가필드,샘 워싱턴',
#  '고두심,김성균',
#  '데인 드한,제이슨 아이삭스',
#  '샤를리즈 테론,제임스 맥어보이',
#  '강예원,한채아']

# %%
list = []
for i, d in enumerate(actor_list):
#     print(d)
    if type(d) == str:
        a= d.split(',')[0:1:]

        print(a)
    list.append(a)
list
#         print(a.split('[]')
#         df_etc.iloc[i]['actor'] = ','.join(
#     else:
#         i, df_etc.iloc[i]
# df_etc = df_etc.drop('Maker', 1)
# df_etc.to_excel('./data/movie_etc.xlsx', encoding='utf-8')
# df_etc = df_etc.drop_duplicates(subset='movieNm', keep='first')
# df_etc
# Out:
# ['김윤석']
# ['아만다 사이프리드']
# ['차태현']
# ['설경구']
# ['로버트 다우니 주니어']
# ['해리슨 포드']
# ['브렌든 프레이저']
# ['크리스찬 베일']
# ['문소리']
# ['정재영']
# ['제임스 맥어보이']
# ['윌 스미스']
# ['리암 니슨']
# ['김민선']
# ['샤이아 라보프']
# ['다니엘 크레이그']
# ['한석규']
# ['손예진']
# ['수애']
# ['레이첼 빌슨']
# ['김명민']
# ['양조위']
# ['변희봉']
# ['소지섭']
# ['키아누 리브스']
# ['크리스틴 스튜어트']
# ['제리 사인펠드']
# ['이연걸']
# ['주지훈']
# ['스티븐 스트레이트']
# ['김하늘']
# ['사라 제시카 파커']
# ['선자 손']
# ['유덕화']
# ['차태현']
# ['휴 잭맨']
# ['천호진']
# ['차인표']
# ['짐 캐리']
# ['정지훈']
# ['이새별']
# ['유지태']
# ['하정우']
# ['조니 뎁']
# ['제라드 버틀러']
# ['카메론 디아즈']
# ['나탈리 포트만']
# ['프레디 하이모어']
# ['김수로']
# ['줄리안 무어']
# ['다니엘 크레이그']
# ['곽선영']
# ['레오나르도 디카프리오']
# ['이미숙']
# ['리지 캐플란']
# ['제이슨 스타뎀']
# ['홍희자']
# ['유해진']
# ['니콜라스 케이지']
# ['공효진']
# ['로리 홀든']
# ['조인성']
# ['김선아']
# ['장근석']
# ['에이미 아담스']
# ['손태영']
# ['전도연']
# ['이연걸']
# ['쿠도 유키']
# ['마크 웰버그']
# ['힐러리 스웽크']
# ['주성치']
# ['임창정']
# ['브래들리 쿠퍼']
# ['스티븐 파스퀄']
# ['이정재']
# ['잭 니콜슨']
# ['키아누 리브스']
# ['프레디 하이모어']
# ['봉태규']
# ['신현준']
# ['안성기']
# ['밀라 쿠니스']
# ['키이라 나이틀리']
# ['나문희']
# ['스캇 스피드맨']
# ['데이비드 듀코브니']
# ['캐서린 헤이글']
# ['가엘 가르시아 베르날']
# ['찰톤 헤스톤']
# ['다니엘 크레이그']
# ['니시지마 히데토시']
# ['무로이 시게루']
# ['최원균']
# ['제이슨 스타뎀']
# ['설경구']
# ['하정우']
# ['샤이아 라보프']
# ['샘 워싱턴']
# ['크리스찬 베일']
# ['김하늘']
# ['김윤석']
# ['다니엘 래드클리프']
# ['금성무']
# ['채닝 테이텀']
# ['한동학']
# ['강동원']
# ['송강호']
# ['하지원']
# ['벤 스틸러']
# ['로버트 패틴슨']
# ['톰 행크스']
# ['김성태']
# ['송요셉']
# ['톰 크루즈']
# ['엄태웅']
# ['브래드 피트']
# ['최경원']
# ['정준호']
# ['박용하']
# ['정지훈']
# ['임창정']
# ['휴 잭맨']
# ['이범수']
# ['김래원']
# ['로버트 다우니 주니어']
# ['데브 파텔']
# ['크리스 파인']
# ['니콜라스 케이지']
# ['한석규']
# ['제니퍼 코넬리']
# ['샬토 코플리']
# ['김강우']
# ['제라드 버틀러']
# ['브루스 윌리스']
# ['에릭 바나']
# ['정재영']
# ['크리스 에반스']
# ['권상우']
# ['빈 디젤']
# ['오연서']
# ['케이 파나베이커']
# ['엄태웅']
# ['서민균']
# ['제프리 딘 모건']
# ['브렌든 프레이저']
# ['정진영']
# ['안젤리나 졸리']
# ['고현정']
# ['시릴 라파엘리']
# ['베라 파미가']
# ['조니 뎁']
# ['랄프 파인즈']
# ['김강우']
# ['박해일']
# ['저스틴 채트윈']
# ['조니 뎁']
# ['윤계상']
# ['다코타 블루 리차드']
# ['존 트라볼타']
# ['브래드 피트']
# ['산드라 블록']
# ['김선영']
# ['밀라 요보비치']
# ['아일라 피셔']
# ['제라드 버틀러']
# ['카고 아이']
# ['정우성']
# ['바비 캠포']
# ['저스틴 롱']
# ['유진']
# ['남상미']
# ['우마 서먼']
# ['클라이브 오웬']
# ['윌 스미스']
# ['강혜정']
# ['오데뜨 유스트만']
# ['조쉬 하트넷']
# ['오웬 윌슨']
# ['제러드 파달렉키']
# ['오드리 토투']
# ['저스틴 롱']
# ['다니엘 데이 루이스']
# ['설경구']
# ['원빈']
# ['레오나르도 디카프리오']
# ['송강호']
# ['로버트 다우니 주니어']
# ['정재영']
# ['차승원']
# ['김윤진']
# ['김주혁']
# ['안젤리나 졸리']
# ['황정민']
# ['엄태웅']
# ['전도연']
# ['톰 크루즈']
# ['조니 뎁']
# ['강동원']
# ['이선균']
# ['제이크 질렌할']
# ['로건 레먼']
# ['이영수']
# ['이병헌']
# ['러셀 크로우']
# ['주진모']
# ['톰 행크스']
# ['황정민']
# ['잭슨 라스본']
# ['차태현']
# ['나문희']
# ['수애']
# ['밀라 요보비치']
# ['벤 반스']
# ['엄정화']
# ['임수정']
# ['김명민']
# ['마크 러팔로']
# ['김인권']
# ['지진희']
# ['안젤리나 졸리']
# ['에릭 벌포']
# ['김수로']
# ['리암 니슨']
# ['지현우']
# ['달이']
# ['박중훈']
# ['샤니 빈슨']
# ['정보석']
# ['오재균']
# ['맷 데이먼']
# ['김미소']
# ['아만다 사이프리드']
# ['김수로']
# ['니콜라스 케이지']
# ['심형래']
# ['제시 아이젠버그']
# ['엘리자베스 슈']
# ['줄리아 로버츠']
# ['임창정']
# ['김해숙']
# ['김정은']
# ['유덕화']
# ['덴젤 워싱턴']
# ['손병호']
# ['장동건']
# ['사라 제시카 파커']
# ['실베스터 스탤론']
# ['주윤발']
# ['존 트라볼타']
# ['산드라 블록']
# ['박희순']
# ['애쉬튼 커처']
# ['정우성']
# ['제이든 스미스']
# ['애드리언 브로디']
# ['에밀리 블런트']
# ['샤이아 라보프']
# ['메릴 스트립']
# ['신경선']
# ['밀라 요보비치']
# ['덴젤 워싱턴']
# ['윤정희']
# ['러셀 크로우']
# ['마크 월버그']
# ['엠마 톰슨']
# ['신하균']
# ['발리에리 르메르시']
# ['멜 깁슨']
# ['제프 브리지스']
# ['김윤진']
# ['이병헌']
# ['아마미 유키']
# ['조쉬 더하멜']
# ['박해일']
# ['유호정']
# ['김윤석']
# ['톰 크루즈']
# ['김명민']
# ['정유미']
# ['휴 잭맨']
# ['이안 맥쉐인']
# ['이새별']
# ['신하균']
# ['손예진']
# ['브라이언 콕스']
# ['송새벽']
# ['로즈 번']
# ['박희순']
# ['김수미']
# ['강신일']
# ['박용우']
# ['잭 블랙']
# ['정진영']
# ['스텔란 스카스가드']
# ['나탈리 포트만']
# ['드웨인 존슨']
# ['장동건']
# ['미키 루크']
# ['아론 에크하트']
# ['미셸 모나한']
# ['우혜진']
# ['윤하']
# ['소지섭']
# ['안젤라 랜스베리']
# ['박중훈']
# ['현빈']
# ['조승우']
# ['콜린 퍼스']
# ['황우슬혜']
# ['송강호']
# ['윤계상']
# ['정려원']
# ['김예론']
# ['로건 레먼']
# ['티모시 올리펀트']
# ['조나 힐']
# ['아만다 사이프리드']
# ['칼럼 블루']
# ['장근석']
# ['차태현']
# ['앤 해서웨이']
# ['크리스 에반스']
# ['조엘 코트니']
# ['정재영']
# ['이안 그루퍼드']
# ['니콜라스 케이지']
# ['황정민']
# ['임창정']
# ['맷 데이먼']
# ['아만다 사이프리드']
# ['공형진']
# ['라이언 필립']
# ['김갑수']
# ['윤은혜']
# ['공리']
# ['나탈리 포트만']
# ['데이비드 코에너']
# ['다니엘 크레이그']
# ['김주혁']
# ['벨렌 루에다']
# ['맷 데이먼']
# ['안성기']
# ['이민정']
# ['아누크 에메']
# ['클라크 게이블']
# ['오군여']
# ['로버트 레드포드']
# ['다니엘 크레이그']
# ['김윤석']
# ['이병헌']
# ['로버트 다우니 주니어']
# ['송중기']
# ['크리스찬 베일']
# ['앤드류 가필드']
# ['최민식']
# ['임수정']
# ['김명민']
# ['엄태웅']
# ['황정민']
# ['휴 잭맨']
# ['진구']
# ['정재영']
# ['조여정']
# ['마틴 프리먼']
# ['이선균']
# ['김윤진']
# ['다니엘 크레이그']
# ['리암 니슨']
# ['설경구']
# ['하지원']
# ['고수']
# ['하정우']
# ['프랑수아 클뤼제']
# ['임창정']
# ['송강호']
# ['류승범']
# ['강지환']
# ['박해일']
# ['김명민']
# ['박희순']
# ['콜린 파렐']
# ['정지훈']
# ['김강우']
# ['드웨인 존슨']
# ['소지섭']
# ['제레미 레너']
# ['조성현']
# ['이범수']
# ['유선']
# ['누미 라파스']
# ['라이언 구즈만']
# ['김수로']
# ['샘 워싱턴']
# ['리즈 위더스푼']
# ['박보영']
# ['주지훈']
# ['샤를리즈 테론']
# ['고현정']
# ['제니퍼 로렌스']
# ['샘 워싱턴']
# ['박용우']
# ['줄리아 로버츠']
# ['조니 뎁']
# ['조셉 고든 레빗']
# ['밀라 요보비치']
# ['송새벽']
# ['김명민']
# ['가이 피어스']
# ['실베스터 스탤론']
# ['박한별']
# ['데인 드한']
# ['벤자민 워커']
# ['김현수']
# ['장동건']
# ['리암 니슨']
# ['엄태웅']
# ['맷 데이먼']
# ['페이지 오하라']
# ['박신양']
# ['톰 행크스']
# ['이완 맥그리거']
# ['김래원']
# ['잭 니콜슨']
# ['강필선']
# ['정연주']
# ['류승룡']
# ['크리스 에반스']
# ['송강호']
# ['하정우']
# ['김수현']
# ['송강호']
# ['하정우']
# ['설경구']
# ['브래드 피트']
# ['이정재']
# ['설경구']
# ['장혁']
# ['크리스 헴스워스']
# ['브루스 윌리스']
# ['유오성']
# ['레이첼 맥아담스']
# ['제시 아이젠버그']
# ['설경구']
# ['찰리 허냄']
# ['여진구']
# ['헨리 카빌']
# ['공유']
# ['마틴 프리먼']
# ['엄정화']
# ['이민기']
# ['이병헌']
# ['빈 디젤']
# ['손예진']
# ['전도연']
# ['황정민']
# ['한석규']
# ['크리스 파인']
# ['톰 크루즈']
# ['레오나르도 디카프리오']
# ['브루스 윌리스']
# ['신하균']
# ['서교']
# ['김강우']
# ['유아인']
# ['맷 데이먼']
# ['이시영']
# ['니콜라스 홀트']
# ['우혜진']
# ['휴 잭맨']
# ['최승현']
# ['니콜라스 홀트']
# ['정재영']
# ['톰 크루즈']
# ['김선아']
# ['로즈 번']
# ['릴리 콜린스']
# ['채닝 테이텀']
# ['윌 스미스']
# ['김강우']
# ['로건 레먼']
# ['이시영']
# ['박성웅']
# ['김아중']
# ['서인국']
# ['임창정']
# ['조니 뎁']
# ['미아 와시코브스카']
# ['제임스 프랭코']
# ['최강희']
# ['성룡']
# ['실베스터 스탤론']
# ['정경호']
# ['레오나르도 디카프리오']
# ['천정명']
# ['톰 행크스']
# ['이제훈']
# ['애쉬튼 커처']
# ['테렌스 스탬프']
# ['에단 호크']
# ['양동근']
# ['휴 잭맨']
# ['이광수']
# ['제라드 버틀러']
# ['엄태웅']
# ['마동석']
# ['해리슨 포드']
# ['저스틴 팀버레이크']
# ['호와킨 피닉스']
# ['정재영']
# ['연정훈']
# ['우혜영']
# ['잉그리드 서린']
# ['최민식']
# ['김남길']
# ['심은경']
# ['황정민']
# ['마크 월버그']
# ['하정우']
# ['톰 크루즈']
# ['휴 잭맨']
# ['최승현']
# ['앤디 서키스']
# ['크리스 에반스']
# ['현빈']
# ['정우성']
# ['이선균']
# ['류승룡']
# ['딜런 오브라이언']
# ['조정석']
# ['리암 니슨']
# ['리차드 아미티지']
# ['러셀 크로우']
# ['황정민']
# ['스칼렛 요한슨']
# ['김우빈']
# ['벤 애플렉']
# ['박해일']
# ['박보영']
# ['송혜교']
# ['김희애']
# ['레나 헤디']
# ['크리스찬 베일']
# ['김윤석']
# ['송승헌']
# ['안젤리나 졸리']
# ['킷 해링턴']
# ['브래드 피트']
# ['루크 에반스']
# ['김강우']
# ['이정재']
# ['차태현']
# ['이진성']
# ['조엘 키나만']
# ['김성균']
# ['애나벨 월리스']
# ['염정아']
# ['엄정화']
# ['쉐일린 우들리']
# ['애런 존슨']
# ['조니 뎁']
# ['홍수민']
# ['장동건']
# ['김다율(김아현)']
# ['장한새']
# ['레오나르도 디카프리오']
# ['라이언 구즈만']
# ['치웨텔 에지오포']
# ['강하늘']
# ['하지원']
# ['정우성']
# ['쉐일린 우들리']
# ['사사키 노조미']
# ['메간 폭스']
# ['설경구']
# ['이 동 길']
# ['크리스 파인']
# ['메릴 스트립']
# ['윤계상']
# ['아론 에크하트']
# ['릴리 콜린스']
# ['카렌 길런']
# ['피어스 브로스넌']
# ['리암 니슨']
# ['케빈 코스트너']
# ['윤상현']
# ['짐 캐리']
# ['프레데릭 벨']
# ['마이클 더글라스']
# ['김상경']
# ['성룡']
# ['리암 니슨']
# ['니콜 키드먼']
# ['조여정']
# ['브래들리 쿠퍼']
# ['잭 오코넬']
# ['장 가뱅']
# ['마크 러팔로']
# ['황정민']
# ['전지현']
# ['로버트 다우니 주니어']
# ['이병헌']
# ['콜린 퍼스']
# ['김무열']
# ['김윤석']
# ['황정민']
# ['맷 데이먼']
# ['김명민']
# ['앤 해서웨이']
# ['아놀드 슈왈제네거']
# ['김우빈']
# ['김윤석']
# ['폴 러드']
# ['해리슨 포드']
# ['딜런 오브라이언']
# ['권상우']
# ['손현주']
# ['이민호']
# ['한효주']
# ['이승기']
# ['다니엘 크레이그']
# ['베네딕트 컴버배치']
# ['드웨인 존슨']
# ['김윤석']
# ['손현주']
# ['최민식']
# ['박해빛나']
# ['오상철']
# ['주지훈']
# ['벤 스틸러']
# ['주원']
# ['엄정화']
# ['하정우']
# ['김상경']
# ['스테파니 스콧']
# ['크리스 헴스워스']
# ['정재영']
# ['조정석']
# ['설경구']
# ['휴 잭맨']
# ['김수미']
# ['진세연']
# ['신하균']
# ['고아성']
# ['이병헌']
# ['김남길']
# ['마일즈 텔러']
# ['이민기']
# ['윤계상']
# ['박보영']
# ['제이슨 클락']
# ['윤계상']
# ['류승룡']
# ['밀라 쿠니스']
# ['리암 니슨']
# ['쉐일린 우들리']
# ['조니 웨스턴']
# ['조지 클루니']
# ['톰 행크스']
# ['조셉 고든 레빗']
# ['유승호']
# ['샐리 헤닝']
# ['오지호']
# ['마이클 키튼']
# ['소메타니 쇼타']
# ['휴 잭맨']
# ['톰 하디']
# ['마크 월버그']
# ['제시 아이젠버그']
# ['에드 스크레인']
# ['러셀 크로우']
# ['류승범']
# ['데인 드한']
# ['잭 블랙']
# ['정우성']
# ['루크 브레이시']
# ['레오나르도 디카프리오']
# ['공유']
# ['황정민']
# ['크리스 에반스']
# ['송강호']
# ['하정우']
# ['김정철']
# ['곽도원']
# ['손예진']
# ['베네딕트 컴버배치']
# ['에디 레드메인']
# ['라이언 레놀즈']
# ['조정석']
# ['제임스 맥어보이']
# ['에바 그린']
# ['맷 데이먼']
# ['닐 세티']
# ['헨리 카빌']
# ['김혜수']
# ['유승호']
# ['베라 파미가']
# ['윌 스미스']
# ['빌 풀만']
# ['이제훈']
# ['베네딕트 컴버배치']
# ['김명민']
# ['임수정']
# ['강하늘']
# ['트래비스 핌멜']
# ['크리스 파인']
# ['서하늬']
# ['김윤석']
# ['테레사 팔머']
# ['김현빈']
# ['강예원']
# ['제인 레비']
# ['김율호']
# ['에밀리아 클라크']
# ['덴젤 워싱턴']
# ['제라드 버틀러']
# ['알렉산더 스카스가드']
# ['이미연']
# ['르네 젤위거']
# ['유지태']
# ['제라드 버틀러']
# ['수애']
# ['톰 행크스']
# ['김정희']
# ['심은경']
# ['톰 행크스']
# ['톰 크루즈']
# ['펠리시티 존스']
# ['제이슨 스타뎀']
# ['멜리사 맥카시']
# ['강동원']
# ['한효주']
# ['윤여정']
# ['이성민']
# ['크리스찬 베일']
# ['크리스 헴스워스']
# ['메리 엘리자베스 윈스티드']
# ['엘리자베스 리저']
# ['류덕환']
# ['마이클 키튼']
# ['류덕환']
# ['도경수']
# ['메간 폭스']
# ['태런 에저튼']
# ['조셉 파인즈']
# ['제니퍼 로렌스']
# ['오달수']
# ['알 파치노']
# ['존 크랜신스키']
# ['클로이 모레츠']
# ['마크 라이런스']
# ['브라이스 달라스 하워드']
# ['이드리스 엘바']
# ['차태현']
# ['브래드 피트']
# ['크리스 프랫']
# ['마이클 매드슨']
# ['이수민']
# ['하정우']
# ['현빈']
# ['제이콥 배덜런']
# ['황정민']
# ['김규백']
# ['콜린 퍼스']
# ['정우성']
# ['이병헌']
# ['톰 크루즈']
# ['나문희']
# ['톰 하디']
# ['크리스 프랫']
# ['설경구']
# ['마크 월버그']
# ['이성민']
# ['지창욱']
# ['정우']
# ['이제훈']
# ['휴 잭맨']
# ['갤 가돗']
# ['다니엘 칼루야']
# ['앤디 서키스']
# ['스테파니 시그만']
# ['벤 애플렉']
# ['라이언 레놀즈']
# ['톰 히들스턴']
# ['제임스 맥어보이']
# ['이선균']
# ['마동석']
# ['강하늘']
# ['제시카 로테']
# ['강소백']
# ['최민식']
# ['마이클 패스벤더']
# ['염정아']
# ['김옥빈']
# ['조진웅']
# ['캐서린 윈닉']
# ['마크 해밀']
# ['설경구']
# ['오웬 티그']
# ['케네스 브래너']
# ['이정재']
# ['안셀 엘고트']
# ['휴 잭맨']
# ['밀라 요보비치']
# ['스칼렛 요한슨']
# ['윤제문']
# ['에이미 아담스']
# ['맨디 무어']
# ['데인 드한']
# ['맷 데이먼']
# ['빈 디젤']
# ['김수현']
# ['타라지 P. 헨슨']
# ['백윤식']
# ['임시완']
# ['찰리 허냄']
# ['톰 크루즈']
# ['손현주']
# ['조진웅']
# ['마이클 패스벤더']
# ['황인아']
# ['진남수']
# ['신하균']
# ['김래원']
# ['틸다 스윈튼']
# ['라이언 고슬링']
# ['키아누 리브스']
# ['김혜수']
# ['김남길']
# ['딜런 오브라이언']
# ['제이미 도넌']
# ['앤드류 가필드']
# ['고두심']
# ['데인 드한']
# ['샤를리즈 테론']
# ['강예원']
# [['김윤석'],
#  ['아만다 사이프리드'],
#  ['차태현'],
#  ['설경구'],
#  ['로버트 다우니 주니어'],
#  ['해리슨 포드'],
#  ['브렌든 프레이저'],
#  ['크리스찬 베일'],
#  ['문소리'],
#  ['정재영'],
#  ['제임스 맥어보이'],
#  ['윌 스미스'],
#  ['리암 니슨'],
#  ['김민선'],
#  ['샤이아 라보프'],
#  ['다니엘 크레이그'],
#  ['한석규'],
#  ['손예진'],
#  ['수애'],
#  ['레이첼 빌슨'],
#  ['김명민'],
#  ['양조위'],
#  ['변희봉'],
#  ['소지섭'],
#  ['키아누 리브스'],
#  ['크리스틴 스튜어트'],
#  ['제리 사인펠드'],
#  ['이연걸'],
#  ['주지훈'],
#  ['스티븐 스트레이트'],
#  ['김하늘'],
#  ['사라 제시카 파커'],
#  ['선자 손'],
#  ['유덕화'],
#  ['차태현'],
#  ['휴 잭맨'],
#  ['천호진'],
#  ['차인표'],
#  ['짐 캐리'],
#  ['정지훈'],
#  ['이새별'],
#  ['유지태'],
#  ['하정우'],
#  ['조니 뎁'],
#  ['제라드 버틀러'],
#  ['카메론 디아즈'],
#  ['나탈리 포트만'],
#  ['프레디 하이모어'],
#  ['김수로'],
#  ['줄리안 무어'],
#  ['다니엘 크레이그'],
#  ['곽선영'],
#  ['레오나르도 디카프리오'],
#  ['이미숙'],
#  ['리지 캐플란'],
#  ['제이슨 스타뎀'],
#  ['홍희자'],
#  ['유해진'],
#  ['니콜라스 케이지'],
#  ['공효진'],
#  ['로리 홀든'],
#  ['조인성'],
#  ['김선아'],
#  ['장근석'],
#  ['에이미 아담스'],
#  ['손태영'],
#  ['전도연'],
#  ['이연걸'],
#  ['쿠도 유키'],
#  ['마크 웰버그'],
#  ['힐러리 스웽크'],
#  ['주성치'],
#  ['임창정'],
#  ['브래들리 쿠퍼'],
#  ['스티븐 파스퀄'],
#  ['이정재'],
#  ['잭 니콜슨'],
#  ['키아누 리브스'],
#  ['프레디 하이모어'],
#  ['봉태규'],
#  ['신현준'],
#  ['안성기'],
#  ['밀라 쿠니스'],
#  ['키이라 나이틀리'],
#  ['나문희'],
#  ['스캇 스피드맨'],
#  ['데이비드 듀코브니'],
#  ['캐서린 헤이글'],
#  ['가엘 가르시아 베르날'],
#  ['찰톤 헤스톤'],
#  ['다니엘 크레이그'],
#  ['니시지마 히데토시'],
#  ['무로이 시게루'],
#  ['최원균'],
#  ['제이슨 스타뎀'],
#  ['설경구'],
#  ['하정우'],
#  ['샤이아 라보프'],
#  ['샘 워싱턴'],
#  ['크리스찬 베일'],
#  ['김하늘'],
#  ['김윤석'],
#  ['다니엘 래드클리프'],
#  ['금성무'],
#  ['채닝 테이텀'],
#  ['한동학'],
#  ['강동원'],
#  ['송강호'],
#  ['하지원'],
#  ['벤 스틸러'],
#  ['로버트 패틴슨'],
#  ['톰 행크스'],
#  ['김성태'],
#  ['송요셉'],
#  ['톰 크루즈'],
#  ['엄태웅'],
#  ['브래드 피트'],
#  ['최경원'],
#  ['정준호'],
#  ['박용하'],
#  ['정지훈'],
#  ['임창정'],
#  ['휴 잭맨'],
#  ['이범수'],
#  ['김래원'],
#  ['로버트 다우니 주니어'],
#  ['데브 파텔'],
#  ['크리스 파인'],
#  ['니콜라스 케이지'],
#  ['한석규'],
#  ['제니퍼 코넬리'],
#  ['샬토 코플리'],
#  ['김강우'],
#  ['제라드 버틀러'],
#  ['브루스 윌리스'],
#  ['에릭 바나'],
#  ['정재영'],
#  ['크리스 에반스'],
#  ['권상우'],
#  ['빈 디젤'],
#  ['오연서'],
#  ['케이 파나베이커'],
#  ['엄태웅'],
#  ['서민균'],
#  ['제프리 딘 모건'],
#  ['브렌든 프레이저'],
#  ['정진영'],
#  ['안젤리나 졸리'],
#  ['고현정'],
#  ['시릴 라파엘리'],
#  ['베라 파미가'],
#  ['조니 뎁'],
#  ['랄프 파인즈'],
#  ['김강우'],
#  ['박해일'],
#  ['저스틴 채트윈'],
#  ['조니 뎁'],
#  ['윤계상'],
#  ['다코타 블루 리차드'],
#  ['존 트라볼타'],
#  ['브래드 피트'],
#  ['산드라 블록'],
#  ['김선영'],
#  ['밀라 요보비치'],
#  ['아일라 피셔'],
#  ['제라드 버틀러'],
#  ['카고 아이'],
#  ['정우성'],
#  ['바비 캠포'],
#  ['저스틴 롱'],
#  ['유진'],
#  ['남상미'],
#  ['우마 서먼'],
#  ['클라이브 오웬'],
#  ['윌 스미스'],
#  ['강혜정'],
#  ['오데뜨 유스트만'],
#  ['조쉬 하트넷'],
#  ['오웬 윌슨'],
#  ['제러드 파달렉키'],
#  ['오드리 토투'],
#  ['저스틴 롱'],
#  ['다니엘 데이 루이스'],
#  ['설경구'],
#  ['원빈'],
#  ['레오나르도 디카프리오'],
#  ['송강호'],
#  ['로버트 다우니 주니어'],
#  ['정재영'],
#  ['차승원'],
#  ['김윤진'],
#  ['김주혁'],
#  ['안젤리나 졸리'],
#  ['황정민'],
#  ['엄태웅'],
#  ['전도연'],
#  ['톰 크루즈'],
#  ['조니 뎁'],
#  ['강동원'],
#  ['이선균'],
#  ['제이크 질렌할'],
#  ['로건 레먼'],
#  ['이영수'],
#  ['이병헌'],
#  ['러셀 크로우'],
#  ['주진모'],
#  ['톰 행크스'],
#  ['황정민'],
#  ['잭슨 라스본'],
#  ['차태현'],
#  ['나문희'],
#  ['수애'],
#  ['밀라 요보비치'],
#  ['벤 반스'],
#  ['엄정화'],
#  ['임수정'],
#  ['김명민'],
#  ['마크 러팔로'],
#  ['김인권'],
#  ['지진희'],
#  ['안젤리나 졸리'],
#  ['에릭 벌포'],
#  ['김수로'],
#  ['리암 니슨'],
#  ['지현우'],
#  ['달이'],
#  ['박중훈'],
#  ['샤니 빈슨'],
#  ['정보석'],
#  ['오재균'],
#  ['맷 데이먼'],
#  ['김미소'],
#  ['아만다 사이프리드'],
#  ['김수로'],
#  ['니콜라스 케이지'],
#  ['심형래'],
#  ['제시 아이젠버그'],
#  ['엘리자베스 슈'],
#  ['줄리아 로버츠'],
#  ['임창정'],
#  ['김해숙'],
#  ['김정은'],
#  ['유덕화'],
#  ['덴젤 워싱턴'],
#  ['손병호'],
#  ['장동건'],
#  ['사라 제시카 파커'],
#  ['실베스터 스탤론'],
#  ['주윤발'],
#  ['존 트라볼타'],
#  ['산드라 블록'],
#  ['박희순'],
#  ['애쉬튼 커처'],
#  ['정우성'],
#  ['제이든 스미스'],
#  ['애드리언 브로디'],
#  ['에밀리 블런트'],
#  ['샤이아 라보프'],
#  ['메릴 스트립'],
#  ['신경선'],
#  ['밀라 요보비치'],
#  ['덴젤 워싱턴'],
#  ['윤정희'],
#  ['러셀 크로우'],
#  ['마크 월버그'],
#  ['엠마 톰슨'],
#  ['신하균'],
#  ['발리에리 르메르시'],
#  ['멜 깁슨'],
#  ['제프 브리지스'],
#  ['김윤진'],
#  ['이병헌'],
#  ['아마미 유키'],
#  ['조쉬 더하멜'],
#  ['박해일'],
#  ['유호정'],
#  ['김윤석'],
#  ['톰 크루즈'],
#  ['김명민'],
#  ['정유미'],
#  ['휴 잭맨'],
#  ['이안 맥쉐인'],
#  ['이새별'],
#  ['신하균'],
#  ['손예진'],
#  ['브라이언 콕스'],
#  ['송새벽'],
#  ['로즈 번'],
#  ['박희순'],
#  ['김수미'],
#  ['강신일'],
#  ['박용우'],
#  ['잭 블랙'],
#  ['정진영'],
#  ['스텔란 스카스가드'],
#  ['나탈리 포트만'],
#  ['드웨인 존슨'],
#  ['장동건'],
#  ['미키 루크'],
#  ['아론 에크하트'],
#  ['미셸 모나한'],
#  ['우혜진'],
#  ['윤하'],
#  ['소지섭'],
#  ['안젤라 랜스베리'],
#  ['박중훈'],
#  ['현빈'],
#  ['조승우'],
#  ['콜린 퍼스'],
#  ['황우슬혜'],
#  ['송강호'],
#  ['윤계상'],
#  ['정려원'],
#  ['김예론'],
#  ['로건 레먼'],
#  ['티모시 올리펀트'],
#  ['조나 힐'],
#  ['아만다 사이프리드'],
#  ['칼럼 블루'],
#  ['장근석'],
#  ['차태현'],
#  ['앤 해서웨이'],
#  ['크리스 에반스'],
#  ['조엘 코트니'],
#  ['정재영'],
#  ['이안 그루퍼드'],
#  ['니콜라스 케이지'],
#  ['황정민'],
#  ['임창정'],
#  ['맷 데이먼'],
#  ['아만다 사이프리드'],
#  ['공형진'],
#  ['라이언 필립'],
#  ['김갑수'],
#  ['윤은혜'],
#  ['공리'],
#  ['나탈리 포트만'],
#  ['데이비드 코에너'],
#  ['다니엘 크레이그'],
#  ['김주혁'],
#  ['벨렌 루에다'],
#  ['맷 데이먼'],
#  ['안성기'],
#  ['이민정'],
#  ['아누크 에메'],
#  ['클라크 게이블'],
#  ['오군여'],
#  ['로버트 레드포드'],
#  ['다니엘 크레이그'],
#  ['김윤석'],
#  ['이병헌'],
#  ['로버트 다우니 주니어'],
#  ['송중기'],
#  ['크리스찬 베일'],
#  ['앤드류 가필드'],
#  ['최민식'],
#  ['임수정'],
#  ['김명민'],
#  ['엄태웅'],
#  ['황정민'],
#  ['휴 잭맨'],
#  ['진구'],
#  ['정재영'],
#  ['조여정'],
#  ['마틴 프리먼'],
#  ['이선균'],
#  ['김윤진'],
#  ['다니엘 크레이그'],
#  ['리암 니슨'],
#  ['설경구'],
#  ['하지원'],
#  ['고수'],
#  ['하정우'],
#  ['프랑수아 클뤼제'],
#  ['임창정'],
#  ['송강호'],
#  ['류승범'],
#  ['강지환'],
#  ['박해일'],
#  ['김명민'],
#  ['박희순'],
#  ['콜린 파렐'],
#  ['정지훈'],
#  ['김강우'],
#  ['드웨인 존슨'],
#  ['소지섭'],
#  ['제레미 레너'],
#  ['조성현'],
#  ['이범수'],
#  ['유선'],
#  ['누미 라파스'],
#  ['라이언 구즈만'],
#  ['김수로'],
#  ['샘 워싱턴'],
#  ['리즈 위더스푼'],
#  ['박보영'],
#  ['주지훈'],
#  ['샤를리즈 테론'],
#  ['고현정'],
#  ['제니퍼 로렌스'],
#  ['샘 워싱턴'],
#  ['박용우'],
#  ['줄리아 로버츠'],
#  ['조니 뎁'],
#  ['조셉 고든 레빗'],
#  ['밀라 요보비치'],
#  ['송새벽'],
#  ['김명민'],
#  ['가이 피어스'],
#  ['실베스터 스탤론'],
#  ['박한별'],
#  ['데인 드한'],
#  ['벤자민 워커'],
#  ['김현수'],
#  ['장동건'],
#  ['리암 니슨'],
#  ['엄태웅'],
#  ['맷 데이먼'],
#  ['페이지 오하라'],
#  ['박신양'],
#  ['톰 행크스'],
#  ['이완 맥그리거'],
#  ['김래원'],
#  ['잭 니콜슨'],
#  ['강필선'],
#  ['정연주'],
#  ['류승룡'],
#  ['크리스 에반스'],
#  ['송강호'],
#  ['하정우'],
#  ['김수현'],
#  ['송강호'],
#  ['하정우'],
#  ['설경구'],
#  ['브래드 피트'],
#  ['이정재'],
#  ['설경구'],
#  ['장혁'],
#  ['크리스 헴스워스'],
#  ['브루스 윌리스'],
#  ['유오성'],
#  ['레이첼 맥아담스'],
#  ['제시 아이젠버그'],
#  ['설경구'],
#  ['찰리 허냄'],
#  ['여진구'],
#  ['헨리 카빌'],
#  ['공유'],
#  ['마틴 프리먼'],
#  ['엄정화'],
#  ['이민기'],
#  ['이병헌'],
#  ['빈 디젤'],
#  ['손예진'],
#  ['전도연'],
#  ['황정민'],
#  ['한석규'],
#  ['크리스 파인'],
#  ['톰 크루즈'],
#  ['레오나르도 디카프리오'],
#  ['브루스 윌리스'],
#  ['신하균'],
#  ['서교'],
#  ['김강우'],
#  ['유아인'],
#  ['맷 데이먼'],
#  ['이시영'],
#  ['니콜라스 홀트'],
#  ['우혜진'],
#  ['휴 잭맨'],
#  ['최승현'],
#  ['니콜라스 홀트'],
#  ['정재영'],
#  ['톰 크루즈'],
#  ['김선아'],
#  ['로즈 번'],
#  ['릴리 콜린스'],
#  ['채닝 테이텀'],
#  ['윌 스미스'],
#  ['김강우'],
#  ['로건 레먼'],
#  ['이시영'],
#  ['박성웅'],
#  ['김아중'],
#  ['서인국'],
#  ['임창정'],
#  ['조니 뎁'],
#  ['미아 와시코브스카'],
#  ['제임스 프랭코'],
#  ['최강희'],
#  ['성룡'],
#  ['실베스터 스탤론'],
#  ['정경호'],
#  ['레오나르도 디카프리오'],
#  ['천정명'],
#  ['톰 행크스'],
#  ['이제훈'],
#  ['애쉬튼 커처'],
#  ['테렌스 스탬프'],
#  ['에단 호크'],
#  ['양동근'],
#  ['휴 잭맨'],
#  ['이광수'],
#  ['제라드 버틀러'],
#  ['엄태웅'],
#  ['마동석'],
#  ['해리슨 포드'],
#  ['저스틴 팀버레이크'],
#  ['호와킨 피닉스'],
#  ['정재영'],
#  ['연정훈'],
#  ['우혜영'],
#  ['잉그리드 서린'],
#  ['최민식'],
#  ['김남길'],
#  ['심은경'],
#  ['황정민'],
#  ['마크 월버그'],
#  ['하정우'],
#  ['톰 크루즈'],
#  ['휴 잭맨'],
#  ['최승현'],
#  ['앤디 서키스'],
#  ['크리스 에반스'],
#  ['현빈'],
#  ['정우성'],
#  ['이선균'],
#  ['류승룡'],
#  ['딜런 오브라이언'],
#  ['조정석'],
#  ['리암 니슨'],
#  ['리차드 아미티지'],
#  ['러셀 크로우'],
#  ['황정민'],
#  ['스칼렛 요한슨'],
#  ['김우빈'],
#  ['벤 애플렉'],
#  ['박해일'],
#  ['박보영'],
#  ['송혜교'],
#  ['김희애'],
#  ['레나 헤디'],
#  ['크리스찬 베일'],
#  ['김윤석'],
#  ['송승헌'],
#  ['안젤리나 졸리'],
#  ['킷 해링턴'],
#  ['브래드 피트'],
#  ['루크 에반스'],
#  ['김강우'],
#  ['이정재'],
#  ['차태현'],
#  ['이진성'],
#  ['조엘 키나만'],
#  ['김성균'],
#  ['애나벨 월리스'],
#  ['염정아'],
#  ['엄정화'],
#  ['쉐일린 우들리'],
#  ['애런 존슨'],
#  ['조니 뎁'],
#  ['홍수민'],
#  ['장동건'],
#  ['김다율(김아현)'],
#  ['장한새'],
#  ['레오나르도 디카프리오'],
#  ['라이언 구즈만'],
#  ['치웨텔 에지오포'],
#  ['강하늘'],
#  ['하지원'],
#  ['정우성'],
#  ['쉐일린 우들리'],
#  ['사사키 노조미'],
#  ['메간 폭스'],
#  ['설경구'],
#  ['이 동 길'],
#  ['크리스 파인'],
#  ['메릴 스트립'],
#  ['윤계상'],
#  ['아론 에크하트'],
#  ['릴리 콜린스'],
#  ['카렌 길런'],
#  ['피어스 브로스넌'],
#  ['리암 니슨'],
#  ['케빈 코스트너'],
#  ['윤상현'],
#  ['짐 캐리'],
#  ['프레데릭 벨'],
#  ['마이클 더글라스'],
#  ['김상경'],
#  ['성룡'],
#  ['리암 니슨'],
#  ['니콜 키드먼'],
#  ['조여정'],
#  ['브래들리 쿠퍼'],
#  ['잭 오코넬'],
#  ['장 가뱅'],
#  ['마크 러팔로'],
#  ['황정민'],
#  ['전지현'],
#  ['로버트 다우니 주니어'],
#  ['이병헌'],
#  ['콜린 퍼스'],
#  ['김무열'],
#  ['김윤석'],
#  ['황정민'],
#  ['맷 데이먼'],
#  ['김명민'],
#  ['앤 해서웨이'],
#  ['아놀드 슈왈제네거'],
#  ['김우빈'],
#  ['김윤석'],
#  ['폴 러드'],
#  ['해리슨 포드'],
#  ['딜런 오브라이언'],
#  ['권상우'],
#  ['손현주'],
#  ['이민호'],
#  ['한효주'],
#  ['이승기'],
#  ['다니엘 크레이그'],
#  ['베네딕트 컴버배치'],
#  ['드웨인 존슨'],
#  ['김윤석'],
#  ['손현주'],
#  ['최민식'],
#  ['박해빛나'],
#  ['오상철'],
#  ['주지훈'],
#  ['벤 스틸러'],
#  ['주원'],
#  ['엄정화'],
#  ['하정우'],
#  ['김상경'],
#  ['스테파니 스콧'],
#  ['크리스 헴스워스'],
#  ['정재영'],
#  ['조정석'],
#  ['설경구'],
#  ['휴 잭맨'],
#  ['김수미'],
#  ['진세연'],
#  ['신하균'],
#  ['고아성'],
#  ['이병헌'],
#  ['김남길'],
#  ['마일즈 텔러'],
#  ['이민기'],
#  ['윤계상'],
#  ['박보영'],
#  ['제이슨 클락'],
#  ['윤계상'],
#  ['류승룡'],
#  ['밀라 쿠니스'],
#  ['리암 니슨'],
#  ['쉐일린 우들리'],
#  ['조니 웨스턴'],
#  ['조지 클루니'],
#  ['톰 행크스'],
#  ['조셉 고든 레빗'],
#  ['유승호'],
#  ['샐리 헤닝'],
#  ['오지호'],
#  ['마이클 키튼'],
#  ['소메타니 쇼타'],
#  ['휴 잭맨'],
#  ['톰 하디'],
#  ['마크 월버그'],
#  ['제시 아이젠버그'],
#  ['에드 스크레인'],
#  ['러셀 크로우'],
#  ['류승범'],
#  ['데인 드한'],
#  ['잭 블랙'],
#  ['정우성'],
#  ['루크 브레이시'],
#  ['레오나르도 디카프리오'],
#  ['공유'],
#  ['황정민'],
#  ['크리스 에반스'],
#  ['송강호'],
#  ['하정우'],
#  ['김정철'],
#  ['곽도원'],
#  ['손예진'],
#  ['베네딕트 컴버배치'],
#  ['에디 레드메인'],
#  ['라이언 레놀즈'],
#  ['조정석'],
#  ['제임스 맥어보이'],
#  ['에바 그린'],
#  ['맷 데이먼'],
#  ['닐 세티'],
#  ['헨리 카빌'],
#  ['김혜수'],
#  ['유승호'],
#  ['베라 파미가'],
#  ['윌 스미스'],
#  ['빌 풀만'],
#  ['이제훈'],
#  ['베네딕트 컴버배치'],
#  ['김명민'],
#  ['임수정'],
#  ['강하늘'],
#  ['트래비스 핌멜'],
#  ['크리스 파인'],
#  ['서하늬'],
#  ['김윤석'],
#  ['테레사 팔머'],
#  ['김현빈'],
#  ['강예원'],
#  ['제인 레비'],
#  ['김율호'],
#  ['에밀리아 클라크'],
#  ['덴젤 워싱턴'],
#  ['제라드 버틀러'],
#  ['알렉산더 스카스가드'],
#  ['이미연'],
#  ['르네 젤위거'],
#  ['유지태'],
#  ['제라드 버틀러'],
#  ['수애'],
#  ['톰 행크스'],
#  ['김정희'],
#  ['심은경'],
#  ['톰 행크스'],
#  ['톰 크루즈'],
#  ['펠리시티 존스'],
#  ['제이슨 스타뎀'],
#  ['멜리사 맥카시'],
#  ['강동원'],
#  ['한효주'],
#  ['윤여정'],
#  ['이성민'],
#  ['크리스찬 베일'],
#  ['크리스 헴스워스'],
#  ['메리 엘리자베스 윈스티드'],
#  ['엘리자베스 리저'],
#  ['류덕환'],
#  ['마이클 키튼'],
#  ['류덕환'],
#  ['도경수'],
#  ['메간 폭스'],
#  ['태런 에저튼'],
#  ['조셉 파인즈'],
#  ['제니퍼 로렌스'],
#  ['오달수'],
#  ['알 파치노'],
#  ['존 크랜신스키'],
#  ['클로이 모레츠'],
#  ['마크 라이런스'],
#  ['브라이스 달라스 하워드'],
#  ['이드리스 엘바'],
#  ['차태현'],
#  ['브래드 피트'],
#  ['크리스 프랫'],
#  ['마이클 매드슨'],
#  ['이수민'],
#  ['하정우'],
#  ['현빈'],
#  ['제이콥 배덜런'],
#  ['황정민'],
#  ['김규백'],
#  ['콜린 퍼스'],
#  ['정우성'],
#  ['이병헌'],
#  ['톰 크루즈'],
#  ['나문희'],
#  ['톰 하디'],
#  ['크리스 프랫'],
#  ['설경구'],
#  ['마크 월버그'],
#  ['이성민'],
#  ['지창욱'],
#  ['정우'],
#  ['이제훈'],
#  ['휴 잭맨'],
#  ['갤 가돗'],
#  ['다니엘 칼루야'],
#  ['앤디 서키스'],
#  ['스테파니 시그만'],
#  ['벤 애플렉'],
#  ['라이언 레놀즈'],
#  ['톰 히들스턴'],
#  ['제임스 맥어보이'],
#  ['이선균'],
#  ['마동석'],
#  ['강하늘'],
#  ['제시카 로테'],
#  ['강소백'],
#  ['최민식'],
#  ['마이클 패스벤더'],
#  ['염정아'],
#  ['김옥빈'],
#  ['조진웅'],
#  ['캐서린 윈닉'],
#  ['마크 해밀'],
#  ['설경구'],
#  ['오웬 티그'],
#  ['케네스 브래너'],
#  ['이정재'],
#  ['안셀 엘고트'],
#  ['휴 잭맨'],
#  ['밀라 요보비치'],
#  ['스칼렛 요한슨'],
#  ['윤제문'],
#  ['에이미 아담스'],
#  ['맨디 무어'],
#  ['데인 드한'],
#  ['맷 데이먼'],
#  ['빈 디젤'],
#  ['김수현'],
#  ['타라지 P. 헨슨'],
#  ['백윤식'],
#  ['임시완'],
#  ['찰리 허냄'],
#  ['톰 크루즈'],
#  ['손현주'],
#  ['조진웅'],
#  ['마이클 패스벤더'],
#  ['황인아'],
#  ['진남수'],
#  ['신하균'],
#  ['김래원'],
#  ['틸다 스윈튼'],
#  ['라이언 고슬링'],
#  ['키아누 리브스'],
#  ['김혜수'],
#  ['김남길'],
#  ['딜런 오브라이언'],
#  ['제이미 도넌'],
#  ['앤드류 가필드'],
#  ['고두심'],
#  ['데인 드한'],
#  ['샤를리즈 테론'],
#  ['강예원']]

# %%
list = [item for sublist in list for item in sublist]

# %%
list
# Out:
# ['김윤석',
#  '아만다 사이프리드',
#  '차태현',
#  '설경구',
#  '로버트 다우니 주니어',
#  '해리슨 포드',
#  '브렌든 프레이저',
#  '크리스찬 베일',
#  '문소리',
#  '정재영',
#  '제임스 맥어보이',
#  '윌 스미스',
#  '리암 니슨',
#  '김민선',
#  '샤이아 라보프',
#  '다니엘 크레이그',
#  '한석규',
#  '손예진',
#  '수애',
#  '레이첼 빌슨',
#  '김명민',
#  '양조위',
#  '변희봉',
#  '소지섭',
#  '키아누 리브스',
#  '크리스틴 스튜어트',
#  '제리 사인펠드',
#  '이연걸',
#  '주지훈',
#  '스티븐 스트레이트',
#  '김하늘',
#  '사라 제시카 파커',
#  '선자 손',
#  '유덕화',
#  '차태현',
#  '휴 잭맨',
#  '천호진',
#  '차인표',
#  '짐 캐리',
#  '정지훈',
#  '이새별',
#  '유지태',
#  '하정우',
#  '조니 뎁',
#  '제라드 버틀러',
#  '카메론 디아즈',
#  '나탈리 포트만',
#  '프레디 하이모어',
#  '김수로',
#  '줄리안 무어',
#  '다니엘 크레이그',
#  '곽선영',
#  '레오나르도 디카프리오',
#  '이미숙',
#  '리지 캐플란',
#  '제이슨 스타뎀',
#  '홍희자',
#  '유해진',
#  '니콜라스 케이지',
#  '공효진',
#  '로리 홀든',
#  '조인성',
#  '김선아',
#  '장근석',
#  '에이미 아담스',
#  '손태영',
#  '전도연',
#  '이연걸',
#  '쿠도 유키',
#  '마크 웰버그',
#  '힐러리 스웽크',
#  '주성치',
#  '임창정',
#  '브래들리 쿠퍼',
#  '스티븐 파스퀄',
#  '이정재',
#  '잭 니콜슨',
#  '키아누 리브스',
#  '프레디 하이모어',
#  '봉태규',
#  '신현준',
#  '안성기',
#  '밀라 쿠니스',
#  '키이라 나이틀리',
#  '나문희',
#  '스캇 스피드맨',
#  '데이비드 듀코브니',
#  '캐서린 헤이글',
#  '가엘 가르시아 베르날',
#  '찰톤 헤스톤',
#  '다니엘 크레이그',
#  '니시지마 히데토시',
#  '무로이 시게루',
#  '최원균',
#  '제이슨 스타뎀',
#  '설경구',
#  '하정우',
#  '샤이아 라보프',
#  '샘 워싱턴',
#  '크리스찬 베일',
#  '김하늘',
#  '김윤석',
#  '다니엘 래드클리프',
#  '금성무',
#  '채닝 테이텀',
#  '한동학',
#  '강동원',
#  '송강호',
#  '하지원',
#  '벤 스틸러',
#  '로버트 패틴슨',
#  '톰 행크스',
#  '김성태',
#  '송요셉',
#  '톰 크루즈',
#  '엄태웅',
#  '브래드 피트',
#  '최경원',
#  '정준호',
#  '박용하',
#  '정지훈',
#  '임창정',
#  '휴 잭맨',
#  '이범수',
#  '김래원',
#  '로버트 다우니 주니어',
#  '데브 파텔',
#  '크리스 파인',
#  '니콜라스 케이지',
#  '한석규',
#  '제니퍼 코넬리',
#  '샬토 코플리',
#  '김강우',
#  '제라드 버틀러',
#  '브루스 윌리스',
#  '에릭 바나',
#  '정재영',
#  '크리스 에반스',
#  '권상우',
#  '빈 디젤',
#  '오연서',
#  '케이 파나베이커',
#  '엄태웅',
#  '서민균',
#  '제프리 딘 모건',
#  '브렌든 프레이저',
#  '정진영',
#  '안젤리나 졸리',
#  '고현정',
#  '시릴 라파엘리',
#  '베라 파미가',
#  '조니 뎁',
#  '랄프 파인즈',
#  '김강우',
#  '박해일',
#  '저스틴 채트윈',
#  '조니 뎁',
#  '윤계상',
#  '다코타 블루 리차드',
#  '존 트라볼타',
#  '브래드 피트',
#  '산드라 블록',
#  '김선영',
#  '밀라 요보비치',
#  '아일라 피셔',
#  '제라드 버틀러',
#  '카고 아이',
#  '정우성',
#  '바비 캠포',
#  '저스틴 롱',
#  '유진',
#  '남상미',
#  '우마 서먼',
#  '클라이브 오웬',
#  '윌 스미스',
#  '강혜정',
#  '오데뜨 유스트만',
#  '조쉬 하트넷',
#  '오웬 윌슨',
#  '제러드 파달렉키',
#  '오드리 토투',
#  '저스틴 롱',
#  '다니엘 데이 루이스',
#  '설경구',
#  '원빈',
#  '레오나르도 디카프리오',
#  '송강호',
#  '로버트 다우니 주니어',
#  '정재영',
#  '차승원',
#  '김윤진',
#  '김주혁',
#  '안젤리나 졸리',
#  '황정민',
#  '엄태웅',
#  '전도연',
#  '톰 크루즈',
#  '조니 뎁',
#  '강동원',
#  '이선균',
#  '제이크 질렌할',
#  '로건 레먼',
#  '이영수',
#  '이병헌',
#  '러셀 크로우',
#  '주진모',
#  '톰 행크스',
#  '황정민',
#  '잭슨 라스본',
#  '차태현',
#  '나문희',
#  '수애',
#  '밀라 요보비치',
#  '벤 반스',
#  '엄정화',
#  '임수정',
#  '김명민',
#  '마크 러팔로',
#  '김인권',
#  '지진희',
#  '안젤리나 졸리',
#  '에릭 벌포',
#  '김수로',
#  '리암 니슨',
#  '지현우',
#  '달이',
#  '박중훈',
#  '샤니 빈슨',
#  '정보석',
#  '오재균',
#  '맷 데이먼',
#  '김미소',
#  '아만다 사이프리드',
#  '김수로',
#  '니콜라스 케이지',
#  '심형래',
#  '제시 아이젠버그',
#  '엘리자베스 슈',
#  '줄리아 로버츠',
#  '임창정',
#  '김해숙',
#  '김정은',
#  '유덕화',
#  '덴젤 워싱턴',
#  '손병호',
#  '장동건',
#  '사라 제시카 파커',
#  '실베스터 스탤론',
#  '주윤발',
#  '존 트라볼타',
#  '산드라 블록',
#  '박희순',
#  '애쉬튼 커처',
#  '정우성',
#  '제이든 스미스',
#  '애드리언 브로디',
#  '에밀리 블런트',
#  '샤이아 라보프',
#  '메릴 스트립',
#  '신경선',
#  '밀라 요보비치',
#  '덴젤 워싱턴',
#  '윤정희',
#  '러셀 크로우',
#  '마크 월버그',
#  '엠마 톰슨',
#  '신하균',
#  '발리에리 르메르시',
#  '멜 깁슨',
#  '제프 브리지스',
#  '김윤진',
#  '이병헌',
#  '아마미 유키',
#  '조쉬 더하멜',
#  '박해일',
#  '유호정',
#  '김윤석',
#  '톰 크루즈',
#  '김명민',
#  '정유미',
#  '휴 잭맨',
#  '이안 맥쉐인',
#  '이새별',
#  '신하균',
#  '손예진',
#  '브라이언 콕스',
#  '송새벽',
#  '로즈 번',
#  '박희순',
#  '김수미',
#  '강신일',
#  '박용우',
#  '잭 블랙',
#  '정진영',
#  '스텔란 스카스가드',
#  '나탈리 포트만',
#  '드웨인 존슨',
#  '장동건',
#  '미키 루크',
#  '아론 에크하트',
#  '미셸 모나한',
#  '우혜진',
#  '윤하',
#  '소지섭',
#  '안젤라 랜스베리',
#  '박중훈',
#  '현빈',
#  '조승우',
#  '콜린 퍼스',
#  '황우슬혜',
#  '송강호',
#  '윤계상',
#  '정려원',
#  '김예론',
#  '로건 레먼',
#  '티모시 올리펀트',
#  '조나 힐',
#  '아만다 사이프리드',
#  '칼럼 블루',
#  '장근석',
#  '차태현',
#  '앤 해서웨이',
#  '크리스 에반스',
#  '조엘 코트니',
#  '정재영',
#  '이안 그루퍼드',
#  '니콜라스 케이지',
#  '황정민',
#  '임창정',
#  '맷 데이먼',
#  '아만다 사이프리드',
#  '공형진',
#  '라이언 필립',
#  '김갑수',
#  '윤은혜',
#  '공리',
#  '나탈리 포트만',
#  '데이비드 코에너',
#  '다니엘 크레이그',
#  '김주혁',
#  '벨렌 루에다',
#  '맷 데이먼',
#  '안성기',
#  '이민정',
#  '아누크 에메',
#  '클라크 게이블',
#  '오군여',
#  '로버트 레드포드',
#  '다니엘 크레이그',
#  '김윤석',
#  '이병헌',
#  '로버트 다우니 주니어',
#  '송중기',
#  '크리스찬 베일',
#  '앤드류 가필드',
#  '최민식',
#  '임수정',
#  '김명민',
#  '엄태웅',
#  '황정민',
#  '휴 잭맨',
#  '진구',
#  '정재영',
#  '조여정',
#  '마틴 프리먼',
#  '이선균',
#  '김윤진',
#  '다니엘 크레이그',
#  '리암 니슨',
#  '설경구',
#  '하지원',
#  '고수',
#  '하정우',
#  '프랑수아 클뤼제',
#  '임창정',
#  '송강호',
#  '류승범',
#  '강지환',
#  '박해일',
#  '김명민',
#  '박희순',
#  '콜린 파렐',
#  '정지훈',
#  '김강우',
#  '드웨인 존슨',
#  '소지섭',
#  '제레미 레너',
#  '조성현',
#  '이범수',
#  '유선',
#  '누미 라파스',
#  '라이언 구즈만',
#  '김수로',
#  '샘 워싱턴',
#  '리즈 위더스푼',
#  '박보영',
#  '주지훈',
#  '샤를리즈 테론',
#  '고현정',
#  '제니퍼 로렌스',
#  '샘 워싱턴',
#  '박용우',
#  '줄리아 로버츠',
#  '조니 뎁',
#  '조셉 고든 레빗',
#  '밀라 요보비치',
#  '송새벽',
#  '김명민',
#  '가이 피어스',
#  '실베스터 스탤론',
#  '박한별',
#  '데인 드한',
#  '벤자민 워커',
#  '김현수',
#  '장동건',
#  '리암 니슨',
#  '엄태웅',
#  '맷 데이먼',
#  '페이지 오하라',
#  '박신양',
#  '톰 행크스',
#  '이완 맥그리거',
#  '김래원',
#  '잭 니콜슨',
#  '강필선',
#  '정연주',
#  '류승룡',
#  '크리스 에반스',
#  '송강호',
#  '하정우',
#  '김수현',
#  '송강호',
#  '하정우',
#  '설경구',
#  '브래드 피트',
#  '이정재',
#  '설경구',
#  '장혁',
#  '크리스 헴스워스',
#  '브루스 윌리스',
#  '유오성',
#  '레이첼 맥아담스',
#  '제시 아이젠버그',
#  '설경구',
#  '찰리 허냄',
#  '여진구',
#  '헨리 카빌',
#  '공유',
#  '마틴 프리먼',
#  '엄정화',
#  '이민기',
#  '이병헌',
#  '빈 디젤',
#  '손예진',
#  '전도연',
#  '황정민',
#  '한석규',
#  '크리스 파인',
#  '톰 크루즈',
#  '레오나르도 디카프리오',
#  '브루스 윌리스',
#  '신하균',
#  '서교',
#  '김강우',
#  '유아인',
#  '맷 데이먼',
#  '이시영',
#  '니콜라스 홀트',
#  '우혜진',
#  '휴 잭맨',
#  '최승현',
#  '니콜라스 홀트',
#  '정재영',
#  '톰 크루즈',
#  '김선아',
#  '로즈 번',
#  '릴리 콜린스',
#  '채닝 테이텀',
#  '윌 스미스',
#  '김강우',
#  '로건 레먼',
#  '이시영',
#  '박성웅',
#  '김아중',
#  '서인국',
#  '임창정',
#  '조니 뎁',
#  '미아 와시코브스카',
#  '제임스 프랭코',
#  '최강희',
#  '성룡',
#  '실베스터 스탤론',
#  '정경호',
#  '레오나르도 디카프리오',
#  '천정명',
#  '톰 행크스',
#  '이제훈',
#  '애쉬튼 커처',
#  '테렌스 스탬프',
#  '에단 호크',
#  '양동근',
#  '휴 잭맨',
#  '이광수',
#  '제라드 버틀러',
#  '엄태웅',
#  '마동석',
#  '해리슨 포드',
#  '저스틴 팀버레이크',
#  '호와킨 피닉스',
#  '정재영',
#  '연정훈',
#  '우혜영',
#  '잉그리드 서린',
#  '최민식',
#  '김남길',
#  '심은경',
#  '황정민',
#  '마크 월버그',
#  '하정우',
#  '톰 크루즈',
#  '휴 잭맨',
#  '최승현',
#  '앤디 서키스',
#  '크리스 에반스',
#  '현빈',
#  '정우성',
#  '이선균',
#  '류승룡',
#  '딜런 오브라이언',
#  '조정석',
#  '리암 니슨',
#  '리차드 아미티지',
#  '러셀 크로우',
#  '황정민',
#  '스칼렛 요한슨',
#  '김우빈',
#  '벤 애플렉',
#  '박해일',
#  '박보영',
#  '송혜교',
#  '김희애',
#  '레나 헤디',
#  '크리스찬 베일',
#  '김윤석',
#  '송승헌',
#  '안젤리나 졸리',
#  '킷 해링턴',
#  '브래드 피트',
#  '루크 에반스',
#  '김강우',
#  '이정재',
#  '차태현',
#  '이진성',
#  '조엘 키나만',
#  '김성균',
#  '애나벨 월리스',
#  '염정아',
#  '엄정화',
#  '쉐일린 우들리',
#  '애런 존슨',
#  '조니 뎁',
#  '홍수민',
#  '장동건',
#  '김다율(김아현)',
#  '장한새',
#  '레오나르도 디카프리오',
#  '라이언 구즈만',
#  '치웨텔 에지오포',
#  '강하늘',
#  '하지원',
#  '정우성',
#  '쉐일린 우들리',
#  '사사키 노조미',
#  '메간 폭스',
#  '설경구',
#  '이 동 길',
#  '크리스 파인',
#  '메릴 스트립',
#  '윤계상',
#  '아론 에크하트',
#  '릴리 콜린스',
#  '카렌 길런',
#  '피어스 브로스넌',
#  '리암 니슨',
#  '케빈 코스트너',
#  '윤상현',
#  '짐 캐리',
#  '프레데릭 벨',
#  '마이클 더글라스',
#  '김상경',
#  '성룡',
#  '리암 니슨',
#  '니콜 키드먼',
#  '조여정',
#  '브래들리 쿠퍼',
#  '잭 오코넬',
#  '장 가뱅',
#  '마크 러팔로',
#  '황정민',
#  '전지현',
#  '로버트 다우니 주니어',
#  '이병헌',
#  '콜린 퍼스',
#  '김무열',
#  '김윤석',
#  '황정민',
#  '맷 데이먼',
#  '김명민',
#  '앤 해서웨이',
#  '아놀드 슈왈제네거',
#  '김우빈',
#  '김윤석',
#  '폴 러드',
#  '해리슨 포드',
#  '딜런 오브라이언',
#  '권상우',
#  '손현주',
#  '이민호',
#  '한효주',
#  '이승기',
#  '다니엘 크레이그',
#  '베네딕트 컴버배치',
#  '드웨인 존슨',
#  '김윤석',
#  '손현주',
#  '최민식',
#  '박해빛나',
#  '오상철',
#  '주지훈',
#  '벤 스틸러',
#  '주원',
#  '엄정화',
#  '하정우',
#  '김상경',
#  '스테파니 스콧',
#  '크리스 헴스워스',
#  '정재영',
#  '조정석',
#  '설경구',
#  '휴 잭맨',
#  '김수미',
#  '진세연',
#  '신하균',
#  '고아성',
#  '이병헌',
#  '김남길',
#  '마일즈 텔러',
#  '이민기',
#  '윤계상',
#  '박보영',
#  '제이슨 클락',
#  '윤계상',
#  '류승룡',
#  '밀라 쿠니스',
#  '리암 니슨',
#  '쉐일린 우들리',
#  '조니 웨스턴',
#  '조지 클루니',
#  '톰 행크스',
#  '조셉 고든 레빗',
#  '유승호',
#  '샐리 헤닝',
#  '오지호',
#  '마이클 키튼',
#  '소메타니 쇼타',
#  '휴 잭맨',
#  '톰 하디',
#  '마크 월버그',
#  '제시 아이젠버그',
#  '에드 스크레인',
#  '러셀 크로우',
#  '류승범',
#  '데인 드한',
#  '잭 블랙',
#  '정우성',
#  '루크 브레이시',
#  '레오나르도 디카프리오',
#  '공유',
#  '황정민',
#  '크리스 에반스',
#  '송강호',
#  '하정우',
#  '김정철',
#  '곽도원',
#  '손예진',
#  '베네딕트 컴버배치',
#  '에디 레드메인',
#  '라이언 레놀즈',
#  '조정석',
#  '제임스 맥어보이',
#  '에바 그린',
#  '맷 데이먼',
#  '닐 세티',
#  '헨리 카빌',
#  '김혜수',
#  '유승호',
#  '베라 파미가',
#  '윌 스미스',
#  '빌 풀만',
#  '이제훈',
#  '베네딕트 컴버배치',
#  '김명민',
#  '임수정',
#  '강하늘',
#  '트래비스 핌멜',
#  '크리스 파인',
#  '서하늬',
#  '김윤석',
#  '테레사 팔머',
#  '김현빈',
#  '강예원',
#  '제인 레비',
#  '김율호',
#  '에밀리아 클라크',
#  '덴젤 워싱턴',
#  '제라드 버틀러',
#  '알렉산더 스카스가드',
#  '이미연',
#  '르네 젤위거',
#  '유지태',
#  '제라드 버틀러',
#  '수애',
#  '톰 행크스',
#  '김정희',
#  '심은경',
#  '톰 행크스',
#  '톰 크루즈',
#  '펠리시티 존스',
#  '제이슨 스타뎀',
#  '멜리사 맥카시',
#  '강동원',
#  '한효주',
#  '윤여정',
#  '이성민',
#  '크리스찬 베일',
#  '크리스 헴스워스',
#  '메리 엘리자베스 윈스티드',
#  '엘리자베스 리저',
#  '류덕환',
#  '마이클 키튼',
#  '류덕환',
#  '도경수',
#  '메간 폭스',
#  '태런 에저튼',
#  '조셉 파인즈',
#  '제니퍼 로렌스',
#  '오달수',
#  '알 파치노',
#  '존 크랜신스키',
#  '클로이 모레츠',
#  '마크 라이런스',
#  '브라이스 달라스 하워드',
#  '이드리스 엘바',
#  '차태현',
#  '브래드 피트',
#  '크리스 프랫',
#  '마이클 매드슨',
#  '이수민',
#  '하정우',
#  '현빈',
#  '제이콥 배덜런',
#  '황정민',
#  '김규백',
#  '콜린 퍼스',
#  '정우성',
#  '이병헌',
#  '톰 크루즈',
#  '나문희',
#  '톰 하디',
#  '크리스 프랫',
#  '설경구',
#  '마크 월버그',
#  '이성민',
#  '지창욱',
#  '정우',
#  '이제훈',
#  '휴 잭맨',
#  '갤 가돗',
#  '다니엘 칼루야',
#  '앤디 서키스',
#  '스테파니 시그만',
#  '벤 애플렉',
#  '라이언 레놀즈',
#  '톰 히들스턴',
#  '제임스 맥어보이',
#  '이선균',
#  '마동석',
#  '강하늘',
#  '제시카 로테',
#  '강소백',
#  '최민식',
#  '마이클 패스벤더',
#  '염정아',
#  '김옥빈',
#  '조진웅',
#  '캐서린 윈닉',
#  '마크 해밀',
#  '설경구',
#  '오웬 티그',
#  '케네스 브래너',
#  '이정재',
#  '안셀 엘고트',
#  '휴 잭맨',
#  '밀라 요보비치',
#  '스칼렛 요한슨',
#  '윤제문',
#  '에이미 아담스',
#  '맨디 무어',
#  '데인 드한',
#  '맷 데이먼',
#  '빈 디젤',
#  '김수현',
#  '타라지 P. 헨슨',
#  '백윤식',
#  '임시완',
#  '찰리 허냄',
#  '톰 크루즈',
#  '손현주',
#  '조진웅',
#  '마이클 패스벤더',
#  '황인아',
#  '진남수',
#  '신하균',
#  '김래원',
#  '틸다 스윈튼',
#  '라이언 고슬링',
#  '키아누 리브스',
#  '김혜수',
#  '김남길',
#  '딜런 오브라이언',
#  '제이미 도넌',
#  '앤드류 가필드',
#  '고두심',
#  '데인 드한',
#  '샤를리즈 테론',
#  '강예원']

# %%
# def flatten(list):
#     result = []
#     for el in list:
#         if hasattr(el, "__iter__") and not isinstance(el, basestring): 
#             #스트링형이 아닌 이터러블의 경우 - 재귀한 후, extend
#             result.extend(flatten(el)) #재귀 호출
#         else:
#             #이터러블이 아니거나 스트링인 경우 - 그냥 append
#             result.append(el)
#     return result

# flatten(list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-70e9c820d09a> in <module>()
#      10     return result
#      11
# ---> 12 flatten(list)
#
# <ipython-input-46-70e9c820d09a> in flatten(list)
#       2     result = []
#       3     for el in list:
# ----> 4         if hasattr(el, "__iter__") and not isinstance(el, basestring):
#       5             #스트링형이 아닌 이터러블의 경우 - 재귀한 후, extend
#       6             result.extend(flatten(el)) #재귀 호출
#
# NameError: name 'basestring' is not defined

# %%
def get_actor_data(movie_list):
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/soap/people.json"
    params = {"key":"a37309d4545a0c715c2171adbda24a74", "peopleNm":list}
    r = requests.get(url, params=params)
    return r.json()

# %%
def make_actor_df(movie_list):
    actor_df = pd.DataFrame(columns = ["peopleNm",  "peopleCd", "filmoNames"])
    for i in list:
        try:
            for data in get_actor_data(i)['peopleListResult']['peopleList']:
                
                actor_df.loc[len(actor_df)] = [
                    data["peopleNm"],
                    data["peopleCd"],
                    data["filmoNames"]
                    
                

                 
                ]
        except:
            i
    return actor_df

# %%
a = make_actor_df(list)

# %%
a
# Out:
# Empty DataFrame
# Columns: [peopleNm, peopleCd, filmoNames]
# Index: []
