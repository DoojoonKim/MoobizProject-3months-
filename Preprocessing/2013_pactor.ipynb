# %%
dict = {'류승룡': 30,
' 박신혜': 11,
'송강호': 34,
' 이정재': 32,
'로버트 다우니 주니어': 38,
' 기네스 팰트로': 33,
'크리스 에반스': 20,
' 송강호': 34,
'하정우': 36,
' 한석규': 25,
'김수현': 3,
' 박기웅': 9,
' 김영애': 48,
'손현주': 15,
' 문정희': 23,
' 이경영': 80,
'설경구': 42,
' 정우성': 33,
'브래드 피트': 35,
' 미레유 에노스': 3,
'이정재': 32,
' 최민식': 30,
'박신양': 15,
' 김정태': 25,
' 문소리': 40,
'산드라 블록': 32,
' 조지 클루니': 31,
' 손예진': 21,
'장혁': 8,
' 수애': 11,
'크리스 헴스워스': 16,
' 나탈리 포트만': 26,
'브루스 윌리스': 65,
' 이병헌': 38,
'유오성': 20,
' 주진모': 27,
'도널 글리슨': 9,
' 레이첼 맥아담스': 20,
'제시 아이젠버그': 21,
' 마크 러팔로': 30,
'휴 잭맨': 26,
' 앤 해서웨이': 27,
' 엄지원': 20,
'찰리 허냄': 9,
' 론 펄먼': 26,
'김윤석': 30,
' 여진구': 8,
'베라 파미가': 13,
' 패트릭 윌슨': 21,
'헨리 카빌': 8,
' 에이미 아담스': 21,
'공유': 13,
' 박희순': 36,
'마틴 프리먼': 15,
' 이안 맥켈런': 18,
'엄정화': 21,
' 김상경': 14,
'이민기': 12,
' 김민희': 17,
'이병헌': 38,
' 브루스 윌리스': 65,
'빈 디젤': 22,
' 드웨인 존슨': 27,
'손예진': 21,
' 김갑수': 13,
'전도연': 20,
' 고수': 13,
'황정민': 37,
' 유준상': 26,
'한석규': 25,
' 이제훈': 17,
'크리스 파인': 16,
' 재커리 퀸토': 9,
'톰 크루즈': 38,
' 모건 프리먼': 54,
'레오나르도 디카프리오': 24,
' 캐리 멀리건': 9,
' 제이 코트니': 6,
'신하균': 30,
' 이태리': 8,
'성동일': 32,
' 서교': 4,
'김강우': 23,
' 김효진': 1,
'맷 데이먼': 45,
' 조디 포스터': 19,
'유아인': 14,
' 김해숙': 44,
'이시영': 10,
' 엄기준': 2,
'니콜라스 홀트': 16,
' 테레사 팔머': 10,
'박해일': 31,
' 윤제문': 42,
'제니퍼 로렌스': 19,
' 조쉬 허처슨': 17,
'T.O.P': 7,
' 한예리': 29,
'김인권': 31,
' 류현경': 24,
' 이완 맥그리거': 52,
'정재영': 1,
' 최다니엘': 6,
' 오연수': 8,
' 로자먼드 파이크': 13,
'고수': 13,
' 한효주': 13,
'김선아': 1,
' 온주완': 11,
'이완 맥그리거': 52,
' 나오미 왓츠': 39,
'로즈 번': 2,
'릴리 콜린스': 7,
' 제이미 캠벨 바우어': 5,
'채닝 테이텀': 25,
' 제이미 폭스': 23,
'윌 스미스': 22,
' 제이든 스미스': 3,
' 김범': 1,
'로건 레먼': 11,
'알렉산드리아 다다리오': 5,
' 오정세': 62,
'저스틴 롱': 20,
' 찰리 로우': 1,
'성준': 10,
' 이수혁': 3,
'김아중': 9,
' 주원': 1,
'서인국': 1,
' 이종석': 6,
'톰 행크스': 40,
' 휴 그랜트': 27,
'임창정': 29,
' 안내상': 19,
'조니 뎁': 43,
' 아미 해머': 12,
'미아 와시코브스카': 15,
' 매튜 구드': 11,
'제임스 프랭코': 40,
' 미쉘 윌리엄스': 23,
'최강희': 11,
' 봉태규': 13,
'성룡': 1,
' 권상우': 18,
'아놀드 슈왈제네거': 30,
' 실베스터 스탤론': 33,
'정경호': 27,
' 한성천': 2,
'제이미 폭스': 23,
' 크리스토프 왈츠': 13,
'김민정': 18,
' 천정명': 9,
'캐서린 키너': 25,
'애쉬튼 커처': 16,
' 조시 게드': 10,
'이제훈': 17,
' 조진웅': 45,
'테렌스 스탬프': 11,
' 바네사 레드그레이브': 15,
'이안 맥켈런': 18,
' 마틴 프리먼': 15,
'에단 호크': 41,
' 줄리 델피': 17,
'양동근': 16,
' 주상욱': 8,
' 제이크 질렌할': 28,
'김래원': 15,
' 이성민': 23,
'제라드 버틀러': 30,
'': 1,
'엄태웅': 13,
' 김민준': 0,
'마동석': 35,
' 이승연': 6,
'해리슨 포드': 39,
' 아사 버터필드': 7,
'저스틴 팀버레이크': 12,
' 벤 애플렉': 35}

# %%
movies = {'7번방의 선물': ['류승룡', ' 박신혜'],
'관상': ['송강호', ' 이정재'],
'아이언맨 3': ['로버트 다우니 주니어', ' 기네스 팰트로'],
'설국열차': ['크리스 에반스', ' 송강호'],
'베를린': ['하정우', ' 한석규'],
'은밀하게 위대하게': ['김수현', ' 박기웅'],
'변호인': ['송강호', ' 김영애'],
'숨바꼭질': ['손현주', ' 문정희'],
'더 테러 라이브': ['하정우', ' 이경영'],
'감시자들': ['설경구', ' 정우성'],
'월드 워 Z': ['브래드 피트', ' 미레유 에노스'],
'신세계': ['이정재', ' 최민식'],
'박수건달': ['박신양', ' 김정태'],
'스파이': ['설경구', ' 문소리'],
'그래비티': ['산드라 블록', ' 조지 클루니'],
'타워': ['설경구', ' 손예진'],
'감기': ['장혁', ' 수애'],
'토르: 다크 월드': ['크리스 헴스워스', ' 나탈리 포트만'],
'레드: 더 레전드': ['브루스 윌리스', ' 이병헌'],
'친구 2': ['유오성', ' 주진모'],
'어바웃 타임': ['도널 글리슨', ' 레이첼 맥아담스'],
'나우 유 씨 미 : 마술사기단': ['제시 아이젠버그', ' 마크 러팔로'],
'레미제라블': ['휴 잭맨', ' 앤 해서웨이'],
'소원': ['설경구', ' 엄지원'],
'퍼시픽 림': ['찰리 허냄', ' 론 펄먼'],
'화이: 괴물을 삼킨 아이': ['김윤석', ' 여진구'],
'컨저링': ['베라 파미가', ' 패트릭 윌슨'],
'맨 오브 스틸': ['헨리 카빌', ' 에이미 아담스'],
'용의자': ['공유', ' 박희순'],
'호빗: 스마우그의 폐허': ['마틴 프리먼', ' 이안 맥켈런'],
'몽타주': ['엄정화', ' 김상경'],
'연애의 온도': ['이민기', ' 김민희'],
'지.아이.조 2': ['이병헌', ' 브루스 윌리스'],
'분노의 질주: 더 맥시멈': ['빈 디젤', ' 드웨인 존슨'],
'공범': ['손예진', ' 김갑수'],
'집으로 가는 길': ['전도연', ' 고수'],
'전설의 주먹': ['황정민', ' 유준상'],
'파파로티': ['한석규', ' 이제훈'],
'스타트렉 다크니스': ['크리스 파인', ' 재커리 퀸토'],
'오블리비언': ['톰 크루즈', ' 모건 프리먼'],
'위대한 개츠비': ['레오나르도 디카프리오', ' 캐리 멀리건'],
'다이하드: 굿 데이 투 다이': ['브루스 윌리스', ' 제이 코트니'],
'런닝맨': ['신하균', ' 이태리'],
'미스터 고': ['성동일', ' 서교'],
'결혼전야': ['김강우', ' 김효진'],
'엘리시움': ['맷 데이먼', ' 조디 포스터'],
'깡철이': ['유아인', ' 김해숙'],
'더 웹툰: 예고살인': ['이시영', ' 엄기준'],
'웜 바디스': ['니콜라스 홀트', ' 테레사 팔머'],
'고령화 가족': ['박해일', ' 윤제문'],
'헝거게임: 캣칭 파이어': ['제니퍼 로렌스', ' 조쉬 허처슨'],
'더 울버린': ['휴 잭맨'],
'동창생': ['T.O.P', ' 한예리'],
'전국노래자랑': ['김인권', ' 류현경'],
'잭 더 자이언트 킬러': ['니콜라스 홀트', ' 이완 맥그리거'],
'열한시': ['정재영', ' 최다니엘'],
'남쪽으로 튀어': ['김윤석', ' 오연수'],
'잭 리처': ['톰 크루즈', ' 로자먼드 파이크'],
'반창꼬': ['고수', ' 한효주'],
'더 파이브': ['김선아', ' 온주완'],
'더 임파서블': ['이완 맥그리거', ' 나오미 왓츠'],
'인시디어스: 두번째 집': ['로즈 번', ' 패트릭 윌슨'],
'섀도우 헌터스: 뼈의 도시': ['릴리 콜린스', ' 제이미 캠벨 바우어'],
'화이트 하우스 다운': ['채닝 테이텀', ' 제이미 폭스'],
'애프터 어스': ['윌 스미스', ' 제이든 스미스'],
'사이코메트리': ['김강우', ' 김범'],
'퍼시 잭슨과 괴물의 바다': ['로건 레먼'],
'남자사용설명서': ['이시영', ' 오정세'],
'다이노소어 어드벤처 3D': ['저스틴 롱', ' 찰리 로우'],
'무서운 이야기 2': ['성준', ' 이수혁'],
'캐치미': ['김아중', ' 주원'],
'노브레싱': ['서인국', ' 이종석'],
'클라우드 아틀라스': ['톰 행크스', ' 휴 그랜트'],
'창수': ['임창정', ' 안내상'],
'론 레인저': ['조니 뎁', ' 아미 해머'],
'스토커': ['미아 와시코브스카', ' 매튜 구드'],
'오즈 그레이트 앤드 파워풀': ['제임스 프랭코', ' 미쉘 윌리엄스'],
'미나문방구': ['최강희', ' 봉태규'],
'차이니즈 조디악': ['성룡', ' 권상우'],
'이스케이프 플랜': ['아놀드 슈왈제네거', ' 실베스터 스탤론'],
'롤러코스터': ['정경호', ' 한성천'],
'장고:분노의 추적자': ['제이미 폭스', ' 크리스토프 왈츠'],
'밤의 여왕': ['김민정', ' 천정명'],
'캡틴 필립스': ['톰 행크스'],
'잡스': [' 조시 게드'],
'분노의 윤리학': ['이제훈', ' 조진웅'],
'송 포 유': ['테렌스 스탬프', ' 바네사 레드그레이브'],
'호빗: 뜻밖의 여정': ['이안 맥켈런', ' 마틴 프리먼'],
'비포 미드나잇': ['에단 호크', ' 줄리 델피'],
'응징자': ['양동근', ' 주상욱'],
'프리즈너스': ['휴 잭맨', ' 제이크 질렌할'],
'마이 리틀 히어로': ['김래원', ' 이성민'],
'백악관 최후의 날': ['제라드 버틀러', ' 모건 프리먼'],
'톱스타': ['엄태웅', ' 김민준'],
'노리개': ['마동석', ' 이승연'],
'엔더스 게임': ['해리슨 포드'],
'히든 카드': ['저스틴 팀버레이크', ' 벤 애플렉']}

# %%
movie_actors = {}
for movie,actors in movies.items() :
    try :
        if len(actors) == 2  :
            movie_actors[movie] = (dict[actors[0]]+dict[actors[1]])/2
        if len(actors) == 1  :
            movie_actors[movie] = dict[actors[0]]
    except :
        print(movie)

# %%
movie_actors
# Out:
# {'7번방의 선물': 20.5,
#  '관상': 33.0,
#  '아이언맨 3': 35.5,
#  '설국열차': 27.0,
#  '베를린': 30.5,
#  '은밀하게 위대하게': 6.0,
#  '변호인': 41.0,
#  '숨바꼭질': 19.0,
#  '더 테러 라이브': 58.0,
#  '감시자들': 37.5,
#  '월드 워 Z': 19.0,
#  '신세계': 31.0,
#  '박수건달': 20.0,
#  '스파이': 41.0,
#  '그래비티': 31.5,
#  '타워': 31.5,
#  '감기': 9.5,
#  '토르: 다크 월드': 21.0,
#  '레드: 더 레전드': 51.5,
#  '친구 2': 23.5,
#  '어바웃 타임': 14.5,
#  '나우 유 씨 미 : 마술사기단': 25.5,
#  '레미제라블': 26.5,
#  '소원': 31.0,
#  '퍼시픽 림': 17.5,
#  '화이: 괴물을 삼킨 아이': 19.0,
#  '컨저링': 17.0,
#  '맨 오브 스틸': 14.5,
#  '용의자': 24.5,
#  '호빗: 스마우그의 폐허': 16.5,
#  '몽타주': 17.5,
#  '연애의 온도': 14.5,
#  '지.아이.조 2': 51.5,
#  '분노의 질주: 더 맥시멈': 24.5,
#  '공범': 17.0,
#  '집으로 가는 길': 16.5,
#  '전설의 주먹': 31.5,
#  '파파로티': 21.0,
#  '스타트렉 다크니스': 12.5,
#  '오블리비언': 46.0,
#  '위대한 개츠비': 16.5,
#  '다이하드: 굿 데이 투 다이': 35.5,
#  '런닝맨': 19.0,
#  '미스터 고': 18.0,
#  '결혼전야': 12.0,
#  '엘리시움': 32.0,
#  '깡철이': 29.0,
#  '더 웹툰: 예고살인': 6.0,
#  '웜 바디스': 13.0,
#  '고령화 가족': 36.5,
#  '헝거게임: 캣칭 파이어': 18.0,
#  '더 울버린': 26,
#  '동창생': 18.0,
# ...

# %%
len(movie_actors)
# Out:
# 97

# %%
dict = movie_actors

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'pactor' })
df.to_csv( './data_2013/2013_pactor', sep=',', encoding='utf-8' )
