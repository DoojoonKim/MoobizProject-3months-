# %%
dict = {'부산행': '647',
 '검사외전': '89',
 '캡틴 아메리카: 시빌 워': '171',
 '밀정': '555',
 '터널': '496',
 '인천상륙작전': '488',
 '럭키': '367',
 '곡성': '521',
 '덕혜옹주': '490',
 '닥터 스트레인지': '102',
 '마스터': '757',
 '신비한 동물사전': '0',
 '판도라': '622',
 '아가씨': '830',
 '귀향': '244',
 '데드풀': '55',
 '나우 유 씨 미 2': '0',
 '형': '802',
 '엑스맨: 아포칼립스': '72',
 '미스 페레그린과 이상한 아이들의 집': '0',
 '히말라야': '506',
 '제이슨 본': '404',
 '아수라': '872',
 '정글북': '58',
 '라라랜드': '41',
 '배트맨 대 슈퍼맨: 저스티스의 시작': '0',
 '굿바이 싱글': '527',
 '봉이 김선달': '312',
 '레버넌트: 죽음에서 돌아온 자': '0',
 '컨저링 2': '94',
 '내부자들: 디 오리지널': '35',
 '수어사이드 스쿼드': '75',
 '인디펜던스 데이 : 리써전스': '41',
 '탐정 홍길동: 사라진 마을': '0',
 '벤허': '64',
 '셜록: 유령신부': '38',
 '특별수사: 사형수의 편지': '0',
 '시간이탈자': '239',
 '동주': '234',
 '워크래프트: 전쟁의 서막': '0',
 '스타트렉 비욘드': '249',
 '미씽: 사라진 여자': '0',
 '당신, 거기 있어줄래요': '1',
 '라이트 아웃': '4',
 '오빠생각': '321',
 '날, 보러와요': '18,891',
 '맨 인 더 다크': '0',
 '고산자, 대동여지도': '345',
 '미 비포 유': '12',
 '매그니피센트 7': '300',
 '갓 오브 이집트': '7',
 '레전드 오브 타잔': '17',
 '좋아해줘': '5',
 '브리짓 존스의 베이비': '0',
 '스플릿': '404',
 '런던 해즈 폴른': '20',
 '국가대표 2': '81',
 '인페르노': '17',
 '그날의 분위기': '233',
 '사냥': '327',
 '널 기다리며': '0',
 '설리: 허드슨강의 기적': '0',
 '잭 리처: 네버 고 백': '39',
 '로그 원: 스타워즈 스토리': '67',
 '메카닉: 리크루트': '15',
 '고스트버스터즈': '0',
 '거울나라의 앨리스': '23',
 '가려진 시간': '0',
 '해어화': '358',
 '계춘할망': '419',
 '로봇, 소리': '2,115',
 '스타워즈: 깨어난 포스': '0',
 '빅쇼트': '19',
 '헌츠맨: 윈터스 워': '0',
 '나를 잊지 말아요': '0',
 '조선마술사': '320',
 '언더 워터': '7',
 '클로버필드 10번지': '9',
 '위자: 저주의 시작': '5',
 '위대한 소원': '0',
 '스포트라이트': '57',
 '구스범스': '9',
 '포인트 브레이크': '26',
 '혼숨': '16',
 '비밀은 없다': '0',
 '닌자터틀 : 어둠의 히어로': '0',
 '순정': '293',
 '독수리 에디': '32',
 '남과 여': '6',
 '대호': '309',
 '부활': '105',
 '조이': '128',
 '대배우': '40',
 '미스컨덕트': '2',
 '13시간': '23',
 '제 5침공': '0',
 '마이 리틀 자이언트': '6',
 '피터와 드래곤': '0',
 '다이버전트 시리즈: 얼리전트': '0',
 '바스티유 데이': '9'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'news' })
df
# Out:
#                    news
# 13시간                 23
# 가려진 시간                0
# 갓 오브 이집트              7
# 거울나라의 앨리스            23
# 검사외전                 89
# 계춘할망                419
# 고산자, 대동여지도          345
# 고스트버스터즈               0
# 곡성                  521
# 구스범스                  9
# 국가대표 2               81
# 굿바이 싱글              527
# 귀향                  244
# 그날의 분위기             233
# 나를 잊지 말아요             0
# 나우 유 씨 미 2            0
# 날, 보러와요          18,891
# 남과 여                  6
# 내부자들: 디 오리지널         35
# 널 기다리며                0
# 닌자터틀 : 어둠의 히어로        0
# 다이버전트 시리즈: 얼리전트       0
# 닥터 스트레인지            102
# 당신, 거기 있어줄래요          1
# 대배우                  40
# 대호                  309
# 덕혜옹주                490
# 데드풀                  55
# 독수리 에디               32
# 동주                  234
# ...                 ...
# 언더 워터                 7
# 엑스맨: 아포칼립스           72
# 오빠생각                321
# 워크래프트: 전쟁의 서막         0
# 위대한 소원                0
# 위자: 저주의 시작            5
# ...

# %%
df.to_csv('./data_2016/2016_news')
