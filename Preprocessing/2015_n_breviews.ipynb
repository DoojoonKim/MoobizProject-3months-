# %%
dict = {'베테랑': 117,
'암살': 236,
'어벤져스: 에이지 오브 울트론': 209,
'국제시장': 214,
'내부자들': 391,
'사도': 112,
'미션 임파서블: 로그네이션': 25,
'킹스맨 : 시크릿 에이전트': 27,
'연평해전': 368,
'쥬라기 월드': 117,
'검은 사제들': 132,
'히말라야': 159,
'마션': 50,
'조선명탐정 : 사라진 놉의 딸': 89,
'매드 맥스: 분노의 도로': 57,
'인턴': 13,
'분노의 질주: 더 세븐': 35,
'터미네이터 제니시스': 476,
'스물': 111,
'극비수사': 45,
'앤트맨': 55,
'스타워즈: 깨어난 포스': 108,
'메이즈 러너: 스코치 트라이얼': 96,
'탐정 : 더 비기닝': 107,
'스파이': 81,
'악의 연대기': 63,
'강남 1970': 131,
'뷰티 인사이드': 1449,
'오늘의 연애': 97,
'테이큰 3': 89,
'007 스펙터': 33,
'이미테이션 게임': 89,
'샌 안드레아스': 65,
'쎄시봉': 6403,
'더 폰': 76,
'대호': 158,
'차이나타운': 51,
'장수상회': 93,
'성난 변호사': 86,
'간신': 185,
'박물관이 살아있다 : 비밀의 무덤': 21,
'그놈이다': 30,
'미쓰 와이프': 153,
'허삼관': 118,
'살인의뢰': 64,
'손님': 63,
'인시디어스 3': 41,
'하트 오브 더 씨': 28,
'헝거게임: 더 파이널': 56,
'기술자들': 168,
'신데렐라': 34,
'픽셀': 35,
'열정같은소리하고있네': 52,
'특종: 량첸살인기': 84,
'서부전선': 265,
'채피': 47,
'헬머니': 90,
'위험한 상견례 2': 59,
'순수의 시대': 56,
'협녀, 칼의 기억': 579,
'오피스': 91,
'무뢰한': 19,
'판타스틱 4': 370,
'내 심장을 쏴라': 53,
'소수의견': 414,
'그레이의 50가지 그림자': 87,
'경성학교: 사라진 소녀들': 43,
'치외법권': 67,
'아메리칸 스나이퍼': 20,
'에베레스트': 22,
'호빗: 다섯 군대 전투': 57,
'극적인 하룻밤': 19,
'도리화가': 283,
'주피터 어센딩': 51,
'패딩턴': 9,
'런 올 나이트': 25,
'인서전트': 43,
'백 투 더 비기닝': 49,
'투모로우랜드': 22,
'스파이 브릿지': 30,
'함정': 86,
'언브로큰': 13,
'하늘을 걷는 남자': 18,
'조선마술사': 124,
'언프렌디드: 친구삭제': 33,
'연애의 맛': 17,
'버드맨': 540,
'기생수 파트1': 99,
'팬': 22,
'더 셰프': 45,
'레전드': 8,
'19곰 테드 2': 13,
'인터스텔라': 52,
'아메리칸 울트라': 52,
'트랜스포터: 리퓰드': 150,
'워킹걸': 2186,
'은밀한 유혹': 42,
'워터 디바이너': 17,
'나의 절친 악당들': 39}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'n_breviews' })
df.to_csv( './data_2015/2015_n_breviews', sep=',', encoding='utf-8' )
