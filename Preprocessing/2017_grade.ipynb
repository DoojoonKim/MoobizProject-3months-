# %%
grade = {'택시운전사': '8.50',
'신과함께-죄와 벌': '8.04',
'공조': '8.51',
'스파이더맨: 홈 커밍': '9.12',
'범죄도시': '9.28',
'군함도': '8.54',
'청년경찰': '8.77',
'더 킹': '8.54',
'미녀와 야수': '8.80',
'킹스맨: 골든 서클': '8.98',
'토르: 라그나로크': '9.40',
'꾼': '7.47',
'강철비': '7.48',
'남한산성': '8.27',
'미이라': '9.02',
'분노의 질주: 더 익스트림': '9.50',
'아이 캔 스피크': '9.33',
'캐리비안의 해적: 죽은 자는 말이 없다': '9.58',
'프리즌': '9.08',
'덩케르크': '9.22',
'가디언즈 오브 갤럭시 VOL. 2': '9.38',
'살인자의 기억법': '7.94',
'트랜스포머: 최후의 기사': '8.10',
'보안관': '8.29',
'조작된 도시': '8.92',
'재심': '9.31',
'박열': '9.15',
'마스터': '8.58',
'원더 우먼': '8.51',
'겟 아웃': '8.22',
'로건': '9.09',
'혹성탈출: 종의 전쟁': '9.13',
'1987': '7.55',
'애나벨 : 인형의 주인': '8.24',
'노무현입니다': '8.35',
'저스티스 리그': '8.05',
'킬러의 보디가드': '9.36',
'콩: 스컬 아일랜드': '8.44',
'23 아이덴티티': '8.64',
'임금님의 사건수첩': '8.62',
'부라더': '9.11',
'기억의 밤': '9.25',
'해피 데스데이': '9.21',
'브이아이피': '8.26',
'특별시민': '8.61',
'에이리언: 커버넌트': '9.27',
'장산범': '8.24',
'악녀': '7.45',
'해빙': '9.16',
'라라랜드': '9.12',
'하루': '8.09',
'지오스톰': '8.37',
'스타워즈: 라스트 제다이': '8.62',
'불한당: 나쁜 놈들의 세상': '8.74',
'그것': '8.86',
'오리엔트 특급 살인': '9.00',
'대립군': '9.08',
'베이비 드라이버': '9.09',
'위대한 쇼맨': '9.61',
'레지던트 이블: 파멸의 날': '8.19',
'공각기동대 : 고스트 인 더 쉘': '8.14',
'패신저스': '8.94',
'아빠는 딸': '9.11',
'컨택트': '7.73',
'47 미터': '8.16',
'얼라이드': '9.16',
'발레리안: 천 개 행성의 도시': '8.35',
'그레이트 월': '8.02',
'침묵': '8.79',
'트리플 엑스 리턴즈': '9.31',
'리얼': '8.15',
'라이프': '8.13',
'히든 피겨스': '9.45',
'반드시 잡는다': '8.45',
'원라인': '9.01',
'로그 원: 스타워즈 스토리': '8.80',
'킹 아서: 제왕의 검': '8.52',
'아메리칸 메이드': '8.92',
'보통사람': '9.23',
'대장 김창수': '6.69',
'어쌔신 크리드': '8.92',
'플립': '9.44',
'석조저택 살인사건': '8.78',
'싱글라이더': '8.56',
'7호실': '9.03',
'사랑하기 때문에': '9.05',
'희생부활자': '8.88',
'옥자': '7.65',
'블레이드 러너 2049': '8.97',
'존 윅 - 리로드': '9.24',
'판도라': '8.13',
'미옥': '8.36',
'어느날': '9.20',
'어쌔신: 더 비기닝': '9.22',
'50가지 그림자: 심연': '8.28',
'핵소 고지': '8.98',
'채비': '9.47',
'더 큐어': '9.27',
'아토믹 블론드': '9.02',
'비정규직 특수요원': '8.30'}

# %%
import pandas as pd
df = pd.DataFrame([grade])
df = df.T
df = df.rename(columns = { 0 : 'grade' })
df
# Out:
#                       grade
# 1987                   7.55
# 23 아이덴티티               8.64
# 47 미터                  8.16
# 50가지 그림자: 심연           8.28
# 7호실                    9.03
# 가디언즈 오브 갤럭시 VOL. 2     9.38
# 강철비                    7.48
# 겟 아웃                   8.22
# 공각기동대 : 고스트 인 더 쉘      8.14
# 공조                     8.51
# 군함도                    8.54
# 그것                     8.86
# 그레이트 월                 8.02
# 기억의 밤                  9.25
# 꾼                      7.47
# 남한산성                   8.27
# 노무현입니다                 8.35
# 대립군                    9.08
# 대장 김창수                 6.69
# 더 큐어                   9.27
# 더 킹                    8.54
# 덩케르크                   9.22
# 라라랜드                   9.12
# 라이프                    8.13
# 레지던트 이블: 파멸의 날         8.19
# 로건                     9.09
# 로그 원: 스타워즈 스토리         8.80
# 리얼                     8.15
# 마스터                    8.58
# 미녀와 야수                 8.80
# ...                     ...
# 재심                     9.31
# ...

# %%
df.to_csv( './data_2017/2017_grade', sep=',', encoding='utf-8' )
