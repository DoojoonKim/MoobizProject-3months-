# %%
dict = {'공유': 13,
' 정유미': 31,
'황정민': 37,
' 강동원': 21,
'크리스 에반스': 20,
' 로버트 다우니 주니어': 38,
'송강호': 34,
' 공유': 13,
'하정우': 36,
' 배두나': 20,
'이정재': 32,
' 이범수': 42,
'유해진': 53,
' 이준': 5,
'곽도원': 19,
' 황정민': 37,
'손예진': 21,
' 박해일': 31,
'베네딕트 컴버배치': 21,
' 레이첼 맥아담스': 20,
'이병헌': 38,
'에디 레드메인': 9,
' 조니 뎁': 43,
'김남길': 15,
' 김주현': 1,
'김민희': 17,
' 김태리': 8,
'강하나': 2,
' 최리': 4,
'라이언 레이놀즈': 32,
'제시 아이젠버그': 21,
' 마크 러팔로': 30,
'조정석': 11,
' 디오': 8,
'제임스 맥어보이': 26,
' 마이클 패스벤더': 25,
'에바 그린': 13,
'아사 버터필드': 7,
' 정우': 36,
'맷 데이먼': 45,
' 알리시아 비칸데르': 16,
'정우성': 33,
'닐 세티': 1,
' 빌 머레이': 23,
'라이언 고슬링': 21,
' 엠마 스톤': 18,
'헨리 카빌': 8,
' 벤 애플렉': 35,
'김혜수': 35,
' 마동석': 35,
'유승호': 12,
' 조재현': 29,
'레오나르도 디카프리오': 24,
' 톰 하디': 18,
'베라 파미가': 13,
' 패트릭 윌슨': 21,
' 조승우': 19,
'윌 스미스': 22,
' 자레드 레토': 8,
'빌 풀만': 20,
' 리암 헴스워스': 12,
'이제훈': 17,
' 김성균': 24,
'잭 휴스턴': 4,
' 모건 프리먼': 54,
' 마틴 프리먼': 15,
'김명민': 19,
' 김상호': 42,
'임수정': 15,
' 조정석': 11,
'강하늘': 13,
' 박정민': 2,
'트래비스 핌멜': 3,
' 벤 포스터': 14,
'크리스 파인': 16,
' 사이먼 페그': 22,
'엄지원': 20,
' 공효진': 23,
'김윤석': 30,
' 변요한': 8,
'테레사 팔머': 10,
' 알리시아 벨라 베일리': 3,
'임시완': 6,
' 고아성': 10,
'강예원': 14,
' 이상윤': 3,
'제인 레비': 4,
' 딜런 미네트': 2,
'차승원': 28,
' 유준상': 26,
'에밀리아 클라크': 4,
' 샘 클라플린': 7,
'덴젤 워싱턴': 31,
' 크리스 프랫': 12,
'제라드 버틀러': 30,
' 니콜라이 코스터 왈도': 6,
'알렉산더 스카스가드': 9,
' 사무엘 L. 잭슨': 72,
'이미연': 23,
' 최지우': 7,
'르네 젤위거': 25,
' 콜린 퍼스': 39,
'유지태': 26,
' 이정현': 1,
' 아론 에크하트': 23,
'수애': 11,
' 오달수': 59,
'톰 행크스': 40,
' 펠리시티 존스': 13,
'문채원': 7,
' 유연석': 19,
'안성기': 99,
' 조진웅': 45,
'심은경': 18,
' 윤제문': 42,
'로라 린니': 21,
'톰 크루즈': 38,
' 코비 스멀더스': 6,
'펠리시티 존스': 13,
' 디에고 루나': 10,
'제이슨 스타뎀': 33,
' 제시카 알바': 30,
'멜리사 맥카시': 6,
' 크리스틴 위그': 12,
'조니 뎁': 43,
' 앤 해서웨이': 27,
'강동원': 21,
' 신은수': 3,
'한효주': 13,
'윤여정': 30,
' 김고은': 6,
'이성민': 23,
' 이희준': 30,
'데이지 리들리': 2,
' 존 보예가': 3,
'크리스찬 베일': 26,
' 스티브 카렐': 23,
'크리스 헴스워스': 16,
' 샤를리즈 테론': 32,
' 김하늘': 17,
' 고아라': 6,
'블레이크 라이블리': 12,
'메리 엘리자베스 윈스티드': 10,
' 존 굿맨': 38,
'엘리자베스 리저': 3,
' 애너리즈 바쏘': 2,
'류덕환': 21,
' 김동영': 18,
'마크 러팔로': 30,
'잭 블랙': 26,
'루크 브레이시': 3,
' 에드가 라미레즈': 9,
' 조복래': 15,
' 김주혁': 22,
'메간 폭스': 10,
' 스티븐 아멜': 1,
'디오': 8,
' 김소현': 6,
'태런 에저튼': 8,
' 휴 잭맨': 26,
'전도연': 20,
'최민식': 30,
'조셉 파인즈': 20,
' 톰 펠튼': 8,
'제니퍼 로렌스': 19,
' 브래들리 쿠퍼': 22,
'오달수': 59,
'알 파치노': 36,
' 안소니 홉킨스': 47,
'존 크랜신스키': 9,
' 제임스 뱃지 데일': 5,
'클로이 모레츠': 16,
' 닉 로빈슨': 2,
'마크 라이런스': 6,
'레베카 홀': 14,
'브라이스 달라스 하워드': 8,
' 오크스 페글리': 3,
'쉐일린 우들리': 7,
' 테오 제임스': 8,
'이드리스 엘바': 19,
'리처드 매든': 2}

# %%
movies = {'부산행': ['공유', ' 정유미'],
'검사외전': ['황정민', ' 강동원'],
'캡틴 아메리카: 시빌 워': ['크리스 에반스', ' 로버트 다우니 주니어'],
'밀정': ['송강호', ' 공유'],
'터널': ['하정우', ' 배두나'],
'인천상륙작전': ['이정재', ' 이범수'],
'럭키': ['유해진', ' 이준'],
'곡성': ['곽도원', ' 황정민'],
'덕혜옹주': ['손예진', ' 박해일'],
'닥터 스트레인지': ['베네딕트 컴버배치', ' 레이첼 맥아담스'],
'마스터': ['이병헌', ' 강동원'],
'신비한 동물사전': ['에디 레드메인', ' 조니 뎁'],
'판도라': ['김남길', ' 김주현'],
'아가씨': ['김민희', ' 김태리'],
'귀향': ['강하나', ' 최리'],
'데드풀': ['라이언 레이놀즈'],
'나우 유 씨 미 2': ['제시 아이젠버그', ' 마크 러팔로'],
'형': ['조정석', ' 디오'],
'엑스맨: 아포칼립스': ['제임스 맥어보이', ' 마이클 패스벤더'],
'미스 페레그린과 이상한 아이들의 집': ['에바 그린'],
'히말라야': ['황정민', ' 정우'],
'제이슨 본': ['맷 데이먼', ' 알리시아 비칸데르'],
'아수라': ['정우성', ' 황정민'],
'정글북': ['닐 세티', ' 빌 머레이'],
'라라랜드': ['라이언 고슬링', ' 엠마 스톤'],
'배트맨 대 슈퍼맨: 저스티스의 시작': ['헨리 카빌', ' 벤 애플렉'],
'굿바이 싱글': ['김혜수', ' 마동석'],
'봉이 김선달': ['유승호', ' 조재현'],
'레버넌트: 죽음에서 돌아온 자': ['레오나르도 디카프리오', ' 톰 하디'],
'컨저링 2': ['베라 파미가', ' 패트릭 윌슨'],
'내부자들: 디 오리지널': ['이병헌', ' 조승우'],
'수어사이드 스쿼드': ['윌 스미스', ' 자레드 레토'],
'인디펜던스 데이 : 리써전스': ['빌 풀만', ' 리암 헴스워스'],
'탐정 홍길동: 사라진 마을': ['이제훈', ' 김성균'],
'벤허': ['잭 휴스턴', ' 모건 프리먼'],
'셜록: 유령신부': ['베네딕트 컴버배치', ' 마틴 프리먼'],
'특별수사: 사형수의 편지': ['김명민', ' 김상호'],
'시간이탈자': ['임수정', ' 조정석'],
'동주': ['강하늘', ' 박정민'],
'워크래프트: 전쟁의 서막': ['트래비스 핌멜', ' 벤 포스터'],
'스타트렉 비욘드': ['크리스 파인', ' 사이먼 페그'],
'미씽: 사라진 여자': ['엄지원', ' 공효진'],
'당신, 거기 있어줄래요': ['김윤석', ' 변요한'],
'라이트 아웃': ['테레사 팔머'],
'오빠생각': ['임시완', ' 고아성'],
'날, 보러와요': ['강예원', ' 이상윤'],
'맨 인 더 다크': ['제인 레비', ' 딜런 미네트'],
'고산자, 대동여지도': ['차승원', ' 유준상'],
'미 비포 유': ['에밀리아 클라크', ' 샘 클라플린'],
'매그니피센트 7': ['덴젤 워싱턴', ' 크리스 프랫'],
'갓 오브 이집트': ['제라드 버틀러', ' 니콜라이 코스터 왈도'],
'레전드 오브 타잔': ['알렉산더 스카스가드', ' 사무엘 L. 잭슨'],
'좋아해줘': ['이미연', ' 최지우'],
'브리짓 존스의 베이비': ['르네 젤위거', ' 콜린 퍼스'],
'스플릿': ['유지태', ' 이정현'],
'런던 해즈 폴른': ['제라드 버틀러', ' 아론 에크하트'],
'국가대표 2': ['수애', ' 오달수'],
'인페르노': ['톰 행크스', ' 펠리시티 존스'],
'그날의 분위기': ['문채원', ' 유연석'],
'사냥': ['안성기', ' 조진웅'],
'널 기다리며': ['심은경', ' 윤제문'],
'설리: 허드슨강의 기적': ['톰 행크스'],
'잭 리처: 네버 고 백': ['톰 크루즈', ' 코비 스멀더스'],
'로그 원: 스타워즈 스토리': ['펠리시티 존스', ' 디에고 루나'],
'메카닉: 리크루트': ['제이슨 스타뎀', ' 제시카 알바'],
'고스트버스터즈': ['멜리사 맥카시', ' 크리스틴 위그'],
'거울나라의 앨리스': ['조니 뎁', ' 앤 해서웨이'],
'가려진 시간': ['강동원', ' 신은수'],
'해어화': ['한효주', ' 유연석'],
'계춘할망': ['윤여정', ' 김고은'],
'로봇, 소리': ['이성민', ' 이희준'],
'스타워즈: 깨어난 포스': ['데이지 리들리', ' 존 보예가'],
'빅쇼트': ['크리스찬 베일', ' 스티브 카렐'],
'헌츠맨: 윈터스 워': ['크리스 헴스워스', ' 샤를리즈 테론'],
'나를 잊지 말아요': ['정우성', ' 김하늘'],
'조선마술사': ['유승호', ' 고아라'],
'언더 워터': ['블레이크 라이블리'],
'클로버필드 10번지': ['메리 엘리자베스 윈스티드', ' 존 굿맨'],
'위자: 저주의 시작': ['엘리자베스 리저', ' 애너리즈 바쏘'],
'위대한 소원': ['류덕환', ' 김동영'],
'스포트라이트': ['마크 러팔로', ' 레이첼 맥아담스'],
'구스범스': ['잭 블랙', ' 딜런 미네트'],
'포인트 브레이크': ['루크 브레이시', ' 에드가 라미레즈'],
'혼숨': ['류덕환', ' 조복래'],
'비밀은 없다': ['손예진', ' 김주혁'],
'닌자터틀 : 어둠의 히어로': ['메간 폭스', ' 스티븐 아멜'],
'순정': ['디오', ' 김소현'],
'독수리 에디': ['태런 에저튼', ' 휴 잭맨'],
'남과 여': ['전도연', ' 공유'],
'대호': ['최민식'],
'부활': ['조셉 파인즈', ' 톰 펠튼'],
'조이': ['제니퍼 로렌스', ' 브래들리 쿠퍼'],
'대배우': ['오달수', ' 윤제문'],
'미스컨덕트': ['알 파치노', ' 안소니 홉킨스'],
'13시간': [' 제임스 뱃지 데일'],
'제 5침공': ['클로이 모레츠', ' 닉 로빈슨'],
'마이 리틀 자이언트': ['마크 라이런스'],
'피터와 드래곤': ['브라이스 달라스 하워드', ' 오크스 페글리'],
'다이버전트 시리즈: 얼리전트': ['쉐일린 우들리', ' 테오 제임스'],
'바스티유 데이': ['이드리스 엘바']}

# %%
movie_actors = {}
for movie,actors in movies.items() :
    try :
        if len(actors) == 2  :
            movie_actors[movie] = (dict[actors[0]]+dict[actors[1]])/2
        if len(actors) == 1  :
            movie_actors[movie] = dict[actors[0]]
    except : 
        print(movie)

# %%
movie_actors
# Out:
# {'부산행': 22.0,
#  '검사외전': 29.0,
#  '캡틴 아메리카: 시빌 워': 29.0,
#  '밀정': 23.5,
#  '터널': 28.0,
#  '인천상륙작전': 37.0,
#  '럭키': 29.0,
#  '곡성': 28.0,
#  '덕혜옹주': 26.0,
#  '닥터 스트레인지': 20.5,
#  '마스터': 29.5,
#  '신비한 동물사전': 26.0,
#  '판도라': 8.0,
#  '아가씨': 12.5,
#  '귀향': 3.0,
#  '데드풀': 32,
#  '나우 유 씨 미 2': 25.5,
#  '형': 9.5,
#  '엑스맨: 아포칼립스': 25.5,
#  '미스 페레그린과 이상한 아이들의 집': 13,
#  '히말라야': 36.5,
#  '제이슨 본': 30.5,
#  '아수라': 35.0,
#  '정글북': 12.0,
#  '라라랜드': 19.5,
#  '배트맨 대 슈퍼맨: 저스티스의 시작': 21.5,
#  '굿바이 싱글': 35.0,
#  '봉이 김선달': 20.5,
#  '레버넌트: 죽음에서 돌아온 자': 21.0,
#  '컨저링 2': 17.0,
#  '내부자들: 디 오리지널': 28.5,
#  '수어사이드 스쿼드': 15.0,
#  '인디펜던스 데이 : 리써전스': 16.0,
#  '탐정 홍길동: 사라진 마을': 20.5,
#  '벤허': 29.0,
#  '셜록: 유령신부': 18.0,
#  '특별수사: 사형수의 편지': 30.5,
#  '시간이탈자': 13.0,
#  '동주': 7.5,
#  '워크래프트: 전쟁의 서막': 8.5,
#  '스타트렉 비욘드': 19.0,
#  '미씽: 사라진 여자': 21.5,
#  '당신, 거기 있어줄래요': 19.0,
#  '라이트 아웃': 10,
#  '오빠생각': 8.0,
#  '날, 보러와요': 8.5,
#  '맨 인 더 다크': 3.0,
#  '고산자, 대동여지도': 27.0,
#  '미 비포 유': 5.5,
#  '매그니피센트 7': 21.5,
# ...

# %%
len(movie_actors)
# Out:
# 100

# %%
dict = movie_actors

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'pactor' })
df.to_csv( './data_2016/2016_pactor', sep=',', encoding='utf-8' )
