# %%
dict = {'7번방의 선물': '12811435',
'관상': '9135806',
'아이언맨 3': '9001679',
'설국열차': '9350351',
'베를린': '7166532',
'은밀하게 위대하게': '6959083',
'변호인': '11374892',
'숨바꼭질': '5604106',
'더 테러 라이브': '5584139',
'감시자들': '5508359',
'월드 워 Z': '5237525',
'신세계': '4682614',
'박수건달': '3897969',
'타워': '5181228',
'감기': '3117859',
'토르: 다크 월드': '3040115',
'레드: 더 레전드': '3004649',
'친구 2': '2971475',
'어바웃 타임': '3396313',
'나우 유 씨 미 : 마술사기단': '2718237',
'레미제라블': '5920977',
'소원': '2711094',
'컨저링': '1928605',
'맨 오브 스틸': '2182227',
'용의자': '4131963',
'호빗: 스마우그의 폐허': '2282807',
'몽타주': '2095592',
'연애의 온도': '1865354',
'지.아이.조 2': '1855917',
'분노의 질주: 더 맥시멈': '1790491',
'공범': '1766285',
'집으로 가는 길': '1854711',
'전설의 주먹': '1744585',
'파파로티': '1716438',
'스타트렉 다크니스': '1607555',
'오블리비언': '1515356',
'위대한 개츠비': '1445217',
'다이하드: 굿 데이 투 다이': '1438056',
'미스터 고': '1329061',
'결혼전야': '1214839',
'엘리시움': '1207732',
'깡철이': '1209363',
'더 웹툰: 예고살인': '1201033',
'웜 바디스': '1169839',
'고령화 가족': '1141222',
'헝거게임: 캣칭 파이어': '1127373',
'더 울버린': '1075333',
'동창생': '1048280',
'전국노래자랑': '978413',
'잭 더 자이언트 킬러': '956154',
'열한시': '870785',
'남쪽으로 튀어': '832894',
'반창꼬': '2475797',
'더 파이브': '731212',
'더 임파서블': '625192',
'인시디어스: 두번째 집': '577758',
'섀도우 헌터스: 뼈의 도시': '571074',
'화이트 하우스 다운': '569500',
'애프터 어스': '537920',
'사이코메트리': '534273',
'퍼시 잭슨과 괴물의 바다': '519584',
'남자사용설명서': '507913',
'무서운 이야기 2': '495535',
'캐치미': '494126',
'노브레싱': '451669',
'창수': '429141',
'헨젤과 그레텔 : 마녀 사냥꾼': '269510',
'론 레인저': '388235',
'스토커': '379241',
'오즈 그레이트 앤드 파워풀': '350563',
'미나문방구': '334323',
'차이니즈 조디악': '315314',
'이스케이프 플랜': '292893',
'롤러코스터': '270156',
'밤의 여왕': '252475',
'캡틴 필립스': '242268',
'잡스': '225343',
'분노의 윤리학': '225618',
'송 포 유': '217314',
'호빗: 뜻밖의 여정': '2818993',
'비포 미드나잇': '209591',
'응징자': '192347',
'프리즈너스': '188760',
'마이 리틀 히어로': '186141',
'백악관 최후의 날': '181257',
'해양경찰 마르코': '181740',
'톱스타': '175153',
'노리개': '169064',
'엔더스 게임': '654480',
'히든 카드': '151476',
'스파이': '3436092',
'퍼시픽 림': '2539115',
'화이: 괴물을 삼킨 아이': '2394487',
'런닝맨': '1422844',
'잭 리처': '784031',
'클라우드 아틀라스': '453102',
'장고:분노의 추적자': '260405'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'audience_cnt' })

# %%
df['audience_cnt'].astype(int)
# Out:
# 7번방의 선물             12811435
# 감기                   3117859
# 감시자들                 5508359
# 결혼전야                 1214839
# 고령화 가족               1141222
# 공범                   1766285
# 관상                   9135806
# 깡철이                  1209363
# 나우 유 씨 미 : 마술사기단     2718237
# 남자사용설명서               507913
# 남쪽으로 튀어               832894
# 노리개                   169064
# 노브레싱                  451669
# 다이하드: 굿 데이 투 다이      1438056
# 더 울버린                1075333
# 더 웹툰: 예고살인           1201033
# 더 임파서블                625192
# 더 테러 라이브             5584139
# 더 파이브                 731212
# 동창생                  1048280
# 런닝맨                  1422844
# 레드: 더 레전드            3004649
# 레미제라블                5920977
# 론 레인저                 388235
# 롤러코스터                 270156
# 마이 리틀 히어로             186141
# 맨 오브 스틸              2182227
# 몽타주                  2095592
# 무서운 이야기 2             495535
# 미나문방구                 334323
#                       ...
# 잡스                    225343
# ...

# %%
df.to_csv( './data_2013/2013_audience_cnt', sep=',', encoding='utf-8' )
