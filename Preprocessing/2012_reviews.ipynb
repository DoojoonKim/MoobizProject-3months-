# %%
p_reviews_2012 = {'도둑들': 1014,
'광해, 왕이 된 남자': 573,
'어벤져스': 649,
'늑대소년': 0,
'다크 나이트 라이즈': 1704,
'바람과 함께 사라지다': 116,
'어메이징 스파이더맨': 209,
'범죄와의 전쟁: 나쁜놈들 전성시대': 216,
'내 아내의 모든 것': 89,
'연가시': 566,
'건축학개론': 126,
'댄싱퀸': 75,
'부러진 화살': 85,
'맨 인 블랙 3': 110,
'레미제라블': 707,
'26년': 1699,
'내가 살인범이다': 312,
'브레이킹 던 part2': 468,
'후궁 : 제왕의 첩': 103,
'호빗: 뜻밖의 여정': 459,
'미션임파서블:고스트프로토콜': 194,
'화차': 43,
'이웃사람': 108,
'007 스카이폴': 159,
'테이큰 2': 106,
'배틀쉽': 581,
'장화신은 고양이': 31,
'타워': 1223,
'코리아': 130,
'나의 PS 파트너 ': 194,
'반창꼬': 430,
'러브픽션': 80,
'공모자들': 83,
'하울링': 93,
'용의자X': 152,
'새미의 어드벤쳐 2': 17,
'차형사': 85,
'은교': 50,
'간첩': 48,
'간기남': 47,
'토탈 리콜': 129,
'R2B: 리턴투베이스': 674,
'돈의 맛': 310,
'잃어버린 세계를 찾아서 2: 신비의 섬': 24,
'회사원': 107,
'가디언즈': 114,
'점박이:한반도의 공룡3D': 0,
'본 레거시': 243,
'가문의 영광5 - 가문의 귀환': 85,
'시체가 돌아왔다': 59,
'원더풀 라디오': 128,
'돈 크라이 마미': 289,
'프로메테우스': 385,
'스텝업4 : 레볼루션': 238,
'셜록홈즈 : 그림자 게임': 74,
'점쟁이들': 215,
'타이탄의 분노': 93,
'디스 민즈 워': 42,
'미확인 동영상 : 절대클릭금지': 73,
'존 카터: 바숨 전쟁의 서막 ': 67,
'나는 왕이로소이다': 50,
'퍼펙트 게임': 163,
'스노우 화이트 앤 더 헌츠맨': 88,
'주먹왕 랄프': 40,
'미쓰GO': 34,
'헝거게임: 판엠의 불꽃': 46,
'맨 온 렛지': 16,
'다크 섀도우': 50,
'백설공주': 13,
'루퍼': 76,
'파파': 45,
'마이 웨이': 151,
'아부의 왕': 16,
'페이스메이커': 95,
'익스펜더블 2': 45,
'밀레니엄 : 여자를 증오한 남자들': 10,
'두 개의 달': 35,
'늑대소년-확장판': 0,
'크로니클': 24,
'링컨: 뱀파이어 헌터': 25,
'음치 클리닉 ': 94,
'극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」': 31,
'위험한 관계': 31,
'모모와 다락방의 수상한 요괴들': 10,
'더 그레이': 0,
'네버엔딩 스토리': 15,
'우리는 동물원을 샀다': 14,
'짱구는 못말려 극장판: 태풍을 부르는 황금스파이 대작전': 5,
'언터처블: 1%의 우정': 78,
'아이스 에이지 4: 대륙 이동설': 17,
'마다가스카3 : 이번엔 서커스다!': 93,
'메리다와 마법의 숲': 3,
'토르: 마법망치의 전설': 5,
'레지던트 이블 5 : 최후의 심판': 67,
'명탐정 코난: 11번째 스트라이커': 65,
'락아웃: 익스트림미션': 43,
'프렌즈: 몬스터섬의비밀': 0,
'무서운 이야기': 57,
'빌리와 용감한 녀석들 3D': 5,
'로렉스': 3}

# %%
import pandas as pd
df1 = pd.DataFrame([p_reviews_2012])
df1 = df1.T
df1 = df1.rename(columns = { 0 : 'p_reviews' })
df1.to_csv( './data_2012/2012_p_reviews', sep=',', encoding='utf-8' )

# %%
n_reviews_2012 = {'도둑들': 654,
'광해, 왕이 된 남자': 60,
'어벤져스': 117,
'늑대소년': 0,
'다크 나이트 라이즈': 294,
'바람과 함께 사라지다': 61,
'어메이징 스파이더맨': 176,
'범죄와의 전쟁: 나쁜놈들 전성시대': 57,
'내 아내의 모든 것': 42,
'연가시': 214,
'건축학개론': 44,
'댄싱퀸': 15,
'부러진 화살': 16,
'맨 인 블랙 3': 77,
'레미제라블': 201,
'26년': 2004,
'내가 살인범이다': 50,
'브레이킹 던 part2': 91,
'후궁 : 제왕의 첩': 201,
'호빗: 뜻밖의 여정': 129,
'미션임파서블:고스트프로토콜': 67,
'화차': 46,
'이웃사람': 101,
'007 스카이폴': 145,
'테이큰 2': 101,
'배틀쉽': 368,
'장화신은 고양이': 22,
'타워': 242,
'코리아': 59,
'나의 PS 파트너 ': 46,
'반창꼬': 75,
'러브픽션': 105,
'공모자들': 83,
'하울링': 60,
'용의자X': 79,
'새미의 어드벤쳐 2': 4,
'차형사': 80,
'은교': 42,
'간첩': 52,
'간기남': 32,
'토탈 리콜': 140,
'R2B: 리턴투베이스': 201,
'돈의 맛': 197,
'잃어버린 세계를 찾아서 2: 신비의 섬': 11,
'회사원': 146,
'가디언즈': 18,
'점박이:한반도의 공룡3D': 0,
'본 레거시': 146,
'가문의 영광5 - 가문의 귀환': 48,
'시체가 돌아왔다': 48,
'원더풀 라디오': 54,
'돈 크라이 마미': 345,
'프로메테우스': 459,
'스텝업4 : 레볼루션': 38,
'셜록홈즈 : 그림자 게임': 18,
'점쟁이들': 155,
'타이탄의 분노': 95,
'디스 민즈 워': 16,
'미확인 동영상 : 절대클릭금지': 47,
'존 카터: 바숨 전쟁의 서막 ': 51,
'나는 왕이로소이다': 33,
'퍼펙트 게임': 34,
'스노우 화이트 앤 더 헌츠맨': 42,
'주먹왕 랄프': 8,
'미쓰GO': 59,
'헝거게임: 판엠의 불꽃': 55,
'맨 온 렛지': 15,
'다크 섀도우': 66,
'백설공주': 14,
'루퍼': 40,
'파파': 25,
'마이 웨이': 156,
'아부의 왕': 32,
'페이스메이커': 20,
'익스펜더블 2': 23,
'밀레니엄 : 여자를 증오한 남자들': 5,
'두 개의 달': 24,
'늑대소년-확장판': 0,
'크로니클': 61,
'링컨: 뱀파이어 헌터': 41,
'음치 클리닉 ': 63,
'극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」': 6,
'위험한 관계': 27,
'모모와 다락방의 수상한 요괴들': 10,
'더 그레이': 0,
'네버엔딩 스토리': 7,
'우리는 동물원을 샀다': 1,
'짱구는 못말려 극장판: 태풍을 부르는 황금스파이 대작전': 1,
'언터처블: 1%의 우정': 8,
'아이스 에이지 4: 대륙 이동설': 2,
'마다가스카3 : 이번엔 서커스다!': 12,
'메리다와 마법의 숲': 6,
'토르: 마법망치의 전설': 4,
'레지던트 이블 5 : 최후의 심판': 72,
'명탐정 코난: 11번째 스트라이커': 17,
'락아웃: 익스트림미션': 38,
'프렌즈: 몬스터섬의비밀': 0,
'무서운 이야기': 30,
'빌리와 용감한 녀석들 3D': 5,
'로렉스': 1}

# %%
import pandas as pd
df2 = pd.DataFrame([n_reviews_2012])
df2 = df2.T
df2 = df2.rename(columns = { 0 : 'n_reviews' })
df2.to_csv( './data_2012/2012_n_reviews', sep=',', encoding='utf-8' )
