# %%
dict = {'부산행': '2',
'검사외전': '2',
'캡틴 아메리카: 시빌 워': '1',
'밀정': '2',
'터널': '1',
'인천상륙작전': '1',
'럭키': '2',
'곡성': '2',
'덕혜옹주': '1',
'닥터 스트레인지': '1',
'마스터': '2',
'신비한 동물사전': '1',
'판도라': '1',
'아가씨': '3',
'귀향': '2',
'데드풀': '3',
'나우 유 씨 미 2': '1',
'형': '1',
'엑스맨: 아포칼립스': '1',
'미스 페레그린과 이상한 아이들의 집': '1',
'히말라야': '1',
'제이슨 본': '2',
'아수라': '3',
'정글북': '1',
'라라랜드': '1',
'배트맨 대 슈퍼맨: 저스티스의 시작': '1',
'굿바이 싱글': '2',
'봉이 김선달': '1',
'레버넌트: 죽음에서 돌아온 자': '2',
'컨저링 2': '2',
'내부자들: 디 오리지널': '3',
'수어사이드 스쿼드': '2',
'인디펜던스 데이 : 리써전스': '1',
'탐정 홍길동: 사라진 마을': '2',
'벤허': '1',
'셜록: 유령신부': '1',
'특별수사: 사형수의 편지': '2',
'시간이탈자': '2',
'동주': '1',
'워크래프트: 전쟁의 서막': '1',
'스타트렉 비욘드': '1',
'미씽: 사라진 여자': '2',
'당신, 거기 있어줄래요': '1',
'라이트 아웃': '2',
'오빠생각': '1',
'날, 보러와요': '3',
'맨 인 더 다크': '3',
'고산자, 대동여지도': '0',
'미 비포 유': '1',
'매그니피센트 7': '2',
'갓 오브 이집트': '1',
'레전드 오브 타잔': '1',
'좋아해줘': '1',
'브리짓 존스의 베이비': '2',
'스플릿': '2',
'런던 해즈 폴른': '2',
'국가대표 2': '1',
'인페르노': '2',
'그날의 분위기': '2',
'사냥': '2',
'널 기다리며': '3',
'설리: 허드슨강의 기적': '1',
'잭 리처: 네버 고 백': '2',
'로그 원: 스타워즈 스토리': '1',
'메카닉: 리크루트': '2',
'고스트버스터즈': '1',
'거울나라의 앨리스': '1',
'가려진 시간': '1',
'해어화': '2',
'계춘할망': '2',
'로봇, 소리': '1',
'스타워즈: 깨어난 포스': '1',
'빅쇼트': '3',
'헌츠맨: 윈터스 워': '1',
'나를 잊지 말아요': '2',
'조선마술사': '1',
'언더 워터': '2',
'클로버필드 10번지': '2',
'위자: 저주의 시작': '1',
'위대한 소원': '2',
'스포트라이트': '2',
'구스범스': '1',
'포인트 브레이크': '2',
'혼숨': '2',
'비밀은 없다': '3',
'닌자터틀 : 어둠의 히어로': '1',
'순정': '1',
'독수리 에디': '1',
'남과 여': '3',
'대호': '1',
'부활': '1',
'조이': '1',
'대배우': '1',
'미스컨덕트': '2',
'13시간': '2',
'제 5침공': '1',
'마이 리틀 자이언트': '0',
'피터와 드래곤': '0',
'다이버전트 시리즈: 얼리전트': '1',
'바스티유 데이': '2'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'rating' })
df.to_csv( './data_2016/2016_rating', sep=',', encoding='utf-8' )
