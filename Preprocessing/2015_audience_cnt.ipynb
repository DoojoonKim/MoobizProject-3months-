# %%
dict = {'베테랑': '13414200',
'암살': '12706663',
'어벤져스: 에이지 오브 울트론': '10494840',
'국제시장': '14262922',
'내부자들': '7072501',
'사도': '6247651',
'미션 임파서블: 로그네이션': '6126488',
'킹스맨 : 시크릿 에이전트': '6129651',
'연평해전': '6044956',
'검은 사제들': '5443049',
'히말라야': '7759711',
'마션': '4881865',
'조선명탐정 : 사라진 놉의 딸': '3872015',
'매드 맥스: 분노의 도로': '3884129',
'인턴': '3611166',
'분노의 질주: 더 세븐': '3248904',
'터미네이터 제니시스': '3240378',
'스물': '3044859',
'극비수사': '2860786',
'앤트맨': '5448134',
'스타워즈: 깨어난 포스': '3273873',
'메이즈 러너: 스코치 트라이얼': '2744422',
'탐정 : 더 비기닝': '2625686',
'스파이': '2318748',
'악의 연대기': '2192525',
'강남 1970': '2192276',
'뷰티 인사이드': '2057996',
'오늘의 연애': '1892125',
'테이큰 3': '2006564',
'007 스펙터': '1820839',
'이미테이션 게임': '1744213',
'샌 안드레아스': '1716455',
'쎄시봉': '1715370',
'더 폰': '1596762',
'대호': '1762733',
'차이나타운': '1472147',
'장수상회': '1166229',
'성난 변호사': '1131154',
'간신': '1110274',
'박물관이 살아있다 : 비밀의 무덤': '1101768',
'그놈이다': '1046313',
'미쓰 와이프': '988451',
'허삼관': '956103',
'살인의뢰': '855988',
'손님': '828029',
'인시디어스 3': '825517',
'하트 오브 더 씨': '809841',
'헝거게임: 더 파이널': '806737',
'기술자들': '2564340',
'신데렐라': '716491',
'픽셀': '681920',
'열정같은소리하고있네': '654407',
'특종: 량첸살인기': '616481',
'서부전선': '609063',
'채피': '573661',
'헬머니': '523871',
'위험한 상견례 2': '472695',
'순수의 시대': '470308',
'협녀, 칼의 기억': '431310',
'오피스': '441208',
'무뢰한': '414663',
'판타스틱 4': '399610',
'내 심장을 쏴라': '387408',
'소수의견': '383582',
'경성학교: 사라진 소녀들': '356436',
'치외법권': '346483',
'아메리칸 스나이퍼': '345782',
'에베레스트': '333038',
'호빗: 다섯 군대 전투': '2836777',
'극적인 하룻밤': '321641',
'도리화가': '317505',
'주피터 어센딩': '309842',
'패딩턴': '339014',
'런 올 나이트': '289534',
'인서전트': '282707',
'백 투 더 비기닝': '266610',
'투모로우랜드': '265810',
'스파이 브릿지': '266493',
'함정': '257996',
'언브로큰': '256802',
'하늘을 걷는 남자': '238439',
'조선마술사': '627586',
'언프렌디드: 친구삭제': '219892',
'연애의 맛': '214539',
'버드맨': '206241',
'기생수 파트1': '187310',
'팬': '186174',
'더 셰프': '187152',
'19곰 테드 2': '170649',
'인터스텔라': '10309432',
'아메리칸 울트라': '161383',
'트랜스포터: 리퓰드': '161245',
'내부자들: 디 오리지널': '2084844',
'워킹걸': '151584',
'은밀한 유혹': '145697',
'워터 디바이너': '136275',
'나의 절친 악당들': '133555',
'쥬라기 월드 ': '5546823',
'그레이의 50가지 그림자': '364415',
'레전드': '180091'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'audience_cnt' })

# %%
df['audience_cnt'].astype(int)
# Out:
# 007 스펙터                1820839
# 19곰 테드 2                170649
# 간신                     1110274
# 강남 1970                2192276
# 검은 사제들                 5443049
# 경성학교: 사라진 소녀들           356436
# 국제시장                  14262922
# 그놈이다                   1046313
# 그레이의 50가지 그림자           364415
# 극비수사                   2860786
# 극적인 하룻밤                 321641
# 기생수 파트1                 187310
# 기술자들                   2564340
# 나의 절친 악당들               133555
# 내 심장을 쏴라                387408
# 내부자들                   7072501
# 내부자들: 디 오리지널           2084844
# 대호                     1762733
# 더 셰프                    187152
# 더 폰                    1596762
# 도리화가                    317505
# 런 올 나이트                 289534
# 레전드                     180091
# 마션                     4881865
# 매드 맥스: 분노의 도로          3884129
# 메이즈 러너: 스코치 트라이얼       2744422
# 무뢰한                     414663
# 미션 임파서블: 로그네이션         6126488
# 미쓰 와이프                  988451
# 박물관이 살아있다 : 비밀의 무덤     1101768
# ...

# %%
df.to_csv( './data_2015/2015_audience_cnt', sep=',', encoding='utf-8' )
