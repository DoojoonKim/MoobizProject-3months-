# %%
n_reviews_2016_3 = {'히말라야': 236,
'제이슨 본': 529,
'아수라': 2380,
'정글북': 99,
'라라랜드': 0,
'배트맨 대 슈퍼맨: 저스티스의 시작': 1030,
'굿바이 싱글': 147,
'봉이 김선달': 277,
'레버넌트: 죽음에서 돌아온 자': 198,
'컨저링 2': 91,
'수어사이드 스쿼드': 1416,
'인디펜던스 데이 : 리써전스': 626,
'탐정 홍길동: 사라진 마을': 129,
'벤허': 87,
'셜록: 유령신부': 838,
'특별수사: 사형수의 편지': 66,
'시간이탈자': 249,
'동주': 18,
'워크래프트: 전쟁의 서막': 306}

# %%
n_reviews_2016_1 = {'부산행': 1530,
'검사외전': 371,
'캡틴 아메리카: 시빌 워': 752,
'밀정': 374,
'터널': 398,
'인천상륙작전': 1448,
'럭키': 187,
'곡성': 1359,
'덕혜옹주': 288,
'닥터 스트레인지': 507}

# %%
n_reviews_2016_9 = {'스포트라이트': 20,
'구스범스': 39,
'포인트 브레이크': 61,
'혼숨': 106,
'비밀은 없다': 224,
'닌자터틀 : 어둠의 히어로': 62,
'순정': 78,
'독수리 에디': 24,
'남과 여': 58,
'대호': 200,
'부활': 2,
'조이': 22,
'대배우': 52,
'미스컨덕트': 111,
'13시간': 17,
'제 5침공': 159,
'마이 리틀 자이언트': 2,
'피터와 드래곤': 4,
'다이버전트 시리즈: 얼리전트': 15,
'바스티유 데이': 17}

# %%
n_reviews_2016_5 = {'스타트렉 비욘드': 64,
'미씽: 사라진 여자': 169,
'당신, 거기 있어줄래요': 86,
'라이트 아웃': 89,
'오빠생각': 100,
'날, 보러와요': 62,
'맨 인 더 다크': 83,
'고산자, 대동여지도': 84,
'미 비포 유': 30,
'매그니피센트 7': 216,
'갓 오브 이집트': 107,
'레전드 오브 타잔': 152,
'좋아해줘': 67,
'브리짓 존스의 베이비': 41,
'스플릿': 28,
'런던 해즈 폴른': 30,
'국가대표 2': 112,
'인페르노': 78,
'그날의 분위기': 109,
'사냥': 894}

# %%
n_reviews_2016_7 = {'널 기다리며': 66,
'설리: 허드슨강의 기적': 34,
'잭 리처: 네버 고 백': 111,
'로그 원: 스타워즈 스토리': 191,
'메카닉: 리크루트': 69,
'고스트버스터즈': 82,
'거울나라의 앨리스': 25,
'가려진 시간': 77,
'해어화': 206,
'계춘할망': 49,
'로봇, 소리': 80,
'스타워즈: 깨어난 포스': 321,
'빅쇼트': 37,
'헌츠맨: 윈터스 워': 165,
'나를 잊지 말아요': 290,
'조선마술사': 333,
'언더 워터': 35,
'클로버필드 10번지': 136,
'위자: 저주의 시작': 32,
'위대한 소원': 16}

# %%
n_reviews_2016_2 = {'마스터': 447,
'신비한 동물사전': 645,
'판도라': 219,
'아가씨': 628,
'귀향': 3,
'데드풀': 282,
'나우 유 씨 미 2': 241,
'형': 87,
'엑스맨: 아포칼립스': 517,
'미스 페레그린과 이상한 아이들의 집': 108}

# %%
n_reviews_2016_1.update(n_reviews_2016_2)

# %%
n_reviews_2016_1.update(n_reviews_2016_3)

# %%
n_reviews_2016_1.update(n_reviews_2016_5)

# %%
n_reviews_2016_1.update(n_reviews_2016_7)

# %%
n_reviews_2016_1.update(n_reviews_2016_9)

# %%
n_reviews_2016_1
# Out:
# {'부산행': 1530,
#  '검사외전': 371,
#  '캡틴 아메리카: 시빌 워': 752,
#  '밀정': 374,
#  '터널': 398,
#  '인천상륙작전': 1448,
#  '럭키': 187,
#  '곡성': 1359,
#  '덕혜옹주': 288,
#  '닥터 스트레인지': 507,
#  '마스터': 447,
#  '신비한 동물사전': 645,
#  '판도라': 219,
#  '아가씨': 628,
#  '귀향': 3,
#  '데드풀': 282,
#  '나우 유 씨 미 2': 241,
#  '형': 87,
#  '엑스맨: 아포칼립스': 517,
#  '미스 페레그린과 이상한 아이들의 집': 108,
#  '히말라야': 236,
#  '제이슨 본': 529,
#  '아수라': 2380,
#  '정글북': 99,
#  '라라랜드': 0,
#  '배트맨 대 슈퍼맨: 저스티스의 시작': 1030,
#  '굿바이 싱글': 147,
#  '봉이 김선달': 277,
#  '레버넌트: 죽음에서 돌아온 자': 198,
#  '컨저링 2': 91,
#  '수어사이드 스쿼드': 1416,
#  '인디펜던스 데이 : 리써전스': 626,
#  '탐정 홍길동: 사라진 마을': 129,
#  '벤허': 87,
#  '셜록: 유령신부': 838,
#  '특별수사: 사형수의 편지': 66,
#  '시간이탈자': 249,
#  '동주': 18,
#  '워크래프트: 전쟁의 서막': 306,
#  '스타트렉 비욘드': 64,
#  '미씽: 사라진 여자': 169,
#  '당신, 거기 있어줄래요': 86,
#  '라이트 아웃': 89,
#  '오빠생각': 100,
#  '날, 보러와요': 62,
#  '맨 인 더 다크': 83,
#  '고산자, 대동여지도': 84,
#  '미 비포 유': 30,
#  '매그니피센트 7': 216,
#  '갓 오브 이집트': 107,
#  '레전드 오브 타잔': 152,
#  '좋아해줘': 67,
#  '브리짓 존스의 베이비': 41,
# ...

# %%
import pandas as pd
df = pd.DataFrame([n_reviews_2016_1])
df = df.T
df = df.rename(columns = { 0 : 'n_reviews' })
df.to_csv( './data_2016/2016_n_reviews', sep=',', encoding='utf-8' )
# Out:
#                  n_reviews
# 13시간                    17
# 가려진 시간                  77
# 갓 오브 이집트               107
# 거울나라의 앨리스               25
# 검사외전                   371
# 계춘할망                    49
# 고산자, 대동여지도              84
# 고스트버스터즈                 82
# 곡성                    1359
# 구스범스                    39
# 국가대표 2                 112
# 굿바이 싱글                 147
# 귀향                       3
# 그날의 분위기                109
# 나를 잊지 말아요              290
# 나우 유 씨 미 2             241
# 날, 보러와요                 62
# 남과 여                    58
# 널 기다리며                  66
# 닌자터틀 : 어둠의 히어로          62
# 다이버전트 시리즈: 얼리전트         15
# 닥터 스트레인지               507
# 당신, 거기 있어줄래요            86
# 대배우                     52
# 대호                     200
# 덕혜옹주                   288
# 데드풀                    282
# 독수리 에디                  24
# 동주                      18
# 라라랜드                     0
# ...                    ...
# 언더 워터                   35
# 엑스맨: 아포칼립스             517
# ...

# %%
df.to_csv( './data_2016/2016_n_reviews', sep=',', encoding='utf-8' )
