# %%
p_reviews_2017 = {
 '택시운전사': 4125,
 '신과함께-죄와 벌': 1945,
 '공조': 617,
 '스파이더맨: 홈 커밍': 1116,
 '범죄도시': 454,
 '군함도': 4704,
 '청년경찰': 1165,
 '더 킹': 991,
 '미녀와 야수': 655,
 '킹스맨: 골든 서클': 1267,
 '토르: 라그나로크': 1293,
 '꾼': 587,
 '강철비': 781,
 '남한산성': 1012,
 '미이라': 1108,
 '분노의 질주: 더 익스트림': 640,
 '아이 캔 스피크': 432,
 '프리즌': 365,
 '덩케르크': 1120,
 '가디언즈 오브 갤럭시 VOL. 2': 1239,
 '살인자의 기억법': 812,
 '트랜스포머: 최후의 기사': 1915,
 '보안관': 418,
 '조작된 도시': 884,
 '재심': 345,
 '박열': 592,
 '마스터': 736,
 '원더 우먼': 822,
 '겟 아웃': 453,
 '로건': 1391,
 '혹성탈출: 종의 전쟁': 1034,
 '1987': 1685,
 '애나벨 : 인형의 주인': 581,
 '노무현입니다': 1190,
 '저스티스 리그': 802,
 '킬러의 보디가드': 181,
 '콩: 스컬 아일랜드': 292,
 '23 아이덴티티': 553,
 '임금님의 사건수첩': 370,
 '부라더': 259,
 '기억의 밤': 515,
 '해피 데스데이': 222,
 '브이아이피': 735,
 '특별시민': 494,
 '에이리언: 커버넌트': 1490,
 '장산범': 550,
 '악녀': 509,
 '해빙': 1278,
 '라라랜드': 0,
 '하루': 324,
 '지오스톰': 418,
 '스타워즈: 라스트 제다이': 526,
 '불한당: 나쁜 놈들의 세상': 547,
 '그것': 377,
 '오리엔트 특급 살인': 342,
 '대립군': 885,
 '베이비 드라이버': 86,
 '위대한 쇼맨': 706,
 '레지던트 이블: 파멸의 날': 293,
 '공각기동대 : 고스트 인 더 쉘': 639,
 '패신저스': 388,
 '아빠는 딸': 82,
 '컨택트': 355,
 '47 미터': 155,
 '얼라이드': 139,
 '발레리안: 천 개 행성의 도시': 232,
 '그레이트 월': 260,
 '침묵': 245,
 '트리플 엑스 리턴즈': 162,
 '리얼': 1180,
 '라이프': 267,
 '히든 피겨스': 106,
 '반드시 잡는다': 180,
 '원라인': 284,
 '로그 원: 스타워즈 스토리': 533,
 '킹 아서: 제왕의 검': 140,
 '아메리칸 메이드': 286,
 '보통사람': 211,
 '대장 김창수': 373,
 '어쌔신 크리드': 455,
 '플립': 62,
 '싱글라이더': 343,
 '7호실': 175,
 '사랑하기 때문에': 326,
 '희생부활자': 422,
 '옥자': 1215,
 '블레이드 러너 2049': 270,
 '존 윅 - 리로드': 147,
 '판도라': 713,
 '미옥': 259,
 '어느날': 130,
 '어쌔신: 더 비기닝': 72,
 '50가지 그림자: 심연': 131,
 '핵소 고지': 193,
 '채비': 198,
 '더 큐어': 454,
 '아토믹 블론드': 70,
 '비정규직 특수요원': 198,
 '캐리비안의 해적: 죽은 자는 말이 없다': 570,
 '석조저택 살인사건': 195}

# %%
len(p_reviews_2017)
# Out:
# 100

# %%
p_reviews_2017
# Out:
# {'택시운전사': 4125,
#  '신과함께-죄와 벌': 1945,
#  '공조': 617,
#  '스파이더맨: 홈 커밍': 1116,
#  '범죄도시': 454,
#  '군함도': 4704,
#  '청년경찰': 1165,
#  '더 킹': 991,
#  '미녀와 야수': 655,
#  '킹스맨: 골든 서클': 1267,
#  '토르: 라그나로크': 1293,
#  '꾼': 587,
#  '강철비': 781,
#  '남한산성': 1012,
#  '미이라': 1108,
#  '분노의 질주: 더 익스트림': 640,
#  '아이 캔 스피크': 432,
#  '프리즌': 365,
#  '덩케르크': 1120,
#  '가디언즈 오브 갤럭시 VOL. 2': 1239,
#  '살인자의 기억법': 812,
#  '트랜스포머: 최후의 기사': 1915,
#  '보안관': 418,
#  '조작된 도시': 884,
#  '재심': 345,
#  '박열': 592,
#  '마스터': 736,
#  '원더 우먼': 822,
#  '겟 아웃': 453,
#  '로건': 1391,
#  '혹성탈출: 종의 전쟁': 1034,
#  '1987': 1685,
#  '애나벨 : 인형의 주인': 581,
#  '노무현입니다': 1190,
#  '저스티스 리그': 802,
#  '킬러의 보디가드': 181,
#  '콩: 스컬 아일랜드': 292,
#  '23 아이덴티티': 553,
#  '임금님의 사건수첩': 370,
#  '부라더': 259,
#  '기억의 밤': 515,
#  '해피 데스데이': 222,
#  '브이아이피': 735,
#  '특별시민': 494,
#  '에이리언: 커버넌트': 1490,
#  '장산범': 550,
#  '악녀': 509,
#  '해빙': 1278,
#  '라라랜드': 0,
#  '하루': 324,
#  '지오스톰': 418,
#  '스타워즈: 라스트 제다이': 526,
#  '불한당: 나쁜 놈들의 세상': 547,
#  '그것': 377,
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame([p_reviews_2017])

# %%
df = df.T

# %%
df = df.rename(columns = { 0 : 'p_reviews' })

# %%
df.columns
# Out:
# Index(['p_reviews'], dtype='object')

# %%
df
# Out:
#                        p_reviews
# 1987                        1685
# 23 아이덴티티                     553
# 47 미터                        155
# 50가지 그림자: 심연                 131
# 7호실                          175
# 가디언즈 오브 갤럭시 VOL. 2          1239
# 강철비                          781
# 겟 아웃                         453
# 공각기동대 : 고스트 인 더 쉘            639
# 공조                           617
# 군함도                         4704
# 그것                           377
# 그레이트 월                       260
# 기억의 밤                        515
# 꾼                            587
# 남한산성                        1012
# 노무현입니다                      1190
# 대립군                          885
# 대장 김창수                       373
# 더 큐어                         454
# 더 킹                          991
# 덩케르크                        1120
# 라라랜드                           0
# 라이프                          267
# 레지던트 이블: 파멸의 날               293
# 로건                          1391
# 로그 원: 스타워즈 스토리               533
# ...

# %%
df.to_csv( './2017_p_reviews', sep=',', encoding='utf-8' )
