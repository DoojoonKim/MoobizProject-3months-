# %%
dict = {'베테랑': 569,
'암살': 675,
'어벤져스: 에이지 오브 울트론': 2660,
'국제시장': 1015,
'내부자들': 920,
'사도': 445,
'미션 임파서블: 로그네이션': 369,
'킹스맨 : 시크릿 에이전트': 141,
'연평해전': 4879,
'쥬라기 월드': 776,
'검은 사제들': 385,
'히말라야': 389,
'마션': 567,
'조선명탐정 : 사라진 놉의 딸': 222,
'매드 맥스: 분노의 도로': 198,
'인턴': 127,
'분노의 질주: 더 세븐': 693,
'터미네이터 제니시스': 818,
'스물': 702,
'극비수사': 190,
'앤트맨': 148,
'스타워즈: 깨어난 포스': 501,
'메이즈 러너: 스코치 트라이얼': 751,
'탐정 : 더 비기닝': 279,
'스파이': 422,
'악의 연대기': 172,
'강남 1970': 1186,
'뷰티 인사이드': 1214,
'오늘의 연애': 860,
'테이큰 3': 333,
'007 스펙터': 220,
'이미테이션 게임': 353,
'샌 안드레아스': 201,
'쎄시봉': 1571,
'더 폰': 448,
'대호': 395,
'차이나타운': 142,
'장수상회': 761,
'성난 변호사': 166,
'간신': 391,
'박물관이 살아있다 : 비밀의 무덤': 146,
'그놈이다': 219,
'미쓰 와이프': 453,
'허삼관': 668,
'살인의뢰': 195,
'손님': 196,
'인시디어스 3': 137,
'하트 오브 더 씨': 101,
'헝거게임: 더 파이널': 240,
'기술자들': 810,
'신데렐라': 135,
'픽셀': 199,
'열정같은소리하고있네': 389,
'특종: 량첸살인기': 193,
'서부전선': 837,
'채피': 207,
'헬머니': 177,
'위험한 상견례 2': 305,
'순수의 시대': 236,
'협녀, 칼의 기억': 664,
'오피스': 167,
'무뢰한': 181,
'판타스틱 4': 1128,
'내 심장을 쏴라': 366,
'소수의견': 730,
'그레이의 50가지 그림자': 245,
'경성학교: 사라진 소녀들': 182,
'치외법권': 215,
'아메리칸 스나이퍼': 80,
'에베레스트': 82,
'호빗: 다섯 군대 전투': 831,
'극적인 하룻밤': 76,
'도리화가': 693,
'주피터 어센딩': 118,
'패딩턴': 90,
'런 올 나이트': 101,
'인서전트': 194,
'백 투 더 비기닝': 87,
'투모로우랜드': 109,
'스파이 브릿지': 166,
'함정': 223,
'언브로큰': 164,
'하늘을 걷는 남자': 79,
'조선마술사': 279,
'언프렌디드: 친구삭제': 94,
'연애의 맛': 80,
'버드맨': 1604,
'기생수 파트1': 184,
'팬': 64,
'더 셰프': 121,
'레전드': 76,
'19곰 테드 2': 72,
'인터스텔라': 758,
'아메리칸 울트라': 191,
'트랜스포터: 리퓰드': 394,
'워킹걸': 600,
'은밀한 유혹': 197,
'워터 디바이너': 90,
'나의 절친 악당들': 278}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'p_breviews' })
df.to_csv( './data_2015/2015_p_breviews', sep=',', encoding='utf-8' )
