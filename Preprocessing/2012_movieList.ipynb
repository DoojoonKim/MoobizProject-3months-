# %%
import pandas as pd

# %%
df = pd.read_csv('./data_2012/2012_movies.csv',header=2)
df
# Out:
#       순번                 영화명              감독  \
# 0      1                 도둑들             최동훈
# 1      2         광해, 왕이 된 남자             추창민
# 2      3                어벤져스           조스 웨던
# 3      4                늑대소년             조성희
# 4      5          다크 나이트 라이즈        크리스토퍼 놀란
# 5      6         바람과 함께 사라지다             김주호
# 6      7          어메이징 스파이더맨            마크 웹
# 7      8  범죄와의 전쟁: 나쁜놈들 전성시대             윤종빈
# 8      9          내 아내의 모든 것             민규동
# 9     10                 연가시             박정우
# 10    11               건축학개론             이용주
# 11    12                 댄싱퀸             이석훈
# 12    13              부러진 화살             정지영
# 13    14            맨 인 블랙 3         배리 소넨필드
# 14    15               레미제라블            톰 후퍼
# 15    16                 26년             조근현
# 16    17            내가 살인범이다             정병길
# 17    18        브레이킹 던 part2            빌 콘돈
# 18    19          후궁 : 제왕의 첩             김대승
# 19    20          호빗: 뜻밖의 여정           피터 잭슨
# ...

# %%
movieList= []

# %%
df = df.loc[:99,]
df
# Out:
#      순번                               영화명                     감독  \
# 0     1                               도둑들                    최동훈
# 1     2                       광해, 왕이 된 남자                    추창민
# 2     3                              어벤져스                  조스 웨던
# 3     4                              늑대소년                    조성희
# 4     5                        다크 나이트 라이즈               크리스토퍼 놀란
# 5     6                       바람과 함께 사라지다                    김주호
# 6     7                        어메이징 스파이더맨                   마크 웹
# 7     8                범죄와의 전쟁: 나쁜놈들 전성시대                    윤종빈
# 8     9                        내 아내의 모든 것                    민규동
# 9    10                               연가시                    박정우
# 10   11                             건축학개론                    이용주
# 11   12                               댄싱퀸                    이석훈
# 12   13                            부러진 화살                    정지영
# ...

# %%
movieList = dict([(i,a ) for i, a in zip(df.영화명,df.감독)])

# %%
movieList
# Out:
# {'도둑들': '최동훈',
#  '광해, 왕이 된 남자': '추창민',
#  '어벤져스': '조스 웨던',
#  '늑대소년': '조성희',
#  '다크 나이트 라이즈': '크리스토퍼 놀란',
#  '바람과 함께 사라지다': '김주호',
#  '어메이징 스파이더맨': '마크 웹',
#  '범죄와의 전쟁: 나쁜놈들 전성시대': '윤종빈',
#  '내 아내의 모든 것': '민규동',
#  '연가시': '박정우',
#  '건축학개론': '이용주',
#  '댄싱퀸': '이석훈',
#  '부러진 화살': '정지영',
#  '맨 인 블랙 3': '배리 소넨필드',
#  '레미제라블': '톰 후퍼',
#  '26년': '조근현',
#  '내가 살인범이다': '정병길',
#  '브레이킹 던 part2': '빌 콘돈',
#  '후궁 : 제왕의 첩': '김대승',
#  '호빗: 뜻밖의 여정': '피터 잭슨',
#  '미션임파서블:고스트프로토콜': '브래드 버드',
#  '화차': '변영주',
#  '이웃사람': '김휘',
#  '007 스카이폴': '샘 멘데스',
#  '테이큰 2': '올리비에 메가턴',
#  '배틀쉽': '피터 버그',
#  '장화신은 고양이': '크리스 밀러',
#  '타워': '김지훈',
#  '코리아': '문현성',
#  '나의 PS 파트너 ': '변성현',
#  '반창꼬': '정기훈',
#  '러브픽션': '전계수',
#  '언터처블: 1%의 우정': '올리비에르 나카체,에릭 토레다노',
#  '아이스 에이지 4: 대륙 이동설': '스티브 마티노,마이크 트메이어',
#  '공모자들': '김홍선',
#  '마다가스카3 : 이번엔 서커스다!': '에릭 다넬,톰 맥그라스,콘래드 베논',
#  '하울링': '유하',
#  '용의자X': '방은진',
#  '새미의 어드벤쳐 2': '벤 스타센',
#  '차형사': '신태라',
#  '은교': '정지우',
#  '간첩': '우민호',
#  '간기남': '김형준',
# ...
