# %%
dict = {'7번방의 선물': 710,
'관상': 1467,
'아이언맨 3': 2659,
'설국열차': 2919,
'베를린': 971,
'은밀하게 위대하게': 11689,
'변호인': 14882,
'숨바꼭질': 574,
'더 테러 라이브': 1364,
'감시자들': 839,
'월드 워 Z': 859,
'신세계': 476,
'박수건달': 652,
'스파이': 482,
'그래비티': 513,
'타워': 954,
'감기': 1336,
'토르: 다크 월드': 596,
'레드: 더 레전드': 302,
'친구 2': 1431,
'어바웃 타임': 271,
'나우 유 씨 미 : 마술사기단': 343,
'레미제라블': 564,
'소원': 2604,
'퍼시픽 림': 693,
'화이: 괴물을 삼킨 아이': 598,
'컨저링': 525,
'맨 오브 스틸': 845,
'용의자': 788,
'호빗: 스마우그의 폐허': 963,
'몽타주': 209,
'연애의 온도': 354,
'지.아이.조 2': 465,
'분노의 질주: 더 맥시멈': 488,
'공범': 280,
'집으로 가는 길': 833,
'전설의 주먹': 447,
'파파로티': 573,
'스타트렉 다크니스': 559,
'오블리비언': 390,
'위대한 개츠비': 212,
'다이하드: 굿 데이 투 다이': 279,
'런닝맨': 669,
'미스터 고': 4512,
'결혼전야': 313,
'엘리시움': 329,
'깡철이': 578,
'더 웹툰: 예고살인': 347,
'웜 바디스': 789,
'고령화 가족': 237,
'헝거게임: 캣칭 파이어': 405,
'더 울버린': 379,
'동창생': 2270,
'전국노래자랑': 660,
'잭 더 자이언트 킬러': 123,
'열한시': 202,
'남쪽으로 튀어': 291,
'잭 리처': 195,
'반창꼬': 653,
'더 파이브': 447,
'더 임파서블': 201,
'인시디어스: 두번째 집': 183,
'섀도우 헌터스: 뼈의 도시': 164,
'화이트 하우스 다운': 118,
'애프터 어스': 185,
'사이코메트리': 548,
'퍼시 잭슨과 괴물의 바다': 404,
'남자사용설명서': 932,
'다이노소어 어드벤처 3D': 65,
'무서운 이야기 2': 600,
'캐치미': 701,
'노브레싱': 1965,
'클라우드 아틀라스': 883,
'창수': 435,
'론 레인저': 157,
'스토커': 295,
'오즈 그레이트 앤드 파워풀': 116,
'미나문방구': 2078,
'차이니즈 조디악': 333,
'이스케이프 플랜': 82,
'롤러코스터': 280,
'장고:분노의 추적자': 291,
'밤의 여왕': 314,
'캡틴 필립스': 205,
'잡스': 672,
'분노의 윤리학': 128,
'송 포 유': 295,
'호빗: 뜻밖의 여정': 955,
'비포 미드나잇': 191,
'응징자': 151,
'프리즈너스': 87,
'마이 리틀 히어로': 514,
'백악관 최후의 날': 311,
'해양경찰 마르코': 117,
'톱스타': 124,
'노리개': 299,
'엔더스 게임': 988,
'히든 카드': 49}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'p_breviews' })
df.to_csv( './data_2013/2013_p_breviews', sep=',', encoding='utf-8' )
