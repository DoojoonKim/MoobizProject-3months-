# %%
dict = {'7번방의 선물': '9.53',
'관상': '9.51',
'아이언맨 3': '9.67',
'설국열차': '8.17',
'베를린': '8.83',
'은밀하게 위대하게': '9.59',
'변호인': '6.08',
'숨바꼭질': '9.11',
'더 테러 라이브': '7.64',
'감시자들': '8.34',
'월드 워 Z': '9.29',
'신세계': '8.99',
'박수건달': '8.98',
'스파이': '7.77',
'그래비티': '9.25',
'타워': '7.88',
'감기': '7.83',
'토르: 다크 월드': '9.47',
'레드: 더 레전드': '8.79',
'친구 2': '7.54',
'어바웃 타임': '9.62',
'나우 유 씨 미 : 마술사기단': '9.38',
'레미제라블': '9.61',
'소원': '9.45',
'퍼시픽 림': '8.55',
'화이: 괴물을 삼킨 아이': '9.23',
'컨저링': '8.02',
'맨 오브 스틸': '9.33',
'용의자': '9.28',
'호빗: 스마우그의 폐허': '9.72',
'몽타주': '8.79',
'연애의 온도': '8.62',
'지.아이.조 2': '8.79',
'분노의 질주: 더 맥시멈': '9.68',
'공범': '9.00',
'집으로 가는 길': '7.47',
'전설의 주먹': '8.29',
'파파로티': '9.28',
'스타트렉 다크니스': '9.42',
'오블리비언': '9.30',
'위대한 개츠비': '9.26',
'다이하드: 굿 데이 투 다이': '8.49',
'런닝맨': '9.17',
'미스터 고': '8.52',
'결혼전야': '8.86',
'엘리시움': '9.01',
'깡철이': '9.06',
'더 웹툰: 예고살인': '8.60',
'웜 바디스': '9.54',
'고령화 가족': '8.81',
'헝거게임: 캣칭 파이어': '9.15',
'더 울버린': '7.75',
'동창생': '9.41',
'전국노래자랑': '8.61',
'잭 더 자이언트 킬러': '9.46',
'열한시': '8.43',
'남쪽으로 튀어': '8.73',
'잭 리처': '9.14',
'반창꼬': '9.15',
'더 파이브': '9.02',
'더 임파서블': '8.07',
'인시디어스: 두번째 집': '8.69',
'섀도우 헌터스: 뼈의 도시': '8.05',
'화이트 하우스 다운': '8.47',
'애프터 어스': '8.35',
'사이코메트리': '9.42',
'퍼시 잭슨과 괴물의 바다': '8.66',
'남자사용설명서': '8.91',
'다이노소어 어드벤처 3D': '8.76',
'무서운 이야기 2': '8.76',
'캐치미': '9.36',
'노브레싱': '9.11',
'클라우드 아틀라스': '8.04',
'창수': '9.45',
'헨젤과 그레텔 : 마녀 사냥꾼': '9.00',
'론 레인저': '8.78',
'스토커': '8.54',
'오즈 그레이트 앤드 파워풀': '9.05',
'미나문방구': '7.63',
'차이니즈 조디악': '7.47',
'이스케이프 플랜': '8.85',
'롤러코스터': '8.94',
'장고:분노의 추적자': '8.23',
'밤의 여왕': '8.99',
'캡틴 필립스': '9.26',
'잡스': '8.49',
'분노의 윤리학': '9.10',
'송 포 유': '9.38',
'호빗: 뜻밖의 여정': '9.72',
'비포 미드나잇': '9.56',
'응징자': '8.63',
'프리즈너스': '9.16',
'마이 리틀 히어로': '9.10',
'백악관 최후의 날': '8.08',
'해양경찰 마르코': '9.19',
'톱스타': '8.37',
'노리개': '8.70',
'엔더스 게임': '9.12',
'히든 카드': '8.59'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'grade' })
df.to_csv( './data_2013/2013_grade', sep=',', encoding='utf-8' )
