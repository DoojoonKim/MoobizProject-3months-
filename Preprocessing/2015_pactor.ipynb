# %%
dict = {'황정민': 37,
' 유아인': 14,
'전지현': 12,
' 이정재': 32,
'로버트 다우니 주니어': 38,
' 크리스 헴스워스': 16,
' 김윤진': 16,
'이병헌': 38,
' 조승우': 19,
'송강호': 34,
'톰 크루즈': 38,
' 제레미 레너': 18,
'콜린 퍼스': 39,
' 태런 에저튼': 8,
'김무열': 12,
' 진구': 8,
'크리스 프랫': 12,
' 브라이스 달라스 하워드': 8,
'김윤석': 30,
' 강동원': 21,
' 정우': 36,
'맷 데이먼': 45,
' 제시카 차스테인': 18,
'김명민': 19,
' 오달수': 59,
'톰 하디': 18,
' 샤를리즈 테론': 32,
'앤 해서웨이': 27,
' 로버트 드 니로': 68,
'빈 디젤': 22,
' 폴 워커': 19,
'아놀드 슈왈제네거': 30,
' 제이슨 클락': 10,
'김우빈': 5,
' 준호': 26,
' 유해진': 53,
'폴 러드': 24,
' 에반젤린 릴리': 4,
'데이지 리들리': 2,
' 존 보예가': 3,
'딜런 오브라이언': 5,
' 토마스 생스터': 3,
'권상우': 18,
' 성동일': 32,
'주드 로': 36,
' 제이슨 스타뎀': 33,
'손현주': 15,
' 마동석': 35,
'이민호': 8,
' 김래원': 15,
'한효주': 13,
' 김대명': 16,
'이승기': 2,
' 문채원': 7,
'리암 니슨': 54,
' 팜케 얀센': 14,
'다니엘 크레이그': 26,
' 레아 세이두': 16,
'베네딕트 컴버배치': 21,
' 키이라 나이틀리': 24,
'드웨인 존슨': 27,
'알렉산드리아 다다리오': 5,
'정우': 36,
' 김윤석': 30,
' 엄지원': 20,
'최민식': 30,
'김혜수': 35,
' 김고은': 6,
'박근형': 61,
' 윤여정': 30,
'이선균': 35,
'주지훈': 11,
' 김강우': 23,
'벤 스틸러': 33,
' 로빈 윌리엄스': 40,
'주원': 1,
'엄정화': 21,
' 송승헌': 13,
'하정우': 36,
' 하지원': 19,
'김상경': 14,
' 김성균': 24,
'류승룡': 30,
' 이성민': 23,
'스테파니 스콧': 1,
' 더모트 멀로니': 21,
'크리스 헴스워스': 16,
' 킬리언 머피': 19,
'제니퍼 로렌스': 19,
' 조쉬 허처슨': 17,
' 김영철': 16,
'릴리 제임스': 5,
'리처드 매든': 2,
'아담 샌들러': 28,
' 케빈 제임스': 13,
'정재영': 1,
' 박보영': 17,
'조정석': 11,
' 이미숙': 21,
'설경구': 42,
' 여진구': 8,
'휴 잭맨': 26,
' 샬토 코플리': 9,
'김수미': 2,
' 정만식': 43,
'진세연': 5,
' 홍종현': 9,
'신하균': 30,
' 장혁': 8,
' 전도연': 20,
'고아성': 10,
' 박성웅': 44,
'전도연': 20,
' 김남길': 15,
'마일즈 텔러': 10,
' 케이트 마라': 9,
'이민기': 12,
'윤계상': 15,
'제이미 도넌': 8,
' 다코타 존슨': 5,
'박보영': 17,
'임창정': 29,
' 최다니엘': 6,
'브래들리 쿠퍼': 22,
' 시에나 밀러': 11,
'제이슨 클락': 10,
' 제이크 질렌할': 28,
'마틴 프리먼': 15,
' 이안 맥켈런': 18,
' 한예리': 29,
' 수지': 2,
'밀라 쿠니스': 16,
' 채닝 테이텀': 25,
'벤 위쇼': 15,
' 휴 그랜트': 27,
' 조엘 킨나만': 8,
'쉐일린 우들리': 7,
' 테오 제임스': 8,
'조니 웨스턴': 2,
' 소피아 블랙 디엘리아': 3,
'조지 클루니': 31,
' 휴 로리': 8,
'톰 행크스': 40,
' 마크 라이런스': 6,
'마동석': 35,
' 조한선': 16,
'잭 오코넬': 6,
' 도널 글리슨': 9,
'조셉 고든 레빗': 19,
' 벤 킹슬리': 43,
'유승호': 12,
' 고아라': 6,
'헤더 소서맨': 1,
'샐리 헤닝': 1,
'오지호': 13,
' 강예원': 14,
'마이클 키튼': 25,
' 에드워드 노튼': 24,
'소메타니 쇼타': 16,
' 아베 사다오': 7,
' 가렛 헤드룬드': 7,
'마크 월버그': 33,
' 아만다 사이프리드': 21,
'매튜 매커너히': 35,
' 앤 해서웨이': 27,
'제시 아이젠버그': 21,
' 크리스틴 스튜어트': 26,
'에드 스크레인': 6,
' 론 샤바놀': 1,
'조여정': 7,
' 클라라': 3,
'임수정': 15,
' 유연석': 19,
'러셀 크로우': 38,
' 올가 쿠릴렌코': 16,
'류승범': 33,
' 고준희': 9}

# %%
movies = {'베테랑': ['황정민', ' 유아인'],
'암살': ['전지현', ' 이정재'],
'어벤져스: 에이지 오브 울트론': ['로버트 다우니 주니어', ' 크리스 헴스워스'],
'국제시장': ['황정민', ' 김윤진'],
'내부자들': ['이병헌', ' 조승우'],
'사도': ['송강호', ' 유아인'],
'미션 임파서블: 로그네이션': ['톰 크루즈', ' 제레미 레너'],
'킹스맨 : 시크릿 에이전트': ['콜린 퍼스', ' 태런 에저튼'],
'연평해전': ['김무열', ' 진구'],
'쥬라기 월드': ['크리스 프랫', ' 브라이스 달라스 하워드'],
'검은 사제들': ['김윤석', ' 강동원'],
'히말라야': ['황정민', ' 정우'],
'마션': ['맷 데이먼', ' 제시카 차스테인'],
'조선명탐정 : 사라진 놉의 딸': ['김명민', ' 오달수'],
'매드 맥스: 분노의 도로': ['톰 하디', ' 샤를리즈 테론'],
'인턴': ['앤 해서웨이', ' 로버트 드 니로'],
'분노의 질주: 더 세븐': ['빈 디젤', ' 폴 워커'],
'터미네이터 제니시스': ['아놀드 슈왈제네거', ' 제이슨 클락'],
'스물': ['김우빈', ' 준호'],
'극비수사': ['김윤석', ' 유해진'],
'앤트맨': ['폴 러드', ' 에반젤린 릴리'],
'스타워즈: 깨어난 포스': ['데이지 리들리', ' 존 보예가'],
'메이즈 러너: 스코치 트라이얼': ['딜런 오브라이언', ' 토마스 생스터'],
'탐정 : 더 비기닝': ['권상우', ' 성동일'],
'스파이': ['주드 로', ' 제이슨 스타뎀'],
'악의 연대기': ['손현주', ' 마동석'],
'강남 1970': ['이민호', ' 김래원'],
'뷰티 인사이드': ['한효주', ' 김대명'],
'오늘의 연애': ['이승기', ' 문채원'],
'테이큰 3': ['리암 니슨', ' 팜케 얀센'],
'007 스펙터': ['다니엘 크레이그', ' 레아 세이두'],
'이미테이션 게임': ['베네딕트 컴버배치', ' 키이라 나이틀리'],
'샌 안드레아스': ['드웨인 존슨'],
'쎄시봉': ['정우', ' 김윤석'],
'더 폰': ['손현주', ' 엄지원'],
'대호': ['최민식'],
'차이나타운': ['김혜수', ' 김고은'],
'장수상회': ['박근형', ' 윤여정'],
'성난 변호사': ['이선균', ' 김고은'],
'간신': ['주지훈', ' 김강우'],
'박물관이 살아있다 : 비밀의 무덤': ['벤 스틸러', ' 로빈 윌리엄스'],
'그놈이다': ['주원', ' 유해진'],
'미쓰 와이프': ['엄정화', ' 송승헌'],
'허삼관': ['하정우', ' 하지원'],
'살인의뢰': ['김상경', ' 김성균'],
'손님': ['류승룡', ' 이성민'],
'인시디어스 3': ['스테파니 스콧', ' 더모트 멀로니'],
'하트 오브 더 씨': ['크리스 헴스워스', ' 킬리언 머피'],
'헝거게임: 더 파이널': ['제니퍼 로렌스', ' 조쉬 허처슨'],
'기술자들': ['김우빈', ' 김영철'],
'신데렐라': ['릴리 제임스'],
'픽셀': ['아담 샌들러', ' 케빈 제임스'],
'열정같은소리하고있네': ['정재영', ' 박보영'],
'특종: 량첸살인기': ['조정석', ' 이미숙'],
'서부전선': ['설경구', ' 여진구'],
'채피': ['휴 잭맨', ' 샬토 코플리'],
'헬머니': ['김수미', ' 정만식'],
'위험한 상견례 2': ['진세연', ' 홍종현'],
'순수의 시대': ['신하균', ' 장혁'],
'협녀, 칼의 기억': ['이병헌', ' 전도연'],
'오피스': ['고아성', ' 박성웅'],
'무뢰한': ['전도연', ' 김남길'],
'판타스틱 4': ['마일즈 텔러', ' 케이트 마라'],
'내 심장을 쏴라': ['이민기', ' 여진구'],
'소수의견': ['윤계상', ' 유해진'],
'그레이의 50가지 그림자': ['제이미 도넌', ' 다코타 존슨'],
'경성학교: 사라진 소녀들': ['박보영', ' 엄지원'],
'치외법권': ['임창정', ' 최다니엘'],
'아메리칸 스나이퍼': ['브래들리 쿠퍼', ' 시에나 밀러'],
'에베레스트': ['제이슨 클락', ' 제이크 질렌할'],
'호빗: 다섯 군대 전투': ['마틴 프리먼', ' 이안 맥켈런'],
'극적인 하룻밤': ['윤계상', ' 한예리'],
'도리화가': ['류승룡', ' 수지'],
'주피터 어센딩': ['밀라 쿠니스', ' 채닝 테이텀'],
'패딩턴': ['벤 위쇼', ' 휴 그랜트'],
'런 올 나이트': ['리암 니슨', ' 조엘 킨나만'],
'인서전트': ['쉐일린 우들리', ' 테오 제임스'],
'백 투 더 비기닝': ['조니 웨스턴', ' 소피아 블랙 디엘리아'],
'투모로우랜드': ['조지 클루니', ' 휴 로리'],
'스파이 브릿지': ['톰 행크스', ' 마크 라이런스'],
'함정': ['마동석', ' 조한선'],
'언브로큰': ['잭 오코넬', ' 도널 글리슨'],
'하늘을 걷는 남자': ['조셉 고든 레빗', ' 벤 킹슬리'],
'조선마술사': ['유승호', ' 고아라'],
'언프렌디드: 친구삭제': ['헤더 소서맨'],
'연애의 맛': ['오지호', ' 강예원'],
'버드맨': ['마이클 키튼', ' 에드워드 노튼'],
'기생수 파트1': ['소메타니 쇼타', ' 아베 사다오'],
'팬': ['휴 잭맨', ' 가렛 헤드룬드'],
'더 셰프': ['브래들리 쿠퍼', ' 시에나 밀러'],
'레전드': ['톰 하디', ' 태런 에저튼'],
'19곰 테드 2': ['마크 월버그', ' 아만다 사이프리드'],
'인터스텔라': [' 앤 해서웨이'],
'아메리칸 울트라': ['제시 아이젠버그', ' 크리스틴 스튜어트'],
'트랜스포터: 리퓰드': ['에드 스크레인', ' 론 샤바놀'],
'내부자들: 디 오리지널': ['이병헌', ' 조승우'],
'워킹걸': ['조여정', ' 클라라'],
'은밀한 유혹': ['임수정', ' 유연석'],
'워터 디바이너': ['러셀 크로우', ' 올가 쿠릴렌코'],
'나의 절친 악당들': ['류승범', ' 고준희']}

# %%
movie_actors = {}
for movie,actors in movies.items() :
    try :
        if len(actors) == 2  :
            movie_actors[movie] = (dict[actors[0]]+dict[actors[1]])/2
        if len(actors) == 1  :
            movie_actors[movie] = dict[actors[0]]
    except : 
        print(movie)

# %%
movie_actors
# Out:
# {'베테랑': 25.5,
#  '암살': 22.0,
#  '어벤져스: 에이지 오브 울트론': 27.0,
#  '국제시장': 26.5,
#  '내부자들': 28.5,
#  '사도': 24.0,
#  '미션 임파서블: 로그네이션': 28.0,
#  '킹스맨 : 시크릿 에이전트': 23.5,
#  '연평해전': 10.0,
#  '쥬라기 월드': 10.0,
#  '검은 사제들': 25.5,
#  '히말라야': 36.5,
#  '마션': 31.5,
#  '조선명탐정 : 사라진 놉의 딸': 39.0,
#  '매드 맥스: 분노의 도로': 25.0,
#  '인턴': 47.5,
#  '분노의 질주: 더 세븐': 20.5,
#  '터미네이터 제니시스': 20.0,
#  '스물': 15.5,
#  '극비수사': 41.5,
#  '앤트맨': 14.0,
#  '스타워즈: 깨어난 포스': 2.5,
#  '메이즈 러너: 스코치 트라이얼': 4.0,
#  '탐정 : 더 비기닝': 25.0,
#  '스파이': 34.5,
#  '악의 연대기': 25.0,
#  '강남 1970': 11.5,
#  '뷰티 인사이드': 14.5,
#  '오늘의 연애': 4.5,
#  '테이큰 3': 34.0,
#  '007 스펙터': 21.0,
#  '이미테이션 게임': 22.5,
#  '샌 안드레아스': 27,
#  '쎄시봉': 33.0,
#  '더 폰': 17.5,
#  '대호': 30,
#  '차이나타운': 20.5,
#  '장수상회': 45.5,
#  '성난 변호사': 20.5,
#  '간신': 17.0,
#  '박물관이 살아있다 : 비밀의 무덤': 36.5,
#  '그놈이다': 27.0,
#  '미쓰 와이프': 17.0,
#  '허삼관': 27.5,
#  '살인의뢰': 19.0,
#  '손님': 26.5,
#  '인시디어스 3': 11.0,
#  '하트 오브 더 씨': 17.5,
#  '헝거게임: 더 파이널': 18.0,
#  '기술자들': 10.5,
#  '신데렐라': 5,
# ...

# %%
len(movie_actors)
# Out:
# 100

# %%
dict = movie_actors

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'pactor' })
df.to_csv( './data_2015/2015_pactor', sep=',', encoding='utf-8' )
