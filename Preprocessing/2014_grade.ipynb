# %%
dict = {'명량': '8.64',
'인터스텔라': '9.58',
'수상한 그녀': '9.55',
'해적: 바다로 간 산적': '8.11',
'변호인': '6.08',
'국제시장': '8.76',
'트랜스포머: 사라진 시대': '6.19',
'군도: 민란의 시대': '9.28',
'엣지 오브 투모로우': '9.23',
'엑스맨: 데이즈 오브 퓨처 패스트': '9.16',
'어메이징 스파이더맨 2': '9.03',
'혹성탈출: 반격의 서막': '8.88',
'타짜-신의 손': '4.38',
'캡틴 아메리카: 윈터 솔져': '9.34',
'역린': '9.05',
'신의 한 수': '8.82',
'끝까지 간다': '9.57',
'표적': '9.15',
'메이즈 러너': '9.30',
'호빗: 다섯 군대 전투': '9.61',
'나의 사랑 나의 신부': '9.17',
'논스톱': '9.45',
'인투 더 스톰': '9.02',
'노아': '9.30',
'남자가 사랑할 때': '9.08',
'루시': '7.99',
'용의자': '9.28',
'기술자들': '8.84',
'나를 찾아줘': '9.09',
'제보자': '8.57',
'피끓는 청춘': '9.38',
'우아한 거짓말': '9.58',
'두근두근 내 인생': '5.62',
'300: 제국의 부활': '8.47',
'엑소더스: 신들과 왕들': '9.04',
'해무(海霧)': '9.01',
'인간중독': '7.81',
'말레피센트': '9.57',
'폼페이: 최후의 날': '8.71',
'퓨리': '9.21',
'드라큘라: 전설의 시작': '8.73',
'가디언즈 오브 갤럭시': '9.38',
'찌라시: 위험한 소문': '8.33',
'빅매치': '8.77',
'슬로우 비디오': '9.07',
'방황하는 칼날': '9.16',
'로보캅': '8.34',
'우리는 형제입니다': '8.38',
'애나벨': '8.96',
'헝거게임: 모킹제이': '9.42',
'월터의 상상은 현실이 된다': '9.16',
'카트': '9.67',
'관능의 법칙': '7.64',
'안녕, 헤이즐': '9.39',
'고질라': '7.95',
'트랜센던스': '8.91',
'상의원': '8.75',
'플랜맨': '9.09',
'우는 남자': '8.16',
'황제를 위하여': '8.66',
'패션왕': '6.45',
'더 울프 오브 월스트리트': '9.28',
'스텝 업: 올 인': '9.42',
'어바웃 타임': '9.62',
'노예 12년': '9.36',
'또 하나의 약속': '9.76',
'엔더스 게임': '9.12',
'소녀괴담': '7.47',
'조선미녀삼총사': '7.46',
'마담 뺑덕': '8.02',
'다이버전트': '8.55',
'주온 : 끝의 시작': '8.56',
'좋은 친구들': '7.94',
'닌자터틀': '8.09',
'나의 독재자': '8.46',
'하이힐': '8.63',
'선 오브 갓': '7.38',
'잭 라이언 : 코드네임 쉐도우': '9.08',
'숲속으로': '9.60',
'레드카펫': '8.85',
'미녀와 야수': '9.27',
'프랑켄슈타인: 불멸의 영웅': '7.71',
'러브, 로지': '8.85',
'오큘러스': '8.30',
'사랑에 대한 모든 것': '8.98',
'노벰버 맨': '8.73',
'툼스톤': '9.42',
'쓰리데이즈 투 킬': '9.34',
'헤라클레스 : 레전드 비긴즈': '7.62',
'극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': '9.14',
'덕수리 5형제': '8.47',
'덤 앤 더머 투': '9.26',
'컬러풀 웨딩즈': '9.41',
'론 서바이버 ': '9.22',
'아빠를 빌려드립니다': '9.39',
'라스트베가스': '9.59',
'호빗: 스마우그의 폐허': '9.72',
'폴리스 스토리 2014': '9.69',
'익스펜더블 3': '9.04'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'grade' })
df.to_csv( './data_2014/2014_grade', sep=',', encoding='utf-8' )
