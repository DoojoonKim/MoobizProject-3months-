# %%
dict = {'최민식': 30,
' 류승룡': 30,
'매튜 매커너히': 35,
' 앤 해서웨이': 27,
'심은경': 18,
' 나문희': 17,
'김남길': 15,
' 손예진': 21,
'송강호': 34,
' 김영애': 48,
'황정민': 37,
' 김윤진': 16,
'마크 월버그': 33,
' 니콜라 펠츠': 3,
'하정우': 36,
' 강동원': 21,
'톰 크루즈': 38,
' 에밀리 블런트': 23,
'휴 잭맨': 26,
' 제임스 맥어보이': 26,
'앤드류 가필드': 9,
' 엠마 스톤': 18,
'앤디 서키스': 13,
' 게리 올드만': 42,
'T.O.P': 7,
' 신세경': 9,
'크리스 에반스': 20,
' 스칼렛 요한슨': 34,
'현빈': 13,
' 정재영': 1,
'정우성': 33,
' 이범수': 42,
'이선균': 35,
' 조진웅': 45,
'류승룡': 30,
' 유준상': 26,
'딜런 오브라이언': 5,
' 토마스 생스터': 3,
'마틴 프리먼': 15,
' 이안 맥켈런': 18,
'조정석': 11,
' 신민아': 15,
'리암 니슨': 54,
' 줄리안 무어': 44,
'리처드 아미티지': 6,
' 사라 웨인 콜리스': 4,
'러셀 크로우': 38,
' 제니퍼 코넬리': 22,
' 한혜진': 6,
'스칼렛 요한슨': 34,
' 모건 프리먼': 54,
'공유': 13,
' 박희순': 36,
'김우빈': 5,
' 김영철': 16,
'벤 애플렉': 35,
' 로자먼드 파이크': 13,
'박해일': 31,
' 유연석': 19,
'박보영': 17,
' 이종석': 6,
'김희애': 8,
' 고아성': 10,
'강동원': 21,
' 송혜교': 11,
'에바 그린': 13,
' 설리반 스탭플턴': 2,
'크리스찬 베일': 26,
' 조엘 에저튼': 1,
'김윤석': 30,
' 박유천': 5,
'송승헌': 13,
' 임지연': 3,
'안젤리나 졸리': 30,
' 엘르 패닝': 18,
'킷 해링턴': 5,
' 에밀리 브라우닝': 9,
'브래드 피트': 35,
' 로건 레먼': 11,
'루크 에반스': 10,
' 도미닉 쿠퍼': 12,
'크리스 프랫': 12,
' 조 샐다나': 20,
'김강우': 23,
' 정진영': 2,
'이정재': 32,
' 신하균': 30,
'차태현': 18,
' 남상미': 8,
'정재영': 1,
' 이성민': 23,
'조엘 킨나만': 8,
' 사무엘 L. 잭슨': 72,
'조진웅': 45,
' 김성균': 24,
'애나벨 월리스': 4,
' 워드 호튼': 2,
'제니퍼 로렌스': 19,
' 조쉬 허처슨': 17,
'벤 스틸러': 33,
' 크리스틴 위그': 12,
'염정아': 24,
' 문정희': 23,
'엄정화': 21,
' 문소리': 40,
'쉐일린 우들리': 7,
' 안셀 엘고트': 5,
'애런 존슨': 8,
' 브라이언 크랜스톤': 12,
'조니 뎁': 43,
' 레베카 홀': 14,
'한석규': 25,
' 고수': 13,
' 한지민': 10,
'장동건': 19,
' 김민희': 17,
'이민기': 12,
' 박성웅': 44,
'주원': 1,
' 최진리': 5,
'레오나르도 디카프리오': 24,
' 조나 힐': 16,
'라이언 구즈먼': 6,
' 브리아나 에비건': 6,
'도널 글리슨': 9,
' 레이첼 맥아담스': 20,
'치웨텔 에지오포': 15,
' 마이클 패스벤더': 25,
'박철민': 49,
' 윤유선': 15,
'해리슨 포드': 39,
'아사 버터필드': 7,
'강하늘': 13,
' 김소은': 6,
'하지원': 19,
' 강예원': 14,
' 이솜': 17,
' 테오 제임스': 8,
'사사키 노조미': 5,
' 아오야기 쇼': 2,
'지성': 7,
' 주지훈': 11,
'메간 폭스': 10,
' 피터 플로스잭': 1,
'설경구': 42,
' 박해일': 31,
'차승원': 28,
' 오정세': 62,
'디오고 모르가도': 2,
' 세바스찬 냅': 1,
'크리스 파인': 16,
' 키이라 나이틀리': 24,
'메릴 스트립': 40,
' 조니 뎁': 43,
'윤계상': 15,
' 고준희': 9,
'레아 세이두': 16,
' 뱅상 카셀': 26,
'아론 에크하트': 23,
' 빌 나이': 17,
'릴리 콜린스': 7,
' 샘 클라플린': 7,
'카렌 길런': 4,
' 브렌튼 스웨이츠': 8,
'에디 레드메인': 9,
' 펠리시티 존스': 13,
'피어스 브로스넌': 44,
' 올가 쿠릴렌코': 16,
' 댄 스티븐스': 7,
'케빈 코스트너': 39,
' 엠버 허드': 17,
'켈란 루츠': 9,
'스콧 앳킨스': 15,
'류세이 료': 1,
'윤상현': 3,
' 송새벽': 19,
'짐 캐리': 27,
' 제프 다니엘스': 27,
'프레데릭 벨': 6,
' 엘로디 퐁탕': 2,
' 테일러 키취': 8,
'김상경': 14,
'마이클 더글라스': 30,
' 로버트 드 니로': 68,
'성룡': 1,
' 류예': 15,
'실베스터 스탤론': 33,
' 제이슨 스타뎀': 33}

# %%
movies = {'명량': ['최민식', ' 류승룡'],
'인터스텔라': [' 앤 해서웨이'],
'수상한 그녀': ['심은경', ' 나문희'],
'해적: 바다로 간 산적': ['김남길', ' 손예진'],
'변호인': ['송강호', ' 김영애'],
'국제시장': ['황정민', ' 김윤진'],
'트랜스포머: 사라진 시대': ['마크 월버그', ' 니콜라 펠츠'],
'군도: 민란의 시대': ['하정우', ' 강동원'],
'엣지 오브 투모로우': ['톰 크루즈', ' 에밀리 블런트'],
'엑스맨: 데이즈 오브 퓨처 패스트': ['휴 잭맨', ' 제임스 맥어보이'],
'어메이징 스파이더맨 2': ['앤드류 가필드', ' 엠마 스톤'],
'혹성탈출: 반격의 서막': ['앤디 서키스', ' 게리 올드만'],
'타짜-신의 손': ['T.O.P', ' 신세경'],
'캡틴 아메리카: 윈터 솔져': ['크리스 에반스', ' 스칼렛 요한슨'],
'역린': ['현빈', ' 정재영'],
'신의 한 수': ['정우성', ' 이범수'],
'끝까지 간다': ['이선균', ' 조진웅'],
'표적': ['류승룡', ' 유준상'],
'메이즈 러너': ['딜런 오브라이언', ' 토마스 생스터'],
'호빗: 다섯 군대 전투': ['마틴 프리먼', ' 이안 맥켈런'],
'나의 사랑 나의 신부': ['조정석', ' 신민아'],
'논스톱': ['리암 니슨', ' 줄리안 무어'],
'인투 더 스톰': ['리처드 아미티지', ' 사라 웨인 콜리스'],
'노아': ['러셀 크로우', ' 제니퍼 코넬리'],
'남자가 사랑할 때': ['황정민', ' 한혜진'],
'루시': ['스칼렛 요한슨', ' 모건 프리먼'],
'용의자': ['공유', ' 박희순'],
'기술자들': ['김우빈', ' 김영철'],
'나를 찾아줘': ['벤 애플렉', ' 로자먼드 파이크'],
'제보자': ['박해일', ' 유연석'],
'피끓는 청춘': ['박보영', ' 이종석'],
'우아한 거짓말': ['김희애', ' 고아성'],
'두근두근 내 인생': ['강동원', ' 송혜교'],
'300: 제국의 부활': ['에바 그린', ' 설리반 스탭플턴'],
'엑소더스: 신들과 왕들': ['크리스찬 베일', ' 조엘 에저튼'],
'해무(海霧)': ['김윤석', ' 박유천'],
'인간중독': ['송승헌', ' 임지연'],
'말레피센트': ['안젤리나 졸리', ' 엘르 패닝'],
'폼페이: 최후의 날': [' 에밀리 브라우닝'],
'퓨리': ['브래드 피트', ' 로건 레먼'],
'드라큘라: 전설의 시작': ['루크 에반스', ' 도미닉 쿠퍼'],
'가디언즈 오브 갤럭시': ['크리스 프랫', ' 조 샐다나'],
'찌라시: 위험한 소문': ['김강우', ' 정진영'],
'빅매치': ['이정재', ' 신하균'],
'슬로우 비디오': ['차태현', ' 남상미'],
'방황하는 칼날': ['정재영', ' 이성민'],
'로보캅': ['조엘 킨나만', ' 사무엘 L. 잭슨'],
'우리는 형제입니다': ['조진웅', ' 김성균'],
'애나벨': ['애나벨 월리스', ' 워드 호튼'],
'헝거게임: 모킹제이': ['제니퍼 로렌스', ' 조쉬 허처슨'],
'월터의 상상은 현실이 된다': ['벤 스틸러', ' 크리스틴 위그'],
'카트': ['염정아', ' 문정희'],
'관능의 법칙': ['엄정화', ' 문소리'],
'안녕, 헤이즐': ['쉐일린 우들리', ' 안셀 엘고트'],
'고질라': ['애런 존슨', ' 브라이언 크랜스톤'],
'트랜센던스': ['조니 뎁', ' 레베카 홀'],
'상의원': ['한석규', ' 고수'],
'플랜맨': ['정재영', ' 한지민'],
'우는 남자': ['장동건', ' 김민희'],
'황제를 위하여': ['이민기', ' 박성웅'],
'패션왕': ['주원', ' 최진리'],
'더 울프 오브 월스트리트': ['레오나르도 디카프리오', ' 조나 힐'],
'스텝 업: 올 인': ['라이언 구즈먼', ' 브리아나 에비건'],
'어바웃 타임': ['도널 글리슨', ' 레이첼 맥아담스'],
'노예 12년': ['치웨텔 에지오포', ' 마이클 패스벤더'],
'또 하나의 약속': ['박철민', ' 윤유선'],
'엔더스 게임': ['해리슨 포드'],
'소녀괴담': ['강하늘', ' 김소은'],
'조선미녀삼총사': ['하지원', ' 강예원'],
'마담 뺑덕': ['정우성', ' 이솜'],
'다이버전트': ['쉐일린 우들리', ' 테오 제임스'],
'주온 : 끝의 시작': ['사사키 노조미', ' 아오야기 쇼'],
'좋은 친구들': ['지성', ' 주지훈'],
'닌자터틀': ['메간 폭스', ' 피터 플로스잭'],
'나의 독재자': ['설경구', ' 박해일'],
'하이힐': ['차승원', ' 오정세'],
'선 오브 갓': ['디오고 모르가도', ' 세바스찬 냅'],
'잭 라이언 : 코드네임 쉐도우': ['크리스 파인', ' 키이라 나이틀리'],
'숲속으로': ['메릴 스트립', ' 조니 뎁'],
'레드카펫': ['윤계상', ' 고준희'],
'미녀와 야수': ['레아 세이두', ' 뱅상 카셀'],
'프랑켄슈타인: 불멸의 영웅': ['아론 에크하트', ' 빌 나이'],
'러브, 로지': ['릴리 콜린스', ' 샘 클라플린'],
'오큘러스': ['카렌 길런', ' 브렌튼 스웨이츠'],
'사랑에 대한 모든 것': ['에디 레드메인', ' 펠리시티 존스'],
'노벰버 맨': ['피어스 브로스넌', ' 올가 쿠릴렌코'],
'툼스톤': ['리암 니슨', ' 댄 스티븐스'],
'쓰리데이즈 투 킬': ['케빈 코스트너', ' 엠버 허드'],
'헤라클레스 : 레전드 비긴즈': ['켈란 루츠'],
'덕수리 5형제': ['윤상현', ' 송새벽'],
'덤 앤 더머 투': ['짐 캐리', ' 제프 다니엘스'],
'컬러풀 웨딩즈': ['프레데릭 벨', ' 엘로디 퐁탕'],
'론 서바이버 ': ['마크 월버그', ' 테일러 키취'],
'아빠를 빌려드립니다': ['김상경', ' 문정희'],
'라스트베가스': ['마이클 더글라스', ' 로버트 드 니로'],
'호빗: 스마우그의 폐허': ['마틴 프리먼', ' 이안 맥켈런'],
'폴리스 스토리 2014': ['성룡', ' 류예'],
'익스펜더블 3': ['실베스터 스탤론', ' 제이슨 스타뎀']}

# %%
movie_actors = {}
for movie,actors in movies.items() :
    try :
        if len(actors) == 2  :
            movie_actors[movie] = (dict[actors[0]]+dict[actors[1]])/2
        if len(actors) == 1  :
            movie_actors[movie] = dict[actors[0]]
    except : 
        print(movie)

# %%
movie_actors
# Out:
# {'명량': 30.0,
#  '인터스텔라': 27,
#  '수상한 그녀': 17.5,
#  '해적: 바다로 간 산적': 18.0,
#  '변호인': 41.0,
#  '국제시장': 26.5,
#  '트랜스포머: 사라진 시대': 18.0,
#  '군도: 민란의 시대': 28.5,
#  '엣지 오브 투모로우': 30.5,
#  '엑스맨: 데이즈 오브 퓨처 패스트': 26.0,
#  '어메이징 스파이더맨 2': 13.5,
#  '혹성탈출: 반격의 서막': 27.5,
#  '타짜-신의 손': 8.0,
#  '캡틴 아메리카: 윈터 솔져': 27.0,
#  '역린': 7.0,
#  '신의 한 수': 37.5,
#  '끝까지 간다': 40.0,
#  '표적': 28.0,
#  '메이즈 러너': 4.0,
#  '호빗: 다섯 군대 전투': 16.5,
#  '나의 사랑 나의 신부': 13.0,
#  '논스톱': 49.0,
#  '인투 더 스톰': 5.0,
#  '노아': 30.0,
#  '남자가 사랑할 때': 21.5,
#  '루시': 44.0,
#  '용의자': 24.5,
#  '기술자들': 10.5,
#  '나를 찾아줘': 24.0,
#  '제보자': 25.0,
#  '피끓는 청춘': 11.5,
#  '우아한 거짓말': 9.0,
#  '두근두근 내 인생': 16.0,
#  '300: 제국의 부활': 7.5,
#  '엑소더스: 신들과 왕들': 13.5,
#  '해무(海霧)': 17.5,
#  '인간중독': 8.0,
#  '말레피센트': 24.0,
#  '폼페이: 최후의 날': 9,
#  '퓨리': 23.0,
#  '드라큘라: 전설의 시작': 11.0,
#  '가디언즈 오브 갤럭시': 16.0,
#  '찌라시: 위험한 소문': 12.5,
#  '빅매치': 31.0,
#  '슬로우 비디오': 13.0,
#  '방황하는 칼날': 12.0,
#  '로보캅': 40.0,
#  '우리는 형제입니다': 34.5,
#  '애나벨': 3.0,
#  '헝거게임: 모킹제이': 18.0,
# ...

# %%
len(movie_actors)
# Out:
# 98

# %%
dict = movie_actors

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'pactor' })
df.to_csv( './data_2014/2014_pactor', sep=',', encoding='utf-8' )
