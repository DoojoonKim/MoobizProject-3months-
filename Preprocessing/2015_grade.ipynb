# %%
dict = {'베테랑': '8.89',
'암살': '8.30',
'어벤져스: 에이지 오브 울트론': '9.52',
'국제시장': '8.76',
'내부자들': '7.77',
'사도': '8.67',
'미션 임파서블: 로그네이션': '9.59',
'킹스맨 : 시크릿 에이전트': '9.32',
'연평해전': '9.45',
'쥬라기 월드': '9.26',
'검은 사제들': '8.48',
'히말라야': '8.18',
'마션': '9.60',
'조선명탐정 : 사라진 놉의 딸': '8.45',
'매드 맥스: 분노의 도로': '8.92',
'인턴': '9.54',
'분노의 질주: 더 세븐': '9.71',
'터미네이터 제니시스': '7.35',
'스물': '9.04',
'극비수사': '8.74',
'앤트맨': '7.77',
'스타워즈: 깨어난 포스': '9.02',
'메이즈 러너: 스코치 트라이얼': '9.38',
'탐정 : 더 비기닝': '8.43',
'스파이': '9.38',
'악의 연대기': '8.45',
'강남 1970': '9.32',
'뷰티 인사이드': '5.65',
'오늘의 연애': '9.28',
'테이큰 3': '8.90',
'007 스펙터': '9.25',
'이미테이션 게임': '9.00',
'샌 안드레아스': '8.84',
'쎄시봉': '2.95',
'더 폰': '9.25',
'대호': '8.28',
'차이나타운': '8.32',
'장수상회': '9.23',
'성난 변호사': '7.91',
'간신': '8.31',
'박물관이 살아있다 : 비밀의 무덤': '9.40',
'그놈이다': '9.31',
'미쓰 와이프': '8.56',
'허삼관': '9.00',
'살인의뢰': '8.61',
'손님': '8.44',
'인시디어스 3': '8.61',
'하트 오브 더 씨': '8.97',
'헝거게임: 더 파이널': '8.65',
'기술자들': '8.84',
'신데렐라': '9.02',
'픽셀': '8.98',
'열정같은소리하고있네': '9.24',
'특종: 량첸살인기': '8.48',
'서부전선': '8.12',
'채피': '8.84',
'헬머니': '7.83',
'위험한 상견례 2': '8.87',
'순수의 시대': '8.89',
'협녀, 칼의 기억': '6.56',
'오피스': '8.19',
'무뢰한': '9.53',
'판타스틱 4': '8.06',
'내 심장을 쏴라': '9.18',
'소수의견': '6.95',
'그레이의 50가지 그림자': '8.28',
'경성학교: 사라진 소녀들': '8.84',
'치외법권': '8.38',
'아메리칸 스나이퍼': '9.14',
'에베레스트': '9.09',
'호빗: 다섯 군대 전투': '9.61',
'극적인 하룻밤': '8.61',
'도리화가': '7.81',
'주피터 어센딩': '8.32',
'패딩턴': '9.64',
'런 올 나이트': '9.04',
'인서전트': '8.90',
'백 투 더 비기닝': '7.99',
'투모로우랜드': '9.02',
'스파이 브릿지': '9.28',
'함정': '8.10',
'언브로큰': '9.66',
'하늘을 걷는 남자': '9.29',
'조선마술사': '7.79',
'언프렌디드: 친구삭제': '8.47',
'연애의 맛': '8.78',
'버드맨': '7.99',
'기생수 파트1': '8.05',
'팬': '8.80',
'더 셰프': '8.95',
'레전드': '9.46',
'19곰 테드 2': '9.04',
'인터스텔라': '9.58',
'아메리칸 울트라': '9.00',
'트랜스포터: 리퓰드': '8.32',
'워킹걸': '3.93',
'은밀한 유혹': '8.76',
'워터 디바이너': '9.21',
'나의 절친 악당들': '9.06'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'grade' })
df.to_csv( './data_2015/2015_grade', sep=',', encoding='utf-8' )
