# %%
import requests
import pandas as pd
import numpy as np
import os
import time

import datetime
import time
import json
from  pandas import DataFrame

# %% [markdown]
# # 영화 리뷰 데이터로 08~17년도 영화 리스트들

# %%
df_movie_review = pd.read_csv('./data/online_data_all')
df_movie_review = df_movie_review.iloc[:,:1]
df_movie_review.columns = ['movieNm']

# %% [markdown]
# # 08~17년도 영화 박스오피스 자료들

# %%
dir = os.listdir('./data')
dir.sort()
xlsx_list = [ file for file in dir if file.startswith('BoxOffice')]

# %%
for i, data in enumerate(xlsx_list):
    if i == 0:
        df = pd.read_excel('./data/'+data)
    else:
        small_df = pd.read_excel('./data/'+data)
        df = pd.concat([df, small_df])

# %%
df
# Out:
#      기간별 박스오피스 검색 리스트               Unnamed: 1           Unnamed: 2  \
# 0                 NaN                      NaN                  NaN
# 1                  순위                      영화명                  개봉일
# 2                 NaN                      NaN                  NaN
# 3                   1        좋은 놈, 나쁜 놈, 이상한 놈  2008-07-17 00:00:00
# 4                   2                      추격자  2008-02-14 00:00:00
# 5                   3                    쿵푸 팬더  2008-06-05 00:00:00
# 6                   4                    맘마미아!  2008-09-03 00:00:00
# 7                   5                    과속스캔들  2008-12-03 00:00:00
# 8                   6           강철중: 공공의 적 1-1  2008-06-19 00:00:00
# 9                   7                     아이언맨  2008-04-30 00:00:00
# 10                  8  인디아나 존스 4 : 크리스탈 해골의 왕국  2008-05-22 00:00:00
# 11                  9             미이라 3:황제의 무덤  2008-07-30 00:00:00
# 12                 10                   다크 나이트  2008-08-06 00:00:00
# ...

# %%
movie_list = ["1991, 봄",
'극장판 진격의 거인 2기: 각성의 포효',
'나츠메 우인장: 세상과 연을 맺다',
"바울",
'벽 속에 숨은 마법시계',
'보헤미안 랩소디',
'완벽한 타인',
'폴란드로 간 아이들',
'그린치',
'극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~',
'극장판 포켓몬스터 모두의 이야기',
'마약왕',
'스윙키즈',
'아쿠아맨',
'그린 북',
'내안의 그놈',
'말모이']
df1= pd.DataFrame({'movieNm':movie_list})
df1
# Out:
#                             movieNm
# 0                           1991, 봄
# 1             극장판 진격의 거인 2기: 각성의 포효
# 2                나츠메 우인장: 세상과 연을 맺다
# 3                                바울
# 4                      벽 속에 숨은 마법시계
# 5                          보헤미안 랩소디
# 6                            완벽한 타인
# 7                        폴란드로 간 아이들
# 8                               그린치
# 9   극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~
# 10                극장판 포켓몬스터 모두의 이야기
# 11                              마약왕
# 12                             스윙키즈
# 13                             아쿠아맨
# 14                             그린 북
# 15                           내안의 그놈
# 16                              말모이

# %%
df = df.rename( columns={'기간별 박스오피스 검색 리스트':'rank','Unnamed: 1' :'movieNm','Unnamed: 2': 'openDt',
              'Unnamed: 3':'sales', 'Unnamed: 4':'salesShare', 'Unnamed: 5':'salesAmt', 
              'Unnamed: 6':'audiCnt', 'Unnamed: 7':'audiCntAnt','Unnamed: 8': 'scrnCnt', 
              'Unnamed: 9':'showCnt', 'Unnamed: 10':'Nation','Unnamed: 11': 'Nation2',
              'Unnamed: 12':'Maker', 'Unnamed: 13':'Company','Unnamed: 14': 'Rate',
              'Unnamed: 15':'Genre', 'Unnamed: 16':'director','Unnamed: 17':'actor'})


# df = df.dropna()
# df.index = pd.RangeIndex(len(df))
# df = df.drop(1,0)
# df.index = pd.RangeIndex(len(df))

# df = df.drop('openDt', axis=1)
# # df['openDt']= pd.to_datetime(df['openDt'])

# %%
df = df.drop(0,0)
df = df.drop(1,0)
df = df.drop(2,0)
df.index = pd.RangeIndex(len(df))
df
# Out:
#        rank                  movieNm               openDt          sales  \
# 0         4                    맘마미아!  2008-09-03 00:00:00    29571255750
# 1         5                    과속스캔들  2008-12-03 00:00:00    28506879500
# 2         6           강철중: 공공의 적 1-1  2008-06-19 00:00:00    28638460100
# 3         7                     아이언맨  2008-04-30 00:00:00    27798047000
# 4         8  인디아나 존스 4 : 크리스탈 해골의 왕국  2008-05-22 00:00:00    26689440000
# 5         9             미이라 3:황제의 무덤  2008-07-30 00:00:00    26217311000
# 6        10                   다크 나이트  2008-08-06 00:00:00    26878184500
# 7        11             우리 생애 최고의 순간  2008-01-10 00:00:00    26113394000
# 8        12                      신기전  2008-09-04 00:00:00    24326353000
# 9        13                      원티드  2008-06-26 00:00:00    19249245000
# 10       14                       핸콕  2008-07-02 00:00:00    17844690500
# 11       15                      테이큰  2008-04-09 00:00:00    15971449000
# ...

# %%
df3 = pd.merge(df,df1, on='movieNm')
# df3 = df3.drop('rank', 1)
# df3 = df3.drop('sales', 1)
# df3 = df3.drop('salesShare', 1)
# df3 = df3.drop('salesAmt', 1)
# df3 = df3.drop('audiCntAnt', 1)
# df3 = df3.drop('showCnt', 1)
# df3 = df3.drop('Nation', 1)
# df3 = df3.drop('Nation2', 1)
# df3 = df3.drop('Maker', 1)
# df3 = df3.drop('Company', 1)
# df3 = df3.drop('Rate', 1)
# df3 = df3.drop('Genre', 1)
# df3 = df3.drop('director', 1)
# df3 = df3.drop('actor', 1)
# df3.to_csv('./data/1991_봄.csv', encoding='euc-kr')
df3
# Out:
#    rank  movieNm               openDt    sales salesShare salesAmt audiCnt  \
# 0  1644  1991, 봄  2018-10-31 00:00:00  1045400          0  1045400     168
#
#   audiCntAnt scrnCnt showCnt Nation Nation2     Maker   Company      Rate  \
# 0        168       1       4     한국      한국  (주)해밀픽쳐스  (주)인디플러그  12세이상관람가
#
#    Genre director actor
# 0  다큐멘터리      권경원   강기훈

# %%
def
# # df = df.dropna()
# df = df.drop(1,0)
# # df = df.drop('Nation2', 1)
# # df = df.drop('1', 1)
# # df = df.drop('2', 1)
# # df = df.drop('4', 1) 
# # df = df.drop('5', 1)
# # df = df.drop('6', 1)
# Out:
#   File "<ipython-input-10-ce176b9d81ff>", line 1
#     def
#        ^
# SyntaxError: invalid syntax

# %%
df_a = df.drop_duplicates(subset='movieNm', keep='first')
df_a.to_excel('./data/국적비교.xlsx')

# %%
df_director = pd.DataFrame({'movieNm':df['movieNm'], 'director':df['director']})
df_director = df_director.dropna()
df_director = df_director.drop(1,0)
df_director.index = pd.RangeIndex(len(df_director))
df_director
# Out:
#                        movieNm                     director
# 0                        맘마미아!                      필리다 로이드
# 1               강철중: 공공의 적 1-1                          강우석
# 2                         아이언맨                        존 파브로
# 3      인디아나 존스 4 : 크리스탈 해골의 왕국                     스티븐 스필버그
# 4                 미이라 3:황제의 무덤                         롭 코헨
# 5                       다크 나이트                     크리스토퍼 놀란
# 6                 우리 생애 최고의 순간                          임순례
# 7                          신기전                          김유진
# 8                          원티드                   티무르 베크맘베토브
# 9                           핸콕                        피터 버그
# 10                         테이큰                       피에르 모렐
# 11                         미인도                          전윤수
# 12                       이글 아이                     D.J. 카루소
# 13               007 퀀텀 오브 솔러스                       마크 포스터
# 14                 눈에는 눈 이에는 이                      곽경택,안권태
# ...

# %% [markdown]
# # 리뷰들을 크롤링 했던 10년치 영화들

# %%
df_movie_review
# Out:
#                      movieNm
# 0                    7번방의 선물
# 1                         감기
# 2                       감시자들
# 3                       결혼전야
# 4                     고령화 가족
# 5                         공범
# 6                         관상
# 7                        깡철이
# 8           나우 유 씨 미 : 마술사기단
# 9                    남자사용설명서
# 10                   남쪽으로 튀어
# 11                       노리개
# 12                      노브레싱
# 13           다이하드: 굿 데이 투 다이
# 14                     더 울버린
# 15                더 웹툰: 예고살인
# 16                    더 임파서블
# 17                  더 테러 라이브
# 18                     더 파이브
# 19                       동창생
# 20                       런닝맨
# 21                 레드: 더 레전드
# 22                     레미제라블
# 23                     론 레인저
# 24                     롤러코스터
# 25                 마이 리틀 히어로
# 26                   맨 오브 스틸
# 27                       몽타주
# 28                 무서운 이야기 2
# 29                     미나문방구
# ..                       ...
# ...

# %% [markdown]
# # 감독의 최대 관객수

# %%
df_director = pd.merge(df_director, df_movie_review, on='movieNm')
df_director = df_director.drop_duplicates(subset='movieNm', keep='first')
# df =d df.iloc[:, :2]
# df_director.index = pd.RangeIndex(len(df))
# df['openDt']= pd.to_datetime(df['openDt'])
df_director
# Out:
#                       movieNm           director
# 0                       맘마미아!            필리다 로이드
# 8              강철중: 공공의 적 1-1                강우석
# 10                       아이언맨              존 파브로
# 13    인디아나 존스 4 : 크리스탈 해골의 왕국           스티븐 스필버그
# 14               미이라 3:황제의 무덤               롭 코헨
# 15                     다크 나이트           크리스토퍼 놀란
# 19               우리 생애 최고의 순간                임순례
# 20                        신기전                김유진
# 23                        원티드         티무르 베크맘베토브
# 25                         핸콕              피터 버그
# 26                        테이큰             피에르 모렐
# 27                        미인도                전윤수
# 29                      이글 아이           D.J. 카루소
# 30              007 퀀텀 오브 솔러스             마크 포스터
# 32                눈에는 눈 이에는 이            곽경택,안권태
# 33                   아내가 결혼했다                정윤수
# 34                    님은 먼 곳에                이준익
# 36                         점퍼             더그 라이만
# ...

# %%
df_audiCnt = pd.DataFrame({'movieNm':df['movieNm'], 'director':df['director'],'audiCnt':df['audiCnt']})
df_audiCnt = df_audiCnt.dropna()
# df_audiCnt = df_audiCnt.drop(1,0)
df_audiCnt
# Out:
#                        movieNm                     director  audiCnt
# 0                        맘마미아!                      필리다 로이드  4552475
# 1                        과속스캔들                          강형철  4361509
# 2               강철중: 공공의 적 1-1                          강우석  4313101
# 3                         아이언맨                        존 파브로  4290816
# 4      인디아나 존스 4 : 크리스탈 해골의 왕국                     스티븐 스필버그  4111753
# 5                 미이라 3:황제의 무덤                         롭 코헨  4090885
# 6                       다크 나이트                     크리스토퍼 놀란  4060490
# 7                 우리 생애 최고의 순간                          임순례  4018059
# 8                          신기전                          김유진  3728430
# 9                          원티드                   티무르 베크맘베토브  2858720
# 10                          핸콕                        피터 버그  2722574
# 11                         테이큰                       피에르 모렐  2359061
# 12                         미인도                          전윤수  2341521
# ...

# %% [markdown]
# # 관객수를 내림차순으로 해주고, 여기서 감독명이 처음 등장하면 감독당 최대관객수 데이터셋
# - movieNm_y에서 이 감독을 최대 관객수의 성과를 냈다

# %%
df_director_set = pd.merge(df_director, df_audiCnt, on='director')
# df_director_set = df_director_set.sort_values(['audiCnt'], ascending=False)
# df_director_2 = df_director_2.sort_values(['audiCnt'], ascending=[False]) 
df_director_set = df_director_set.sort_values(['audiCnt'], ascending=False)
df_director_set = df_director_set.drop_duplicates('director', keep='first')
df_director_set.index = pd.RangeIndex(len(df_director_set))
df_director_set.to_csv('./data/감독파워.csv', encoding='euc-kr')

# %% [markdown]
# # 10년 영화데이터들 엑셀로 만들어두기

# %%
df.to_excel('./data/Moobiz_data.xlsx', encoding='utf-8')

# %%
df
# Out:
#        rank                  movieNm               openDt          sales  \
# 0         4                    맘마미아!  2008-09-03 00:00:00    29571255750
# 1         5                    과속스캔들  2008-12-03 00:00:00    28506879500
# 2         6           강철중: 공공의 적 1-1  2008-06-19 00:00:00    28638460100
# 3         7                     아이언맨  2008-04-30 00:00:00    27798047000
# 4         8  인디아나 존스 4 : 크리스탈 해골의 왕국  2008-05-22 00:00:00    26689440000
# 5         9             미이라 3:황제의 무덤  2008-07-30 00:00:00    26217311000
# 6        10                   다크 나이트  2008-08-06 00:00:00    26878184500
# 7        11             우리 생애 최고의 순간  2008-01-10 00:00:00    26113394000
# 8        12                      신기전  2008-09-04 00:00:00    24326353000
# 9        13                      원티드  2008-06-26 00:00:00    19249245000
# 10       14                       핸콕  2008-07-02 00:00:00    17844690500
# 11       15                      테이큰  2008-04-09 00:00:00    15971449000
# ...

# %% [markdown]
# # 배우 데이터셋

# %%
df_etc = pd.DataFrame({'rank':df['rank'],'movieNm': df['movieNm'], 'Maker' :df['Maker'], "genre":df['Genre'], 'director':df['director'], 'actor': df['actor'] })


df_etc
# Out:
#        rank                  movieNm                     Maker  \
# 0         4                    맘마미아!                       NaN
# 1         5                    과속스캔들       (주)토일렛픽쳐스,(주)디씨지플러스
# 2         6           강철중: 공공의 적 1-1    (주)시네마서비스글로벌,(주)시네마서비스
# 3         7                     아이언맨                       NaN
# 4         8  인디아나 존스 4 : 크리스탈 해골의 왕국                       NaN
# 5         9             미이라 3:황제의 무덤                       NaN
# 6        10                   다크 나이트                       NaN
# 7        11             우리 생애 최고의 순간                 (주)엠케이픽처스
# 8        12                      신기전              (주)시네마서비스글로벌
# 9        13                      원티드                       NaN
# 10       14                       핸콕                       NaN
# 11       15                      테이큰                       NaN
# 12       16                      미인도            ㈜이룸영화사,(주)영화사참
# 13       17                    이글 아이                       NaN
# ...

# %% [markdown]
# # 영화배우들중 앞에 3명까지는 주연배우라 가정하고 actor1, 2, 3로 나눠서 데이터셋 만들기

# %%
df_actor1 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
for i, d in enumerate(df_etc['actor']):
    if type(d) == str:
        df_actor1.iloc[i]['actor1'] = ','.join(d.split(',')[0:1])
    else:
        i, df_etc.iloc[i]

        
df_actor2 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
for i, d in enumerate(df_etc['actor']):
    if type(d) == str:
        df_actor2.iloc[i]['actor1'] = ','.join(d.split(',')[1:2])
    else:
        i, df_etc.iloc[i]

df_actor3 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
for i, d in enumerate(df_etc['actor']):
    if type(d) == str:
        df_actor3.iloc[i]['actor1'] = ','.join(d.split(',')[2:3])
    else:
        i, df_etc.iloc[i]

# df_actor4 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor4.iloc[i]['actor1'] = ','.join(d.split(',')[3:4])
#     else:
#         i, df_etc.iloc[i]

# df_actor5 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor5.iloc[i]['actor1'] = ','.join(d.split(',')[4:5])
#     else:
#         i, df_etc.iloc[i]

# df_actor6 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor6.iloc[i]['actor1'] = ','.join(d.split(',')[5:6])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor7 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor7.iloc[i]['actor1'] = ','.join(d.split(',')[6:7])
#     else:
#         i, df_etc.iloc[i]

# df_actor8 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor8.iloc[i]['actor1'] = ','.join(d.split(',')[7:8])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor9 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor9.iloc[i]['actor1'] = ','.join(d.split(',')[8:9])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor10 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor10.iloc[i]['actor1'] = ','.join(d.split(',')[9:10])
#     else:
#         i, df_etc.iloc[i]

# df_actor11 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor11.iloc[i]['actor1'] = ','.join(d.split(',')[10:11])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor12 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor12.iloc[i]['actor1'] = ','.join(d.split(',')[11:12])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor13 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor13.iloc[i]['actor1'] = ','.join(d.split(',')[12:13])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor14 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor14.iloc[i]['actor1'] = ','.join(d.split(',')[13:14])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor15 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor15.iloc[i]['actor1'] = ','.join(d.split(',')[14:15])
#     else:
#         i, df_etc.iloc[i]
        
# df_actor16 = pd.DataFrame({'movieNm' : df_etc['movieNm'], 'actor1':'' })
# for i, d in enumerate(df_etc['actor']):
#     if type(d) == str:
#         df_actor16.iloc[i]['actor1'] = ','.join(d.split(',')[15:16])
#     else:
#         i, df_etc.iloc[i]



# df_actor = pd.concat([df_actor1, df_actor2, df_actor3 ,df_actor4, df_actor5,
#                      df_actor6, df_actor7, df_actor8, df_actor9, df_actor10,
#                      df_actor11, df_actor12, df_actor13, df_actor14, df_actor15,
#                      df_actor16], ignore_index=True )
# df_actor

# %%
df_actor_audiCnt = pd.DataFrame({'movieNm': df['movieNm'], 'audiCntAmt': df['audiCntAnt'] })
# df_actor_audiCnt = df_actor_audiCnt.dropna()
# df_actor_audiCnt = df_actor_audiCnt.drop(1,0)
# df_actor_audiCnt.to_excel('./data/asd.xlsx', encoding='utf-8')
# = pd.to_numeric(df_actor_audiCnt['audiCntAmt'])
# df_actor_audiCnt = pd.merge(df_actor1, df_actor_audiCnt, on='movieNm')
# df_actor_audiCnt = pd.merge(df_actor2, df_actor_audiCnt, on='movieNm')
# df_actor_audiCnt = pd.merge(df_actor3, df_actor_audiCnt, on='movieNm')
# df_actor_audiCnt = df_actor_audiCnt.rename(columns={'actor1_x':'actor2', 'actor1_y':'actor3'})
# df_actor_audiCnt
# df_actor_audiCnt
# .sort_values('audiCntAmt', ascending=False)
# Out:
#                        movieNm audiCntAmt
# 0                        맘마미아!    4552475
# 1                        과속스캔들    4361509
# 2               강철중: 공공의 적 1-1    4313101
# 3                         아이언맨    4290816
# 4      인디아나 존스 4 : 크리스탈 해골의 왕국    4111753
# 5                 미이라 3:황제의 무덤    4090885
# 6                       다크 나이트    4060490
# 7                 우리 생애 최고의 순간    4018872
# 8                          신기전    3728430
# 9                          원티드    2858720
# 10                          핸콕    2722574
# 11                         테이큰    2359061
# 12                         미인도    2341521
# 13                       이글 아이    2292172
# 14               007 퀀텀 오브 솔러스    2205159
# 15                 눈에는 눈 이에는 이    2058616
# 16                    아내가 결혼했다    1799447
# 17                     님은 먼 곳에    1706037
# 18                          점퍼    1665268
# 19                고死 : 피의 중간고사    1634192
# 20                       무방비도시    1600856
# ...

# %%
# df_actor_audiCnt['audiCntAmt'].str.stripe()
# df_actor_audiCnt['audiCntAmt'].int.extract('(\d+)')
# df_actor_audiCnt.audiCntAmt.astype(int)
# df_actor_audiCnt
# df_actor_audiCnt.sort_values('audiCntAmt', ascending=False)
# df_actor_audiCnt = df_actor_audiCnt[df_actor_audiCnt['movieNm']!= '영화명']

# %%
df_actor_audiCnt = df_actor_audiCnt[df_actor_audiCnt['movieNm']!= '영화명']
df_actor_audiCnt = df_actor_audiCnt.sort_values('audiCntAmt', ascending=False)
df_actor_audiCnt
# Out:
#                              movieNm audiCntAmt
# 29360                            NaN  650269619
# 20255                            NaN  565401541
# 24553                            NaN  564438332
# 16798                            NaN  493486269
# 13434                            NaN  401403800
# 9806                             NaN  336788651
# 6514                             NaN  304035008
# 3000                             NaN  260190281
# 1816                             NaN  257159914
# 4360                             NaN  239519591
# 26718                             명량   17615152
# 23287                             명량   17615057
# 17438                             명량   17615039
# 13435                             명량   17613682
# 25835                           국제시장   14262498
# 21179                           국제시장   14262198
# 16802                           국제시장   14261581
# 21776                            베테랑   13414200
# 16799                            베테랑   13414009
# ...

# %%
df_actor = pd.concat([df_actor1, df_actor2, df_actor3], ignore_index=True)
# Out:
#                        movieNm       actor1
# 0                        맘마미아!    아만다 사이프리드
# 1                        과속스캔들          차태현
# 2               강철중: 공공의 적 1-1          설경구
# 3                         아이언맨  로버트 다우니 주니어
# 4      인디아나 존스 4 : 크리스탈 해골의 왕국       해리슨 포드
# 5                 미이라 3:황제의 무덤     브렌든 프레이저
# 6                       다크 나이트      크리스찬 베일
# 7                 우리 생애 최고의 순간          문소리
# 8                          신기전          정재영
# 9                          원티드     제임스 맥어보이
# 10                          핸콕        윌 스미스
# 11                         테이큰        리암 니슨
# 12                         미인도          김민선
# 13                       이글 아이      샤이아 라보프
# 14               007 퀀텀 오브 솔러스     다니엘 크레이그
# 15                 눈에는 눈 이에는 이          한석규
# 16                    아내가 결혼했다          손예진
# 17                     님은 먼 곳에           수애
# 18                          점퍼       레이첼 빌슨
# 19                고死 : 피의 중간고사          이범수
# ...

# %%
df_actor = df_actor.dropna()
df_actor = df_actor[df_actor['movieNm'] != '영화명']
df_actor
# Out:
#                        movieNm       actor1
# 0                        맘마미아!    아만다 사이프리드
# 1                        과속스캔들          차태현
# 2               강철중: 공공의 적 1-1          설경구
# 3                         아이언맨  로버트 다우니 주니어
# 4      인디아나 존스 4 : 크리스탈 해골의 왕국       해리슨 포드
# 5                 미이라 3:황제의 무덤     브렌든 프레이저
# 6                       다크 나이트      크리스찬 베일
# 7                 우리 생애 최고의 순간          문소리
# 8                          신기전          정재영
# 9                          원티드     제임스 맥어보이
# 10                          핸콕        윌 스미스
# 11                         테이큰        리암 니슨
# 12                         미인도          김민선
# 13                       이글 아이      샤이아 라보프
# 14               007 퀀텀 오브 솔러스     다니엘 크레이그
# 15                 눈에는 눈 이에는 이          한석규
# 16                    아내가 결혼했다          손예진
# 17                     님은 먼 곳에           수애
# 18                          점퍼       레이첼 빌슨
# 19                고死 : 피의 중간고사          이범수
# ...

# %%
df_actor_att = pd.merge(df_actor, df_actor_audiCnt, on='movieNm')
df_actor_att = df_actor_att.sort_values('audiCntAmt', ascending=False)
df_actor_att = df_actor_att.drop_duplicates('actor1', keep='first')
df_actor_att.index = pd.RangeIndex(len(df_actor_att))
df_actor_att.to_excel('./data/배우최대관객수.xlsx', encoding='utf-8')
# df_actor_att.to_csv('./data/배우최대관객수.csv', encoding='euc-kr')
# to_csv('./data/배우최대관객수.csv', encoding='euc-kr')

# %% [markdown]
# # 밑에부터는 안봐도 됨

# %%
df_actor = pd.DataFrame({'movieNm':df['movieNm'], 'audiCnt':df['audiCnt'], 'actor':df['actor']})
df_actor

# %%
# df_actor = df_actor.drop_duplicates(subset='movieNm', keep='first')
df_actor['audiCnt'] = df_actor['audiCnt'].sort_values(ascending=False)

# %%
df_actor = df_actor.drop_duplicates(subset='movieNm', keep='first')
df_actor.index = pd.RangeIndex(len(df_actor))

# %%
df_actor = df_actor.dropna()
df_actor.to_excel('./data/배두별 최대 관객수.xlsx', encoding='utf-8')

# %%
actor_list = ['김윤석,하정우', '아만다 사이프리드,메릴 스트립', '차태현,박보영', '설경구,정재영',
       '로버트 다우니 주니어,테렌스 하워드', '해리슨 포드,샤이아 라보프', '브렌든 프레이저,마리아 벨로',
       '크리스찬 베일,마이클 케인', '문소리,김정은', '정재영,한은정', '제임스 맥어보이,안젤리나 졸리',
       '윌 스미스,샤를리즈 테론', '리암 니슨,매기 그레이스', '김민선,김영호', '샤이아 라보프,미셸 모나한',
       '다니엘 크레이그,올가 큐리렌코', '한석규,차승원', '손예진,김주혁', '수애,정진영',
       '레이첼 빌슨,헤이든 크리스텐슨', '김명민,손예진', '양조위,금성무', '변희봉,손현주', '소지섭,강지환',
       '키아누 리브스,제니퍼 코넬리', '크리스틴 스튜어트,로버트 패틴슨', '제리 사인펠드,르네 젤위거', '이연걸,성룡',
       '주지훈,김재욱', '스티븐 스트레이트,카밀라 벨', '김하늘,윤계상', '사라 제시카 파커,킴 캐트럴',
       '선자 손,윌 켐프', '유덕화,매기 큐', '차태현,하지원', '휴 잭맨,니콜 키드먼', '천호진,조현재',
       '차인표,신명철', '짐 캐리,주이 데샤넬', '정지훈,매튜 폭스', '이새별,박해일', '유지태,이연희',
       '하정우,이정민', '조니 뎁,헬레나 본햄 카터', '제라드 버틀러', '카메론 디아즈,애쉬튼 커처',
       '나탈리 포트만,스칼렛 요한슨', '프레디 하이모어,사라 볼거', '김수로,이한위', '줄리안 무어,마크 러팔로',
       '다니엘 크레이그,니콜 키드먼', '곽선영,조승우', '레오나르도 디카프리오,러셀 크로우', '이미숙,김민희',
       '리지 캐플란,오데뜨 유스트만', '제이슨 스타뎀,세프론 버로우스', '홍희자,황정민', '유해진,진구',
       '니콜라스 케이지,존 보이트', '공효진,이종혁', '로리 홀든,토마스 제인', '조인성,주진모', '김선아,박진희',
       '장근석,문메이슨', '에이미 아담스,패트릭 뎀시', '손태영,장근석', '전도연,하정우', '이연걸,유덕화',
       '쿠도 유키,마츠야마 켄이치', '마크 웰버그,주이 데샤넬', '힐러리 스웽크,제라드 버틀러', '주성치,서교',
       '임창정,송지효', '브래들리 쿠퍼,레슬리 빕', '스티븐 파스퀄,레이코 아일리스워스', '이정재,김석훈',
       '잭 니콜슨,모건 프리먼', '키아누 리브스,포레스트 휘테커', '프레디 하이모어,조나단 리스 마이어스',
       '봉태규,김영애', '신현준,허준호', '안성기,이창민', '밀라 쿠니스,마크 웰버그',
       '키이라 나이틀리,랄프 파인즈', '나문희,김선아', '스캇 스피드맨,리브 타일러', '데이비드 듀코브니',
       '캐서린 헤이글,제임스 마스던', '가엘 가르시아 베르날,윌리엄 허트', '찰톤 헤스톤,잭 호킨스',
       '다니엘 크레이그,제이미 벨', '니시지마 히데토시,카타오카 레이코', '무로이 시게루,코바야시 넨지',
       '최원균,이삼순', '제이슨 스타뎀,나탈리아 루다코바', '설경구,하지원', '하정우,성동일',
       '샤이아 라보프,메간 폭스', '샘 워싱턴,조 샐다나', '크리스찬 베일,샘 워싱턴', '김하늘,강지환',
       '김윤석,정경호', '다니엘 래드클리프,엠마 왓슨', '금성무,양조위', '채닝 테이텀,버튼 페레즈',
       '한동학,장동건', '강동원,임수정', '송강호,김옥빈', '하지원,김명민', '벤 스틸러,에이미 아담스',
       '로버트 패틴슨,크리스틴 스튜어트', '톰 행크스,이완 맥그리거', '김성태,최강희', '송요셉,황정민',
       '톰 크루즈,빌 나이히', '엄태웅,정유미', '브래드 피트,케이트 블란쳇', '최경원,조승우', '정준호,최경원',
       '박용하,박희순', '정지훈,나오미 해리스', '임창정,박예진', '휴 잭맨,리브 슈라이버', '이범수,조안',
       '김래원,엄정화', '로버트 다우니 주니어,주드 로', '데브 파텔,프리다 핀토', '크리스 파인,재커리 퀸토',
       '니콜라스 케이지,로즈 번', '한석규,손예진', '제니퍼 코넬리,드류 베리모어', '샬토 코플리,제이슨 코프',
       '김강우,조재현', '제라드 버틀러,제이미 폭스', '브루스 윌리스,라다 미첼', '에릭 바나,레이첼 맥아덤즈',
       '정재영,구교환', '크리스 에반스,다코타 패닝', '권상우,이보영', '빈 디젤,폴 워커', '오연서,장경아',
       '케이 파나베이커,애셔 북', '엄태웅,박용우', '서민균,이범수', '제프리 딘 모건,빌리 크루덥',
       '브렌든 프레이저,시에나 길로리', '정진영,장근석', '안젤리나 졸리,존 말코비치', '고현정,김민희',
       '시릴 라파엘리,데이빗 벨', '베라 파미가,이사벨 퍼만', '조니 뎁,크리스찬 베일', '랄프 파인즈,케이트 윈슬렛',
       '김강우,황정민', '박해일,신민아', '저스틴 채트윈,주윤발', '조니 뎁,히스 레저', '윤계상,조재현',
       '다코타 블루 리차드,이안 그루퍼드', '존 트라볼타,덴젤 워싱턴', '브래드 피트,크리스토프 왈츠',
       '산드라 블록,라이언 레놀즈', '김선영,이범수', '밀라 요보비치,티모시 올리펀트', '아일라 피셔,휴 댄시',
       '제라드 버틀러,앰버 발레타', '카고 아이,미나미 아키나', '정우성,고원원', '바비 캠포,닉 자노',
       '저스틴 롱,알리슨 로먼', '유진,박한별', '남상미,류승룡', '우마 서먼,콜린 퍼스',
       '클라이브 오웬,나오미 왓츠', '윌 스미스,우디 해럴슨', '강혜정,박희순', '오데뜨 유스트만,게리 올드만',
       '조쉬 하트넷,이병헌', '오웬 윌슨,제니퍼 애니스턴', '제러드 파달렉키,다니엘 파나베이커',
       '오드리 토투,브누와 뽀엘부르드', '저스틴 롱,매튜 그레이 구블러', '다니엘 데이 루이스,마리온 꼬띨라르',
       '설경구,류승범', '원빈,김새론', '레오나르도 디카프리오,엘렌 페이지', '송강호,강동원',
       '로버트 다우니 주니어,기네스 팰트로우', '정재영,박해일', '차승원,권상우', '김윤진,김호연', '김주혁,류승범',
       '안젤리나 졸리', '황정민,김승훈', '엄태웅,이민정', '전도연,이정재', '톰 크루즈,카메론 디아즈',
       '조니 뎁,앤 해서웨이', '강동원,김한나', '이선균,최강희', '제이크 질렌할,젬마 아터튼',
       '로건 레먼,피어스 브로스넌', '이영수,설경구', '이병헌,최민식', '러셀 크로우,케이트 블란쳇',
       '주진모,송승헌', '톰 행크스,조앤 쿠삭', '황정민,김성훈', '잭슨 라스본,데브 파텔', '차태현,강예원',
       '나문희,김수미', '수애,유지태', '밀라 요보비치,웬트워스 밀러', '벤 반스,조지 헨리', '엄정화,류승룡',
       '임수정,공유', '김명민,엄기준', '마크 러팔로,레오나르도 디카프리오', '김인권,김정태', '지진희,심호성',
       '안젤리나 졸리,조니 뎁', '에릭 벌포,스카티 톰슨', '김수로,황정음', '리암 니슨,퀸튼 잭슨',
       '지현우,조한선', '달이,성동일', '박중훈,정유미', '샤니 빈슨,릭 말람브리', '정보석,배한성',
       '오재균,한석규', '맷 데이먼,제이슨 아이삭스', '김미소,유오성', '아만다 사이프리드,크리스토퍼 에건',
       '김수로,한재석', '니콜라스 케이지,모니카 벨루치', '심형래,마이클 리스폴리', '제시 아이젠버그,앤드류 가필드',
       '엘리자베스 슈,제시카 스자르', '줄리아 로버츠,제임스 프랑코', '임창정,엄지원', '김해숙,박진희',
       '김정은,진구', '유덕화,양가휘', '덴젤 워싱턴,크리스 파인', '손병호,임원희', '장동건,케이트 보스워스',
       '사라 제시카 파커,크리스틴 데이비스', '실베스터 스탤론,제이슨 스타뎀', '주윤발,주신',
       '존 트라볼타,조나단 리스 마이어스', '산드라 블록', '박희순,고창석', '애쉬튼 커처,캐서린 헤이글',
       '정우성,양자경', '제이든 스미스,성룡', '애드리언 브로디,토퍼 그레이스', '에밀리 블런트,베니치오 델 토로',
       '샤이아 라보프,마이클 더글라스', '메릴 스트립,알렉 볼드윈', '신경선,윤이나', '밀라 요보비치,윌 패튼',
       '덴젤 워싱턴,게리 올드만', '윤정희,이다윗', '러셀 크로우,엘리자베스 뱅크스', '마크 월버그,레이첼 와이즈',
       '엠마 톰슨', '신하균,박소현', '발리에리 르메르시,막심 고다르', '멜 깁슨', '제프 브리지스,가렛 헤드룬드',
       '김윤진,박해일', '이병헌,한채영', '아마미 유키', '조쉬 더하멜,존 말코비치', '박해일,류승룡',
       '유호정,심은경', '김윤석,유아인', '톰 크루즈,제레미 레너', '김명민,김호연', '정유미,공유', '휴 잭맨',
       '이안 맥쉐인,페넬로페 크루즈', '이새별,고창석', '신하균,고수', '손예진,이민기',
       '브라이언 콕스,제임스 프랭코', '송새벽,이시영', '로즈 번,재뉴어리 존스', '박희순,장혁', '김수미,신현준',
       '강신일,김미경', '박용우,류승룡', '잭 블랙', '정진영,이문식', '스텔란 스카스가드,스튜어트 타운젠드',
       '나탈리 포트만,뱅상 카셀', '드웨인 존슨,폴 워커', '장동건,오다기리 조', '미키 루크,헨리 카빌',
       '아론 에크하트,미쉘 로드리게즈', '미셸 모나한,제이크 질렌할', '우혜진,엄태웅', '윤하,류승범',
       '소지섭,한효주', '안젤라 랜스베리,짐 캐리', '박중훈,이선균', '현빈,탕웨이', '조승우,양동근',
       '콜린 퍼스,제프리 러쉬', '황우슬혜,함은정', '송강호,신세경', '윤계상,김규리', '정려원,권상우',
       '김예론,김동욱', '로건 레먼,올랜도 블룸', '티모시 올리펀트,알렉스 페티퍼', '조나 힐,브래드 피트',
       '아만다 사이프리드,킬리언 머피', '칼럼 블루,조 샐다나', '장근석,김하늘', '차태현,김수정', '앤 해서웨이',
       '크리스 에반스,휴고 위빙', '조엘 코트니,엘르 패닝', '정재영,전도연', '이안 그루퍼드,리차드 록스버그',
       '니콜라스 케이지,론 펄먼', '황정민,김민희', '임창정,김규리', '맷 데이먼,에밀리 블런트',
       '아만다 사이프리드,게리 올드만', '공형진,김주혁', '라이언 필립,매튜 매커너히', '김갑수,서영희',
       '윤은혜,박한별', '공리,주윤발', '나탈리 포트만,애쉬튼 커처', '데이비드 코에너',
       '다니엘 크레이그,해리슨 포드', '김주혁,유해진', '벨렌 루에다', '맷 데이먼,기네스 팰트로우',
       '안성기,박원상', '이민정,이정진', '아누크 에메,장-루이 트린티냥', '클라크 게이블,비비안 리',
       '오군여,주혜민', '로버트 레드포드,데미 무어', '다니엘 크레이그,루니 마라', '김윤석,김혜수',
       '이병헌,류승룡', '로버트 다우니 주니어,스칼렛 요한슨', '송중기,박보영', '크리스찬 베일,게리 올드만',
       '앤드류 가필드,엠마 스톤', '최민식,하정우', '임수정,이선균', '김명민,강지원', '엄태웅,한가인',
       '황정민,엄정화', '휴 잭맨,러셀 크로우', '진구,한혜진', '정재영,박시후', '조여정,김동욱',
       '마틴 프리먼,이안 맥켈런', '이선균,김민희', '김윤진,마동석', '다니엘 크레이그,하비에르 바르뎀',
       '리암 니슨,테일러 키치', '설경구,손예진', '하지원,배두나', '고수,한효주', '하정우,공효진',
       '프랑수아 클뤼제,오마 사이', '임창정,최다니엘', '송강호,이여진', '류승범,이요원', '강지환,성유리',
       '박해일,김무열', '김명민,염정아', '박희순,박시연', '콜린 파렐,케이트 베킨세일', '정지훈,유준상',
       '김강우,백윤식', '드웨인 존슨,마이클 케인', '소지섭,이미연', '제레미 레너,레이첼 와이즈', '조성현,정준호',
       '이범수,류승범', '유선,남보라', '누미 라파스,마이클 패스벤더', '라이언 구즈만,캐서린 맥코믹',
       '김수로,오상철', '샘 워싱턴,리암 니슨', '리즈 위더스푼,크리스 파인', '박보영,주원', '주지훈,백윤식',
       '샤를리즈 테론,크리스틴 스튜어트', '고현정,유해진', '제니퍼 로렌스,조쉬 허처슨',
       '샘 워싱턴,엘리자베스 뱅크스', '박용우,고아라', '줄리아 로버츠,릴리 콜린스', '조니 뎁,미쉘 파이퍼',
       '조셉 고든 레빗,브루스 윌리스', '밀라 요보비치,미셸 로드리게즈', '송새벽,성동일', '김명민,안성기',
       '가이 피어스,매기 그레이스', '실베스터 스탤론,브루스 윌리스', '박한별,김지석', '데인 드한,알렉스 러셀',
       '벤자민 워커,도미닉 쿠퍼', '김현수,노강민', '장동건,장쯔이', '리암 니슨,더못 멀로니', '엄태웅,김현정',
       '맷 데이먼,스칼렛 요한슨', '페이지 오하라,로비 벤슨', '박신양,김정태', '톰 행크스,할리 베리',
       '이완 맥그리거,나오미 왓츠', '김래원,지대한', '잭 니콜슨,페이 더너웨이', '강필선', '정연주',
       '류승룡,박신혜', '크리스 에반스,송강호', '송강호,이정재', '하정우,한석규', '김수현,박기웅',
       '송강호,김영애', '하정우,이경영', '설경구,정우성', '브래드 피트,미레유 에노스', '이정재,최민식',
       '설경구,문소리', '장혁,수애', '크리스 헴스워스,톰 히들스턴', '브루스 윌리스,존 말코비치', '유오성,주진모',
       '레이첼 맥아담스,도널 글리슨', '제시 아이젠버그,마크 러팔로', '설경구,엄지원', '찰리 허냄,론 펄먼',
       '여진구,김윤석', '헨리 카빌,에이미 아담스', '공유,박희순', '마틴 프리먼,베네딕트 컴버배치',
       '엄정화,김상경', '이민기,김민희', '이병헌,브루스 윌리스', '빈 디젤,드웨인 존슨', '손예진,김갑수',
       '전도연,고수', '황정민,유준상', '한석규,이제훈', '크리스 파인,칼 어번', '톰 크루즈,모건 프리먼',
       '레오나르도 디카프리오,캐리 뮬리건', '브루스 윌리스,제이 코트니', '신하균,이태리', '서교,성동일',
       '김강우,김효진', '유아인,김해숙', '맷 데이먼,조디 포스터', '이시영,엄기준', '니콜라스 홀트,테레사 팔머',
       '우혜진,박해일', '휴 잭맨,사나다 히로유키', '최승현,한예리', '니콜라스 홀트,이완 맥그리거',
       '정재영,김옥빈', '톰 크루즈,로자문드 파이크', '김선아,마동석', '로즈 번,패트릭 윌슨',
       '릴리 콜린스,제이미 캠벨 바우어', '채닝 테이텀,제이미 폭스', '윌 스미스,제이든 스미스', '김강우,김범',
       '로건 레먼,알렉산드리아 다다리오', '이시영,김영현', '박성웅,우혜진', '김아중,주원', '서인국,이종석',
       '임창정,안내상', '조니 뎁,아미 해머', '미아 와시코브스카,매튜 구드', '제임스 프랭코,미쉘 윌리엄스',
       '최강희,봉태규', '성룡,권상우', '실베스터 스탤론,아놀드 슈왈제네거', '정경호,한성천',
       '레오나르도 디카프리오,제이미 폭스', '천정명,김민정', '톰 행크스,캐서린 키너', '이제훈,조진웅',
       '애쉬튼 커처,조시 게드', '테렌스 스탬프,바네사 레드그레이브', '에단 호크,줄리 델피', '양동근,주상욱',
       '휴 잭맨,제이크 질렌할', '이광수,송지효', '제라드 버틀러,모건 프리먼', '엄태웅,김민준', '마동석,이승연',
       '해리슨 포드,아사 버터필드', '저스틴 팀버레이크,벤 애플렉', '호와킨 피닉스,필립 세이모어 호프만',
       '정재영,한지민', '연정훈,이지훈', '우혜영,박철민', '잉그리드 서린,군넬 린드블롬', '최민식,류승룡',
       '김남길,손예진', '심은경,나문희', '황정민,김윤진', '마크 월버그,제시카 고메즈', '하정우,강동원',
       '톰 크루즈,에밀리 블런트', '휴 잭맨,제임스 맥어보이', '최승현,신세경', '앤디 서키스,게리 올드만',
       '크리스 에반스,스칼렛 요한슨', '현빈,정재영', '정우성,안성기', '이선균,조진웅', '류승룡,유준상',
       '딜런 오브라이언,카야 스코델라리오', '조정석,신민아', '리암 니슨,줄리안 무어',
       '리차드 아미티지,사라 웨인 콜리스', '러셀 크로우,엠마 왓슨', '황정민,한혜진', '스칼렛 요한슨,모건 프리먼',
       '김우빈,김영철', '벤 애플렉,로자먼드 파이크', '박해일,유연석', '박보영,이종석', '송혜교,김승욱',
       '김희애,고아성', '레나 헤디,에바 그린', '크리스찬 베일,조엘 에저튼', '김윤석,박유천', '송승헌,임지연',
       '안젤리나 졸리,엘르 패닝', '킷 해링턴,에밀리 브라우닝', '브래드 피트,로건 레먼', '루크 에반스,도미닉 쿠퍼',
       '김강우,고창석', '이정재,신하균', '차태현,남상미', '이진성,정재영', '조엘 키나만,사무엘 L. 잭슨',
       '김성균,조진웅', '애나벨 월리스,워드 호튼', '염정아,문정희', '엄정화,문소리', '쉐일린 우들리,안셀 엘고트',
       '애런 존슨,브라이언 크랜스톤', '조니 뎁,레베카 홀', '홍수민,한석규', '장동건,김민희',
       '김다율(김아현),주원', '장한새,이민기', '레오나르도 디카프리오,매튜 매커너히',
       '라이언 구즈만,브리아나 에비건', '치웨텔 에지오포,마이클 패스벤더', '강하늘,김소은', '하지원,강예원',
       '정우성,이솜', '쉐일린 우들리,케이트 윈슬렛', '사사키 노조미', '메간 폭스,윌리엄 피츠너', '설경구,박해일',
       '이 동 길,차승원', '크리스 파인,키이라 나이틀리', '메릴 스트립,조니 뎁', '윤계상,고준희',
       '아론 에크하트,빌 나이', '릴리 콜린스,샘 클라플린', '카렌 길런,브렌튼 스웨이츠',
       '피어스 브로스넌,올가 쿠릴렌코', '리암 니슨,보이드 홀브룩', '케빈 코스트너,앰버 허드', '윤상현,송새벽',
       '짐 캐리,토미 스나이더', '프레데릭 벨,엘로디 퐁탕', '마이클 더글라스,제리 페라라', '김상경,문정희',
       '성룡,유엽', '리암 니슨,팜케 얀센', '니콜 키드먼,벤 위쇼', '조여정,클라라', '브래들리 쿠퍼,시에나 밀러',
       '잭 오코넬,도널 글리슨', '장 가뱅,애니 지라르도', '마크 러팔로,에단 호크', '황정민,유아인',
       '전지현,이정재', '로버트 다우니 주니어,크리스 헴스워스', '이병헌,조승우', '콜린 퍼스,태런 에저튼',
       '김무열,진구', '김윤석,강동원', '황정민,정우', '맷 데이먼,제시카 차스테인', '김명민,오달수',
       '앤 해서웨이,로버트 드니로', '아놀드 슈왈제네거,제이슨 클락', '김우빈,이준호', '김윤석,유해진',
       '폴 러드,마이클 더글라스', '해리슨 포드,마크 해밀', '딜런 오브라이언,토마스 생스터', '권상우,성동일',
       '손현주,마동석', '이민호,김래원', '한효주,김대명', '이승기,문채원', '다니엘 크레이그,레아 세이두',
       '베네딕트 컴버배치,키이라 나이틀리', '드웨인 존슨,알렉산드리아 다다리오', '김윤석,정우', '손현주,엄지원',
       '최민식,정만식', '박해빛나,박근형', '오상철,이선균', '주지훈,김강우', '벤 스틸러,로빈 윌리엄스',
       '주원,유해진', '엄정화,송승헌', '하정우,하지원', '김상경,김성균', '스테파니 스콧,더못 멀로니',
       '크리스 헴스워스,킬리언 머피', '정재영,박보영', '조정석,이미숙', '설경구,여진구', '휴 잭맨,샬토 코플리',
       '김수미,정만식', '진세연,홍종현', '신하균,장혁', '고아성,박성웅', '이병헌,전도연', '김남길,전도연',
       '마일즈 텔러,케이트 마라', '이민기,여진구', '윤계상,유해진', '박보영,엄지원', '제이슨 클락,조슈 브롤린',
       '윤계상,한예리', '류승룡,배수지', '밀라 쿠니스,채닝 테이텀', '리암 니슨,조엘 킨나만',
       '쉐일린 우들리,테오 제임스', '조니 웨스턴,소피아 블랙 디엘리아', '조지 클루니,휴 로리',
       '톰 행크스,마크 라이런스', '조셉 고든 레빗,벤 킹슬리', '유승호,고아라', '샐리 헤닝,모세 제이콥 스톰',
       '오지호,최령', '마이클 키튼,에드워드 노튼', '소메타니 쇼타,후카츠 에리', '휴 잭맨,가렛 헤드룬드',
       '톰 하디,태런 에저튼', '마크 월버그,세스 맥팔레인', '제시 아이젠버그,크리스틴 스튜어트',
       '에드 스크레인,론 샤바놀', '러셀 크로우,올가 쿠릴렌코', '류승범,고준희', '데인 드한,로버트 패틴슨',
       '잭 블랙,딜런 미네트', '정우성,김하늘', '루크 브레이시,에드가 라미레즈', '레오나르도 디카프리오,톰 하디',
       '공유,김정희', '황정민,강동원', '크리스 에반스,로버트 다우니 주니어', '송강호,공유', '하정우,배두나',
       '김정철,이정재', '곽도원,황정민', '손예진,박해일', '베네딕트 컴버배치,레이첼 맥아담스',
       '에디 레드메인,콜린 파렐', '라이언 레놀즈,모레나 바카린', '조정석,도경수', '제임스 맥어보이,마이클 패스벤더',
       '에바 그린,사무엘 L. 잭슨', '맷 데이먼,줄리아 스타일즈', '닐 세티,빌 머레이', '헨리 카빌,벤 애플렉',
       '김혜수,마동석', '유승호,조재현', '베라 파미가,패트릭 윌슨', '윌 스미스,자레드 레토',
       '빌 풀만,리암 헴스워스', '이제훈,김성균', '베네딕트 컴버배치,마틴 프리먼', '김명민,김상호',
       '임수정,조정석', '강하늘,박정민', '트래비스 핌멜,벤 포스터', '크리스 파인,사이먼 페그', '서하늬,엄지원',
       '김윤석,변요한', '테레사 팔머,알리시아 벨라 베일리', '김현빈,임시완', '강예원,이상윤',
       '제인 레비,딜런 미네트', '김율호,차승원', '에밀리아 클라크,샘 클라플린', '덴젤 워싱턴,크리스 프랫',
       '제라드 버틀러,니콜라이 코스터 왈도', '알렉산더 스카스가드,마고 로비', '이미연,최지우',
       '르네 젤위거,콜린 퍼스', '유지태,이정현', '제라드 버틀러,아론 에크하트', '수애,오달수',
       '톰 행크스,펠리시티 존스', '김정희,문채원', '심은경,윤제문', '톰 행크스,아론 에크하트',
       '톰 크루즈,코비 스멀더스', '펠리시티 존스,디에고 루나', '제이슨 스타뎀,제시카 알바',
       '멜리사 맥카시,크리스 헴스워스', '강동원,신은수', '한효주,유연석', '윤여정,김고은', '이성민,이희준',
       '크리스찬 베일,스티브 카렐', '크리스 헴스워스,샤를리즈 테론', '메리 엘리자베스 윈스티드,존 굿맨',
       '엘리자베스 리저,애너리즈 바쏘', '류덕환,김동영', '마이클 키튼,마크 러팔로', '류덕환,조복래',
       '도경수,김소현', '메간 폭스,스티븐 아멜', '태런 에저튼,폴 레이놀즈', '조셉 파인즈,톰 펠튼',
       '제니퍼 로렌스,브래들리 쿠퍼', '오달수,윤제문', '알 파치노,안소니 홉킨스', '존 크랜신스키,파블로 쉬레이버',
       '클로이 모레츠,닉 로빈슨', '마크 라이런스,레베카 홀', '브라이스 달라스 하워드,오크스 페글리',
       '이드리스 엘바,리처드 매든', '차태현,김유정', '브래드 피트,마리옹 꼬띠아르', '크리스 프랫,제니퍼 로렌스',
       '마이클 매드슨,스텔라 매브', '이수민,송강호', '하정우,차태현', '현빈,유해진', '제이콥 배덜런,톰 홀랜드',
       '황정민,김규백', '김규백,박서준', '콜린 퍼스,줄리안 무어', '정우성,곽도원', '이병헌,김윤석',
       '톰 크루즈,소피아 부텔라', '나문희,이제훈', '톰 하디,마크 라이런스', '크리스 프랫,조 샐다나',
       '설경구,김남길', '마크 월버그,안소니 홉킨스', '이성민,조진웅', '지창욱,심은경', '정우,강하늘',
       '이제훈,최희서', '휴 잭맨,패트릭 스튜어트', '갤 가돗,로빈 라이트', '다니엘 칼루야,앨리슨 윌리암스',
       '앤디 서키스,우디 해럴슨', '스테파니 시그만,알리시아 벨라 베일리', '벤 애플렉,갤 가돗',
       '라이언 레놀즈,사무엘 L. 잭슨', '톰 히들스턴,브리 라슨', '제임스 맥어보이,안야 테일러 조이',
       '이선균,안재홍', '마동석,이동휘', '강하늘,김무열', '제시카 로테,이스라엘 브로우사드', '강소백,장동건',
       '최민식,곽도원', '마이클 패스벤더,캘리 헤르난데스', '염정아,박혁권', '김옥빈,신하균', '조진웅,신구',
       '캐서린 윈닉,제라드 버틀러', '마크 해밀,캐리 피셔', '설경구,임시완', '오웬 티그,빌 스카스가드',
       '케네스 브래너,페넬로페 크루즈', '이정재,여진구', '안셀 엘고트,케빈 스페이시', '휴 잭맨,잭 에프런',
       '밀라 요보비치,알리 라터', '스칼렛 요한슨,마이클 피트', '윤제문,정소민', '에이미 아담스,제레미 레너',
       '맨디 무어,클레어 홀트', '데인 드한,카라 델러비인', '맷 데이먼,페드로 파스칼', '빈 디젤,사무엘 L. 잭슨',
       '김수현,성동일', '타라지 P. 헨슨,옥타비아 스펜서', '백윤식,성동일', '임시완,진구', '찰리 허냄,주드 로',
       '톰 크루즈,도널 글리슨', '손현주,장혁', '조진웅,송승헌', '마이클 패스벤더,마리옹 꼬띠아르', '황인아,고수',
       '진남수,이병헌', '신하균,도경수', '김래원,김해숙', '틸다 스윈튼,제이크 질렌할',
       '라이언 고슬링,해리슨 포드', '키아누 리브스,이안 맥쉐인', '김혜수,이선균', '김남길,천우희',
       '딜런 오브라이언,테일러 키취', '제이미 도넌,다코타 존슨', '앤드류 가필드,샘 워싱턴', '고두심,김성균',
       '데인 드한,제이슨 아이삭스', '샤를리즈 테론,제임스 맥어보이', '강예원,한채아']

# %%
list = []
for i, d in enumerate(actor_list):
#     print(d)
    if type(d) == str:
        a= d.split(',')[0:2:]

#         print(a)
    list.append(a)
#         print(a.split('[]')
#         df_etc.iloc[i]['actor'] = ','.join(
#     else:
#         i, df_etc.iloc[i]
# df_etc = df_etc.drop('Maker', 1)
# df_etc.to_excel('./data/movie_etc.xlsx', encoding='utf-8')
# df_etc = df_etc.drop_duplicates(subset='movieNm', keep='first')
# df_etc

# %%
list = [item for sublist in list for item in sublist]

# %%
actor = pd.DataFrame(list)

# %%
actor.columns = ['actor']

# %%
df_actor1 = pd.DataFrame({'actor1':''},index=[0])
for i, d in enumerate(df_actor['actor']):
    if type(d) == str:
        df_actor1.iloc[i]['actor1'] = d.split(',')[0::1]
    else:
        i, df_etc.iloc[i]

# df_etc.to_excel('./data/movie_etc.xlsx', encoding='utf-8')
# df_etc = df_etc.drop_duplicates(subset='movieNm', keep='first')
df_actor1

# %%
df_actor1 = pd.DataFrame(actor1)
df_actor2 = pd.DataFrame(actor2)
df_actor2

# %%
list

# %%
actor1 = list[0::2]

# %%
actor2 = list[1::2]

# %% [markdown]
# # 감독 프레임

# %%
df['director'] = df_etc['director']

# %%
df

# %%
df_director = pd.DataFrame({'movieNm':df['movieNm'], 'audiCnt':df['audiCnt'], 'director':df['director'], 'directorAtt':''})

# %%
df_director_2 = df_director.loc[df_director['director'] == df['director']]

# %%
# df_director_2['audiCnt'] = df_director_2['audiCnt'].sort_values(ascending=False)

# %% [markdown]
# # 감독별 최대 관객수

# %%
# df_director_2 = df_director_2.sort_values(['audiCnt'], ascending=[False])

# %%
df_director_2 = df_director_2.drop_duplicates(subset='movieNm', keep='first')
df_director_2 = df_director_2.drop_duplicates(subset='director', keep='first')
df_director_2.index = pd.RangeIndex(len(df_director_2))
# df_director_2 = df_director_2.drop('modvieNm', 1)
df_director_2 = df_director_2.drop('directorAtt', 1)
df_director_2.to_csv('./data/감독별 최대 관객수.csv', encoding='euc-kr')

# %% [markdown]
# # 감독별 평균 관객수

# %%
df_d = pd.read_excel('./data/DailyData_set(2008-2017).xlsx')
df_d2 = pd.read_excel('./data/Moobiz_data.xlsx')

# %%
dir = os.listdir('./data')
dir.sort()
xlsx_list = [ file for file in dir if file.startswith('BoxOffice')]

# %%
for i, data in enumerate(xlsx_list):
    if i == 0:
        df = pd.read_excel('./data/'+data)
    else:
        small_df = pd.read_excel('./data/'+data)
        df = pd.concat([df, small_df])
df

# %%
df = df.rename( columns={'기간별 박스오피스 검색 리스트':'rank','Unnamed: 1' :'movieNm','Unnamed: 2': 'openDt',
              'Unnamed: 3':'sales', 'Unnamed: 4':'salesShare', 'Unnamed: 5':'salesAmt', 
              'Unnamed: 6':'audiCnt', 'Unnamed: 7':'audiCntAnt','Unnamed: 8': 'scrnCnt', 
              'Unnamed: 9':'showCnt', 'Unnamed: 10':'Nation','Unnamed: 11': 'Nation2',
              'Unnamed: 12':'Maker', 'Unnamed: 13':'Company','Unnamed: 14': 'Rate',
              'Unnamed: 15':'Genre', 'Unnamed: 16':'director','Unnamed: 17':'actor'})

# %%
df_i = pd.DataFrame({'director':df_director_2['director']})

# %%
df = pd.merge(df, df_i, on='director')

# %%
df_o = pd.DataFrame({'movieNm':df['movieNm'], 'director':df['director'], 'audiCnt':df['audiCnt']})
df_o.to_excel('./data/감독 평균.xlsx', encoding='utf-8')

# %%
import numpy as np

# %%
df = df.iloc[:, 1:]

df

# %%
df_o
# df_o.groupby(['director'])

# %%
df_o = df_o.iloc[:,1:]
df_o

# %%
df_o.duplicated(['director'])

# %%
df_o.groupby(['director']).mean()

# %%
# df_director
for i, data in enumerate(df_director['director']):
    print(type(data))
    if data == df_director['director']:
        df_director.iloc[i]['']= df_director[i]['audiCnt']
    else:
        continue

# %% [markdown]
# # 데이터 전처리(국가, 등급, 비성수기/성수기, 4계절 등)
# ## 국적-> 한국 : 0, 미국 : 1, 그외 : 2

# %%
# a.month
df_Nation = pd.DataFrame({'movieNm':df['movieNm'], 'Nation': df['Nation'], 'NationAtt':''})
for idx, a in enumerate(df['Nation']):
#     if type(a) is not str:
#         continue
    if a == '한국':
        df_Nation.iloc[idx]['NationAtt'] = 0
    elif a == '미국':
        df_Nation.iloc[idx]['NationAtt'] = 1
    else:
        df_Nation.iloc[idx]['NationAtt'] = 2
df_Nation = df_Nation.drop('Nation', 1)
df_Nation
# .to_excel('./data/NationAtt.xlsx', encoding='utf-8')

# %% [markdown]
# # 등급분류
# ## 12세 이상 : 0, 15세 이상 : 1, 청소년 불가 : 2, 그외 : 3

# %%
# a.month
df_Rate = pd.DataFrame({'movieNm':df['movieNm'], 'Rating': df['rate'], 'RatingAtt':''})
for idx, a in enumerate(df['rate']):
#     if type(a) is not str:
#         continue
    if a == '12세이상관람가':
        df_Rate.iloc[idx]['RatingAtt'] = 0
    elif a == '15세이상관람가':
        df_Rate.iloc[idx]['RatingAtt'] = 1
    elif a == '청소년관람불가':
        df_Rate.iloc[idx]['RatingAtt'] = 2
    else:
        df_Rate.iloc[idx]['RatingAtt'] = 3
df_Rate = df_Rate.drop('Rating', 1)
df_Rate.to_excel('./data/RatingAtt.xlsx', encoding='utf-8')

# %% [markdown]
# # 4계절

# %%
# a.month
#peak이면 0
df_Season = pd.DataFrame({'movieNm':df['movieNm'], 'openDt': df['openDt'], 'openDt_season':'', 'openDt_peak':''
                   })

for idx, a in enumerate(df['openDt']):
#     print(idx, a)
    a = pd.to_datetime(a)
#     print(a.month)
#     a = datetime.datetime.strftime(a, '%Y-%m-%d')
#     a= datetime.datetime.strptime(a, '%Y-%m-%d')
#     a = datetime.date(a)
#     print(a.year)
#     a = datetime.datetime.strftime(a, '%Y%m%d').date()
#     print(type(a))
#     if type(a) is not datetime.datetime:
#         continue
#     elif a.year != 2017:
#         continue
    if a.month >= 3 and a.month <= 5: 
        df_Season.iloc[idx]['openDt_season'] = 0
    elif a.month >= 6 and a.month <= 8: 
        df_Season.iloc[idx]['openDt_season'] = 1
    elif a.month >= 9 and a.month <= 11: 
        df_Season.iloc[idx]['openDt_season'] = 2
    else:
        df_Season.iloc[idx]['openDt_season'] = 3
# a.month
#peak이면 0


for idx, b in enumerate(df['openDt']):

    b = pd.to_datetime(b)

    if b.month == 7: 
        df_Season.iloc[idx]['openDt_peak'] = 0
    elif b.month == 8: 
        df_Season.iloc[idx]['openDt_peak'] = 0
    elif b.month == 9: 
        df_Season.iloc[idx]['openDt_peak'] = 0
    elif b.month == 12: 
        df_Season.iloc[idx]['openDt_peak'] = 1
    elif b.month == 1: 
        df_Season.iloc[idx]['openDt_peak'] = 1
    elif b.month == 2: 
        df_Season.iloc[idx]['openDt_peak'] = 1
    elif b.month == 3: 
        df_Season.iloc[idx]['openDt_peak'] = 2
    elif b.month == 4: 
        df_Season.iloc[idx]['openDt_peak'] = 2
    elif b.month == 5: 
        df_Season.iloc[idx]['openDt_peak'] = 2
    elif b.month == 6: 
        df_Season.iloc[idx]['openDt_peak'] = 2
    elif b.month == 10: 
        df_Season.iloc[idx]['openDt_peak'] = 2
    elif b.month == 11: 
        df_Season.iloc[idx]['openDt_peak'] = 2
df_Season = df_Season.drop('openDt', 1)
# df_Season
df_Season.to_excel('./data/df_Season.xlsx')

# %% [markdown]
# # 데이터들 합치기

# %%
df_Season = pd.read_excel('./data/df_Season.xlsx')
df_RatingAtt = pd.read_excel('./data/RatingAtt.xlsx')
df_Nation = pd.read_excel('./data/NationAtt.xlsx')
df_BoxOffice = pd.read_excel('./data/개봉일7일과 차이Ver2.xlsx')

# %%
df_Season

# %%
df_Nation

# %%
df_RatingAtt

# %%
df_BoxOffice

# %% [markdown]
# # 개봉당일 데이터셋

# %%
df_all = pd.read_excel('./data/2008~2017개봉일_개봉일7일.xlsx')
df_all

# %%
# df_1 = df_0.drop_duplicates(subset='movieNm', keep='first')
df_1 = pd.merge(df_movie_review, df_1, on='movieNm')
# df_1.to_excel('./data/df_1.xlsx', encoding='utf-8')
df_1

# %% [markdown]
# # 개봉 7일 후

# %%
df_7 = df_0.loc[pd.to_datetime(df_0['openDt']) + datetime.timedelta(weeks = 1) == df_0['searchDay']]
df_7 = pd.merge(df_movie_review, df_7, on='movieNm')
df_7.to_excel('./data/df_7.xlsx', encoding='utf-8')

# %% [markdown]
# # 개봉일 모두 다

# %%
df_0 = pd.DataFrame({'movieNm':df_0['movieNm'], 'rank':df_0['rank'], 'audiCnt':df_0['audiCnt'], 'showCnt':df_0['showCnt']})
df_1 = pd.DataFrame({'movieNm':df_1['movieNm'], 'rank':df_1['rank'], 'audiCnt':df_1['audiCnt'], 'showCnt':df_1['showCnt']})
df_2 = pd.DataFrame({'movieNm':df_2['movieNm'], 'rank':df_2['rank'], 'audiCnt':df_2['audiCnt'], 'showCnt':df_2['showCnt']})
df_3 = pd.DataFrame({'movieNm':df_3['movieNm'], 'rank':df_3['rank'], 'audiCnt':df_3['audiCnt'], 'showCnt':df_3['showCnt']})

# %%
df_0

# %%
df_all_2 = pd.merge(df_0, df_1, on='movieNm')
df_all_2 = pd.merge(df_all_2, df_2, on='movieNm')
# df_all_2 = pd.merge(df_all_2, df_3, on='movieNm')
# df_all_2 = pd.merge(df_all_2, df_4, on='movieNm')
df_all_2

# %%
df_all_2['rankAtt_1'] = df_all_2['rank_x'] - df_all_2['rank_y']
df_all_2['rankAtt_2'] = df_all_2['rank_y'] - df_all_2['rank']
df_all_2['audiCntAtt_1'] = df_all_2['audiCnt_x'] - df_all_2['audiCnt_y']
df_all_2['audiCntAtt_2'] = df_all_2['audiCnt_y'] - df_all_2['audiCnt']
df_all_2['showCntAtt_1'] = df_all_2['showCnt_x'] - df_all_2['showCnt_y']
df_all_2['showCntAtt_2'] = df_all_2['showCnt_y'] - df_all_2['showCnt']

# %%
df_all_2

# %%
df_all_2.iplot(kind='bar', xTitle='Date', yTitle='Average',
    title='Monthly Average Views and Reads')

# %% [markdown]
# # 데이터셋

# %%
df_dataset = pd.merge(df_0, df_Nation, on='movieNm')
df_dataset = pd.merge(df_dataset, df_RatingAtt, on='movieNm')
df_dataset = pd.merge(df_dataset, df_Season, on='movieNm')
df_dataset.to_excel('./data/dataset_모든 날짜.xlsx', encoding='utf-8')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
corr = df_dataset.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
correlation = df_dataset.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')

# %%
df_dataset_1 = df_dataset.drop_duplicates(subset='movieNm', keep='first')
df_dataset_1.to_excel('./data/dataset.xlsx', encoding='utf-8')

# %%
correlation = df_dataset_1.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')

# %%
df_0 = pd.merge(df_1, df_7, on=['movieNm'])
df_0 = df_0.drop_duplicates(subset='movieNm', keep='last')
df_0.index = pd.RangeIndex(len(df_0))

# %%
# df_0.to_excel('./data/개봉일&개봉일7일.xlsx', encoding='utf-8')

# %%
# df_0

# %%
zxc = pd.read_excel('./data/dataset.xlsx')
zxc2 = pd.read_excel('./data/개봉일간 차이.xlsx')
zxc3 = df_director_2

# %%
zxc

# %%
zxc = pd.merge(zxc, zxc2, on='movieNm')
zxc

# %%
zxc3
