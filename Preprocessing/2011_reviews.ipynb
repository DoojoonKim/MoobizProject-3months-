# %%
p_reviews_2011 = {'트랜스포머 3': 363,
'최종병기 활': 0,
'써니': 0,
'완득이': 104,
'쿵푸팬더 2': 66,
'미션임파서블:고스트프로토콜': 194,
'조선명탐정 : 각시투구꽃의 비밀': 122,
'도가니': 231,
'해리포터와 죽음의 성물2': 471,
'리얼 스틸': 126,
'캐리비안의 해적: 낯선 조류': 106,
'퀵': 88,
'고지전': 123,
'혹성탈출: 진화의 시작': 218,
'오싹한 연애': 82,
'위험한 상견례': 81,
'엑스맨: 퍼스트 클래스': 186,
'의뢰인': 60,
'가문의 영광4 - 가문의 수난': 32,
'7광구': 90,
'마당을 나온 암탉': 61,
'라스트 갓파더': 654,
'글러브': 140,
'아이들...': 137,
'걸리버 여행기': 31,
'평양성': 119,
'토르: 천둥의 신': 62,
'헬로우 고스트': 115,
'블랙 스완': 106,
'분노의 질주: 언리미티드': 53,
'마이 웨이': 151,
'브레이킹 던 part1': 123,
'신들의 전쟁': 85,
'월드 인베이젼': 235,
'셜록홈즈 : 그림자 게임': 74,
'소스 코드': 86,
'특수본': 95,
'수상한 고객들': 42,
'오직 그대만': 97,
'개구쟁이 스머프': 19,
'심장이 뛴다': 115,
'라푼젤': 81,
'파퍼씨네 펭귄들': 9,
'메가마인드': 63,
'만추': 215,
'체포왕': 44,
'퍼펙트 게임': 163,
'킹스 스피치': 19,
'틴틴 : 유니콘호의 비밀': 24,
'화이트: 저주의 멜로디': 48,
'푸른소금': 116,
'황해': 202,
'풍산개': 61,
'통증': 45,
'고양이: 죽음을 보는 두 개의 눈': 28,
'삼총사 3D': 18,
'아이 엠 넘버 포': 52,
'리오': 58,
'명탐정 코난 : 침묵의 15분': 115,
'머니볼': 29,
'인 타임': 24,
'콜롬비아나': 7,
'너는 펫': 118,
'챔프': 32,
'러브 & 드럭스': 10,
'퍼스트 어벤져': 38,
'앨빈과 슈퍼밴드3': 8,
'슈퍼 에이트': 25,
'카운트다운': 17,
'카 2': 10,
'해리 포터와 죽음의 성물1': 180,
'시즌 오브 더 위치: 마녀 호송단': 14,
'랭고': 12,
'모비딕': 11,
'티끌모아 로맨스': 67,
'사랑이 무서워': 10,
'컨트롤러': 16,
'레드 라이딩 후드': 31,
'커플즈': 14,
'짱구는 못말려 극장판 : 초시공! 태풍을 부르는 나의 신부': 91,
'새미의 어드벤쳐': 17,
'링컨 차를 타는 변호사': 11,
'세상에서 가장 아름다운 이별': 15,
'마이 블랙 미니드레스': 65,
'트론: 새로운 시작': 42,
'상하이': 86,
'친구와 연인사이': 5,
'극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」': 4,
'파이널 데스티네이션5': 30,
'카우보이 & 에이리언': 29,
'적과의 동침': 20,
'줄리아의 눈': 24,
'컨테이젼': 36,
'생텀': 48,
'알파 앤 오메가': 13,
'노미오와 줄리엣': 7}

# %%
import pandas as pd
df1 = pd.DataFrame([p_reviews_2011])
df1 = df1.T
df1 = df1.rename(columns = { 0 : 'p_reviews' })
df1.to_csv( './data_2011/2011_p_reviews', sep=',', encoding='utf-8' )

# %%
n_reviews_2011 = {'트랜스포머 3': 399,
'최종병기 활': 0,
'써니': 0,
'완득이': 25,
'쿵푸팬더 2': 20,
'미션임파서블:고스트프로토콜': 67,
'조선명탐정 : 각시투구꽃의 비밀': 30,
'도가니': 35,
'해리포터와 죽음의 성물2': 80,
'리얼 스틸': 29,
'캐리비안의 해적: 낯선 조류': 123,
'퀵': 65,
'고지전': 49,
'혹성탈출: 진화의 시작': 67,
'오싹한 연애': 25,
'위험한 상견례': 42,
'엑스맨: 퍼스트 클래스': 24,
'의뢰인': 49,
'가문의 영광4 - 가문의 수난': 93,
'7광구': 437,
'마당을 나온 암탉': 21,
'라스트 갓파더': 391,
'글러브': 28,
'아이들...': 95,
'걸리버 여행기': 57,
'평양성': 48,
'토르: 천둥의 신': 65,
'헬로우 고스트': 30,
'블랙 스완': 21,
'분노의 질주: 언리미티드': 10,
'마이 웨이': 156,
'브레이킹 던 part1': 66,
'신들의 전쟁': 112,
'월드 인베이젼': 141,
'셜록홈즈 : 그림자 게임': 18,
'소스 코드': 39,
'특수본': 59,
'수상한 고객들': 26,
'오직 그대만': 25,
'개구쟁이 스머프': 5,
'심장이 뛴다': 37,
'라푼젤': 15,
'파퍼씨네 펭귄들': 8,
'메가마인드': 17,
'만추': 104,
'체포왕': 13,
'퍼펙트 게임': 34,
'킹스 스피치': 14,
'틴틴 : 유니콘호의 비밀': 15,
'화이트: 저주의 멜로디': 68,
'푸른소금': 119,
'황해': 167,
'풍산개': 41,
'통증': 35,
'고양이: 죽음을 보는 두 개의 눈': 51,
'삼총사 3D': 20,
'아이 엠 넘버 포': 21,
'리오': 22,
'명탐정 코난 : 침묵의 15분': 29,
'머니볼': 12,
'인 타임': 43,
'콜롬비아나': 8,
'너는 펫': 66,
'챔프': 20,
'러브 & 드럭스': 11,
'퍼스트 어벤져': 65,
'앨빈과 슈퍼밴드3': 3,
'슈퍼 에이트': 60,
'카운트다운': 20,
'카 2': 4,
'해리 포터와 죽음의 성물1': 69,
'시즌 오브 더 위치: 마녀 호송단': 18,
'랭고': 16,
'모비딕': 24,
'티끌모아 로맨스': 35,
'사랑이 무서워': 7,
'컨트롤러': 31,
'레드 라이딩 후드': 33,
'커플즈': 12,
'짱구는 못말려 극장판 : 초시공! 태풍을 부르는 나의 신부': 14,
'새미의 어드벤쳐': 4,
'링컨 차를 타는 변호사': 10,
'세상에서 가장 아름다운 이별': 4,
'마이 블랙 미니드레스': 33,
'트론: 새로운 시작': 50,
'상하이': 17,
'친구와 연인사이': 3,
'극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」': 0,
'파이널 데스티네이션5': 9,
'카우보이 & 에이리언': 41,
'적과의 동침': 21,
'줄리아의 눈': 17,
'컨테이젼': 37,
'생텀': 54,
'알파 앤 오메가': 2,
'노미오와 줄리엣': 2}

# %%
import pandas as pd
df2 = pd.DataFrame([n_reviews_2011])
df2 = df2.T
df2 = df2.rename(columns = { 0 : 'n_reviews' })
df2.to_csv( './data_2011/2011_n_reviews', sep=',', encoding='utf-8' )
