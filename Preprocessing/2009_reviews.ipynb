# %%
p_reviews_2009 = {'해운대': 261,
'국가대표': 0,
'트랜스포머: 패자의 역습': 822,
'2012': 0,
'아바타': 0,
'터미네이터 : 미래전쟁의 시작': 284,
'7급 공무원': 45,
'과속스캔들': 223,
'쌍화점': 129,
'거북이 달린다': 50,
'해리 포터와 혼혈 왕자': 211,
'워낭소리': 0,
'적벽대전 2 : 최후의 결전': 62,
'지.아이.조 : 전쟁의 서막': 233,
'굿모닝 프레지던트': 50,
'전우치': 401,
'박쥐': 205,
'내 사랑 내 곁에': 141,
'박물관이 살아있다 2': 21,
'뉴 문': 123,
'천사와 악마': 105,
'애자': 31,
'그림자 살인': 48,
'차우': 81,
'작전명 발키리': 81,
'벤자민 버튼의 시간은 거꾸로 간다': 0,
'불꽃처럼 나비처럼': 57,
'유감스러운 도시': 53,
'작전': 107,
'닌자 어쌔신': 522,
'청담보살': 26,
'엑스맨 탄생: 울버린': 81,
'킹콩을 들다': 122,
'인사동 스캔들': 14,
'셜록 홈즈': 50,
'슬럼독 밀리어네어': 47,
'스타 트렉: 더 비기닝': 80,
'노잉': 47,
'백야행': 80,
'트랜스포터-라스트 미션': 36,
'그는 당신에게 반하지 않았다': 22,
'디스트릭트 9': 125,
'마린보이': 49,
'써로게이트': 29,
'모범시민': 66,
'시간 여행자의 아내': 0,
'김씨표류기': 88,
'푸시': 18,
'슬픔보다 더 슬픈 이야기': 31,
'분노의 질주: 더 오리지널': 26,
'여고괴담 5': 19,
'페임': 20,
'핸드폰': 48,
'홍길동의 후예': 47,
'왓치맨': 72,
'예스맨': 45,
'잉크하트 : 어둠의 부활': 46,
'이태원 살인사건': 29,
'체인질링': 17,
'여배우들': 35,
'퍼블릭 에너미': 26,
'더 리더: 책 읽어주는 남자': 0,
'10억': 48,
'파르나서스 박사의 상상극장': 49,
'집행자': 25,
'문프린세스 : 문에이커의 비밀': 19,
'펠햄 123': 18,
'바스터즈: 거친 녀석들': 12,
'프로포즈': 15,
'정승필 실종사건': 20,
'퍼펙트 겟어웨이': 24,
'주온-원혼의 부활': 15,
'호우시절': 34,
'드래그 미 투 헬': 28,
'지구가 멈추는 날': 73,
'요가학원': 27,
'불신지옥': 29,
'뉴욕은 언제나 사랑 중': 0,
'인터내셔널': 10,
'세븐 파운즈': 16,
'디파이언스': 24,
'우리 집에 왜 왔니': 39,
'언데드': 14,
'말리와 나': 20,
'13일의 금요일': 4,
'13구역: 얼티메이텀': 26,
'오펀: 천사의 비밀': 48,
'오감도': 26,
'드래곤볼 에볼루션': 26,
'쇼퍼홀릭': 5,
'게이머': 11,
'파이널 데스티네이션 4': 9,
'나는 비와 함께 간다': 33,
'코코 샤넬': 14}

# %%
import pandas as pd
df1 = pd.DataFrame([p_reviews_2009])
df1 = df1.T
df1 = df1.rename(columns = { 0 : 'p_reviews' })
df1.to_csv( './data_2009/2009_p_reviews', sep=',', encoding='utf-8' )

# %%
n_reviews_2009 = {'해운대': 90,
'국가대표': 0,
'트랜스포머: 패자의 역습': 278,
'2012': 0,
'아바타': 0,
'터미네이터 : 미래전쟁의 시작': 177,
'7급 공무원': 13,
'과속스캔들': 28,
'쌍화점': 149,
'거북이 달린다': 32,
'해리 포터와 혼혈 왕자': 315,
'워낭소리': 0,
'적벽대전 2 : 최후의 결전': 41,
'지.아이.조 : 전쟁의 서막': 180,
'굿모닝 프레지던트': 49,
'전우치': 200,
'박쥐': 391,
'내 사랑 내 곁에': 79,
'박물관이 살아있다 2': 24,
'뉴 문': 115,
'천사와 악마': 34,
'애자': 11,
'그림자 살인': 44,
'차우': 46,
'작전명 발키리': 39,
'벤자민 버튼의 시간은 거꾸로 간다': 0,
'불꽃처럼 나비처럼': 46,
'유감스러운 도시': 58,
'작전': 23,
'닌자 어쌔신': 203,
'청담보살': 20,
'엑스맨 탄생: 울버린': 40,
'킹콩을 들다': 13,
'인사동 스캔들': 16,
'셜록 홈즈': 35,
'슬럼독 밀리어네어': 10,
'스타 트렉: 더 비기닝': 26,
'노잉': 71,
'백야행': 43,
'트랜스포터-라스트 미션': 40,
'그는 당신에게 반하지 않았다': 16,
'디스트릭트 9': 50,
'마린보이': 53,
'써로게이트': 23,
'모범시민': 70,
'시간 여행자의 아내': 0,
'김씨표류기': 27,
'푸시': 38,
'슬픔보다 더 슬픈 이야기': 24,
'분노의 질주: 더 오리지널': 6,
'여고괴담 5': 46,
'페임': 30,
'핸드폰': 50,
'홍길동의 후예': 26,
'왓치맨': 142,
'예스맨': 7,
'잉크하트 : 어둠의 부활': 31,
'이태원 살인사건': 48,
'체인질링': 4,
'여배우들': 35,
'퍼블릭 에너미': 55,
'더 리더: 책 읽어주는 남자': 0,
'10억': 104,
'파르나서스 박사의 상상극장': 86,
'집행자': 13,
'문프린세스 : 문에이커의 비밀': 33,
'펠햄 123': 38,
'바스터즈: 거친 녀석들': 4,
'프로포즈': 11,
'정승필 실종사건': 65,
'퍼펙트 겟어웨이': 23,
'주온-원혼의 부활': 37,
'호우시절': 45,
'드래그 미 투 헬': 39,
'지구가 멈추는 날': 238,
'요가학원': 113,
'불신지옥': 16,
'뉴욕은 언제나 사랑 중': 7,
'인터내셔널': 21,
'세븐 파운즈': 26,
'디파이언스': 6,
'우리 집에 왜 왔니': 17,
'언데드': 18,
'말리와 나': 14,
'13일의 금요일': 13,
'13구역: 얼티메이텀': 11,
'오펀: 천사의 비밀': 20,
'오감도': 91,
'드래곤볼 에볼루션': 87,
'쇼퍼홀릭': 2,
'게이머': 15,
'파이널 데스티네이션 4': 16,
'나는 비와 함께 간다': 104,
'코코 샤넬': 19}

# %%
import pandas as pd
df2 = pd.DataFrame([n_reviews_2009])
df2 = df2.T
df2 = df2.rename(columns = { 0 : 'n_reviews' })
df2.to_csv( './data_2009/2009_n_reviews', sep=',', encoding='utf-8' )
