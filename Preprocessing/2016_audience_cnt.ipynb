# %%
dict = {'부산행': '11566874',
'검사외전': '9707119',
'캡틴 아메리카: 시빌 워': '8678117',
'밀정': '7500457',
'터널': '7120780',
'인천상륙작전': '7050475',
'럭키': '6975571',
'곡성': '6879989',
'덕혜옹주': '5599995',
'닥터 스트레인지': '5447269',
'마스터': '7147924',
'신비한 동물사전': '2414064',
'판도라': '4584893',
'아가씨': '4288825',
'귀향': '14495',
'나우 유 씨 미 2': '3100113',
'형': '2982320',
'엑스맨: 아포칼립스': '2938771',
'미스 페레그린과 이상한 아이들의 집': '2718160',
'히말라야': '7759711',
'제이슨 본': '2611969',
'아수라': '2594545',
'정글북': '2537438',
'라라랜드': '3598388',
'배트맨 대 슈퍼맨: 저스티스의 시작': '2256691',
'굿바이 싱글': '2108561',
'봉이 김선달': '2051386',
'레버넌트: 죽음에서 돌아온 자': '2007649',
'컨저링 2': '1928605',
'내부자들: 디 오리지널': '2084844',
'수어사이드 스쿼드': '1898220',
'인디펜던스 데이 : 리써전스': '1500744',
'탐정 홍길동: 사라진 마을': '1430885',
'셜록: 유령신부': '1278885',
'특별수사: 사형수의 편지': '1243065',
'시간이탈자': '1202168',
'동주': '1175875',
'워크래프트: 전쟁의 서막': '1163223',
'스타트렉 비욘드': '1157472',
'미씽: 사라진 여자': '1153201',
'당신, 거기 있어줄래요': '1168782',
'라이트 아웃': '1111284',
'오빠생각': '1069962',
'날, 보러와요': '1063286',
'맨 인 더 다크': '1003406',
'고산자, 대동여지도': '974262',
'미 비포 유': '945172',
'매그니피센트 7': '921317',
'갓 오브 이집트': '910345',
'레전드 오브 타잔': '858406',
'좋아해줘': '848117',
'브리짓 존스의 베이비': '820995',
'스플릿': '758195',
'런던 해즈 폴른': '731584',
'국가대표 2': '710117',
'인페르노': '689071',
'그날의 분위기': '653226',
'사냥': '645834',
'널 기다리며': '635177',
'설리: 허드슨강의 기적': '627424',
'잭 리처: 네버 고 백': '612328',
'로그 원: 스타워즈 스토리': '1019285',
'메카닉: 리크루트': '551897',
'거울나라의 앨리스': '513202',
'가려진 시간': '511369',
'해어화': '485695',
'계춘할망': '482784',
'로봇, 소리': '476653',
'스타워즈: 깨어난 포스': '3273873',
'빅쇼트': '447220',
'헌츠맨: 윈터스 워': '444927',
'나를 잊지 말아요': '427113',
'조선마술사': '627586',
'클로버필드 10번지': '357736',
'위자: 저주의 시작': '331886',
'위대한 소원': '308457',
'스포트라이트': '301125',
'혼숨': '288016',
'비밀은 없다': '250904',
'닌자터틀 : 어둠의 히어로': '235211',
'순정': '240661',
'독수리 에디': '226318',
'남과 여': '203729',
'대호': '1762733',
'부활': '176539',
'조이': '172199',
'대배우': '169983',
'13시간': '145955',
'제 5침공': '135874',
'마이 리틀 자이언트': '125800',
'피터와 드래곤': '109137',
'다이버전트 시리즈: 얼리전트': '103565',
'바스티유 데이': '96579',
'데드풀': '3317184',
'벤허': '1400397',
'고스트버스터즈': '515553',
'구스범스': '305131',
'포인트 브레이크': '295096',
'미스컨덕트': '149088'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'audience_cnt' })

# %%
df['audience_cnt'].astype(int)
# Out:
# 13시간                145955
# 가려진 시간              511369
# 갓 오브 이집트            910345
# 거울나라의 앨리스           513202
# 검사외전               9707119
# 계춘할망                482784
# 고산자, 대동여지도          974262
# 고스트버스터즈             515553
# 곡성                 6879989
# 구스범스                305131
# 국가대표 2              710117
# 굿바이 싱글             2108561
# 귀향                   14495
# 그날의 분위기             653226
# 나를 잊지 말아요           427113
# 나우 유 씨 미 2         3100113
# 날, 보러와요            1063286
# 남과 여                203729
# 내부자들: 디 오리지널       2084844
# 널 기다리며              635177
# 닌자터틀 : 어둠의 히어로      235211
# 다이버전트 시리즈: 얼리전트     103565
# 닥터 스트레인지           5447269
# 당신, 거기 있어줄래요       1168782
# 대배우                 169983
# 대호                 1762733
# 덕혜옹주               5599995
# 데드풀                3317184
# 독수리 에디              226318
# 동주                 1175875
#                     ...
# 아수라                2594545
# 엑스맨: 아포칼립스         2938771
# 오빠생각               1069962
# ...

# %%
df.to_csv( './data_2016/2016_audience_cnt', sep=',', encoding='utf-8' )
