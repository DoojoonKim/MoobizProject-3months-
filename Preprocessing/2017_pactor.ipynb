# %%
dict = {'송강호': 34,
' 토마스 크레취만': 17,
'하정우': 36,
' 차태현': 18,
'현빈': 13,
' 유해진': 53,
'톰 홀랜드': 6,
' 마이클 키튼': 25,
'마동석': 35,
' 윤계상': 15,
'황정민': 37,
' 소지섭': 9,
'박서준': 5,
' 강하늘': 13,
'조인성': 8,
' 정우성': 33,
'엠마 왓슨': 16,
' 댄 스티븐스': 7,
'콜린 퍼스': 39,
' 줄리안 무어': 44,
'크리스 헴스워스': 16,
' 마크 러팔로': 30,
' 유지태': 26,
'정우성': 33,
' 곽도원': 19,
'이병헌': 38,
' 김윤석': 30,
'톰 크루즈': 38,
' 소피아 부텔라': 6,
'빈 디젤': 22,
' 드웨인 존슨': 27,
'나문희': 17,
' 이제훈': 17,
'조니 뎁': 43,
' 하비에르 바르뎀': 25,
'한석규': 25,
' 김래원': 15,
'톰 하디': 18,
' 마크 라이런스': 6,
'크리스 프랫': 12,
' 조 샐다나': 20,
'설경구': 42,
' 김남길': 15,
'마크 월버그': 33,
' 안소니 홉킨스': 47,
'이성민': 23,
' 조진웅': 45,
'지창욱': 4,
' 심은경': 18,
'정우': 36,
'이제훈': 17,
' 최희서': 13,
' 강동원': 21,
'갤 가돗': 4,
' 크리스 파인': 16,
'다니엘 칼루야': 2,
' 앨리슨 윌리암스': 1,
'휴 잭맨': 26,
'앤디 서키스': 13,
' 우디 해럴슨': 43,
'김윤석': 30,
' 하정우': 36,
'스테파니 시그만': 1,
' 탈리타 베이트먼': 1,
'노무현': 3,
'벤 애플렉': 35,
' 갤 가돗': 4,
'라이언 레이놀즈': 32,
' 사무엘 L. 잭슨': 72,
'톰 히들스턴': 11,
'제임스 맥어보이': 26,
' 안야 테일러 조이': 4,
'이선균': 35,
' 안재홍': 36,
' 이동휘': 19,
'강하늘': 13,
' 김무열': 12,
'제시카 로테': 1,
' 이스라엘 브로우사드': 2,
'장동건': 19,
' 김명민': 19,
'최민식': 30,
'마이클 패스벤더': 25,
' 캐서린 워터스턴': 4,
'염정아': 24,
' 박혁권': 32,
'김옥빈': 13,
' 신하균': 30,
'조진웅': 45,
' 신구': 21,
'라이언 고슬링': 21,
' 엠마 스톤': 18,
'김명민': 19,
' 변요한': 8,
'제라드 버틀러': 30,
' 짐 스터게스': 15,
'데이지 리들리': 2,
' 마크 해밀': 13,
' 임시완': 6,
'빌 스카스가드': 8,
' 제이든 리버허': 1,
'케네스 브래너': 19,
' 페넬로페 크루즈': 34,
'이정재': 32,
' 여진구': 8,
'안셀 엘고트': 5,
' 케빈 스페이시': 32,
' 잭 에프론': 13,
'밀라 요보비치': 30,
' 알리 라터': 7,
'스칼렛 요한슨': 34,
'제니퍼 로렌스': 19,
' 크리스 프랫': 12,
'윤제문': 42,
' 정소민': 5,
'에이미 아담스': 21,
' 제레미 레너': 18,
'맨디 무어': 14,
' 클레어 홀트': 2,
'브래드 피트': 35,
' 마리옹 꼬띠아르': 24,
'데인 드한': 13,
' 카라 델레바인': 3,
'맷 데이먼': 45,
' 윌렘 대포': 51,
' 박신혜': 11,
'김수현': 3,
' 이성민': 23,
'제이크 질렌할': 28,
' 레베카 퍼거슨': 10,
'타라지 P. 헨슨': 8,
' 옥타비아 스펜서': 10,
'백윤식': 24,
' 성동일': 32,
'임시완': 6,
' 진구': 8,
'펠리시티 존스': 13,
' 디에고 루나': 10,
'찰리 허냄': 9,
' 주드 로': 36,
' 도널 글리슨': 9,
'손현주': 15,
' 장혁': 8,
' 송승헌': 13,
'매들린 캐롤': 1,
' 캘런 맥오리피': 4,
'고수': 13,
' 김주혁': 22,
' 공효진': 23,
'신하균': 30,
'도경수': 8,
'차태현': 18,
'김유정': 14,
'김래원': 15,
'김해숙': 44,
'틸다 스윈튼': 25,
' 폴 다노': 12,
' 해리슨 포드': 39,
'키아누 리브스': 41,
'김남길': 15,
' 김주현': 1,
'김혜수': 35,
' 이선균': 35,
' 천우희': 22,
'딜런 오브라이언': 5,
'다코타 존슨': 5,
' 제이미 도넌': 8,
'앤드류 가필드': 9,
' 샘 워싱턴': 23,
'고두심': 17,
' 김성균': 24,
' 미아 고스': 4,
'샤를리즈 테론': 32,
' 제임스 맥어보이': 26,
'강예원': 14,
' 한채아': 3}

# %%
movies = {'택시운전사': ['송강호', ' 토마스 크레취만'],
'신과함께-죄와 벌': ['하정우', ' 차태현'],
'공조': ['현빈', ' 유해진'],
'스파이더맨: 홈 커밍': ['톰 홀랜드', ' 마이클 키튼'],
'범죄도시': ['마동석', ' 윤계상'],
'군함도': ['황정민', ' 소지섭'],
'청년경찰': ['박서준', ' 강하늘'],
'더 킹': ['조인성', ' 정우성'],
'미녀와 야수': ['엠마 왓슨', ' 댄 스티븐스'],
'킹스맨: 골든 서클': ['콜린 퍼스', ' 줄리안 무어'],
'토르: 라그나로크': ['크리스 헴스워스', ' 마크 러팔로'],
'꾼': ['현빈', ' 유지태'],
'강철비': ['정우성', ' 곽도원'],
'남한산성': ['이병헌', ' 김윤석'],
'미이라': ['톰 크루즈', ' 소피아 부텔라'],
'분노의 질주: 더 익스트림': ['빈 디젤', ' 드웨인 존슨'],
'아이 캔 스피크': ['나문희', ' 이제훈'],
'캐리비안의 해적: 죽은 자는 말이 없다': ['조니 뎁', ' 하비에르 바르뎀'],
'프리즌': ['한석규', ' 김래원'],
'덩케르크': [' 마크 라이런스'],
'가디언즈 오브 갤럭시 VOL. 2': ['크리스 프랫', ' 조 샐다나'],
'살인자의 기억법': ['설경구', ' 김남길'],
'트랜스포머: 최후의 기사': ['마크 월버그', ' 안소니 홉킨스'],
'보안관': ['이성민', ' 조진웅'],
'조작된 도시': ['지창욱', ' 심은경'],
'재심': ['정우', ' 강하늘'],
'박열': ['이제훈', ' 최희서'],
'마스터': ['이병헌', ' 강동원'],
'원더 우먼': ['갤 가돗', ' 크리스 파인'],
'겟 아웃': ['다니엘 칼루야', ' 앨리슨 윌리암스'],
'로건': ['휴 잭맨'],
'혹성탈출: 종의 전쟁': ['앤디 서키스', ' 우디 해럴슨'],
'1987': ['김윤석', ' 하정우'],
'애나벨 : 인형의 주인': ['스테파니 시그만', ' 탈리타 베이트먼'],
'노무현입니다': ['노무현'],
'저스티스 리그': ['벤 애플렉', ' 갤 가돗'],
'킬러의 보디가드': ['라이언 레이놀즈', ' 사무엘 L. 잭슨'],
'콩: 스컬 아일랜드': ['톰 히들스턴', ' 사무엘 L. 잭슨'],
'23 아이덴티티': ['제임스 맥어보이', ' 안야 테일러 조이'],
'임금님의 사건수첩': ['이선균', ' 안재홍'],
'부라더': ['마동석', ' 이동휘'],
'기억의 밤': ['강하늘', ' 김무열'],
'해피 데스데이': ['제시카 로테', ' 이스라엘 브로우사드'],
'브이아이피': ['장동건', ' 김명민'],
'특별시민': ['최민식', ' 곽도원'],
'에이리언: 커버넌트': ['마이클 패스벤더', ' 캐서린 워터스턴'],
'장산범': ['염정아', ' 박혁권'],
'악녀': ['김옥빈', ' 신하균'],
'해빙': ['조진웅', ' 신구'],
'라라랜드': ['라이언 고슬링', ' 엠마 스톤'],
'하루': ['김명민', ' 변요한'],
'지오스톰': ['제라드 버틀러', ' 짐 스터게스'],
'스타워즈: 라스트 제다이': ['데이지 리들리', ' 마크 해밀'],
'불한당: 나쁜 놈들의 세상': ['설경구', ' 임시완'],
'그것': ['빌 스카스가드', ' 제이든 리버허'],
'오리엔트 특급 살인': ['케네스 브래너', ' 페넬로페 크루즈'],
'대립군': ['이정재', ' 여진구'],
'베이비 드라이버': ['안셀 엘고트', ' 케빈 스페이시'],
'위대한 쇼맨': ['휴 잭맨', ' 잭 에프론'],
'레지던트 이블: 파멸의 날': ['밀라 요보비치', ' 알리 라터'],
'공각기동대 : 고스트 인 더 쉘': ['스칼렛 요한슨'],
'패신저스': ['제니퍼 로렌스', ' 크리스 프랫'],
'아빠는 딸': ['윤제문', ' 정소민'],
'컨택트': ['에이미 아담스', ' 제레미 레너'],
'47 미터': ['맨디 무어', ' 클레어 홀트'],
'얼라이드': ['브래드 피트', ' 마리옹 꼬띠아르'],
'발레리안: 천 개 행성의 도시': ['데인 드한', ' 카라 델레바인'],
'그레이트 월': ['맷 데이먼', ' 윌렘 대포'],
'침묵': ['최민식', ' 박신혜'],
'트리플 엑스 리턴즈': ['빈 디젤', ' 사무엘 L. 잭슨'],
'리얼': ['김수현', ' 이성민'],
'라이프': ['제이크 질렌할', ' 레베카 퍼거슨'],
'히든 피겨스': ['타라지 P. 헨슨', ' 옥타비아 스펜서'],
'반드시 잡는다': ['백윤식', ' 성동일'],
'원라인': ['임시완', ' 진구'],
'로그 원: 스타워즈 스토리': ['펠리시티 존스', ' 디에고 루나'],
'킹 아서: 제왕의 검': ['찰리 허냄', ' 주드 로'],
'아메리칸 메이드': ['톰 크루즈', ' 도널 글리슨'],
'보통사람': ['손현주', ' 장혁'],
'대장 김창수': ['조진웅', ' 송승헌'],
'어쌔신 크리드': ['마이클 패스벤더', ' 마리옹 꼬띠아르'],
'플립': ['매들린 캐롤', ' 캘런 맥오리피'],
'석조저택 살인사건': ['고수', ' 김주혁'],
'싱글라이더': ['이병헌', ' 공효진'],
'7호실': ['신하균'],
'사랑하기 때문에': ['차태현'],
'희생부활자': ['김래원', ' 김해숙'],
'옥자': ['틸다 스윈튼', ' 폴 다노'],
'블레이드 러너 2049': ['라이언 고슬링', ' 해리슨 포드'],
'존 윅 - 리로드': ['키아누 리브스'],
'판도라': ['김남길', ' 김주현'],
'미옥': ['김혜수', ' 이선균'],
'어느날': ['김남길', ' 천우희'],
'어쌔신: 더 비기닝': ['딜런 오브라이언', ' 마이클 키튼'],
'50가지 그림자: 심연': ['다코타 존슨', ' 제이미 도넌'],
'핵소 고지': ['앤드류 가필드', ' 샘 워싱턴'],
'채비': ['고두심', ' 김성균'],
'더 큐어': ['데인 드한', ' 미아 고스'],
'아토믹 블론드': ['샤를리즈 테론', ' 제임스 맥어보이'],
'비정규직 특수요원': ['강예원', ' 한채아']}

# %%
(dict['김래원']+dict['김해숙'])/2
# Out:
# 29.5

# %%
movie_actors = {}
for movie,actors in movies.items() :
    try :
        if len(actors) == 2  :
            movie_actors[movie] = (dict[actors[0]]+dict[actors[1]])/2
        if len(actors) == 1  :
            movie_actors[movie] = dict[actors[0]]
    except : 
        print(movie)
# Out:
# 희생부활자

# %%
movie_actors['희생부활자'] = 29.5

# %%
movie_actors

# %%
len(movie_actors)
# Out:
# 100

# %%
movie_actors
# Out:
# {'택시운전사': 25.5,
#  '신과함께-죄와 벌': 27.0,
#  '공조': 33.0,
#  '스파이더맨: 홈 커밍': 15.5,
#  '범죄도시': 25.0,
#  '군함도': 23.0,
#  '청년경찰': 9.0,
#  '더 킹': 20.5,
#  '미녀와 야수': 11.5,
#  '킹스맨: 골든 서클': 41.5,
#  '토르: 라그나로크': 23.0,
#  '꾼': 19.5,
#  '강철비': 26.0,
#  '남한산성': 34.0,
#  '미이라': 22.0,
#  '분노의 질주: 더 익스트림': 24.5,
#  '아이 캔 스피크': 17.0,
#  '캐리비안의 해적: 죽은 자는 말이 없다': 34.0,
#  '프리즌': 20.0,
#  '덩케르크': 6,
#  '가디언즈 오브 갤럭시 VOL. 2': 16.0,
#  '살인자의 기억법': 28.5,
#  '트랜스포머: 최후의 기사': 40.0,
#  '보안관': 34.0,
#  '조작된 도시': 11.0,
#  '재심': 24.5,
#  '박열': 15.0,
#  '마스터': 29.5,
#  '원더 우먼': 10.0,
#  '겟 아웃': 1.5,
#  '로건': 26,
#  '혹성탈출: 종의 전쟁': 28.0,
#  '1987': 33.0,
#  '애나벨 : 인형의 주인': 1.0,
#  '노무현입니다': 3,
#  '저스티스 리그': 19.5,
#  '킬러의 보디가드': 52.0,
#  '콩: 스컬 아일랜드': 41.5,
#  '23 아이덴티티': 15.0,
#  '임금님의 사건수첩': 35.5,
#  '부라더': 27.0,
#  '기억의 밤': 12.5,
#  '해피 데스데이': 1.5,
#  '브이아이피': 19.0,
#  '특별시민': 24.5,
#  '에이리언: 커버넌트': 14.5,
#  '장산범': 28.0,
#  '악녀': 21.5,
#  '해빙': 33.0,
#  '라라랜드': 19.5,
#  '하루': 13.5,
#  '지오스톰': 22.5,
#  '스타워즈: 라스트 제다이': 7.5,
#  '불한당: 나쁜 놈들의 세상': 24.0,
#  '그것': 4.5,
#  '오리엔트 특급 살인': 26.5,
#  '대립군': 20.0,
#  '베이비 드라이버': 18.5,
#  '위대한 쇼맨': 19.5,
#  '레지던트 이블: 파멸의 날': 18.5,
#  '공각기동대 : 고스트 인 더 쉘': 34,
#  '패신저스': 15.5,
#  '아빠는 딸': 23.5,
#  '컨택트': 19.5,
#  '47 미터': 8.0,
#  '얼라이드': 29.5,
#  '발레리안: 천 개 행성의 도시': 8.0,
#  '그레이트 월': 48.0,
#  '침묵': 20.5,
#  '트리플 엑스 리턴즈': 47.0,
#  '리얼': 13.0,
#  '라이프': 19.0,
#  '히든 피겨스': 9.0,
#  '반드시 잡는다': 28.0,
#  '원라인': 7.0,
#  '로그 원: 스타워즈 스토리': 11.5,
#  '킹 아서: 제왕의 검': 22.5,
#  '아메리칸 메이드': 23.5,
#  '보통사람': 11.5,
#  '대장 김창수': 29.0,
#  '어쌔신 크리드': 24.5,
#  '플립': 2.5,
#  '석조저택 살인사건': 17.5,
#  '싱글라이더': 30.5,
#  '7호실': 30,
#  '사랑하기 때문에': 18,
#  '옥자': 18.5,
#  '블레이드 러너 2049': 30.0,
#  '존 윅 - 리로드': 41,
#  '판도라': 8.0,
#  '미옥': 35.0,
#  '어느날': 18.5,
#  '어쌔신: 더 비기닝': 15.0,
#  '50가지 그림자: 심연': 6.5,
#  '핵소 고지': 16.0,
#  '채비': 20.5,
#  '더 큐어': 8.5,
#  '아토믹 블론드': 29.0,
#  '비정규직 특수요원': 8.5,
#  '희생부활자': 29.5}

# %%
dict = movie_actors

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'pactor' })
df.to_csv( './data_2017/2017_pactor', sep=',', encoding='utf-8' )
