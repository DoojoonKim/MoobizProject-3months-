# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data_2017/2017_pactor')

# %%
df2 = pd.read_csv('./data_2016/2016_pactor')

# %%
df3 = pd.read_csv('./data_2015/2015_pactor')

# %%
df4 = pd.read_csv('./data_2014/2014_pactor')

# %%
df5 = pd.read_csv('./data_2013/2013_pactor')

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.rename(columns = {'Unnamed: 0' : 'movies'},inplace=True)

# %%
df.drop_duplicates(['movies'],keep='last')
# Out:
#                 movies  pactor
# 0                 1987    33.0
# 1             23 아이덴티티    15.0
# 2                47 미터     8.0
# 3         50가지 그림자: 심연     6.5
# 4                  7호실    30.0
# 5   가디언즈 오브 갤럭시 VOL. 2    16.0
# 6                  강철비    26.0
# 7                 겟 아웃     1.5
# 8    공각기동대 : 고스트 인 더 쉘    34.0
# 9                   공조    33.0
# 10                 군함도    23.0
# 11                  그것     4.5
# 12              그레이트 월    48.0
# 13               기억의 밤    12.5
# 14                   꾼    19.5
# 15                남한산성    34.0
# 16              노무현입니다     3.0
# 17                 대립군    20.0
# 18              대장 김창수    29.0
# 19                더 큐어     8.5
# 20                 더 킹    20.5
# 21                덩케르크     6.0
# 23                 라이프    19.0
# 24      레지던트 이블: 파멸의 날    18.5
# 25                  로건    26.0
# 27                  리얼    13.0
# 30                  미옥    35.0
# 31                 미이라    22.0
# 32                  박열    15.0
# ...

# %%
df.to_csv('./data_all/pactor_all')
