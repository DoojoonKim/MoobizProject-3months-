# %%
dict = {'7번방의 선물': 52,
'관상': 111,
'아이언맨 3': 135,
'설국열차': 1349,
'베를린': 252,
'은밀하게 위대하게': 711,
'변호인': 11765,
'숨바꼭질': 108,
'더 테러 라이브': 687,
'감시자들': 248,
'월드 워 Z': 139,
'신세계': 104,
'박수건달': 170,
'스파이': 265,
'그래비티': 69,
'타워': 436,
'감기': 683,
'토르: 다크 월드': 56,
'레드: 더 레전드': 72,
'친구 2': 711,
'어바웃 타임': 25,
'나우 유 씨 미 : 마술사기단': 44,
'레미제라블': 44,
'소원': 218,
'퍼시픽 림': 222,
'화이: 괴물을 삼킨 아이': 79,
'컨저링': 314,
'맨 오브 스틸': 101,
'용의자': 107,
'호빗: 스마우그의 폐허': 40,
'몽타주': 49,
'연애의 온도': 90,
'지.아이.조 2': 123,
'분노의 질주: 더 맥시멈': 25,
'공범': 49,
'집으로 가는 길': 336,
'전설의 주먹': 183,
'파파로티': 94,
'스타트렉 다크니스': 77,
'오블리비언': 52,
'위대한 개츠비': 27,
'다이하드: 굿 데이 투 다이': 103,
'런닝맨': 102,
'미스터 고': 1103,
'결혼전야': 84,
'엘리시움': 62,
'깡철이': 85,
'더 웹툰: 예고살인': 106,
'웜 바디스': 82,
'고령화 가족': 58,
'헝거게임: 캣칭 파이어': 59,
'더 울버린': 232,
'동창생': 188,
'전국노래자랑': 166,
'잭 더 자이언트 킬러': 15,
'열한시': 57,
'남쪽으로 튀어': 79,
'잭 리처': 31,
'반창꼬': 102,
'더 파이브': 89,
'더 임파서블': 106,
'인시디어스: 두번째 집': 45,
'섀도우 헌터스: 뼈의 도시': 74,
'화이트 하우스 다운': 49,
'애프터 어스': 74,
'사이코메트리': 62,
'퍼시 잭슨과 괴물의 바다': 113,
'남자사용설명서': 174,
'다이노소어 어드벤처 3D': 19,
'무서운 이야기 2': 143,
'캐치미': 69,
'노브레싱': 263,
'클라우드 아틀라스': 374,
'창수': 38,
'론 레인저': 48,
'스토커': 94,
'오즈 그레이트 앤드 파워풀': 27,
'미나문방구': 1060,
'차이니즈 조디악': 215,
'이스케이프 플랜': 30,
'롤러코스터': 62,
'장고:분노의 추적자': 158,
'밤의 여왕': 68,
'캡틴 필립스': 38,
'잡스': 178,
'분노의 윤리학': 27,
'송 포 유': 46,
'호빗: 뜻밖의 여정': 41,
'비포 미드나잇': 11,
'응징자': 46,
'프리즈너스': 21,
'마이 리틀 히어로': 96,
'백악관 최후의 날': 125,
'해양경찰 마르코': 16,
'톱스타': 40,
'노리개': 59,
'엔더스 게임': 136,
'히든 카드': 10}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'n_breviews' })
df.to_csv( './data_2013/2013_n_breviews', sep=',', encoding='utf-8' )
