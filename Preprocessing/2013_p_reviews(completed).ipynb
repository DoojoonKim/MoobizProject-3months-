# %%
p_reviews_2013_1 = {'7번방의 선물': 953,
'관상': 666,
'아이언맨 3': 931,
'설국열차': 2802,
'베를린': 1106,
'은밀하게 위대하게': 2570,
'변호인': 3324,
'숨바꼭질': 633,
'더 테러 라이브': 697,
'감시자들': 286,
'월드 워 Z': 521,
'신세계': 389,
'박수건달': 339,
'스파이': 150,
'그래비티': 0,
'타워': 1223,
'감기': 635,
'토르: 다크 월드': 221,
'레드: 더 레전드': 224,
'친구 2': 272}

# %%
p_reviews_2013_2 = {
'어바웃 타임': 179,
'나우 유 씨 미 : 마술사기단': 588,
'레미제라블': 707,
'소원': 386,
'퍼시픽 림': 533,
'화이: 괴물을 삼킨 아이': 390,
'컨저링': 112,
'맨 오브 스틸': 897,
'용의자': 636,
'호빗: 스마우그의 폐허': 340,
'몽타주': 189,
'연애의 온도': 296,
'지.아이.조 2': 221,
'분노의 질주: 더 맥시멈': 262,
'공범': 97,
'집으로 가는 길': 162,
'전설의 주먹': 198,
'파파로티': 217,
'스타트렉 다크니스': 328,
'오블리비언': 388}

# %%
p_reviews_2013_4 = {'위대한 개츠비': 142,
'다이하드: 굿 데이 투 다이': 63,
'런닝맨': 135,
'미스터 고': 888,
'결혼전야': 113,
'엘리시움': 145,
'깡철이': 336,
'더 웹툰: 예고살인': 107,
'웜 바디스': 340,
'고령화 가족': 89,
'헝거게임: 캣칭 파이어': 165,
'더 울버린': 411,
'동창생': 386,
'전국노래자랑': 328,
'잭 더 자이언트 킬러': 177,
'열한시': 178,
'남쪽으로 튀어': 162,
'잭 리처': 126,
'반창꼬': 431,
'더 파이브': 134}

# %%
p_reviews_2013_8 = {'이스케이프 플랜': 66,
'롤러코스터': 332,
'장고:분노의 추적자': 130,
'밤의 여왕': 44,
'캡틴 필립스': 65,
'잡스': 249,
'분노의 윤리학': 84,
'송 포 유': 34,
'호빗: 뜻밖의 여정': 459,
'비포 미드나잇': 52,
'응징자': 62,
'프리즈너스': 50,
'마이 리틀 히어로': 86,
'백악관 최후의 날': 132,
'해양경찰 마르코': 23,
'톱스타': 69,
'노리개': 52,
'엔더스 게임': 218,
'히든 카드': 14}

# %%
p_reviews_2013_6 = {'더 임파서블': 121,
 '인시디어스: 두번째 집': 56,
 '섀도우 헌터스: 뼈의 도시': 92,
 '화이트 하우스 다운': 74,
 '애프터 어스': 335,
 '사이코메트리': 125,
 '퍼시 잭슨과 괴물의 바다': 103,
 '남자사용설명서': 511,
 '다이노소어 어드벤처 3D': 11,
 '무서운 이야기 2': 331,
 '캐치미': 90,
 '노브레싱': 588,
 '클라우드 아틀라스': 311,
 '창수': 177,
 '헨젤과 그레텔 : 마녀 사냥꾼': 51,
 '론 레인저': 73,
 '스토커': 174,
 '오즈 그레이트 앤드 파워풀': 60,
 '미나문방구': 137,
 '차이니즈 조디악': 52}

# %%
p_reviews_2013_1.update(p_reviews_2013_2)

# %%
p_reviews_2013_1.update(p_reviews_2013_4)

# %%
p_reviews_2013_1.update(p_reviews_2013_6)

# %%
p_reviews_2013_1.update(p_reviews_2013_8)

# %%
p_reviews_2013 = p_reviews_2013_1

# %%
p_reviews_2013
# Out:
# {'7번방의 선물': 953,
#  '관상': 666,
#  '아이언맨 3': 931,
#  '설국열차': 2802,
#  '베를린': 1106,
#  '은밀하게 위대하게': 2570,
#  '변호인': 3324,
#  '숨바꼭질': 633,
#  '더 테러 라이브': 697,
#  '감시자들': 286,
#  '월드 워 Z': 521,
#  '신세계': 389,
#  '박수건달': 339,
#  '스파이': 150,
#  '그래비티': 0,
#  '타워': 1223,
#  '감기': 635,
#  '토르: 다크 월드': 221,
#  '레드: 더 레전드': 224,
#  '친구 2': 272,
#  '어바웃 타임': 179,
#  '나우 유 씨 미 : 마술사기단': 588,
#  '레미제라블': 707,
#  '소원': 386,
#  '퍼시픽 림': 533,
#  '화이: 괴물을 삼킨 아이': 390,
#  '컨저링': 112,
#  '맨 오브 스틸': 897,
#  '용의자': 636,
#  '호빗: 스마우그의 폐허': 340,
#  '몽타주': 189,
#  '연애의 온도': 296,
#  '지.아이.조 2': 221,
#  '분노의 질주: 더 맥시멈': 262,
#  '공범': 97,
#  '집으로 가는 길': 162,
#  '전설의 주먹': 198,
#  '파파로티': 217,
#  '스타트렉 다크니스': 328,
#  '오블리비언': 388,
#  '위대한 개츠비': 142,
#  '다이하드: 굿 데이 투 다이': 63,
#  '런닝맨': 135,
#  '미스터 고': 888,
#  '결혼전야': 113,
#  '엘리시움': 145,
#  '깡철이': 336,
#  '더 웹툰: 예고살인': 107,
#  '웜 바디스': 340,
#  '고령화 가족': 89,
#  '헝거게임: 캣칭 파이어': 165,
#  '더 울버린': 411,
#  '동창생': 386,
#  '전국노래자랑': 328,
#  '잭 더 자이언트 킬러': 177,
# ...

# %%
import pandas as pd
df = pd.DataFrame([p_reviews_2013])
df = df.T
df = df.rename(columns = { 0 : 'p_reviews' })
df.to_csv( './data_2013/2013_p_reviews', sep=',', encoding='utf-8' )
