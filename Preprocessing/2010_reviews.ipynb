# %%
p_reviews_2010 = {'아바타': 0,
'아저씨': 384,
'인셉션': 493,
'의형제': 299,
'아이언맨 2': 163,
'전우치': 401,
'이끼': 127,
'포화속으로': 345,
'하모니': 318,
'방자전': 31,
'솔트': 92,
'부당거래': 84,
'시라노; 연애조작단': 322,
'타이탄': 101,
'해리 포터와 죽음의 성물1': 180,
'하녀': 43,
'나잇&데이': 55,
'이상한 나라의 앨리스': 44,
'초능력자': 158,
'이클립스': 121,
'쩨쩨한 로맨스': 57,
'페르시아의 왕자: 시간의 모래': 45,
'퍼시 잭슨과 번개 도둑': 101,
'해결사': 43,
'악마를 보았다': 190,
'로빈 후드': 47,
'무적자': 62,
'토이 스토리 3': 134,
'구르믈 버서난 달처럼': 26,
'황해': 202,
'라스트 에어벤더': 61,
'헬로우 고스트': 115,
'육혈포 강도단': 22,
'심야의 F.M.': 76,
'레지던트 이블 4: 끝나지 않은 전쟁 3D': 47,
'나니아 연대기: 새벽 출정호의 항해': 31,
'용서는 없다': 49,
'베스트셀러': 52,
'김종욱 찾기': 70,
'셜록 홈즈': 50,
'파괴된 사나이': 163,
'셔터 아일랜드': 51,
'방가? 방가!': 19,
'평행이론': 75,
'투어리스트': 49,
'스카이 라인': 665,
'고死 두 번째 이야기: 교생실습': 175,
'A-특공대': 30,
'주유소 습격사건 2': 56,
'마음이2': 26,
'내 깡패 같은 애인': 63,
'스텝 업 3D': 141,
'오션스': 39,
'그린 존': 27,
'이층의 악당': 33,
'반가운 살인자': 91,
'퀴즈왕': 36,
'마법사의 제자': 28,
'소셜 네트워크': 42,
'먹고 기도하고 사랑하라': 13,
'불량남녀': 28,
'친정엄마': 32,
'식객2 : 김치전쟁': 33,
'적인걸: 측천무후의 비밀': 7,
'언스토퍼블': 16,
'대한민국 1%': 55,
'파라노말 액티비티': 130,
'워리어스 웨이': 57,
'나인': 120,
'섹스 앤 더 시티 2': 21,
'익스펜더블': 29,
'공자 춘추전국시대': 0,
'프롬 파리 위드 러브': 29,
'파라노말 액티비티 2': 30,
'블라인드 사이드': 15,
'맨발의 꿈': 56,
'라스트 갓파더': 654,
'베스트 키드': 23,
'울프맨': 16,
'울지마, 톤즈': 0,
'월 스트리트: 머니 네버 슬립스': 8,
'사랑은 너무 복잡해': 10,
'인플루언스': 0,
'폐가': 226,
'포스 카인드': 22,
'시': 21,
'러블리 본즈': 21,
'내니맥피 2: 유모와마법소동': 10,
'쓰리 데이즈': 18,
'페스티발': 132,
'꼬마 니콜라': 13,
'엣지 오브 다크니스': 194,
'레터스 투 줄리엣': 8,
'앨빈과 슈퍼밴드2': 23,
'피라냐': 43,
'킬러스': 31,
'검우강호': 36,
'프레데터스': 24,
'일라이': 12}

# %%
import pandas as pd
df1 = pd.DataFrame([p_reviews_2010])
df1 = df1.T
df1 = df1.rename(columns = { 0 : 'p_reviews' })
df1.to_csv( './data_2010/2010_p_reviews', sep=',', encoding='utf-8' )

# %%
n_reviews_2010 = {'아바타': 0,
'아저씨': 39,
'인셉션': 80,
'의형제': 46,
'아이언맨 2': 177,
'전우치': 200,
'이끼': 120,
'포화속으로': 154,
'하모니': 33,
'방자전': 27,
'솔트': 73,
'부당거래': 33,
'시라노; 연애조작단': 51,
'타이탄': 124,
'해리 포터와 죽음의 성물1': 69,
'하녀': 125,
'나잇&데이': 29,
'이상한 나라의 앨리스': 48,
'초능력자': 236,
'이클립스': 78,
'쩨쩨한 로맨스': 36,
'페르시아의 왕자: 시간의 모래': 22,
'퍼시 잭슨과 번개 도둑': 102,
'해결사': 51,
'악마를 보았다': 219,
'로빈 후드': 39,
'무적자': 99,
'토이 스토리 3': 13,
'구르믈 버서난 달처럼': 38,
'황해': 167,
'라스트 에어벤더': 181,
'헬로우 고스트': 30,
'육혈포 강도단': 17,
'심야의 F.M.': 52,
'레지던트 이블 4: 끝나지 않은 전쟁 3D': 56,
'나니아 연대기: 새벽 출정호의 항해': 16,
'용서는 없다': 36,
'베스트셀러': 23,
'김종욱 찾기': 31,
'셜록 홈즈': 35,
'파괴된 사나이': 75,
'셔터 아일랜드': 36,
'방가? 방가!': 10,
'평행이론': 51,
'투어리스트': 74,
'스카이 라인': 263,
'고死 두 번째 이야기: 교생실습': 356,
'A-특공대': 10,
'주유소 습격사건 2': 54,
'마음이2': 9,
'내 깡패 같은 애인': 13,
'스텝 업 3D': 15,
'오션스': 15,
'그린 존': 20,
'이층의 악당': 24,
'반가운 살인자': 53,
'퀴즈왕': 29,
'마법사의 제자': 24,
'소셜 네트워크': 28,
'먹고 기도하고 사랑하라': 19,
'불량남녀': 11,
'친정엄마': 3,
'식객2 : 김치전쟁': 21,
'적인걸: 측천무후의 비밀': 3,
'언스토퍼블': 7,
'대한민국 1%': 18,
'파라노말 액티비티': 74,
'워리어스 웨이': 98,
'나인': 110,
'섹스 앤 더 시티 2': 7,
'익스펜더블': 52,
'공자 춘추전국시대': 0,
'프롬 파리 위드 러브': 38,
'파라노말 액티비티 2': 24,
'블라인드 사이드': 9,
'맨발의 꿈': 5,
'라스트 갓파더': 391,
'베스트 키드': 10,
'울프맨': 30,
'울지마, 톤즈': 0,
'월 스트리트: 머니 네버 슬립스': 6,
'사랑은 너무 복잡해': 2,
'인플루언스': 0,
'폐가': 134,
'포스 카인드': 12,
'시': 2,
'러블리 본즈': 24,
'내니맥피 2: 유모와마법소동': 1,
'쓰리 데이즈': 9,
'페스티발': 31,
'꼬마 니콜라': 5,
'엣지 오브 다크니스': 18,
'레터스 투 줄리엣': 1,
'앨빈과 슈퍼밴드2': 8,
'피라냐': 66,
'킬러스': 41,
'검우강호': 44,
'프레데터스': 32,
'일라이': 22}

# %%
import pandas as pd
df2 = pd.DataFrame([n_reviews_2010])
df2 = df2.T
df2 = df2.rename(columns = { 0 : 'n_reviews' })
df2.to_csv( './data_2010/2010_n_reviews', sep=',', encoding='utf-8' )
