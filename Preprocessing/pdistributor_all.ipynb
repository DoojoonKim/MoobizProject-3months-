# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data_2017/2017_pdistributor')

# %%
df2 = pd.read_csv('./data_2016/2016_pdistributor')

# %%
df3 = pd.read_csv('./data_2015/2015_pdistributor')

# %%
df4 = pd.read_csv('./data_2014/2014_pdistributor')

# %%
df5 = pd.read_csv('./data_2013/2013_pdistributor')

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.rename(columns={'Unnamed: 0':'movies'},inplace=True)

# %%
df.set_index('movies')
# Out:
#                     pdistributor
# movies
# 1987                         228
# 23 아이덴티티                     195
# 47 미터                         46
# 50가지 그림자: 심연                 195
# 7호실                          315
# 가디언즈 오브 갤럭시 VOL. 2            29
# 강철비                          170
# 겟 아웃                         195
# 공각기동대 : 고스트 인 더 쉘            315
# 공조                           228
# 군함도                          228
# 그것                           214
# 그레이트 월                       195
# 기억의 밤                          3
# 꾼                            224
# 남한산성                         228
# 노무현입니다                         1
# 대립군                          179
# 대장 김창수                         3
# 더 큐어                         179
# 더 킹                          170
# 덩케르크                         214
# 라라랜드                          88
# 라이프                           20
# 레지던트 이블: 파멸의 날               195
# 로건                           179
# 로그 원: 스타워즈 스토리                29
# ...

# %%
df.drop_duplicates(['movies'],keep='last')
# Out:
#                 movies  pdistributor
# 0                 1987           228
# 1             23 아이덴티티           195
# 2                47 미터            46
# 3         50가지 그림자: 심연           195
# 4                  7호실           315
# 5   가디언즈 오브 갤럭시 VOL. 2            29
# 6                  강철비           170
# 7                 겟 아웃           195
# 8    공각기동대 : 고스트 인 더 쉘           315
# 9                   공조           228
# 10                 군함도           228
# 11                  그것           214
# 12              그레이트 월           195
# 13               기억의 밤             3
# 14                   꾼           224
# 15                남한산성           228
# 16              노무현입니다             1
# 17                 대립군           179
# 18              대장 김창수             3
# 19                더 큐어           179
# 20                 더 킹           170
# 21                덩케르크           214
# 23                 라이프            20
# 24      레지던트 이블: 파멸의 날           195
# ...

# %%
df.to_csv('./data_all/pdistributor_all')
