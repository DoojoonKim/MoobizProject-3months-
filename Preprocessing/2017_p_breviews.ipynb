# %%
p_breviews = {'택시운전사': 2862,
'신과함께-죄와 벌': 2894,
'공조': 485,
'스파이더맨: 홈 커밍': 399,
'범죄도시': 1047,
'군함도': 2741,
'청년경찰': 1151,
'더 킹': 868,
'미녀와 야수': 166,
'킹스맨: 골든 서클': 547,
'토르: 라그나로크': 467,
'꾼': 199,
'강철비': 572,
'남한산성': 524,
'미이라': 293,
'분노의 질주: 더 익스트림': 298,
'아이 캔 스피크': 415,
'프리즌': 1183,
'덩케르크': 435,
'가디언즈 오브 갤럭시 VOL. 2': 473,
'살인자의 기억법': 703,
'트랜스포머: 최후의 기사': 842,
'보안관': 145,
'조작된 도시': 591,
'재심': 239,
'박열': 721,
'마스터': 928,
'원더 우먼': 219,
'겟 아웃': 657,
'로건': 453,
'혹성탈출: 종의 전쟁': 424,
'1987': 846,
'애나벨 : 인형의 주인': 120,
'노무현입니다': 1748,
'저스티스 리그': 740,
'킬러의 보디가드': 141,
'콩: 스컬 아일랜드': 529,
'23 아이덴티티': 127,
'임금님의 사건수첩': 441,
'부라더': 660,
'기억의 밤': 301,
'해피 데스데이': 160,
'브이아이피': 432,
'특별시민': 413,
'에이리언: 커버넌트': 564,
'장산범': 296,
'악녀': 168,
'해빙': 152,
'라라랜드': 91,
'하루': 169,
'지오스톰': 90,
'스타워즈: 라스트 제다이': 212,
'불한당: 나쁜 놈들의 세상': 777,
'그것': 164,
'오리엔트 특급 살인': 206,
'대립군': 437,
'베이비 드라이버': 87,
'위대한 쇼맨': 486,
'레지던트 이블: 파멸의 날': 396,
'공각기동대 : 고스트 인 더 쉘': 631,
'패신저스': 154,
'아빠는 딸': 979,
'컨택트': 940,
'47 미터': 198,
'얼라이드': 457,
'발레리안: 천 개 행성의 도시': 216,
'그레이트 월': 454,
'침묵': 257,
'트리플 엑스 리턴즈': 286,
'리얼': 1512,
'라이프': 208,
'히든 피겨스': 328,
'반드시 잡는다': 207,
'원라인': 183,
'로그 원: 스타워즈 스토리': 255,
'킹 아서: 제왕의 검': 260,
'아메리칸 메이드': 84,
'보통사람': 327,
'대장 김창수': 286,
'어쌔신 크리드': 744,
'플립': 3408,
'석조저택 살인사건': 107,
'싱글라이더': 261,
'7호실': 277,
'사랑하기 때문에': 398,
'희생부활자': 189,
'옥자': 444,
'블레이드 러너 2049': 771,
'존 윅 - 리로드': 216,
'판도라': 515,
'미옥': 154,
'어느날': 149,
'어쌔신: 더 비기닝': 193,
'50가지 그림자: 심연': 104,
'핵소 고지': 441,
'채비': 236,
'더 큐어': 105,
'아토믹 블론드': 122,
'비정규직 특수요원': 581}

# %%
import pandas as pd
df = pd.DataFrame([p_breviews])
df = df.T
df = df.rename(columns = { 0 : 'p_breviews' })
df
# Out:
#                     p_breviews
# 1987                       846
# 23 아이덴티티                   127
# 47 미터                      198
# 50가지 그림자: 심연               104
# 7호실                        277
# 가디언즈 오브 갤럭시 VOL. 2         473
# 강철비                        572
# 겟 아웃                       657
# 공각기동대 : 고스트 인 더 쉘          631
# 공조                         485
# 군함도                       2741
# 그것                         164
# 그레이트 월                     454
# 기억의 밤                      301
# 꾼                          199
# 남한산성                       524
# 노무현입니다                    1748
# 대립군                        437
# 대장 김창수                     286
# 더 큐어                       105
# 더 킹                        868
# 덩케르크                       435
# 라라랜드                        91
# 라이프                        208
# 레지던트 이블: 파멸의 날             396
# 로건                         453
# 로그 원: 스타워즈 스토리             255
# 리얼                        1512
# 마스터                        928
# ...

# %%
df.to_csv( './data_2017/2017_p_breviews', sep=',', encoding='utf-8' )
