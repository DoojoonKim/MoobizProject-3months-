# %%
n_breviews ={'택시운전사': 676,
'신과함께-죄와 벌': 1118,
'공조': 128,
'스파이더맨: 홈 커밍': 62,
'범죄도시': 162,
'군함도': 630,
'청년경찰': 278,
'더 킹': 218,
'미녀와 야수': 34,
'킹스맨: 골든 서클': 120,
'토르: 라그나로크': 52,
'꾼': 123,
'강철비': 278,
'남한산성': 187,
'미이라': 62,
'분노의 질주: 더 익스트림': 31,
'아이 캔 스피크': 41,
'프리즌': 306,
'덩케르크': 56,
'가디언즈 오브 갤럭시 VOL. 2': 69,
'살인자의 기억법': 291,
'트랜스포머: 최후의 기사': 384,
'보안관': 53,
'조작된 도시': 114,
'재심': 31,
'박열': 136,
'마스터': 421,
'원더 우먼': 74,
'겟 아웃': 369,
'로건': 88,
'혹성탈출: 종의 전쟁': 84,
'1987': 375,
'애나벨 : 인형의 주인': 43,
'노무현입니다': 446,
'저스티스 리그': 339,
'킬러의 보디가드': 22,
'콩: 스컬 아일랜드': 176,
'23 아이덴티티': 42,
'임금님의 사건수첩': 136,
'부라더': 164,
'기억의 밤': 48,
'해피 데스데이': 23,
'브이아이피': 147,
'특별시민': 104,
'에이리언: 커버넌트': 84,
'장산범': 124,
'악녀': 105,
'해빙': 24,
'라라랜드': 13,
'하루': 69,
'지오스톰': 32,
'스타워즈: 라스트 제다이': 64,
'불한당: 나쁜 놈들의 세상': 237,
'그것': 41,
'오리엔트 특급 살인': 61,
'대립군': 75,
'베이비 드라이버': 15,
'위대한 쇼맨': 41,
'레지던트 이블: 파멸의 날': 164,
'공각기동대 : 고스트 인 더 쉘': 265,
'패신저스': 34,
'아빠는 딸': 121,
'컨택트': 526,
'47 미터': 87,
'얼라이드': 139,
'발레리안: 천 개 행성의 도시': 95,
'그레이트 월': 174,
'침묵': 62,
'트리플 엑스 리턴즈': 37,
'리얼': 481,
'라이프': 113,
'히든 피겨스': 47,
'반드시 잡는다': 56,
'원라인': 35,
'로그 원: 스타워즈 스토리': 67,
'킹 아서: 제왕의 검': 87,
'아메리칸 메이드': 17,
'보통사람': 39,
'대장 김창수': 213,
'어쌔신 크리드': 174,
'플립': 468,
'석조저택 살인사건': 32,
'싱글라이더': 86,
'7호실': 43,
'사랑하기 때문에': 68,
'희생부활자': 45,
'옥자': 254,
'블레이드 러너 2049': 145,
'존 윅 - 리로드': 38,
'판도라': 217,
'미옥': 45,
'어느날': 22,
'어쌔신: 더 비기닝': 35,
'50가지 그림자: 심연': 40,
'핵소 고지': 118,
'채비': 30,
'더 큐어': 16,
'아토믹 블론드': 45,
'비정규직 특수요원': 172}

# %%
import pandas as pd
df = pd.DataFrame([n_breviews])
df = df.T
df = df.rename(columns = { 0 : 'n_breviews' })
df
# Out:
#                     n_breviews
# 1987                       375
# 23 아이덴티티                    42
# 47 미터                       87
# 50가지 그림자: 심연                40
# 7호실                         43
# 가디언즈 오브 갤럭시 VOL. 2          69
# 강철비                        278
# 겟 아웃                       369
# 공각기동대 : 고스트 인 더 쉘          265
# 공조                         128
# 군함도                        630
# 그것                          41
# 그레이트 월                     174
# 기억의 밤                       48
# 꾼                          123
# 남한산성                       187
# 노무현입니다                     446
# 대립군                         75
# 대장 김창수                     213
# 더 큐어                        16
# 더 킹                        218
# 덩케르크                        56
# 라라랜드                        13
# 라이프                        113
# 레지던트 이블: 파멸의 날             164
# 로건                          88
# 로그 원: 스타워즈 스토리              67
# 리얼                         481
# 마스터                        421
# ...

# %%
df.set_index('movies')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movies'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0abc6d8224cb> in <module>()
# ----> 1 df.set_index('movies')
#
# ...

# %%
df.to_csv( './data_2017/2017_n_breviews', sep=',', encoding='utf-8' )
