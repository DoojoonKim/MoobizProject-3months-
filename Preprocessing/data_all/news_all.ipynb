# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data_2017/2017_news')

# %%
df2 = pd.read_csv('./data_2016/2016_news')

# %%
df3 = pd.read_csv('./data_2015/2015_news')

# %%
df4 = pd.read_csv('./data_2014/2014_news')

# %%
df5 = pd.read_csv('./data_2013/2013_news')

# %%
news = pd.concat([df1,df2,df3,df4,df5])

# %%
news
# Out:
#             Unnamed: 0   news
# 0                 1987    507
# 1             23 아이덴티티     38
# 2                47 미터      1
# 3         50가지 그림자: 심연     13
# 4                  7호실    240
# 5   가디언즈 오브 갤럭시 VOL. 2     73
# 6                  강철비    475
# 7                 겟 아웃     17
# 8    공각기동대 : 고스트 인 더 쉘      2
# 9                   공조    685
# 10                 군함도    798
# 11                  그것      0
# 12              그레이트 월     18
# 13               기억의 밤      2
# 14                   꾼    643
# 15                남한산성    560
# 16              노무현입니다    245
# 17                 대립군    245
# 18              대장 김창수    326
# 19                더 큐어      1
# 20                 더 킹      2
# 21                덩케르크    119
# 22                라라랜드     41
# 23                 라이프    128
# 24      레지던트 이블: 파멸의 날      1
# 25                  로건     62
# 26      로그 원: 스타워즈 스토리     67
# 27                  리얼  1,051
# 28                 마스터    757
# 29              미녀와 야수    161
# ...

# %%
news.rename(columns = {'Unnamed: 0' : 'movies'},inplace=True)

# %%
df = news.drop_duplicates(['movies'],keep='last')

# %%
df
# Out:
#                 movies   news
# 0                 1987    507
# 1             23 아이덴티티     38
# 2                47 미터      1
# 3         50가지 그림자: 심연     13
# 4                  7호실    240
# 5   가디언즈 오브 갤럭시 VOL. 2     73
# 6                  강철비    475
# 7                 겟 아웃     17
# 8    공각기동대 : 고스트 인 더 쉘      2
# 9                   공조    685
# 10                 군함도    798
# 11                  그것      0
# 12              그레이트 월     18
# 13               기억의 밤      2
# 14                   꾼    643
# 15                남한산성    560
# 16              노무현입니다    245
# 17                 대립군    245
# 18              대장 김창수    326
# 19                더 큐어      1
# 20                 더 킹      2
# 21                덩케르크    119
# 23                 라이프    128
# 24      레지던트 이블: 파멸의 날      1
# 25                  로건     62
# 27                  리얼  1,051
# 30                  미옥    142
# 31                 미이라     79
# 32                  박열    428
# 33             반드시 잡는다      0
# ...

# %%
df.to_csv('./data_all/news_all')
