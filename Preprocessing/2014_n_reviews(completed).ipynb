# %%
movies_1 = {
'명량': 612,
'인터스텔라': 0,
'수상한 그녀': 82,
'해적: 바다로 간 산적': 356,
'변호인': 3848,
'국제시장': 88,
'트랜스포머: 사라진 시대': 772,
'군도: 민란의 시대': 1404,
'엣지 오브 투모로우': 208,
'엑스맨: 데이즈 오브 퓨처 패스트': 165,
'어메이징 스파이더맨 2': 220,
'혹성탈출: 반격의 서막': 123,
'타짜-신의 손': 699,
'캡틴 아메리카: 윈터 솔져': 84,
'역린': 633,
'신의 한 수': 165,
'끝까지 간다': 51,
'표적': 144,
'메이즈 러너': 220,
'호빗: 다섯 군대 전투': 169,
'나의 사랑 나의 신부': 37,
'논스톱': 88,
'인투 더 스톰': 72,
'노아': 283,
'남자가 사랑할 때': 72,
'루시': 268,
'용의자': 114,
'기술자들': 297,
'나를 찾아줘': 37,
'제보자': 53,
'피끓는 청춘': 194,
'우아한 거짓말': 26,
'두근두근 내 인생': 170,
'300: 제국의 부활': 139,
'엑소더스: 신들과 왕들': 156,
'해무(海霧)': 454,
'인간중독': 177,
'말레피센트': 79,
'폼페이: 최후의 날': 104,
'퓨리': 79,
'드라큘라: 전설의 시작': 58,
'가디언즈 오브 갤럭시': 297,
'찌라시: 위험한 소문': 92,
'빅매치': 42,
'슬로우 비디오': 97,
'방황하는 칼날': 55,
'로보캅': 133,
'우리는 형제입니다': 35,
'애나벨': 123,
'헝거게임: 모킹제이': 208}

# %%
movies_2 = {
'월터의 상상은 현실이 된다': 0,
'카트': 87,
'관능의 법칙': 54,
'안녕, 헤이즐': 31,
'고질라': 277,
'트랜센던스': 98,
'상의원': 103,
'플랜맨': 36,
'우는 남자': 315,
'황제를 위하여': 109,
'패션왕': 230,
'더 울프 오브 월스트리트': 54,
'스텝 업: 올 인': 42,
'어바웃 타임': 19,
'노예 12년': 30,
'또 하나의 약속': 49,
'엔더스 게임': 143,
'소녀괴담': 241,
'조선미녀삼총사': 182,
'마담 뺑덕': 115,
'다이버전트': 50,
'주온 : 끝의 시작': 122,
'좋은 친구들': 95,
'닌자터틀': 59,
'나의 독재자': 101,
'하이힐': 0,
'선 오브 갓': 0,
'잭 라이언 : 코드네임 쉐도우': 72,
'숲속으로': 134,
'레드카펫': 26,
'미녀와 야수': 15,
'프랑켄슈타인: 불멸의 영웅': 76,
'러브, 로지': 31,
'오큘러스': 60,
'사랑에 대한 모든 것': 33,
'노벰버 맨': 26,
'툼스톤': 57,
'쓰리데이즈 투 킬': 34,
'헤라클레스 : 레전드 비긴즈': 0,
'극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': 8,
'덕수리 5형제': 44,
'덤 앤 더머 투': 36,
'컬러풀 웨딩즈': 15,
'론 서바이버 ': 23,
'아빠를 빌려드립니다': 27,
'라스트베가스': 10,
'호빗: 스마우그의 폐허': 69,
'폴리스 스토리 2014': 15,
'익스펜더블 3': 20}

# %%
movies_1.update(movies_2)

# %%
movies_1
# Out:
# {'명량': 612,
#  '인터스텔라': 0,
#  '수상한 그녀': 82,
#  '해적: 바다로 간 산적': 356,
#  '변호인': 3848,
#  '국제시장': 88,
#  '트랜스포머: 사라진 시대': 772,
#  '군도: 민란의 시대': 1404,
#  '엣지 오브 투모로우': 208,
#  '엑스맨: 데이즈 오브 퓨처 패스트': 165,
#  '어메이징 스파이더맨 2': 220,
#  '혹성탈출: 반격의 서막': 123,
#  '타짜-신의 손': 699,
#  '캡틴 아메리카: 윈터 솔져': 84,
#  '역린': 633,
#  '신의 한 수': 165,
#  '끝까지 간다': 51,
#  '표적': 144,
#  '메이즈 러너': 220,
#  '호빗: 다섯 군대 전투': 169,
#  '나의 사랑 나의 신부': 37,
#  '논스톱': 88,
#  '인투 더 스톰': 72,
#  '노아': 283,
#  '남자가 사랑할 때': 72,
#  '루시': 268,
#  '용의자': 114,
#  '기술자들': 297,
#  '나를 찾아줘': 37,
#  '제보자': 53,
#  '피끓는 청춘': 194,
#  '우아한 거짓말': 26,
#  '두근두근 내 인생': 170,
#  '300: 제국의 부활': 139,
#  '엑소더스: 신들과 왕들': 156,
#  '해무(海霧)': 454,
#  '인간중독': 177,
#  '말레피센트': 79,
#  '폼페이: 최후의 날': 104,
#  '퓨리': 79,
#  '드라큘라: 전설의 시작': 58,
#  '가디언즈 오브 갤럭시': 297,
#  '찌라시: 위험한 소문': 92,
#  '빅매치': 42,
#  '슬로우 비디오': 97,
#  '방황하는 칼날': 55,
#  '로보캅': 133,
#  '우리는 형제입니다': 35,
#  '애나벨': 123,
#  '헝거게임: 모킹제이': 208,
#  '월터의 상상은 현실이 된다': 0,
#  '카트': 87,
#  '관능의 법칙': 54,
# ...

# %%
import pandas as pd
df = pd.DataFrame([movies_1])
df = df.T
df = df.rename(columns = { 0 : 'n_reviews' })
df.to_csv( './data_2014/2014_n_reviews', sep=',', encoding='utf-8' )
