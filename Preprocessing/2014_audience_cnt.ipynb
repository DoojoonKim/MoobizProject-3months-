# %%
dict = {'명량': '17615437',
'인터스텔라': '10309432',
'수상한 그녀': '8659755',
'해적: 바다로 간 산적': '8666208',
'변호인': '11374892',
'국제시장': '14262922',
'트랜스포머: 사라진 시대': '5295929',
'군도: 민란의 시대': '4775811',
'엣지 오브 투모로우': '4697209',
'엑스맨: 데이즈 오브 퓨처 패스트': '4313446',
'어메이징 스파이더맨 2': '4164946',
'혹성탈출: 반격의 서막': '4002539',
'타짜-신의 손': '4015364',
'캡틴 아메리카: 윈터 솔져': '3963964',
'역린': '3849700',
'신의 한 수': '3566844',
'끝까지 간다': '3450305',
'표적': '2841884',
'메이즈 러너': '2299751',
'호빗: 다섯 군대 전투': '2836777',
'나의 사랑 나의 신부': '2141155',
'논스톱': '2084457',
'인투 더 스톰': '2078825',
'노아': '2026574',
'남자가 사랑할 때': '1980120',
'루시': '1974843',
'용의자': '4131963',
'기술자들': '2564340',
'나를 찾아줘': '1764233',
'제보자': '1755181',
'피끓는 청춘': '1676040',
'우아한 거짓말': '1619871',
'두근두근 내 인생': '1624573',
'300: 제국의 부활': '1593116',
'엑소더스: 신들과 왕들': '1511845',
'인간중독': '1441990',
'말레피센트': '1396899',
'폼페이: 최후의 날': '1373888',
'퓨리': '1362105',
'드라큘라: 전설의 시작': '1321718',
'가디언즈 오브 갤럭시': '2736060',
'찌라시: 위험한 소문': '1221420',
'빅매치': '1177435',
'슬로우 비디오': '1169546',
'방황하는 칼날': '989593',
'로보캅': '979509',
'우리는 형제입니다': '970377',
'헝거게임: 모킹제이': '854407',
'월터의 상상은 현실이 된다': '957127',
'카트': '814621',
'안녕, 헤이즐': '749146',
'고질라': '709734',
'트랜센던스': '696412',
'상의원': '790370',
'플랜맨': '635744',
'우는 남자': '603093',
'황제를 위하여': '591502',
'패션왕': '594876',
'더 울프 오브 월스트리트': '586005',
'스텝 업: 올 인': '565049',
'어바웃 타임': '3396313',
'노예 12년': '499038',
'또 하나의 약속': '497994',
'엔더스 게임': '654480',
'소녀괴담': '481707',
'조선미녀삼총사': '480361',
'마담 뺑덕': '471248',
'다이버전트': '424086',
'주온 : 끝의 시작': '410644',
'좋은 친구들': '407323',
'나의 독재자': '386074',
'하이힐': '343487',
'선 오브 갓': '329286',
'잭 라이언 : 코드네임 쉐도우': '327591',
'숲속으로': '341882',
'레드카펫': '316955',
'프랑켄슈타인: 불멸의 영웅': '299205',
'러브, 로지': '296748',
'오큘러스': '279438',
'사랑에 대한 모든 것': '278087',
'노벰버 맨': '252447',
'툼스톤': '242770',
'쓰리데이즈 투 킬': '229644',
'헤라클레스 : 레전드 비긴즈': '221327',
'덕수리 5형제': '210775',
'덤 앤 더머 투': '192739',
'컬러풀 웨딩즈': '190470',
'론 서바이버 ': '190611',
'아빠를 빌려드립니다': '172652',
'라스트베가스': '177938',
'호빗: 스마우그의 폐허': '2282807',
'폴리스 스토리 2014': '153591',
'익스펜더블 3': '152033',
'해무(海霧)': '1475091',
'애나벨': '926107',
'관능의 법칙': '781516',
'닌자터틀': '400333',
'미녀와 야수': '316334',
'극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': '215046'}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'audience_cnt' })
df.to_csv( './data_2014/2014_audience_cnt', sep=',', encoding='utf-8' )

# %%
df['audience_cnt'].astype(int)
# Out:
# 300: 제국의 부활                                       1593116
# 가디언즈 오브 갤럭시                                       2736060
# 고질라                                                709734
# 관능의 법칙                                             781516
# 국제시장                                             14262922
# 군도: 민란의 시대                                        4775811
# 극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~      215046
# 기술자들                                              2564340
# 끝까지 간다                                            3450305
# 나를 찾아줘                                            1764233
# 나의 독재자                                             386074
# 나의 사랑 나의 신부                                       2141155
# 남자가 사랑할 때                                         1980120
# 노벰버 맨                                              252447
# 노아                                                2026574
# 노예 12년                                             499038
# ...

# %%
df.to_csv( './data_2014/2014_audience_cnt', sep=',', encoding='utf-8' )
