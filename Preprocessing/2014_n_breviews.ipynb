# %%
dict = {'명량': 348,
'인터스텔라': 52,
'수상한 그녀': 114,
'해적: 바다로 간 산적': 487,
'변호인': 11765,
'국제시장': 214,
'트랜스포머: 사라진 시대': 1882,
'군도: 민란의 시대': 204,
'엣지 오브 투모로우': 61,
'엑스맨: 데이즈 오브 퓨처 패스트': 120,
'어메이징 스파이더맨 2': 112,
'혹성탈출: 반격의 서막': 60,
'타짜-신의 손': 2393,
'캡틴 아메리카: 윈터 솔져': 44,
'역린': 182,
'신의 한 수': 106,
'끝까지 간다': 87,
'표적': 30,
'메이즈 러너': 57,
'호빗: 다섯 군대 전투': 57,
'나의 사랑 나의 신부': 39,
'논스톱': 36,
'인투 더 스톰': 65,
'노아': 67,
'남자가 사랑할 때': 63,
'루시': 204,
'용의자': 107,
'기술자들': 168,
'나를 찾아줘': 21,
'제보자': 134,
'피끓는 청춘': 134,
'우아한 거짓말': 42,
'두근두근 내 인생': 1602,
'300: 제국의 부활': 77,
'엑소더스: 신들과 왕들': 45,
'해무(海霧)': 198,
'인간중독': 84,
'말레피센트': 16,
'폼페이: 최후의 날': 41,
'퓨리': 35,
'드라큘라: 전설의 시작': 28,
'가디언즈 오브 갤럭시': 69,
'찌라시: 위험한 소문': 52,
'빅매치': 114,
'슬로우 비디오': 124,
'방황하는 칼날': 40,
'로보캅': 144,
'우리는 형제입니다': 46,
'애나벨': 17,
'헝거게임: 모킹제이': 35,
'월터의 상상은 현실이 된다': 45,
'카트': 415,
'관능의 법칙': 87,
'안녕, 헤이즐': 38,
'고질라': 127,
'트랜센던스': 73,
'상의원': 120,
'플랜맨': 69,
'우는 남자': 112,
'황제를 위하여': 70,
'패션왕': 1181,
'더 울프 오브 월스트리트': 21,
'스텝 업: 올 인': 32,
'어바웃 타임': 25,
'노예 12년': 84,
'또 하나의 약속': 128,
'엔더스 게임': 136,
'소녀괴담': 67,
'조선미녀삼총사': 364,
'마담 뺑덕': 105,
'다이버전트': 40,
'주온 : 끝의 시작': 201,
'좋은 친구들': 65,
'닌자터틀': 96,
'나의 독재자': 323,
'하이힐': 70,
'선 오브 갓': 89,
'잭 라이언 : 코드네임 쉐도우': 14,
'숲속으로': 15,
'레드카펫': 44,
'미녀와 야수': 8,
'프랑켄슈타인: 불멸의 영웅': 50,
'러브, 로지': 22,
'오큘러스': 26,
'사랑에 대한 모든 것': 19,
'노벰버 맨': 17,
'툼스톤': 14,
'쓰리데이즈 투 킬': 25,
'헤라클레스 : 레전드 비긴즈': 389,
'극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': 12,
'덕수리 5형제': 50,
'덤 앤 더머 투': 25,
'컬러풀 웨딩즈': 15,
'론 서바이버 ': 119,
'아빠를 빌려드립니다': 69,
'라스트베가스': 28,
'호빗: 스마우그의 폐허': 40,
'폴리스 스토리 2014': 16,
'익스펜더블 3': 65}

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'n_breviews' })
df.to_csv( './data_2014/2014_n_breviews', sep=',', encoding='utf-8' )
