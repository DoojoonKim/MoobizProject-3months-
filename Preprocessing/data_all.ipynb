# %%
import pandas as pd

# %%
data_2013 = pd.read_csv('./data_2013/online_data_2013')

# %%
data_2014 = pd.read_csv('./data_2014/online_data_2014')

# %%
data_2015 = pd.read_csv('./data_2015/online_data_2015')

# %%
data_2016 = pd.read_csv('./data_2016/online_data_2016')

# %%
data_2017 = pd.read_csv('./data_2017/online_data_2017')

# %%
df= pd.concat([data_2013,data_2014,data_2015,data_2016,data_2017])

# %%
df
# Out:
#               movies  grade  p_breviews  n_breviews  breviews  p_reviews  \
# 0            7번방의 선물   9.53         710          52       762        953
# 1                 감기   7.83        1336         683      2019        635
# 2               감시자들   8.34         839         248      1087        286
# 3               결혼전야   8.86         313          84       397        113
# 4             고령화 가족   8.81         237          58       295         89
# 5                 공범   9.00         280          49       329         97
# 6                 관상   9.51        1467         111      1578        666
# 7                깡철이   9.06         578          85       663        336
# 8   나우 유 씨 미 : 마술사기단   9.38         343          44       387        588
# 9            남자사용설명서   8.91         932         174      1106        511
# 10           남쪽으로 튀어   8.73         291          79       370        162
# 11               노리개   8.70         299          59       358         52
# ...

# %%
df.to_csv('./data_all/online_data_all')

# %%
data_all = pd.read_csv('./data_all/online_data_all')

# %%
data_all = data_all.set_index(['movies'])

# %%
data_all = data_all.drop('Unnamed: 0',1)

# %%
data_all
# Out:
#                   grade  p_breviews  n_breviews  breviews  p_reviews  \
# movies
# 7번방의 선물            9.53         710          52       762        953
# 감기                 7.83        1336         683      2019        635
# 감시자들               8.34         839         248      1087        286
# 결혼전야               8.86         313          84       397        113
# 고령화 가족             8.81         237          58       295         89
# 공범                 9.00         280          49       329         97
# 관상                 9.51        1467         111      1578        666
# 깡철이                9.06         578          85       663        336
# 나우 유 씨 미 : 마술사기단   9.38         343          44       387        588
# 남자사용설명서            8.91         932         174      1106        511
# 남쪽으로 튀어            8.73         291          79       370        162
# 노리개                8.70         299          59       358         52
# ...

# %%
data_all.sort_values(by='reviews')
# Out:
#                                                grade  p_breviews  n_breviews  \
# movies
# 하이힐                                             8.63         204          70
# 라라랜드                                            9.12          91          13
# 헤라클레스 : 레전드 비긴즈                                 7.62         772         389
# 매드 맥스: 분노의 도로                                   8.92         198          57
# 라라랜드                                            9.12          91          13
# 인터스텔라                                           9.58         758          52
# 선 오브 갓                                          7.38         171          89
# 월터의 상상은 현실이 된다                                  9.16         196          45
# 인터스텔라                                           9.58         758          52
# 피터와 드래곤                                         8.67          20           7
# 귀향                                              7.93          52          21
# ...

# %%
data_all = data_all.drop(['인터스텔라','라라랜드','월터의 상상은 현실이 된다','헤라클레스 : 레전드 비긴즈','선 오브 갓','매드 맥스: 분노의 도로'])

# %%
data_all.sort_values(by='reviews')
# Out:
#                                                grade  p_breviews  n_breviews  \
# movies
# 하이힐                                             8.63         204          70
# 피터와 드래곤                                         8.67          20           7
# 귀향                                              7.93          52          21
# 극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~   9.14          81          12
# 마이 리틀 자이언트                                      8.97          61          14
# 해양경찰 마르코                                        9.19         117          16
# 부활                                              8.71          41          10
# 송 포 유                                           9.38         295          46
# 히든 카드                                           8.59          49          10
# 라스트베가스                                          9.59         325          28
# 다이버전트 시리즈: 얼리전트                                 8.79         122          32
# ...

# %%
df = df.drop_duplicates(['movies'],keep='last')

# %%
df.sort_values(by='reviews')
# Out:
#                                            movies  grade  p_breviews  \
# 68                                          인터스텔라   9.58         758
# 94                                헤라클레스 : 레전드 비긴즈   7.62         772
# 41                                         선 오브 갓   7.38         171
# 22                                  매드 맥스: 분노의 도로   8.92         198
# 90                                            하이힐   8.63         204
# 64                                 월터의 상상은 현실이 된다   9.16         196
# 21                                           라라랜드   9.12          91
# 92                                        피터와 드래곤   8.67          20
# 12                                             귀향   7.93          52
# 6   극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~   9.14          81
# 38                                     마이 리틀 자이언트   8.97          61
# 89                                       해양경찰 마르코   9.19         117
# 52                                             부활   8.71          41
# ...

# %%
df = df.set_index('movies')

# %%
df = df.drop(['인터스텔라','라라랜드','월터의 상상은 현실이 된다','헤라클레스 : 레전드 비긴즈','선 오브 갓','매드 맥스: 분노의 도로'])

# %%
df = df.drop_duplicates(['audience_cnt'],keep='last')

# %%
df
# Out:
#                   grade  p_breviews  n_breviews  breviews  p_reviews  \
# movies
# 7번방의 선물            9.53         710          52       762        953
# 감기                 7.83        1336         683      2019        635
# 감시자들               8.34         839         248      1087        286
# 결혼전야               8.86         313          84       397        113
# 고령화 가족             8.81         237          58       295         89
# 공범                 9.00         280          49       329         97
# 관상                 9.51        1467         111      1578        666
# 깡철이                9.06         578          85       663        336
# 나우 유 씨 미 : 마술사기단   9.38         343          44       387        588
# 남자사용설명서            8.91         932         174      1106        511
# 남쪽으로 튀어            8.73         291          79       370        162
# 노리개                8.70         299          59       358         52
# ...

# %%
df.sort_values(by='audience_cnt',ascending=False)
# Out:
#                   grade  p_breviews  n_breviews  breviews  p_reviews  \
# movies
# 명량                 8.64        1324         348      1672       2840
# 신과함께-죄와 벌          8.04        2894        1118      4012       1945
# 국제시장               8.76        1015         214      1229        720
# 베테랑                8.89         569         117       686        887
# 7번방의 선물            9.53         710          52       762        953
# 암살                 8.30         675         236       911       1248
# 택시운전사              8.50        2862         676      3538       4125
# 부산행                8.23        3300        1846      5146       2920
# 변호인                6.08       14882       11765     26647       3324
# 어벤져스: 에이지 오브 울트론   9.52        2660         209      2869       1272
# 검사외전               9.01         631         110       741        953
# 설국열차               8.17        2919        1349      4268       2802
# ...

# %%
feature_data = pd.read_csv('./data_all/feature_data')

# %%
del feature_data['Unnamed: 0']

# %%
feature_data
# Out:
#                  movies  rating  rank  screen  salesShare  audiCnt  showCnt  \
# 0              23 아이덴티티       2     5     396         4.6    11348     1132
# 1                 47 미터       2     5     364         1.0    13314      622
# 2    가디언즈 오브 갤럭시 VOL. 2       1     9     167         1.0     3854      255
# 3                   강철비       2     3     610         7.5    76078     1599
# 4                  겟 아웃       2     7     180         1.1     3700      326
# 5     공각기동대 : 고스트 인 더 쉘       2     9     151         0.5     1533      242
# 6                    공조       2    10     339         2.7    15745      629
# 7                   군함도       2     9     192         1.0     7677      233
# 8                    그것       2     9     220         2.0     3979      381
# 9                그레이트 월       1     9     367         3.0    15833     1006
# 10                기억의 밤       2     7      97         0.3     2062      138
# ...

# %%
df = pd.merge(feature_data,df, on='movies')

# %%
df.drop_duplicates(['movies'],keep='last')
# Out:
#                  movies  rating  rank  screen  salesShare  audiCnt  showCnt  \
# 0              23 아이덴티티       2     5     396         4.6    11348     1132
# 1                 47 미터       2     5     364         1.0    13314      622
# 2    가디언즈 오브 갤럭시 VOL. 2       1     9     167         1.0     3854      255
# 3                   강철비       2     3     610         7.5    76078     1599
# 4                  겟 아웃       2     7     180         1.1     3700      326
# 5     공각기동대 : 고스트 인 더 쉘       2     9     151         0.5     1533      242
# 6                    공조       2    10     339         2.7    15745      629
# 7                   군함도       2     9     192         1.0     7677      233
# 8                    그것       2     9     220         2.0     3979      381
# 9                그레이트 월       1     9     367         3.0    15833     1006
# 10                기억의 밤       2     7      97         0.3     2062      138
# ...

# %%
df = df.set_index('movies')

# %%
df
# Out:
#                     rating  rank  screen  salesShare  audiCnt  showCnt  \
# movies
# 23 아이덴티티                 2     5     396         4.6    11348     1132
# 47 미터                    2     5     364         1.0    13314      622
# 가디언즈 오브 갤럭시 VOL. 2       1     9     167         1.0     3854      255
# 강철비                      2     3     610         7.5    76078     1599
# 겟 아웃                     2     7     180         1.1     3700      326
# 공각기동대 : 고스트 인 더 쉘        2     9     151         0.5     1533      242
# 공조                       2    10     339         2.7    15745      629
# 군함도                      2     9     192         1.0     7677      233
# 그것                       2     9     220         2.0     3979      381
# 그레이트 월                   1     9     367         3.0    15833     1006
# 기억의 밤                    2     7      97         0.3     2062      138
# 꾼                        2     3     553         4.2    21186     1265
# ...

# %%
df.to_csv('./data_all/data')
