# %%
n_reviews_2013_1 = {'베테랑': 181,
'암살': 285,
'어벤져스: 에이지 오브 울트론': 601,
'국제시장': 88,
'내부자들': 184,
'사도': 286,
'미션 임파서블: 로그네이션': 214,
'킹스맨 : 시크릿 에이전트': 59,
'연평해전': 305,
'쥬라기 월드': 372,
'검은 사제들': 256,
'히말라야': 236,
'마션': 157,
'조선명탐정 : 사라진 놉의 딸': 69,
'매드 맥스: 분노의 도로': 0,
'인턴': 36,
'분노의 질주: 더 세븐': 24,
'터미네이터 제니시스': 338,
'스물': 167,
'극비수사': 168,
'앤트맨': 367,
'스타워즈: 깨어난 포스': 321,
'메이즈 러너: 스코치 트라이얼': 137,
'탐정 : 더 비기닝': 67,
'스파이': 45,
'악의 연대기': 115,
'강남 1970': 202,
'뷰티 인사이드': 234,
'오늘의 연애': 242,
'테이큰 3': 282,
'007 스펙터': 248,
'이미테이션 게임': 33,
'샌 안드레아스': 89,
'쎄시봉': 558,
'더 폰': 124,
'대호': 200,
'차이나타운': 159,
'장수상회': 23,
'성난 변호사': 56,
'간신': 137,
'박물관이 살아있다 : 비밀의 무덤': 32,
'그놈이다': 168,
'미쓰 와이프': 44,
'허삼관': 112,
'살인의뢰': 156,
'손님': 361,
'인시디어스 3': 41,
'하트 오브 더 씨': 42,
'헝거게임: 더 파이널': 60,
'기술자들': 297}

# %%
n_reviews_2015_2 = {'신데렐라': 25,
'픽셀': 151,
'열정같은소리하고있네': 125,
'특종: 량첸살인기': 125,
'서부전선': 266,
'채피': 85,
'헬머니': 38,
'위험한 상견례 2': 42,
'순수의 시대': 159,
'협녀, 칼의 기억': 328,
'오피스': 97,
'무뢰한': 88,
'판타스틱 4': 253,
'내 심장을 쏴라': 76,
'소수의견': 109,
'그레이의 50가지 그림자 (Fifty Shades of Grey)': 135,
'경성학교: 사라진 소녀들': 212,
'치외법권': 162,
'아메리칸 스나이퍼': 21,
'에베레스트': 42,
'호빗: 다섯 군대 전투': 169,
'극적인 하룻밤': 38,
'도리화가': 359,
'주피터 어센딩': 122,
'패딩턴': 7,
'런 올 나이트': 19,
'인서전트': 50,
'백 투 더 비기닝': 94,
'투모로우랜드': 55,
'스파이 브릿지': 17,
'함정': 93,
'언브로큰': 30,
'하늘을 걷는 남자': 14,
'조선마술사': 333,
'언프렌디드: 친구삭제': 47,
'연애의 맛': 33,
'버드맨': 38,
'기생수 파트1': 44,
'팬': 35,
'더 셰프': 28,
'레전드': 85,
'19곰 테드 2': 28,
'인터스텔라': 0,
'아메리칸 울트라': 109,
'트랜스포터: 리퓰드': 25,
'워킹걸': 91,
'은밀한 유혹': 55,
'워터 디바이너': 17,
'나의 절친 악당들': 102}

# %%
n_reviews_2013_1.update(n_reviews_2015_2)

# %%
n_reviews_2015 = n_reviews_2013_1

# %%
dict = n_reviews_2015

# %%
import pandas as pd
df = pd.DataFrame([dict])
df = df.T
df = df.rename(columns = { 0 : 'n_reviews' })
df.to_csv( './data_2015/2015_n_reviews', sep=',', encoding='utf-8' )
