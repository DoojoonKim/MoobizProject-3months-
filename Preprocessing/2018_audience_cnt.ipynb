# %%
import pandas as pd

# %%
df = pd.read_csv('./data_2018/2018_movies.csv',header=2)
df
# Out:
#        순위                     영화명         개봉일              매출액 매출액 점유율  \
# 0       1               신과함께-인과 연  2018-08-01  102,659,863,909    6.6%
# 1       2            어벤져스: 인피니티 워  2018-04-25   99,919,006,769    6.4%
# 2       3            미션 임파서블: 폴아웃  2018-07-25   55,888,375,112    3.6%
# 3       4               신과함께-죄와 벌  2017-12-20   47,348,157,705    3.0%
# 4       5           쥬라기 월드: 폴른 킹덤  2018-06-06   49,770,711,037    3.2%
# 5       6                앤트맨과 와스프  2018-07-04   47,465,443,185    3.0%
# 6       7                     안시성  2018-09-19   46,334,401,026    3.0%
# 7       8                보헤미안 랩소디  2018-10-31   47,053,521,489    3.0%
# 8       9                   블랙 팬서  2018-02-14   45,883,143,457    2.9%
# 9      10                    1987  2017-12-27   42,911,577,108    2.8%
# 10     11                      독전  2018-05-22   43,484,892,913    2.8%
# 11     12                  완벽한 타인  2018-10-31   42,385,887,974    2.7%
# ...

# %%
del df['순위']
del df['개봉일']
del df['매출액']
del df['스크린수']
del df['대표국적']
del df['국적']
del df['매출액 점유율']
del df['배급사']

# %%
audience_cnt = df.loc[:99,:]

# %%
audience_cnt.rename(columns={'영화명':'movies','관객수':'audience_cnt'},inplace=True)

# %%
audience_cnt
# Out:
#                       movies audience_cnt
# 0                  신과함께-인과 연   12,274,159
# 1               어벤져스: 인피니티 워   11,211,880
# 2               미션 임파서블: 폴아웃    6,584,915
# 3                  신과함께-죄와 벌    5,871,259
# 4              쥬라기 월드: 폴른 킹덤    5,661,128
# 5                   앤트맨과 와스프    5,447,826
# 6                        안시성    5,440,001
# 7                   보헤미안 랩소디    5,426,662
# 8                      블랙 팬서    5,398,994
# 9                       1987    5,289,561
# 10                        독전    5,063,620
# 11                    완벽한 타인    5,056,102
# 12                        공작    4,974,512
# 13                        베놈    3,888,096
# 14                      암수살인    3,789,321
# 15                     데드풀 2    3,784,602
# 16                        코코    3,510,017
# 17                 그것만이 내 세상    3,417,629
# 18                        마녀    3,189,091
# 19                   탐정: 리턴즈    3,152,872
# 20                   인크레더블 2    3,033,052
# ...

# %%
audience_cnt.to_csv('./data_2018/2018_audience_cnt')

# %%
audience_cnt['movies'].to_csv('./data_2018/2018_movieList')
