# %%
import pandas as pd

# %%
df = pd.read_csv('./data_2011/2011_movies.csv',header=2)
df
# Out:
#       순번                      영화명             감독                     제작사  \
# 0      1                  트랜스포머 3         마이클 베이                     NaN
# 1      2                   최종병기 활            김한민      (주)디씨지플러스,(주)다세포클럽
# 2      3                       써니            강형철     (주)알로하픽쳐스,(주)토일렛픽쳐스
# 3      4                      완득이             이한      (주)유비유필름,어나더픽쳐스(주)
# 4      5                   쿵푸팬더 2            여인영                     NaN
# 5      6           미션임파서블:고스트프로토콜         브래드 버드               파라마운트 픽쳐스
# 6      7        조선명탐정 : 각시투구꽃의 비밀            김석윤                 청년필름(주)
# 7      8                      도가니            황동혁       (주)삼거리픽쳐스,(주)판타지오
# 8      9            해리포터와 죽음의 성물2        데이빗 예이츠                     NaN
# 9     10                    리얼 스틸           숀 레비                     NaN
# 10    11          캐리비안의 해적: 낯선 조류           롭 마샬                     NaN
# 11    12                        퀵            조범구     (주)제이케이필름,씨제이이앤엠(주)
# ...

# %%
df = df.loc[:99,]
df
# Out:
#      순번                                 영화명          감독  \
# 0     1                             트랜스포머 3      마이클 베이
# 1     2                              최종병기 활         김한민
# 2     3                                  써니         강형철
# 3     4                                 완득이          이한
# 4     5                              쿵푸팬더 2         여인영
# 5     6                      미션임파서블:고스트프로토콜      브래드 버드
# 6     7                   조선명탐정 : 각시투구꽃의 비밀         김석윤
# 7     8                                 도가니         황동혁
# 8     9                       해리포터와 죽음의 성물2     데이빗 예이츠
# 9    10                               리얼 스틸        숀 레비
# 10   11                     캐리비안의 해적: 낯선 조류        롭 마샬
# 11   12                                   퀵         조범구
# 12   13                                 고지전          장훈
# 13   14                        혹성탈출: 진화의 시작    루퍼트 와이어트
# 14   15                              오싹한 연애         황인호
# 15   16                             위험한 상견례         김진영
# ...

# %%
movieList = dict([(i,a ) for i, a in zip(df.영화명,df.감독)])

# %%
movieList
# Out:
# {'트랜스포머 3': '마이클 베이',
#  '최종병기 활': '김한민',
#  '써니': '강형철',
#  '완득이': '이한',
#  '쿵푸팬더 2': '여인영',
#  '미션임파서블:고스트프로토콜': '브래드 버드',
#  '조선명탐정 : 각시투구꽃의 비밀': '김석윤',
#  '도가니': '황동혁',
#  '해리포터와 죽음의 성물2': '데이빗 예이츠',
#  '리얼 스틸': '숀 레비',
#  '캐리비안의 해적: 낯선 조류': '롭 마샬',
#  '퀵': '조범구',
#  '고지전': '장훈',
#  '혹성탈출: 진화의 시작': '루퍼트 와이어트',
#  '오싹한 연애': '황인호',
#  '위험한 상견례': '김진영',
#  '엑스맨: 퍼스트 클래스': '매튜 본',
#  '의뢰인': '손영성',
#  '가문의 영광4 - 가문의 수난': '정태원',
#  '블라인드': '안상훈',
#  '7광구': '김지훈',
#  '마당을 나온 암탉': '오성윤,민성아',
#  '라스트 갓파더': '심형래',
#  '글러브': '강우석',
#  '아이들...': '이규만',
#  '걸리버 여행기': '롭 레터맨',
#  '평양성': '이준익',
#  '토르: 천둥의 신': '케네스 브래너',
#  '헬로우 고스트': '김영탁',
#  '블랙 스완': '대런 아로노프스키',
#  '분노의 질주: 언리미티드': '저스틴 린',
#  '마이 웨이': '강제규',
#  '브레이킹 던 part1': '빌 콘돈',
#  '신들의 전쟁': '타셈 싱',
#  '월드 인베이젼': '조나단 리브스만',
#  '셜록홈즈 : 그림자 게임': '가이 리치',
#  '소스 코드': '던칸 존스',
#  '특수본': '황병국',
#  '수상한 고객들': '조진모',
#  '오직 그대만': '송일곤',
#  '개구쟁이 스머프': '라자 고스넬',
#  '심장이 뛴다': '윤재근',
#  '라푼젤': '네이슨 그레노,바이론 하워드',
#  '파퍼씨네 펭귄들': '마크 워터스',
# ...
