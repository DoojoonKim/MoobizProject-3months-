# %%
import requests
import pandas as pd
import numpy as np
import os
import time

import datetime
import time
import json
from  pandas import DataFrame

# %%
dir1 = os.listdir('./data')
dir1.sort()

xlsx_list1 = [file for file in dir1 if file.startswith('개봉일') ]

# %%
df_scrnCnt1 = pd.read_excel('./data/개봉일 스크린 수(2013).xlsx')
df_scrnCnt2 = pd.read_excel('./data/개봉일 스크린 수(2014).xlsx')
df_scrnCnt3 = pd.read_excel('./data/개봉일 스크린 수(2015).xlsx')
df_scrnCnt4 = pd.read_excel('./data/개봉일 스크린 수(2016).xlsx')
df_scrnCnt5 = pd.read_excel('./data/개봉일 스크린 수(2017).xlsx')

# %%
df_scrnCnt = pd.concat([df_scrnCnt1, df_scrnCnt2, df_scrnCnt3, df_scrnCnt3, df_scrnCnt4, df_scrnCnt5])

# %%
df_scrnCnt.index = pd.RangeIndex(len(df_scrnCnt))

# %%
df_scrnCnt
# Out:
#                                     movieNm      openDt  rank  scrnCnt
# 0                                호빗: 뜻밖의 여정  2012-12-13     1     1011
# 1                                       26년  2012-11-29     2      446
# 2                                나의 PS 파트너   2012-12-06     3      403
# 3                                      원 데이  2012-12-13     4      227
# 4                                  늑대소년-확장판  2012-12-06     5      220
# 5                                      가디언즈  2012-11-29     6      185
# 6                                  내가 살인범이다  2012-11-08     7      119
# 7                               광해, 왕이 된 남자  2012-09-13     8       92
# 8                              브레이킹 던 part2  2012-11-15     9       74
# 9     극장판 파워레인저: 캡틴포스 VS 미라클포스 199 히어로 대결전   2012-12-13    10      157
# 10                                    레미제라블  2012-12-19     1      589
# 11                         가문의 영광5 - 가문의 귀환  2012-12-19     3      423
# ...
