# %% [markdown]
# ## import package

# %%
import requests
import pandas as pd
import numpy as np
import os
import time

import datetime
import time
import json
from  pandas import DataFrame

# %% [markdown]
# ## 2013~2017 개봉일 데이터

# %%
dir1 = os.listdir('./data')
dir1.sort()

xlsx_list1 = [file for file in dir1 if file.startswith('개봉일') ]

# %%
# for i,data in enumerate(xlsx_list1):
#     print(data)

#     if i == 0:
#         df_openDt = pd.read_excel('./data/'+data)

    
#     else:
#         small_df_openDt = pd.read_excel('./data/'+data)
#         df1 = pd.concat([df_openDt, small_df_openDt])
# #         .reset_index(drop = True)

# %%
df_openDt1 = pd.read_excel('./data/개봉일특성_2013.xlsx')
df_openDt2 = pd.read_excel('./data/개봉일특성_2014.xlsx')
df_openDt3 = pd.read_excel('./data/개봉일특성_2015.xlsx')
df_openDt4 = pd.read_excel('./data/개봉일특성_2016.xlsx')
df_openDt5 = pd.read_excel('./data/개봉일특성_2017.xlsx')

# %%
df_openDt_result = pd.concat([df_openDt1,df_openDt2,df_openDt3,df_openDt4,df_openDt5])

# %%
df_openDt_result
# Out:
#                     영화명        개봉일  개봉일 특성
# 0               7번방의 선물 2013-01-23     4.0
# 1                  설국열차 2013-08-01     2.0
# 2                    관상 2013-09-11     3.0
# 3                아이언맨 3 2013-04-25     1.0
# 4                   베를린 2013-01-30     4.0
# 5             은밀하게 위대하게 2013-06-05     2.0
# 6                   변호인 2013-12-18     4.0
# 7                  숨바꼭질 2013-08-14     2.0
# 8              더 테러 라이브 2013-07-31     2.0
# 9                  감시자들 2013-07-03     2.0
# 10               월드 워 Z 2013-06-20     2.0
# 11                  신세계 2013-02-21     4.0
# 12                 박수건달 2013-01-09     4.0
# 13                  스파이 2013-09-05     3.0
# 14                 그래비티 2013-10-17     3.0
# 15                   타워 2012-12-25     NaN
# 16                   감기 2013-08-14     2.0
# 17            토르: 다크 월드 2013-10-30     3.0
# 18            레드: 더 레전드 2013-07-18     2.0
# 19                 친구 2 2013-11-14     3.0
# 20               어바웃 타임 2013-12-05     4.0
# ...

# %%
cols = ['영화명', '개봉일', '개봉일 특성']

# %%
df_openDt_result.index = pd.RangeIndex(len(df_openDt_result.index))

# %%
df_openDt_result = df_openDt_result.drop('개봉일', axis=1)
df_openDt_result
# Out:
#                      영화명  개봉일 특성
# 0                7번방의 선물     4.0
# 1                   설국열차     2.0
# 2                     관상     3.0
# 3                 아이언맨 3     1.0
# 4                    베를린     4.0
# 5              은밀하게 위대하게     2.0
# 6                    변호인     4.0
# 7                   숨바꼭질     2.0
# 8               더 테러 라이브     2.0
# 9                   감시자들     2.0
# 10                월드 워 Z     2.0
# 11                   신세계     4.0
# 12                  박수건달     4.0
# 13                   스파이     3.0
# 14                  그래비티     3.0
# 15                    타워     NaN
# 16                    감기     2.0
# 17             토르: 다크 월드     3.0
# 18             레드: 더 레전드     2.0
# 19                  친구 2     3.0
# 20                어바웃 타임     4.0
# 21      나우 유 씨 미 : 마술사기단     2.0
# 22                    소원     3.0
# 23                 레미제라블     NaN
# 24                 퍼시픽 림     2.0
# 25         화이: 괴물을 삼킨 아이     3.0
# 26                   컨저링     3.0
# ...

# %%
df_openDt_result = df_openDt_result.dropna()

# %% [markdown]
# # 2013~2017년 국적 데이터 수집

# %%
dir2 = os.listdir('./data')
dir2.sort()

xlsx_list2 = [file for file in dir2 if file.startswith('국적') ]

# %%
df_Nation1 = pd.read_excel('./data/국적특성_2013.xlsx')
df_Nation2 = pd.read_excel('./data/국적특성_2014.xlsx')
df_Nation3 = pd.read_excel('./data/국적특성_2015.xlsx')
df_Nation4 = pd.read_excel('./data/국적특성_2016.xlsx')
df_Nation5 = pd.read_excel('./data/국적특성_2017.xlsx')

# %%
df_Nation_result = pd.concat([df_Nation1,df_Nation2,df_Nation3,df_Nation4,df_Nation5])

# %%
df_Nation_result.index = pd.RangeIndex(len(df_Nation_result.index))

# %%
df_Nation_result
# Out:
#                      영화명   국적  국적 특성
# 0                7번방의 선물   한국      0
# 1                   설국열차   한국      0
# 2                     관상   한국      0
# 3                 아이언맨 3   미국      1
# 4                    베를린   한국      0
# 5              은밀하게 위대하게   한국      0
# 6                    변호인   한국      0
# 7                   숨바꼭질   한국      0
# 8               더 테러 라이브   한국      0
# 9                   감시자들   한국      0
# 10                월드 워 Z   미국      1
# 11                   신세계   한국      0
# 12                  박수건달   한국      0
# 13                   스파이   한국      0
# 14                  그래비티   미국      1
# 15                    타워   한국      0
# 16                    감기   한국      0
# 17             토르: 다크 월드   미국      1
# 18             레드: 더 레전드   미국      1
# 19                  친구 2   한국      0
# 20                어바웃 타임   영국      1
# 21      나우 유 씨 미 : 마술사기단   미국      1
# 22                    소원   한국      0
# 23                 레미제라블   미국      1
# ...

# %%
df_Nation_result = df_Nation_result.dropna()

# %% [markdown]
# # 2013~2017년 박스오피스 데이터 수집

# %%
dir3 = os.listdir('./data')
dir3.sort()
xlsx_list3 = [file for file in dir3 if file.endswith('_boxoffice.xlsx')]

# %%
xlsx_list3
# Out:
# ['2013_boxoffice.xlsx',
#  '2014_boxoffice.xlsx',
#  '2015_boxoffice.xlsx',
#  '2016_boxoffice.xlsx',
#  '2017_boxoffice.xlsx']

# %%
df_boxoffice1 = pd.read_excel('./data/2013_boxoffice.xlsx')
df_boxoffice2 = pd.read_excel('./data/2014_boxoffice.xlsx')
df_boxoffice3 = pd.read_excel('./data/2015_boxoffice.xlsx')
df_boxoffice4 = pd.read_excel('./data/2016_boxoffice.xlsx')
df_boxoffice5 = pd.read_excel('./data/2017_boxoffice.xlsx')

# %%
df_boxoffice_result = pd.concat([df_boxoffice1.head(100),df_boxoffice2.head(100),
                                df_boxoffice3.head(100), df_boxoffice4.head(100),
                                df_boxoffice5.head(100)])

# %%
df_boxoffice_result
# Out:
#    연도별 박스오피스 검색 리스트           Unnamed: 1           Unnamed: 2   Unnamed: 3  \
# 0               NaN                  NaN                  NaN          NaN
# 1                순위                  영화명                  개봉일          매출액
# 2                 1              7번방의 선물  2013-01-23 00:00:00  91431914670
# 3                 2                 설국열차  2013-08-01 00:00:00  67010087500
# 4                 3                   관상  2013-09-11 00:00:00  66005427500
# 5                 4               아이언맨 3  2013-04-25 00:00:00  70806364000
# 6                 5                  베를린  2013-01-30 00:00:00  52355568637
# 7                 6            은밀하게 위대하게  2013-06-05 00:00:00  48700887413
# 8                 7                  변호인  2013-12-18 00:00:00  40953398000
# 9                 8                 숨바꼭질  2013-08-14 00:00:00  39602977500
# 10                9             더 테러 라이브  2013-07-31 00:00:00  39869706381
# ...

# %%
df_boxoffice_result.columns = ['순위', '영화명', '개봉일', '매출액', '매출액점유율', '관객수', '스크린수', '상영횟수', '대표국적', '국적', '배급사']
df_boxoffice_result
# Out:
#      순위                  영화명                  개봉일          매출액   매출액점유율  \
# 0   NaN                  NaN                  NaN          NaN      NaN
# 1    순위                  영화명                  개봉일          매출액  매출액 점유율
# 2     1              7번방의 선물  2013-01-23 00:00:00  91431914670    0.059
# 3     2                 설국열차  2013-08-01 00:00:00  67010087500    0.043
# 4     3                   관상  2013-09-11 00:00:00  66005427500    0.043
# 5     4               아이언맨 3  2013-04-25 00:00:00  70806364000    0.046
# 6     5                  베를린  2013-01-30 00:00:00  52355568637    0.034
# 7     6            은밀하게 위대하게  2013-06-05 00:00:00  48700887413    0.031
# 8     7                  변호인  2013-12-18 00:00:00  40953398000    0.026
# 9     8                 숨바꼭질  2013-08-14 00:00:00  39602977500    0.026
# 10    9             더 테러 라이브  2013-07-31 00:00:00  39869706381    0.026
# 11   10                 감시자들  2013-07-03 00:00:00  39380162179    0.025
# ...

# %%
df_boxoffice_result = df_boxoffice_result.drop(0,0)
df_boxoffice_result = df_boxoffice_result.drop(1,0)

# %%
df_boxoffice_result.index = pd.RangeIndex(len(df_boxoffice_result.index))
df_boxoffice_result
# Out:
#      순위                  영화명                  개봉일          매출액 매출액점유율  \
# 0     1              7번방의 선물  2013-01-23 00:00:00  91431914670  0.059
# 1     2                 설국열차  2013-08-01 00:00:00  67010087500  0.043
# 2     3                   관상  2013-09-11 00:00:00  66005427500  0.043
# 3     4               아이언맨 3  2013-04-25 00:00:00  70806364000  0.046
# 4     5                  베를린  2013-01-30 00:00:00  52355568637  0.034
# 5     6            은밀하게 위대하게  2013-06-05 00:00:00  48700887413  0.031
# 6     7                  변호인  2013-12-18 00:00:00  40953398000  0.026
# 7     8                 숨바꼭질  2013-08-14 00:00:00  39602977500  0.026
# 8     9             더 테러 라이브  2013-07-31 00:00:00  39869706381  0.026
# 9    10                 감시자들  2013-07-03 00:00:00  39380162179  0.025
# 10   11               월드 워 Z  2013-06-20 00:00:00  38555356000  0.025
# 11   12                  신세계  2013-02-21 00:00:00  34881330905  0.022
# ...

# %%
df_boxoffice_result['관객수'] = pd.to_numeric(df_boxoffice_result['관객수'])

# %%
df_boxoffice_result = df_boxoffice_result[df_boxoffice_result["관객수"] > 100000]

# %%
df_boxoffice_result = df_boxoffice_result.dropna()

# %%
df_Record_of_The_Day = pd.read_excel('./data/Records_of_the_day(2013-2017).xlsx')
df_Record_of_The_Day
# Out:
#                                     movieNm      openDt  rank  scrnCnt  \
# 0                                호빗: 뜻밖의 여정  2012-12-13     1     1011
# 1                                       26년  2012-11-29     2      446
# 2                                나의 PS 파트너   2012-12-06     3      403
# 3                                      원 데이  2012-12-13     4      227
# 4                                  늑대소년-확장판  2012-12-06     5      220
# 5                                      가디언즈  2012-11-29     6      185
# 6                                  내가 살인범이다  2012-11-08     7      119
# 7                               광해, 왕이 된 남자  2012-09-13     8       92
# 8                              브레이킹 던 part2  2012-11-15     9       74
# 9     극장판 파워레인저: 캡틴포스 VS 미라클포스 199 히어로 대결전   2012-12-13    10      157
# 10                                    레미제라블  2012-12-19     1      589
# 11                         가문의 영광5 - 가문의 귀환  2012-12-19     3      423
# ...

# %%
df_Record_of_The_Day.columns = ['영화명', '개봉일', '순위', '스크린 개수', '개봉일 매출액', '개봉일 매출액 비율', '개봉일 관객수', '개봉일 상영횟수']

# %%
df_Record_of_The_Day = df_Record_of_The_Day.dropna()

# %% [markdown]
# # 개봉일, 국적, 박스오피스 데이터프레임 병합

# %%
df_result = pd.merge(df_boxoffice_result,df_Nation_result)

# %%
df_result = pd.merge(df_result, df_openDt_result)

# %%
df_result = pd.merge(df_result, df_Record_of_The_Day, on = '영화명')

# %%
df_result
# Out:
#     순위_x                영화명                개봉일_x          매출액 매출액점유율  \
# 0      1            7번방의 선물  2013-01-23 00:00:00  91431914670  0.059
# 1      2               설국열차  2013-08-01 00:00:00  67010087500  0.043
# 2      3                 관상  2013-09-11 00:00:00  66005427500  0.043
# 3      4             아이언맨 3  2013-04-25 00:00:00  70806364000  0.046
# 4      5                베를린  2013-01-30 00:00:00  52355568637  0.034
# 5      6          은밀하게 위대하게  2013-06-05 00:00:00  48700887413  0.031
# 6      7                변호인  2013-12-18 00:00:00  40953398000  0.026
# 7      7                변호인  2013-12-18 00:00:00  40953398000  0.026
# 8      6                변호인  2013-12-18 00:00:00  41918383800  0.025
# 9      6                변호인  2013-12-18 00:00:00  41918383800  0.025
# 10     8               숨바꼭질  2013-08-14 00:00:00  39602977500  0.026
# 11     9           더 테러 라이브  2013-07-31 00:00:00  39869706381  0.026
# 12    10               감시자들  2013-07-03 00:00:00  39380162179  0.025
# ...

# %%
df_result = df_result.drop(['순위_x','개봉일_x', '대표국적', '국적', '배급사'], axis=1)
df_result
# Out:
#                    영화명          매출액 매출액점유율       관객수  스크린수    상영횟수  국적 특성  \
# 0              7번방의 선물  91431914670  0.059  12811206   866  166815      0
# 1                 설국열차  67010087500  0.043   9349993  1128  124823      0
# 2                   관상  66005427500  0.043   9134581  1240  125073      0
# 3               아이언맨 3  70806364000  0.046   9001331  1389  163584      1
# 4                  베를린  52355568637  0.034   7166290   894  111744      0
# 5            은밀하게 위대하게  48700887413  0.031   6959083  1341  117461      0
# 6                  변호인  40953398000  0.026   5687047   923   55006      0
# 7                  변호인  40953398000  0.026   5687047   923   55006      0
# 8                  변호인  41918383800  0.025   5687571   925   97261      0
# 9                  변호인  41918383800  0.025   5687571   925   97261      0
# 10                숨바꼭질  39602977500  0.026   5604103   779   88062      0
# 11            더 테러 라이브  39869706381  0.026   5584139   809   93488      0
# ...

# %%
df_result = df_result.drop(['개봉일_y'], axis=1)

# %%
df_result.dtypes
# Out:
# 영화명            object
# 매출액            object
# 매출액점유율         object
# 관객수             int64
# 스크린수           object
# 상영횟수           object
# 국적 특성           int64
# 개봉일 특성        float64
# 순위_y            int64
# 스크린 개수          int64
# 개봉일 매출액         int64
# 개봉일 매출액 비율    float64
# 개봉일 관객수         int64
# 개봉일 상영횟수        int64
# dtype: object

# %%
df_result['매출액'] = pd.to_numeric(df_result['매출액'])
df_result['매출액점유율'] = pd.to_numeric(df_result['매출액점유율'])
df_result['관객수'] = pd.to_numeric(df_result['관객수'])
df_result['스크린수'] = pd.to_numeric(df_result['스크린수'])
df_result['상영횟수'] = pd.to_numeric(df_result['상영횟수'])
# df_result['국적 특성'] = pd.to_numeric(df_result['국적 특성'])
# df_result['개봉일 특성'] = pd.to_numeric(df_result['개봉일 특성'])
# df_result['개봉일_y'] = pd.to_numeric(df_result['개봉일_y'])
# df_result['순위_y'] = pd.to_numeric(df_result['순위_y'])
# df_result['스크린 개수'] = pd.to_numeric(df_result['스크린 개수'])

# %%
df_result
# Out:
#                    영화명          매출액  매출액점유율       관객수  스크린수    상영횟수  국적 특성  \
# 0              7번방의 선물  91431914670   0.059  12811206   866  166815      0
# 1                 설국열차  67010087500   0.043   9349993  1128  124823      0
# 2                   관상  66005427500   0.043   9134581  1240  125073      0
# 3               아이언맨 3  70806364000   0.046   9001331  1389  163584      1
# 4                  베를린  52355568637   0.034   7166290   894  111744      0
# 5            은밀하게 위대하게  48700887413   0.031   6959083  1341  117461      0
# 6                  변호인  40953398000   0.026   5687047   923   55006      0
# 7                  변호인  40953398000   0.026   5687047   923   55006      0
# 8                  변호인  41918383800   0.025   5687571   925   97261      0
# 9                  변호인  41918383800   0.025   5687571   925   97261      0
# 10                숨바꼭질  39602977500   0.026   5604103   779   88062      0
# ...

# %% [markdown]
# # 관람등급

# %%
rate_2013 = {'7번방의 선물': '2',
'관상': '2',
'아이언맨 3': '1',
'설국열차': '2',
'베를린': '2',
'은밀하게 위대하게': '2',
'변호인': '2',
'숨바꼭질': '2',
'더 테러 라이브': '2',
'감시자들': '2',
'월드 워 Z': '2',
'신세계': '3',
'박수건달': '2',
'스파이': '2',
'그래비티': '1',
'타워': '1',
'감기': '2',
'토르: 다크 월드': '1',
'레드: 더 레전드': '2',
'친구 2': '3',
'어바웃 타임': '2',
'나우 유 씨 미 : 마술사기단': '1',
'레미제라블': '1',
'소원': '1',
'퍼시픽 림': '1',
'화이: 괴물을 삼킨 아이': '3',
'컨저링': '2',
'맨 오브 스틸': '1',
'용의자': '2',
'호빗: 스마우그의 폐허': '1',
'몽타주': '2',
'연애의 온도': '3',
'지.아이.조 2': '2',
'분노의 질주: 더 맥시멈': '2',
'공범': '2',
'집으로 가는 길': '2',
'전설의 주먹': '3',
'파파로티': '2',
'스타트렉 다크니스': '1',
'오블리비언': '2',
'위대한 개츠비': '2',
'다이하드: 굿 데이 투 다이': '2',
'런닝맨': '2',
'미스터 고': '1',
'결혼전야': '2',
'엘리시움': '3',
'깡철이': '2',
'더 웹툰: 예고살인': '2',
'웜 바디스': '2',
'고령화 가족': '2',
'헝거게임: 캣칭 파이어': '2',
'더 울버린': '2',
'동창생': '2',
'전국노래자랑': '1',
'잭 더 자이언트 킬러': '1',
'열한시': '2',
'남쪽으로 튀어': '2',
'잭 리처': '2',
'반창꼬': '2',
'더 파이브': '3',
'더 임파서블': '1',
'인시디어스: 두번째 집': '2',
'섀도우 헌터스: 뼈의 도시': '2',
'화이트 하우스 다운': '2',
'애프터 어스': '1',
'사이코메트리': '3',
'퍼시 잭슨과 괴물의 바다': '1',
'남자사용설명서': '2',
'다이노소어 어드벤처 3D': '0',
'무서운 이야기 2': '2',
'캐치미': '1',
'노브레싱': '2',
'클라우드 아틀라스': '3',
'창수': '3',
'론 레인저': '2',
'스토커': '3',
'오즈 그레이트 앤드 파워풀': '0',
'미나문방구': '0',
'차이니즈 조디악': '1',
'이스케이프 플랜': '3',
'롤러코스터': '2',
'장고:분노의 추적자': '3',
'밤의 여왕': '2',
'캡틴 필립스': '2',
'잡스': '1',
'분노의 윤리학': '3',
'송 포 유': '1',
'호빗: 뜻밖의 여정': '1',
'비포 미드나잇': '3',
'응징자': '3',
'프리즈너스': '3',
'마이 리틀 히어로': '0',
'백악관 최후의 날': '3',
'해양경찰 마르코': '0',
'톱스타': '2',
'노리개': '3',
'엔더스 게임': '1',
'히든 카드': '3'}
rate_2014 = {'명량': '2',
'인터스텔라': '1',
'수상한 그녀': '2',
'해적: 바다로 간 산적': '1',
'변호인': '2',
'국제시장': '1',
'트랜스포머: 사라진 시대': '1',
'군도: 민란의 시대': '2',
'엣지 오브 투모로우': '1',
'엑스맨: 데이즈 오브 퓨처 패스트': '1',
'어메이징 스파이더맨 2': '1',
'혹성탈출: 반격의 서막': '1',
'타짜-신의 손': '3',
'캡틴 아메리카: 윈터 솔져': '2',
'역린': '2',
'신의 한 수': '3',
'끝까지 간다': '2',
'표적': '2',
'메이즈 러너': '1',
'호빗: 다섯 군대 전투': '1',
'나의 사랑 나의 신부': '2',
'논스톱': '2',
'인투 더 스톰': '1',
'노아': '2',
'남자가 사랑할 때': '2',
'루시': '3',
'용의자': '2',
'기술자들': '2',
'나를 찾아줘': '3',
'제보자': '1',
'피끓는 청춘': '2',
'우아한 거짓말': '1',
'두근두근 내 인생': '1',
'300: 제국의 부활': '3',
'엑소더스: 신들과 왕들': '1',
'해무(海霧)': '3',
'인간중독': '3',
'말레피센트': '1',
'폼페이: 최후의 날': '2',
'퓨리': '2',
'드라큘라: 전설의 시작': '2',
'가디언즈 오브 갤럭시': '1',
'찌라시: 위험한 소문': '2',
'빅매치': '2',
'슬로우 비디오': '1',
'방황하는 칼날': '3',
'로보캅': '1',
'우리는 형제입니다': '1',
'애나벨': '2',
'헝거게임: 모킹제이': '2',
'월터의 상상은 현실이 된다': '1',
'카트': '1',
'관능의 법칙': '3',
'안녕, 헤이즐': '1',
'고질라': '1',
'트랜센던스': '1',
'상의원': '2',
'플랜맨': '2',
'우는 남자': '3',
'황제를 위하여': '3',
'패션왕': '2',
'더 울프 오브 월스트리트': '3',
'스텝 업: 올 인': '1',
'어바웃 타임': '2',
'노예 12년': '2',
'또 하나의 약속': '1',
'엔더스 게임': '1',
'소녀괴담': '2',
'조선미녀삼총사': '1',
'마담 뺑덕': '3',
'다이버전트': '2',
'주온 : 끝의 시작': '2',
'좋은 친구들': '3',
'닌자터틀': '1',
'나의 독재자': '2',
'하이힐': '3',
'선 오브 갓': '1',
'잭 라이언 : 코드네임 쉐도우': '1',
'숲속으로': '0',
'레드카펫': '2',
'미녀와 야수': '0',
'프랑켄슈타인: 불멸의 영웅': '1',
'러브, 로지': '2',
'오큘러스': '2',
'사랑에 대한 모든 것': '1',
'노벰버 맨': '2',
'툼스톤': '3',
'쓰리데이즈 투 킬': '2',
'헤라클레스 : 레전드 비긴즈': '2',
'극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~': '0',
'덕수리 5형제': '2',
'덤 앤 더머 투': '2',
'컬러풀 웨딩즈': '1',
'론 서바이버 ': '2',
'아빠를 빌려드립니다': '1',
'라스트베가스': '2',
'호빗: 스마우그의 폐허': '1',
'폴리스 스토리 2014': '2',
'익스펜더블 3': '2'}
rate_2015 = {'베테랑': '2',
'암살': '2',
'어벤져스: 에이지 오브 울트론': '1',
'국제시장': '1',
'내부자들': '3',
'사도': '1',
'미션 임파서블: 로그네이션': '2',
'킹스맨 : 시크릿 에이전트': '3',
'연평해전': '1',
'쥬라기 월드': '1',
'검은 사제들': '2',
'히말라야': '1',
'마션': '1',
'조선명탐정 : 사라진 놉의 딸': '1',
'매드 맥스: 분노의 도로': '2',
'인턴': '1',
'분노의 질주: 더 세븐': '2',
'터미네이터 제니시스': '2',
'스물': '2',
'극비수사': '2',
'앤트맨': '1',
'스타워즈: 깨어난 포스': '1',
'메이즈 러너: 스코치 트라이얼': '1',
'탐정 : 더 비기닝': '2',
'스파이': '2',
'악의 연대기': '2',
'강남 1970': '3',
'뷰티 인사이드': '1',
'오늘의 연애': '2',
'테이큰 3': '2',
'007 스펙터': '2',
'이미테이션 게임': '2',
'샌 안드레아스': '1',
'쎄시봉': '2',
'더 폰': '2',
'대호': '1',
'차이나타운': '3',
'장수상회': '1',
'성난 변호사': '2',
'간신': '3',
'박물관이 살아있다 : 비밀의 무덤': '0',
'그놈이다': '2',
'미쓰 와이프': '2',
'허삼관': '1',
'살인의뢰': '3',
'손님': '2',
'인시디어스 3': '2',
'하트 오브 더 씨': '1',
'헝거게임: 더 파이널': '2',
'기술자들': '2',
'신데렐라': '0',
'픽셀': '1',
'열정같은소리하고있네': '2',
'특종: 량첸살인기': '2',
'서부전선': '1',
'채피': '2',
'헬머니': '3',
'위험한 상견례 2': '2',
'순수의 시대': '3',
'협녀, 칼의 기억': '2',
'오피스': '2',
'무뢰한': '3',
'판타스틱 4': '1',
'내 심장을 쏴라': '2',
'소수의견': '2',
'그레이의 50가지 그림자': '3',
'경성학교: 사라진 소녀들': '2',
'치외법권': '2',
'아메리칸 스나이퍼': '3',
'에베레스트': '1',
'호빗: 다섯 군대 전투': '1',
'극적인 하룻밤': '3',
'도리화가': '1',
'주피터 어센딩': '1',
'패딩턴': '0',
'런 올 나이트': '3',
'인서전트': '2',
'백 투 더 비기닝': '2',
'투모로우랜드': '1',
'스파이 브릿지': '1',
'함정': '3',
'언브로큰': '2',
'하늘을 걷는 남자': '1',
'조선마술사': '1',
'언프렌디드: 친구삭제': '2',
'연애의 맛': '3',
'버드맨': '3',
'기생수 파트1': '3',
'팬': '0',
'더 셰프': '2',
'레전드': '3',
'19곰 테드 2': '3',
'인터스텔라': '1',
'아메리칸 울트라': '3',
'트랜스포터: 리퓰드': '2',
'내부자들: 디 오리지널': '3',
'워킹걸': '3',
'은밀한 유혹': '2',
'워터 디바이너': '2',
'나의 절친 악당들': '3'}
rate_2016 = {'부산행': '2',
'검사외전': '2',
'캡틴 아메리카: 시빌 워': '1',
'밀정': '2',
'터널': '1',
'인천상륙작전': '1',
'럭키': '2',
'곡성': '2',
'덕혜옹주': '1',
'닥터 스트레인지': '1',
'마스터': '2',
'신비한 동물사전': '1',
'판도라': '1',
'아가씨': '3',
'귀향': '2',
'데드풀': '3',
'나우 유 씨 미 2': '1',
'형': '1',
'엑스맨: 아포칼립스': '1',
'미스 페레그린과 이상한 아이들의 집': '1',
'히말라야': '1',
'제이슨 본': '2',
'아수라': '3',
'정글북': '1',
'라라랜드': '1',
'배트맨 대 슈퍼맨: 저스티스의 시작': '1',
'굿바이 싱글': '2',
'봉이 김선달': '1',
'레버넌트: 죽음에서 돌아온 자': '2',
'컨저링 2': '2',
'내부자들: 디 오리지널': '3',
'수어사이드 스쿼드': '2',
'인디펜던스 데이 : 리써전스': '1',
'탐정 홍길동: 사라진 마을': '2',
'벤허': '1',
'셜록: 유령신부': '1',
'특별수사: 사형수의 편지': '2',
'시간이탈자': '2',
'동주': '1',
'워크래프트: 전쟁의 서막': '1',
'스타트렉 비욘드': '1',
'미씽: 사라진 여자': '2',
'당신, 거기 있어줄래요': '1',
'라이트 아웃': '2',
'오빠생각': '1',
'날, 보러와요': '3',
'맨 인 더 다크': '3',
'고산자, 대동여지도': '0',
'미 비포 유': '1',
'매그니피센트 7': '2',
'갓 오브 이집트': '1',
'레전드 오브 타잔': '1',
'좋아해줘': '1',
'브리짓 존스의 베이비': '2',
'스플릿': '2',
'런던 해즈 폴른': '2',
'국가대표 2': '1',
'인페르노': '2',
'그날의 분위기': '2',
'사냥': '2',
'널 기다리며': '3',
'설리: 허드슨강의 기적': '1',
'잭 리처: 네버 고 백': '2',
'로그 원: 스타워즈 스토리': '1',
'메카닉: 리크루트': '2',
'고스트버스터즈': '1',
'거울나라의 앨리스': '1',
'가려진 시간': '1',
'해어화': '2',
'계춘할망': '2',
'로봇, 소리': '1',
'스타워즈: 깨어난 포스': '1',
'빅쇼트': '3',
'헌츠맨: 윈터스 워': '1',
'나를 잊지 말아요': '2',
'조선마술사': '1',
'언더 워터': '2',
'클로버필드 10번지': '2',
'위자: 저주의 시작': '1',
'위대한 소원': '2',
'스포트라이트': '2',
'구스범스': '1',
'포인트 브레이크': '2',
'혼숨': '2',
'비밀은 없다': '3',
'닌자터틀 : 어둠의 히어로': '1',
'순정': '1',
'독수리 에디': '1',
'남과 여': '3',
'대호': '1',
'부활': '1',
'조이': '1',
'대배우': '1',
'미스컨덕트': '2',
'13시간': '2',
'제 5침공': '1',
'마이 리틀 자이언트': '0',
'피터와 드래곤': '0',
'다이버전트 시리즈: 얼리전트': '1',
'바스티유 데이': '2'}
rate_2017 = {'택시운전사': '2',
'신과함께-죄와 벌': '1',
'공조': '2',
'스파이더맨: 홈 커밍': '1',
'범죄도시': '3',
'군함도': '2',
'청년경찰': '2',
'더 킹': '2',
'미녀와 야수': '0',
'킹스맨: 골든 서클': '3',
'토르: 라그나로크': '1',
'꾼': '2',
'강철비': '2',
'남한산성': '2',
'미이라': '2',
'분노의 질주: 더 익스트림': '2',
'아이 캔 스피크': '1',
'캐리비안의 해적: 죽은 자는 말이 없다': '1',
'프리즌': '3',
'덩케르크': '1',
'가디언즈 오브 갤럭시 VOL. 2': '1',
'살인자의 기억법': '2',
'트랜스포머: 최후의 기사': '1',
'보안관': '2',
'조작된 도시': '2',
'재심': '2',
'박열': '1',
'마스터': '2',
'원더 우먼': '1',
'겟 아웃': '2',
'로건': '3',
'혹성탈출: 종의 전쟁': '1',
'1987': '2',
'애나벨 : 인형의 주인': '2',
'노무현입니다': '1',
'저스티스 리그': '1',
'킬러의 보디가드': '2',
'콩: 스컬 아일랜드': '1',
'23 아이덴티티': '2',
'임금님의 사건수첩': '1',
'부라더': '1',
'기억의 밤': '2',
'해피 데스데이': '2',
'브이아이피': '3',
'특별시민': '2',
'에이리언: 커버넌트': '2',
'장산범': '2',
'악녀': '3',
'해빙': '2',
'라라랜드': '1',
'하루': '2',
'지오스톰': '1',
'스타워즈: 라스트 제다이': '1',
'불한당: 나쁜 놈들의 세상': '3',
'그것': '2',
'오리엔트 특급 살인': '1',
'대립군': '2',
'베이비 드라이버': '2',
'위대한 쇼맨': '1',
'레지던트 이블: 파멸의 날': '3',
'공각기동대 : 고스트 인 더 쉘': '2',
'패신저스': '1',
'아빠는 딸': '1',
'컨택트': '1',
'47 미터': '2',
'얼라이드': '2',
'발레리안: 천 개 행성의 도시': '1',
'그레이트 월': '1',
'침묵': '2',
'트리플 엑스 리턴즈': '2',
'리얼': '3',
'라이프': '2',
'히든 피겨스': '1',
'반드시 잡는다': '2',
'원라인': '2',
'로그 원: 스타워즈 스토리': '1',
'킹 아서: 제왕의 검': '1',
'아메리칸 메이드': '2',
'보통사람': '2',
'대장 김창수': '1',
'어쌔신 크리드': '2',
'플립': '1',
'석조저택 살인사건': '2',
'싱글라이더': '2',
'7호실': '2',
'사랑하기 때문에': '1',
'희생부활자': '2',
'옥자': '1',
'블레이드 러너 2049': '2',
'존 윅 - 리로드': '3',
'판도라': '1',
'미옥': '3',
'어느날': '2',
'어쌔신: 더 비기닝': '2',
'50가지 그림자: 심연': '3',
'핵소 고지': '2',
'채비': '1',
'더 큐어': '3',
'아토믹 블론드': '3',
'비정규직 특수요원': '2'}

# %%
rate_2013_movieNm = [file for i, file in enumerate(rate_2013.keys()) ]
rate_2014_movieNm = [file for i, file in enumerate(rate_2014.keys()) ]
rate_2015_movieNm = [file for i, file in enumerate(rate_2015.keys()) ]
rate_2016_movieNm = [file for i, file in enumerate(rate_2016.keys()) ]
rate_2017_movieNm = [file for i, file in enumerate(rate_2017.keys()) ]

# %%
rate_2013_specific = [ file for i, file in enumerate(rate_2013.values())]
rate_2014_specific = [ file for i, file in enumerate(rate_2014.values())]
rate_2015_specific = [ file for i, file in enumerate(rate_2015.values())]
rate_2016_specific = [ file for i, file in enumerate(rate_2016.values())]
rate_2017_specific = [ file for i, file in enumerate(rate_2017.values())]

# %%
df_rate_2013 = pd.DataFrame({'영화명': rate_2013_movieNm, '등급특성':rate_2013_specific})
df_rate_2014 = pd.DataFrame({'영화명': rate_2014_movieNm, '등급특성':rate_2014_specific})
df_rate_2015 = pd.DataFrame({'영화명': rate_2015_movieNm, '등급특성':rate_2015_specific})
df_rate_2016 = pd.DataFrame({'영화명': rate_2016_movieNm, '등급특성':rate_2016_specific})
df_rate_2017 = pd.DataFrame({'영화명': rate_2017_movieNm, '등급특성':rate_2017_specific})

# %%
df_rate = pd.concat([df_rate_2013, df_rate_2014, df_rate_2015, df_rate_2016, df_rate_2017])

# %%
df_rate.index = pd.RangeIndex(len(df_rate.index))

# %%
# df_result = df_result.drop('영화명', axis=1)
# df_result

# %%
# df_result_rate = pd.merge(df_result, df_rate)
df_result
# Out:
#                    영화명          매출액  매출액점유율       관객수  스크린수    상영횟수  국적 특성  \
# 0              7번방의 선물  91431914670   0.059  12811206   866  166815      0
# 1                 설국열차  67010087500   0.043   9349993  1128  124823      0
# 2                   관상  66005427500   0.043   9134581  1240  125073      0
# 3               아이언맨 3  70806364000   0.046   9001331  1389  163584      1
# 4                  베를린  52355568637   0.034   7166290   894  111744      0
# 5            은밀하게 위대하게  48700887413   0.031   6959083  1341  117461      0
# 6                  변호인  40953398000   0.026   5687047   923   55006      0
# 7                  변호인  40953398000   0.026   5687047   923   55006      0
# 8                  변호인  41918383800   0.025   5687571   925   97261      0
# 9                  변호인  41918383800   0.025   5687571   925   97261      0
# 10                숨바꼭질  39602977500   0.026   5604103   779   88062      0
# ...

# %%
df_rate
# Out:
#                   영화명 등급특성
# 0             7번방의 선물    2
# 1                  관상    2
# 2              아이언맨 3    1
# 3                설국열차    2
# 4                 베를린    2
# 5           은밀하게 위대하게    2
# 6                 변호인    2
# 7                숨바꼭질    2
# 8            더 테러 라이브    2
# 9                감시자들    2
# 10             월드 워 Z    2
# 11                신세계    3
# 12               박수건달    2
# 13                스파이    2
# 14               그래비티    1
# 15                 타워    1
# 16                 감기    2
# 17          토르: 다크 월드    1
# 18          레드: 더 레전드    2
# 19               친구 2    3
# 20             어바웃 타임    2
# 21   나우 유 씨 미 : 마술사기단    1
# 22              레미제라블    1
# 23                 소원    1
# 24              퍼시픽 림    1
# 25      화이: 괴물을 삼킨 아이    3
# 26                컨저링    2
# 27            맨 오브 스틸    1
# 28                용의자    2
# 29       호빗: 스마우그의 폐허    1
# ..                ...  ...
# 467                리얼    3
# 468               라이프    2
# ...

# %% [markdown]
# # 상관관계 분석

# %% [markdown]
# # 2013~2017년 관람등급 추가

# %%
df = pd.merge(df_result, df_rate, on='영화명')

# %%
df
# Out:
#                    영화명          매출액  매출액점유율       관객수  스크린수    상영횟수  국적 특성  \
# 0              7번방의 선물  91431914670   0.059  12811206   866  166815      0
# 1                 설국열차  67010087500   0.043   9349993  1128  124823      0
# 2                   관상  66005427500   0.043   9134581  1240  125073      0
# 3               아이언맨 3  70806364000   0.046   9001331  1389  163584      1
# 4                  베를린  52355568637   0.034   7166290   894  111744      0
# 5            은밀하게 위대하게  48700887413   0.031   6959083  1341  117461      0
# 6                  변호인  40953398000   0.026   5687047   923   55006      0
# 7                  변호인  40953398000   0.026   5687047   923   55006      0
# 8                  변호인  40953398000   0.026   5687047   923   55006      0
# 9                  변호인  40953398000   0.026   5687047   923   55006      0
# 10                 변호인  41918383800   0.025   5687571   925   97261      0
# ...

# %%
df['매출액'] = pd.to_numeric(df['매출액'])
df['순위'] = pd.to_numeric(df['순위_y'])
df['매출액점유율'] = pd.to_numeric(df['매출액점유율'])
df['관객수'] = pd.to_numeric(df['관객수'])
df['스크린수'] = pd.to_numeric(df['스크린수'])
df['상영횟수'] = pd.to_numeric(df['상영횟수'])
df['개봉일 특성'] = pd.to_numeric(df['개봉일 특성'])
df['등급특성'] = pd.to_numeric(df['등급특성'])

# %%
df.corr()
# Out:
#                  매출액    매출액점유율       관객수      스크린수      상영횟수     국적 특성  \
# 매출액         1.000000  0.997550  0.997186  0.721418  0.920003 -0.202709
# 매출액점유율      0.997550  1.000000  0.998459  0.698365  0.911395 -0.207408
# 관객수         0.997186  0.998459  1.000000  0.696198  0.909166 -0.227418
# 스크린수        0.721418  0.698365  0.696198  1.000000  0.766671 -0.089550
# 상영횟수        0.920003  0.911395  0.909166  0.766671  1.000000 -0.161652
# 국적 특성      -0.202709 -0.207408 -0.227418 -0.089550 -0.161652  1.000000
# 개봉일 특성      0.008873  0.010087  0.019109 -0.086205 -0.123912 -0.135011
# 순위_y        0.152096  0.151736  0.160857 -0.028708  0.073249 -0.251204
# 스크린 개수      0.140068  0.128220  0.117592  0.478234  0.207559  0.173470
# 개봉일 매출액     0.315680  0.308140  0.299085  0.517438  0.307499  0.039602
# 개봉일 매출액 비율  0.284518  0.280645  0.266073  0.527380  0.348260  0.117328
# 개봉일 관객수     0.315465  0.309215  0.302018  0.519381  0.306226  0.014921
# ...
