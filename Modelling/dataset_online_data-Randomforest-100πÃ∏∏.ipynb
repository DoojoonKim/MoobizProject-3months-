# %%
import pandas as pd
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np

# %%
df = pd.read_csv('./data_all/online_data_all')

# %%
df.drop_duplicates('movies',keep='first',inplace=True)

# %%
df.set_index('movies',inplace=True)

# %%
df
# Out:
#                          grade  p_breviews  n_breviews  breviews  p_reviews  \
# movies
# 7번방의 선물                   9.53         710          52       762        953
# 감기                        7.83        1336         683      2019        635
# 감시자들                      8.34         839         248      1087        286
# 결혼전야                      8.86         313          84       397        113
# 고령화 가족                    8.81         237          58       295         89
# 공범                        9.00         280          49       329         97
# 관상                        9.51        1467         111      1578        666
# 깡철이                       9.06         578          85       663        336
# 나우 유 씨 미 : 마술사기단          9.38         343          44       387        588
# 남자사용설명서                   8.91         932         174      1106        511
# 남쪽으로 튀어                   8.73         291          79       370        162
# 노리개                       8.70         299          59       358         52
# 노브레싱                      9.11        1965         263      2228        588
# 다이하드: 굿 데이 투 다이           8.49         279         103       382         63
# 더 울버린                     7.75         379         232       611        411
# 더 웹툰: 예고살인                8.60         347         106       453        107
# 더 임파서블                    8.07         201         106       307        121
# 더 테러 라이브                  7.64        1364         687      2051        697
# 더 파이브                     9.02         447          89       536        134
# 동창생                       9.41        2270         188      2458        386
# 런닝맨                       9.17         669         102       771        135
# 레드: 더 레전드                 8.79         302          72       374        224
# 레미제라블                     9.61         564          44       608        707
# 론 레인저                     8.78         157          48       205         73
# 롤러코스터                     8.94         280          62       342        332
# 마이 리틀 히어로                 9.10         514          96       610         86
# 맨 오브 스틸                   9.33         845         101       946        897
# 몽타주                       8.79         209          49       258        189
# 무서운 이야기 2                 8.76         600         143       743        331
# 미나문방구                     7.63        2078        1060      3138        137
# ...                        ...         ...         ...       ...        ...
# 스파이더위크가의 비밀               9.23         108          15       123         23
# 스피드 레이서                   9.18          10           1        11        202
# 신기전                       8.90         200          43       243        158
# 아기와 나                     9.78          22           1        23         61
# 아내가 결혼했다                  7.98          93          34       127         44
# 아이언맨                      9.09         235          45       280        139
# 어거스트 러쉬                   9.38         434          70       504          0
# 에이리언 VS 프레데터2             9.30         294          47       341         30
# 엑스파일:나는 믿고싶다              9.62          58           6        64          4
# 영화는 영화다                   9.10         159          27       186        131
# 오스트레일리아                   9.47          72           7        79         10
# 우리 생애 최고의 순간              9.30         454          67       521        145
# 울학교 이티                    8.90         114          25       139         23
# 원티드                      10.00           7           0         7        161
# 이글 아이                     9.26         125          20       145         49
# 인디아나 존스 4 : 크리스탈 해골의 왕국   9.66         344          24       368        105
# 적벽대전:거대한 전쟁의 시작           7.67         209          90       299         76
# 점퍼                        9.32         152          22       174         51
# 좋은 놈, 나쁜 놈, 이상한 놈         9.31         709         105       814        844
# 천일의 스캔들                   9.17          21           2        23         10
# 추격자                       7.50           2           4         6        232
# 크로싱                      10.00          11           0        11         60
# 클로버필드                     9.03         193          43       236        161
# 테이큰                       9.08          11           2        13        114
# 트럭                        9.50           2           0         2         25
# 트와일라잇                     9.53         344          32       376          0
# 포비든 킹덤: 전설의 마스터를 찾아서      9.47         231          23       254          0
# 해프닝                       9.44          67           8        75         20
# 핸콕                        9.54         181          19       200         66
# 황금 나침반                    9.01         245          63       308         34
#
#                          n_reviews  reviews  audience_cnt
# movies
# 7번방의 선물                         41      994      12811435
# 감기                             283      918       3117859
# 감시자들                           167      453       5508359
# 결혼전야                            35      148       1214839
# 고령화 가족                          49      138       1141222
# 공범                              89      186       1766285
# 관상                             328      994       9135806
# 깡철이                            128      464       1209363
# 나우 유 씨 미 : 마술사기단               150      738       2718237
# 남자사용설명서                         70      581        507913
# 남쪽으로 튀어                         97      259        832894
# 노리개                             29       81        169064
# 노브레싱                           152      740        451669
# 다이하드: 굿 데이 투 다이                 82      145       1438056
# 더 울버린                          403      814       1075333
# 더 웹툰: 예고살인                      69      176       1201033
# 더 임파서블                          67      188        625192
# 더 테러 라이브                       218      915       5584139
# 더 파이브                           80      214        731212
# 동창생                            164      550       1048280
# 런닝맨                             64      199       1422844
# 레드: 더 레전드                      112      336       3004649
# 레미제라블                          201      908       5920977
# 론 레인저                           66      139        388235
# 롤러코스터                          103      435        270156
# 마이 리틀 히어로                       35      121        186141
# 맨 오브 스틸                        314     1211       2182227
# 몽타주                             40      229       2095592
# 무서운 이야기 2                      177      508        495535
# 미나문방구                           73      210        334323
# ...                            ...      ...           ...
# 스파이더위크가의 비밀                     14       37        676155
# 스피드 레이서                         82      284        798718
# 신기전                             51      209       3728439
# 아기와 나                           26       87        435940
# 아내가 결혼했다                        37       81       1799501
# 아이언맨                            33      172       4300365
# 어거스트 러쉬                          0        0       2227459
# 에이리언 VS 프레데터2                   39       69        289701
# 엑스파일:나는 믿고싶다                    18       22        244023
# 영화는 영화다                         14      145       1311118
# 오스트레일리아                          7       17        999030
# 우리 생애 최고의 순간                    31      176       4018872
# 울학교 이티                          13       36        652178
# 원티드                             78      239       2858750
# 이글 아이                           26       75       2292172
# 인디아나 존스 4 : 크리스탈 해골의 왕국         72      177       4111753
# 적벽대전:거대한 전쟁의 시작                 94      170       1572064
# 점퍼                              68      119       1665268
# 좋은 놈, 나쁜 놈, 이상한 놈              497     1341       6686054
# 천일의 스캔들                          4       14        693836
# 추격자                             51      283       5046096
# 크로싱                             24       84        898000
# 클로버필드                          160      321        558389
# 테이큰                             11      125       2359061
# 트럭                              13       38        550195
# 트와일라잇                            0        0       1376760
# 포비든 킹덤: 전설의 마스터를 찾아서             0        0       1211890
# 해프닝                             62       82        347791
# 핸콕                              75      141       2722574
# 황금 나침반                          49       83       2906958
#
# [880 rows x 8 columns]

# %%
X = df[ df.columns[0:7] ]
X.head()
# Out:
#          grade  p_breviews  n_breviews  breviews  p_reviews  n_reviews  \
# movies
# 7번방의 선물   9.53         710          52       762        953         41
# 감기        7.83        1336         683      2019        635        283
# 감시자들      8.34         839         248      1087        286        167
# 결혼전야      8.86         313          84       397        113         35
# 고령화 가족    8.81         237          58       295         89         49
#
#          reviews
# movies
# 7번방의 선물      994
# 감기           918
# 감시자들         453
# 결혼전야         148
# 고령화 가족       138

# %%
y = df['audience_cnt']
y.head()
# Out:
# movies
# 7번방의 선물    12811435
# 감기          3117859
# 감시자들        5508359
# 결혼전야        1214839
# 고령화 가족      1141222
# Name: audience_cnt, dtype: int64

# %%
def func(x) :
    if 1000000 > int(x) :
        return 0
    else :
        return 1

# %%
y = y.apply(func)

# %%
X_train, X_test, y_train, y_test= train_test_split( X, y, test_size=.2 )
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (704, 7) (176, 7) (704,) (176,)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
    {'n_estimators':[3,10,30,50,60,70,100], 'max_features':[2,4,6]},
    {'bootstrap':[False], 'n_estimators':[3,10,30,50,60,70,100], 'max_features':[2,3,4]},
]
forest_reg = RandomForestClassifier()
grid_search = GridSearchCV(forest_reg, param_grid,cv = 5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)
grid_search.fit(X,y)
grid_search.best_params_
# Out:
# {'max_features': 2, 'n_estimators': 60}

# %%
clf2 = RandomForestClassifier(max_features=2,n_estimators=60)
clf2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=60, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
col = X.columns
for i in range(len(X.columns)):
    print(col[i],clf2.feature_importances_[i])
# Out:
# grade 0.13352175427375315
# p_breviews 0.1544210769057728
# n_breviews 0.11089594589022393
# breviews 0.13706803688832045
# p_reviews 0.19526653131801455
# n_reviews 0.1105271298857196
# reviews 0.15829952483819554

# %%
pre = clf2.predict(X_test)
acSore = metrics.accuracy_score(y_test,pre)
acSore
# Out:
# 0.7102272727272727

# %%
print(metrics.classification_report(y_test, pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.75        96
#            1       0.70      0.62      0.66        80
#
#    micro avg       0.71      0.71      0.71       176
#    macro avg       0.71      0.70      0.70       176
# weighted avg       0.71      0.71      0.71       176

# %%
y.value_counts()
# Out:
# 0    465
# 1    415
# Name: audience_cnt, dtype: int64

# %%
x = np.array(pre)
unique, counts = np.unique(x, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 105]
#  [  1  71]]

# %%
from sklearn.externals import joblib
import pickle
pickle.dumps(clf2)
joblib.dump(clf2, 'clf1_2.pkl')
# Out:
# ['clf1_2.pkl']
